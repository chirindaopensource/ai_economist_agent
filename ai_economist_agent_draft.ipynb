# %% [markdown]
# # **`README.md`**
#
# # AI Economist Agent: An Agentic Framework for Model-Grounded Economic Analysis
#
# <!-- PROJECT SHIELDS -->
# [![License: MIT](https://img.shields.io/badge/License-MIT-blue.svg)](https://opensource.org/licenses/MIT)
# [![Python Version](https://img.shields.io/badge/python-3.10%2B-blue.svg)](https://www.python.org/)
# [![Source](https://img.shields.io/badge/Source-arXiv%20Preprint-B31B1B)](https://arxiv.org/abs/2606.20041)
# [![Year](https://img.shields.io/badge/Year-2026-purple)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Discipline: CS](https://img.shields.io/badge/Discipline-Computer%20Science-00529B)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Discipline: AI](https://img.shields.io/badge/Discipline-Artificial%20Intelligence-00529B)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Discipline: Macro](https://img.shields.io/badge/Discipline-Macroeconomics-00529B)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Discipline: FinEcon](https://img.shields.io/badge/Discipline-Financial%20Econometrics-00529B)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Discipline: Graph](https://img.shields.io/badge/Discipline-Graph%20Theory-00529B)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Data: Evidence](https://img.shields.io/badge/Data-Synthetic%20Evidence%20Corpus-lightgrey)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Data: Temporal](https://img.shields.io/badge/Data-Synthetic%20Temporal%20Facts-lightgrey)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Method: RAG](https://img.shields.io/badge/Method-Retrieval--Augmented%20Generation-orange)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Method: KG](https://img.shields.io/badge/Method-Knowledge%20Graphs%20Neo4j-orange)](https://neo4j.com/)
# [![Method: DSGE](https://img.shields.io/badge/Method-DSGE%20Modeling-orange)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Method: MS-VAR](https://img.shields.io/badge/Method-Markov--Switching%20VAR-orange)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Method: Agents](https://img.shields.io/badge/Method-Agentic%20Orchestration-orange)](https://github.com/chirindaopensource/ai_economist_agent)
# [![Code style: black](https://img.shields.io/badge/code%20style-black-000000.svg)](https://github.com/psf/black)
# [![Pandas](https://img.shields.io/badge/pandas-%23150458.svg?style=flat&logo=pandas&logoColor=white)](https://pandas.pydata.org/)
# [![NumPy](https://img.shields.io/badge/numpy-%23013243.svg?style=flat&logo=numpy&logoColor=white)](https://numpy.org/)
# [![SciPy](https://img.shields.io/badge/SciPy-%230C55A5.svg?style=flat&logo=scipy&logoColor=white)](https://scipy.org/)
# [![Neo4j](https://img.shields.io/badge/Neo4j-008CC1?style=flat&logo=neo4j&logoColor=white)](https://neo4j.com/)
# [![Open Source](https://img.shields.io/badge/Open%20Source-%E2%9D%A4-brightgreen)](https://github.com/chirindaopensource/ai_economist_agent)
#
# **Repository:** `https://github.com/chirindaopensource/ai_economist_agent`
#
# **Owner:** 2026 Craig Chirinda (Open Source Projects)
#
# ## Table of Contents
# - [Introduction](#introduction)
# - [Theoretical Background](#theoretical-background)
# - [Features](#features)
# - [Methodology Implemented](#methodology-implemented)
# - [Core Components (Notebook Structure)](#core-components-notebook-structure)
# - [Key Callable: execute_master_ai_economist_pipeline](#key-callable-execute_master_ai_economist_pipeline)
# - [Prerequisites](#prerequisites)
# - [Installation](#installation)
# - [Input Data Structure](#input-data-structure)
# - [Usage](#usage)
# - [Output Structure](#output-structure)
# - [Project Structure](#project-structure)
# - [Customization](#customization)
# - [Contributing](#contributing)
# - [Recommended Extensions](#recommended-extensions)
# - [License](#license)
# - [Citation](#citation)
# - [Acknowledgments](#acknowledgments)
#
# ## Introduction
#
# This project is an independent, professional-grade implementation of the ideas, methodologies, and experimental protocols from the paper titled **"AI Economist Agent: An Agentic Framework for Model-Grounded Economic Analysis with RAG, Knowledge Graphs, and Large Language Models"** by the author:
# *   **Masahiro Kato**
#
# This repository provides a complete, end-to-end computational framework for replicating the paper's findings. It addresses a critical epistemic failure in the application of Large Language Models (LLMs) to economic analysis: the generation of fluent narratives that lack formal grounding in macroeconomic theory and explicit mathematical models.
#
# By implementing a strict architectural separation of concerns, this codebase ensures that LLMs are restricted to planning, retrieval, and narrative synthesis, while all quantitative claims are delegated to deterministic, external macroeconometric solvers. The framework utilizes a typed Neo4j Knowledge Graph to enforce this separation, ultimately delivering **Institutional-Grade Automated Economic Intelligence with Regulatory-Compliant Epistemic Traceability**.
#
# ## Theoretical Background
#
# The implemented methods bridge advanced natural language processing with rigorous macroeconometrics and graph theory.
#
# **1. Epistemic Traceability & Agentic Orchestration:**
# The pipeline moves beyond standard Retrieval-Augmented Generation (RAG) by structurally prohibiting the LLM from generating quantitative data. Instead, the LLM acts as an orchestrator, selecting approved mathematical models from a Knowledge Graph. The final report is generated from a strict information tuple: $(s, E_s, P_s^{\text{pre}}, C_s, r_s, m_s, O_s, P_s^{\text{post}})$, ensuring every numerical claim is traceable to an executed `ModelRun` object.
#
# **2. Knowledge Graph Topology:**
# To prevent "model leakage," the framework employs a typed property graph. Textual evidence (`EvidenceSpan`) is stored entirely separately from mathematical definitions (`ModelSpecification`). This topological isolation guarantees that a RAG-only agent cannot accidentally hallucinate a model execution merely by reading a model's name in a retrieved text document.
#
# **3. Macroeconometrics (DSGE-lite):**
# For Application 1 (U.S. Inflation Persistence), the computational layer executes a linearized 3-equation New Keynesian framework:
# *   **IS Curve:** $y_t = E_t y_{t+1} - \frac{1}{\sigma}(i_t - E_t \pi_{t+1}) + g_t$
# *   **Phillips Curve:** $\pi_t = \beta E_t \pi_{t+1} + \kappa y_t + u_t$
# *   **Taylor Rule:** $i_t = \rho_i i_{t-1} + (1-\rho_i)(\phi_\pi \pi_t + \phi_y y_t) + v_t$
#
# The system is solved using Blanchard-Kahn conditions via generalized Schur decomposition, verifying saddle-path stability before simulating a 12-step horizon with AR(1) shocks.
#
# **4. Financial Econometrics & Stress Testing (MS-VAR):**
# For Application 2 (CRE Refinancing Stress), the layer executes a 2-state Markov-Switching Vector Autoregression ($Y_t = c_{S_t} + A_{1,S_t} Y_{t-1} + \epsilon_{S_t,t}$). The Hamilton filter computes conditional regime probabilities. The resulting macro-financial paths are deterministically mapped to Basel III/CCAR bank stress metrics, including logistic Probability of Default ($PD_t = \Lambda(\alpha_0 + \alpha_1 p_t^{CRE} + \alpha_2 s_t^{credit})$) and the Common Equity Tier 1 ratio ($CET1_t$).
#
# ## Features
#
# -   **End-to-End Automation:** A singular orchestrator function (`execute_master_ai_economist_pipeline`) executes the entire research protocol from raw data ingestion and schema validation to cryptographic packaging and LaTeX report generation.
# -   **Strict Determinism:** Enforces `temperature = 0` and `seed = 42` for the local `llama3.1:8b` inference engine, coupled with deterministic PRNG initialization for all Monte Carlo shock simulations.
# -   **Atomic Graph Mutations:** Executes Neo4j database transactions to ensure the "Graph Reset" completely purges prior states, and that "Graph Write-Back" creates `ModelRun` and `ModelOutputPoint` nodes as an all-or-nothing transaction.
# -   **Fail-Closed Data Governance:** Implements rigorous pandas schema validation, enforcing extension dtypes (`Int64`, `string`) and executing set-difference operations to guarantee primary/foreign key referential integrity before any LLM inference occurs.
# -   **Regulatory-Compliant Provenance:** Serializes all intermediate artifacts and computes SHA-256 cryptographic hashes of the executed computational runner modules, anchoring numeric outputs to the exact Python code executed.
#
# ## Methodology Implemented
#
# 1.  **Infrastructure Provisioning:** Validates the deterministic LLM endpoint, audits network isolation (enforcing the "no external data" constraint), and provisions the Neo4j database with uniqueness constraints.
# 2.  **Data Validation & Cleansing:** Validates 12 raw DataFrames against declarative schemas, strips identifier whitespace, normalizes evidence tags, and enforces a strict UTC timezone policy.
# 3.  **Graph Reset & Loading:** Atomically purges the Knowledge Graph and loads the cleansed data using a strict two-phase strategy (nodes, then edges) to maintain referential integrity.
# 4.  **Agentic Planning & Retrieval:** The Planner LLM structures the scenario objective. The system executes parallel Text Retrieval (50/50 weighted tag-overlap and confidence) and Pre-Execution Graph Retrieval (constrained single-hop Cypher queries).
# 5.  **Model Selection & Execution:** The Model-Selection LLM maps the graph context to an execution request. The Computational Layer solves the DSGE/MS-VAR models and simulates the 12-step paths.
# 6.  **Graph Write-Back & Post-Retrieval:** The execution artifacts are written atomically to the graph. A read-committed query retrieves the full traceability path ($P_s^{\text{post}}$).
# 7.  **Report Generation & Judging:** Reports are generated under three isolated conditions (LLM-only, RAG-only, Model-grounded). The Judge LLM scores the reports, enforcing a strict logic gate: model grounding requires an executed model object.
# 8.  **Archival:** All artifacts, runtime environments, and assumption registries are packaged into an immutable provenance directory.
#
# ## Core Components (Notebook Structure)
#
# *Note: All orchestrator callables and their constituent helper functions are contained within a singular, comprehensive Jupyter Notebook (`ai_economist_agent_draft.ipynb`).*
#
# The notebook is structured as a logical Directed Acyclic Graph (DAG) of 29 distinct tasks:
# 1.  Configuration Validation & Infrastructure Provisioning (Tasks 1-3, 11-12)
# 2.  DataFrame Schema Validation & Referential Integrity (Tasks 4-5)
# 3.  Row-Level Invariants, Cleansing, & Datetime Normalization (Tasks 6-8)
# 4.  JSON Payload Validation & Synthetic Data Scaling (Tasks 9-10)
# 5.  Graph Reset & Pre-Run Materialization (Tasks 13-14)
# 6.  Text Retrieval & Pre-Execution Graph Retrieval (Tasks 15-16)
# 7.  Planner & Model-Selection Agent Orchestration (Tasks 17-18)
# 8.  Computational Runners: DSGE-lite & MS-VAR (Tasks 19-20)
# 9.  Graph Write-Back & Post-Execution Retrieval (Tasks 21-22)
# 10. Report Generation & Rubric-Based Judging (Tasks 23-24)
# 11. End-to-End Orchestration & Application Execution (Tasks 25-27)
# 12. Provenance Archival & Final Validation Reporting (Tasks 28-29)
#
# ## Key Callable: `execute_master_ai_economist_pipeline`
#
# The project is designed around a single, top-level user-facing interface function:
#
# -   **`execute_master_ai_economist_pipeline`:** This apex orchestrator function coordinates the entire AI Economist Agent experimental protocol. A single call to this function ingests the raw DataFrames, provisions the infrastructure, executes the data cleansing and graph loading, runs the agentic workflow for both Application 1 and Application 2, and packages the results into an immutable provenance archive. It guarantees complete state isolation and prevents look-ahead bias by threading a global assumption registry.
#
# ## Prerequisites
#
# -   Python 3.10+
# -   Neo4j Database 5.x (Local or AuraDB)
# -   Local LLM Inference Server (e.g., Ollama running `llama3.1:8b` on port 11434)
# -   Core Python dependencies: `numpy`, `pandas`, `scipy`, `neo4j`, `requests`, `psutil`, `pyyaml`, `faker` (for synthetic testing).
#
# ## Installation
#
# 1.  **Clone the repository:**
#     ```sh
#     git clone https://github.com/chirindaopensource/ai_economist_agent.git
#     cd ai_economist_agent
#     ```
#
# 2.  **Create and activate a virtual environment (recommended):**
#     ```sh
#     python -m venv venv
#     source venv/bin/activate  # On Windows, use `venv\Scripts\activate`
#     ```
#
# 3.  **Install Python dependencies:**
#     ```sh
#     pip install -r requirements.txt
#     ```
#
# ## Input Data Structure
#
# The pipeline requires 12 primary raw data structures (pandas DataFrames), adhering strictly to the schemas defined in Table 1 and Table 3 of the methodology:
# 1.  **`raw_source_documents_df`**: Canonical provenance table for textual sources.
# 2.  **`raw_evidence_spans_df`**: Primary textual evidence payload (`span_text`, `tags`, `synthetic_confidence`).
# 3.  **`raw_temporal_facts_df`**: Time-bounding evidence spans (`validity_start`, `validity_end`).
# 4.  **`raw_shocks_df`**: Encodes scenario shock drivers.
# 5.  **`raw_variable_concepts_df`**: Canonical variable dictionary.
# 6.  **`raw_models_df`**: Abstract model families.
# 7.  **`raw_model_specifications_df`**: The approved, governed unit the LLM is allowed to select (contains `calibration_params_json`).
# 8.  **`raw_model_equations_df`**: Stores approved LaTeX equations for auditability.
# 9.  **`raw_model_assumptions_df`**: Stores modeling assumptions distinctly from equations.
# 10. **`raw_model_documents_df`**: Governance/provenance documents for model approval.
# 11. **`raw_implementation_functions_df`**: The mapping from approved spec to executable Python function family.
# 12. **`raw_model_variable_relationships_df`**: Explicit join table enabling safe model selection.
#
# Additionally, the pipeline requires a **`config.yaml`** file, which serves as the deterministic source of truth for all hyperparameters, LLM settings, and mathematical calibrations.
#
# ## Usage
#
# Here is the granular, step-by-step guide to executing the end-to-end pipeline for **"AI Economist Agent: An Agentic Framework for Model-Grounded Economic Analysis with RAG, Knowledge Graphs, and Large Language Models"**. This example demonstrates how to synthetically generate the required Knowledge Graph input data, load the study configuration from a YAML file, and execute the full research pipeline using the `execute_master_ai_economist_pipeline` orchestrator.
#
# *Note: It is assumed that all the callables that are defined in the `ai_economist_agent_draft.ipynb` notebook are present in a single Jupyter notebook or execution environment, and that there is no separate folder with ".py" functions. It is also assumed that a valid `config.yaml` file containing the `study_config` dictionary is saved in the current working directory.*
#
# ### **Step 1: Synthetic Data Generation (`dataframes_dict`)**
#
# The first requirement is a high-fidelity synthetic representation of the 12 raw input DataFrames. These datasets must adhere strictly to the schemas defined in the study, utilizing pandas extension types (e.g., `string`, `Int64`, `boolean`) to ensure perfect compatibility with the rigorous validation layer (Task 4).
#
# **Methodology:**
# 1.  **Schema Enforcement:** We explicitly cast columns to their required dtypes (`string`, `datetime64[ns]`, `float64`, `Int64`, `boolean`) to pass the strict `validate_dataframe_schema` checks.
# 2.  **Referential Integrity:** We ensure that foreign keys (e.g., `doc_id`, `spec_id`, `scenario_id`) perfectly match their corresponding primary keys to pass the `validate_referential_integrity` checks (Task 5).
# 3.  **Data Assembly:** We construct a master dictionary `dataframes_dict` containing all 12 DataFrames, ready for ingestion by the pipeline.
#
# ```python
# import pandas as pd
# import numpy as np
# from typing import Dict, Any
# from unittest.mock import MagicMock
#
# # Set deterministic seed for reproducibility
# np.random.seed(42)
#
# def generate_synthetic_kg_inputs() -> Dict[str, pd.DataFrame]:
#     """
#     Generates the 12 synthetic DataFrames required for the AI Economist Agent pipeline.
#
#     Purpose:
#         To create a high-fidelity mock dataset that mimics the schema and relational
#         properties of the Knowledge Graph inputs defined in Table 1 and Table 3 of
#         the manuscript. This allows for the execution of the research pipeline.
#
#     Inputs:
#         None.
#
#     Processes:
#         1.  Constructs raw dictionaries for each of the 12 required tables.
#         2.  Converts dictionaries to pandas DataFrames.
#         3.  Explicitly casts columns to strict pandas extension types (string, Int64, boolean)
#             and datetime64[ns] to satisfy the Task 4 schema validation.
#
#     Outputs:
#         Dict[str, pd.DataFrame]: A dictionary mapping the 12 table names to their
#                                  respective DataFrames.
#
#     Raises:
#         ValueError: If DataFrame construction fails.
#     """
#     # 1. Raw Source Documents
#     # Canonical provenance table for textual sources.
#     raw_source_documents_df = pd.DataFrame({
#         "doc_id": pd.Series(["DOC_MACRO_REV_2024", "DOC_FED_OUTLOOK_2024"], dtype="string"),
#         "title": pd.Series(["Macroeconomic Review and Stress Testing Analysis", "Federal Reserve Monetary Policy Outlook"], dtype="string"),
#         "publication_date": pd.to_datetime(["2024-05-15", "2024-06-01"]),
#         "document_type": pd.Series(["internal_report", "external_outlook"], dtype="string"),
#         "source_institution": pd.Series(["Internal Economics Division", "Federal Reserve Board"], dtype="string")
#     })
#
#     # 2. Raw Evidence Spans
#     # Primary textual evidence payload used by retrieval.
#     raw_evidence_spans_df = pd.DataFrame({
#         "evidence_id": pd.Series(["EV_1571", "EV_841", "EV_1161", "EV_1321", "EV_1801", "EV_721", "EV_1967", "EV_2028", "EV_2107", "EV_1197"], dtype="string"),
#         "doc_id": pd.Series(["DOC_MACRO_REV_2024", "DOC_MACRO_REV_2024", "DOC_MACRO_REV_2024", "DOC_MACRO_REV_2024", "DOC_FED_OUTLOOK_2024", "DOC_FED_OUTLOOK_2024", "DOC_MACRO_REV_2024", "DOC_MACRO_REV_2024", "DOC_FED_OUTLOOK_2024", "DOC_MACRO_REV_2024"], dtype="string"),
#         "span_text": pd.Series([
#             "A more restrictive policy path usually lifts nominal yields, although the term premium may vary by regime.",
#             "Global oil supply shocks tend to raise headline inflation before the pass-through fades.",
#             "Credit losses reduce common equity capital and lower the stressed CET1 ratio.",
#             "Declines in CRE values raise loss-given-default and can increase credit losses.",
#             "China growth surprises transmit to global trade volumes through supply-chain and commodity channels.",
#             "Funding stress and confidence effects can increase uninsured deposit outflows.",
#             "Funding stress and confidence effects can increase uninsured deposit outflows.",
#             "Deposit outflows increase net cash outflows and reduce liquidity coverage ratios.",
#             "Funding stress and confidence effects can increase uninsured deposit outflows.",
#             "Funding stress and confidence effects can increase uninsured deposit outflows."
#         ], dtype="string"),
#         "tags": pd.Series([
#             "monetary_policy,yields,term_premium", "inflation,supply_shock,oil", "credit_loss,bank_capital,cet1",
#             "cre,lgd,credit_loss", "global_growth,trade,commodities", "funding_stress,deposits,liquidity",
#             "funding_stress,deposits,liquidity", "deposits,liquidity,lcr", "funding_stress,deposits,liquidity",
#             "funding_stress,deposits,liquidity"
#         ], dtype="string"),
#         "synthetic_confidence": pd.Series([0.935, 0.933, 0.940, 0.939, 0.936, 0.932, 0.939, 0.938, 0.937, 0.931], dtype="float64"),
#         "char_start_position": pd.Series([1024, 2048, 3072, 4096, 512, 768, 1280, 1536, 640, 896], dtype="Int64"),
#         "char_end_position": pd.Series([1132, 2144, 3152, 4184, 620, 840, 1352, 1620, 712, 968], dtype="Int64")
#     })
#
#     # 3. Raw Temporal Facts
#     # Time-bounding evidence spans: observation time vs validity window.
#     raw_temporal_facts_df = pd.DataFrame({
#         "fact_id": pd.Series(["TF_1571_01", "TF_841_01", "TF_1161_01", "TF_1321_01", "TF_1801_01", "TF_721_01", "TF_1967_01", "TF_2028_01", "TF_2107_01", "TF_1197_01"], dtype="string"),
#         "evidence_id": pd.Series(["EV_1571", "EV_841", "EV_1161", "EV_1321", "EV_1801", "EV_721", "EV_1967", "EV_2028", "EV_2107", "EV_1197"], dtype="string"),
#         "observation_time": pd.to_datetime(["2024-04-30T00:00:00Z", "2024-03-31T00:00:00Z", "2024-04-15T00:00:00Z", "2024-04-20T00:00:00Z", "2024-05-10T00:00:00Z", "2024-05-05T00:00:00Z", "2024-04-25T00:00:00Z", "2024-04-28T00:00:00Z", "2024-05-02T00:00:00Z", "2024-04-18T00:00:00Z"], utc=True),
#         "validity_start": pd.to_datetime(["2024-05-01T00:00:00Z", "2024-04-01T00:00:00Z", "2024-04-15T00:00:00Z", "2024-04-20T00:00:00Z", "2024-05-10T00:00:00Z", "2024-05-05T00:00:00Z", "2024-04-25T00:00:00Z", "2024-04-28T00:00:00Z", "2024-05-02T00:00:00Z", "2024-04-18T00:00:00Z"], utc=True),
#         "validity_end": pd.to_datetime(["2025-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2025-06-30T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z"], utc=True),
#         "temporal_description": pd.Series(["Yield response to policy path observed in Q2 2024 regime", "Oil supply shock pass-through window", "CET1 capital impact observation", "CRE valuation decline period", "China growth spillover transmission window", "Funding stress confidence channel activation", "Deposit outflow stress episode", "Liquidity coverage stress measurement", "Uninsured deposit flight window", "Bank funding pressure period"], dtype="string")
#     })
#
#     # 4. Raw Shocks
#     # Encodes scenario shock drivers.
#     raw_shocks_df = pd.DataFrame({
#         "shock_id": pd.Series(["SHOCK_MONETARY_TIGHT", "SHOCK_COST_PUSH"], dtype="string"),
#         "scenario_id": pd.Series(["SCEN_APP1_INFLATION", "SCEN_APP1_INFLATION"], dtype="string"),
#         "shock_description": pd.Series(["Restrictive monetary policy path lifting nominal yields", "Persistent services inflation cost-push shock"], dtype="string"),
#         "shock_type": pd.Series(["monetary_policy", "supply_side"], dtype="string"),
#         "severity_level": pd.Series([3, 2], dtype="Int64")
#     })
#
#     # 5. Raw Variable Concepts
#     # Canonical variable dictionary.
#     raw_variable_concepts_df = pd.DataFrame({
#         "concept_id": pd.Series(["VAR_INFLATION", "VAR_FFR", "VAR_10Y_YIELD", "VAR_OUTPUT_GAP"], dtype="string"),
#         "scenario_id": pd.Series(["SCEN_APP1_INFLATION", "SCEN_APP1_INFLATION", "SCEN_APP1_INFLATION", "SCEN_APP1_INFLATION"], dtype="string"),
#         "variable_name": pd.Series(["U.S. headline inflation", "Federal funds rate", "U.S. ten-year yield", "U.S. output gap"], dtype="string"),
#         "variable_symbol": pd.Series(["π_t", "i_t", "i_t^(10)", "y_t"], dtype="string"),
#         "measurement_unit": pd.Series(["percent_annual", "percent_annual", "percent_annual", "percent_deviation"], dtype="string"),
#         "is_target_variable": pd.Series([True, True, True, True], dtype="boolean")
#     })
#
#     # 6. Raw Models
#     # Abstract model families.
#     raw_models_df = pd.DataFrame({
#         "model_id": pd.Series(["MOD_DSGE_LITE", "MOD_VAR", "MOD_REGIME_SWITCH"], dtype="string"),
#         "model_name": pd.Series(["Dynamic Stochastic General Equilibrium (Lite)", "Vector Autoregression", "Markov-Switching Vector Autoregression"], dtype="string"),
#         "model_category": pd.Series(["structural", "reduced_form", "nonlinear"], dtype="string"),
#         "complexity_level": pd.Series([3, 1, 4], dtype="Int64")
#     })
#
#     # 7. Raw Model Specifications
#     # The approved, governed unit the LLM is allowed to select.
#     raw_model_specifications_df = pd.DataFrame({
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_VAR_001", "MSPEC_REGIME_SWITCHING_005"], dtype="string"),
#         "model_id": pd.Series(["MOD_DSGE_LITE", "MOD_VAR", "MOD_REGIME_SWITCH"], dtype="string"),
#         "spec_description": pd.Series(["3-equation New Keynesian model with AR(1) shocks and term structure.", "Reduced-form Vector Autoregression with 2 lags.", "2-state Markov-Switching VAR for normal and stress dynamics."], dtype="string"),
#         "calibration_params_json": pd.Series(['{"sigma": 1.5, "beta": 0.99, "kappa": 0.15, "phi_pi": 1.5, "phi_y": 0.125, "rho_i": 0.8, "rho_g": 0.9, "rho_u": 0.85, "rho_v": 0.7, "rho_tau": 0.6}', '{"lag_order": 2}', '{"p11": 0.95, "p22": 0.85, "n_regimes": 2}'], dtype="string")
#     })
#
#     # 8. Raw Model Equations
#     # Stores approved equations for auditability and governance.
#     raw_model_equations_df = pd.DataFrame({
#         "eq_id": pd.Series(["EQ_IS_CURVE", "EQ_NK_PHILLIPS", "EQ_TAYLOR_RULE", "EQ_TERM_STRUCTURE", "EQ_MSVAR_STATE"], dtype="string"),
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_REGIME_SWITCHING_005"], dtype="string"),
#         "equation_name": pd.Series(["IS Curve", "New Keynesian Phillips Curve", "Monetary Policy Rule (Taylor Rule)", "Term Structure Equation", "MS-VAR State Equation"], dtype="string"),
#         "latex_equation": pd.Series([r"y_t = E_t y_{t+1} - \frac{1}{\sigma}(i_t - E_t \pi_{t+1}) + g_t", r"\pi_t = \beta E_t \pi_{t+1} + \kappa y_t + u_t", r"i_t = \rho_i i_{t-1} + (1-\rho_i)(\phi_\pi \pi_t + \phi_y y_t) + v_t", r"i_t^{(10)} = \frac{1}{10} \sum_{j=0}^{9} E_t i_{t+j} + \tau_t", r"Y_t = c_{S_t} + A_{1,S_t} Y_{t-1} + \epsilon_{S_t,t}"], dtype="string"),
#         "equation_order": pd.Series([1, 2, 3, 4, 1], dtype="Int64")
#     })
#
#     # 9. Raw Model Assumptions
#     # Stores modeling assumptions distinctly from equations.
#     raw_model_assumptions_df = pd.DataFrame({
#         "assumption_id": pd.Series(["ASSUM_LINEAR", "ASSUM_AR1_SHOCKS", "ASSUM_MARKOV_FIRST_ORDER"], dtype="string"),
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_REGIME_SWITCHING_005"], dtype="string"),
#         "assumption_text": pd.Series(["Model is linearized around a zero steady state.", "Exogenous shocks follow AR(1) processes.", "Regime transitions follow a first-order Markov process."], dtype="string"),
#         "assumption_type": pd.Series(["functional_form", "stochastic_process", "stochastic_process"], dtype="string")
#     })
#
#     # 10. Raw Model Documents
#     # Governance / provenance documents for model approval.
#     raw_model_documents_df = pd.DataFrame({
#         "model_document_id": pd.Series(["MDOC_DSGE_001", "MDOC_MSVAR_001"], dtype="string"),
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_REGIME_SWITCHING_005"], dtype="string"),
#         "title": pd.Series(["DSGE Model Risk Validation Report", "MS-VAR Stress Testing Methodology"], dtype="string"),
#         "document_text": pd.Series(["Approved for inflation scenario analysis.", "Approved for CRE stress testing."], dtype="string"),
#         "version": pd.Series(["v1.2", "v2.0"], dtype="string")
#     })
#
#     # 11. Raw Implementation Functions
#     # The mapping from approved spec -> executable function family.
#     raw_implementation_functions_df = pd.DataFrame({
#         "impl_id": pd.Series(["IMPL_DSGE_RUNNER", "IMPL_MSVAR_RUNNER"], dtype="string"),
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_REGIME_SWITCHING_005"], dtype="string"),
#         "execution_tool_name": pd.Series(["dsge_lite_runner", "regime_switching_runner"], dtype="string"),
#         "solver_method": pd.Series(["Blanchard-Kahn", "Hamilton Filter"], dtype="string"),
#         "horizon_steps": pd.Series([12, 12], dtype="Int64"),
#         "python_module_path": pd.Series(["computational_layer.dsge_lite", "computational_layer.regime_switching"], dtype="string")
#     })
#
#     # 12. Raw Model Variable Relationships
#     # Explicit join table that makes model selection safe and queryable.
#     raw_model_variable_relationships_df = pd.DataFrame({
#         "relationship_id": pd.Series(["REL_0001", "REL_0002", "REL_0003", "REL_0004"], dtype="string"),
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004"], dtype="string"),
#         "concept_id": pd.Series(["VAR_INFLATION", "VAR_FFR", "VAR_10Y_YIELD", "VAR_OUTPUT_GAP"], dtype="string"),
#         "relationship_type": pd.Series(["OUTPUTS_VARIABLE", "OUTPUTS_VARIABLE", "OUTPUTS_VARIABLE", "OUTPUTS_VARIABLE"], dtype="string"),
#         "is_endogenous": pd.Series([True, True, True, True], dtype="boolean"),
#         "variable_role": pd.Series(["forward_looking", "forward_looking", "expectation", "forward_looking"], dtype="string")
#     })
#
#     # Assemble the master dictionary
#     dataframes_dict = {
#         "raw_source_documents_df": raw_source_documents_df,
#         "raw_evidence_spans_df": raw_evidence_spans_df,
#         "raw_temporal_facts_df": raw_temporal_facts_df,
#         "raw_shocks_df": raw_shocks_df,
#         "raw_variable_concepts_df": raw_variable_concepts_df,
#         "raw_models_df": raw_models_df,
#         "raw_model_specifications_df": raw_model_specifications_df,
#         "raw_model_equations_df": raw_model_equations_df,
#         "raw_model_assumptions_df": raw_model_assumptions_df,
#         "raw_model_documents_df": raw_model_documents_df,
#         "raw_implementation_functions_df": raw_implementation_functions_df,
#         "raw_model_variable_relationships_df": raw_model_variable_relationships_df
#     }
#
#     return dataframes_dict
#
# # Generate the synthetic dataset dictionary
# dataframes_dict = generate_synthetic_kg_inputs()
#
# # Preview the data to verify schema compliance
# print("Synthetic Knowledge Graph Inputs Generated Successfully.")
# print(f"Total DataFrames created: {len(dataframes_dict)}")
# print("\nPreview of raw_evidence_spans_df:")
# print(dataframes_dict["raw_evidence_spans_df"].head(2))
# ```
#
# ### **Step 2: Loading the Configuration (`config.yaml`)**
#
# The study relies on a deterministic configuration file (`config.yaml`) that defines all hyperparameters, LLM settings, and mathematical calibrations. We assume this file exists in the working directory and contains the `study_config` dictionary defined in the prompt.
#
# **Methodology:**
# 1.  **File I/O:** Open `config.yaml` in read mode.
# 2.  **Parsing:** Use `yaml.safe_load` to convert the YAML structure into a nested Python dictionary.
# 3.  **Verification:** Print keys to ensure the file was loaded correctly.
#
# ```python
# import yaml
#
# def load_study_configuration(filepath: str = "config.yaml") -> Dict[str, Any]:
#     """
#     Loads the study configuration parameters from a YAML file into a Python dictionary.
#
#     Purpose:
#         To ingest the deterministic hyperparameters, LLM settings, and mathematical
#         calibrations defined in the external configuration file. This ensures
#         reproducibility by separating code from configuration.
#
#     Inputs:
#         filepath (str): The relative or absolute path to the YAML configuration file.
#                         Default is "config.yaml".
#
#     Processes:
#         1.  File Access: Attempts to open the specified file in read mode.
#         2.  Parsing: Uses PyYAML's safe_load to parse the YAML structure securely.
#         3.  Validation: Catches and handles FileNotFoundError and YAMLError.
#
#     Outputs:
#         Dict[str, Any]: A nested dictionary containing the study configuration.
#
#     Raises:
#         TypeError: If filepath is not a string.
#         FileNotFoundError: If the config.yaml file does not exist.
#         yaml.YAMLError: If the file contains invalid YAML syntax.
#     """
#     # Validate input type to ensure string path
#     if not isinstance(filepath, str):
#         # Raise TypeError if the path is not a string
#         raise TypeError(f"filepath must be a string, got {type(filepath).__name__}.")
#
#     try:
#         # Open the file stream in read mode with UTF-8 encoding
#         with open(filepath, "r", encoding="utf-8") as file:
#             # Parse the YAML content safely into a Python dictionary
#             config = yaml.safe_load(file)
#
#         # Log success to the console for user visibility
#         print(f"Successfully loaded configuration from {filepath}")
#
#         # Return the parsed configuration dictionary
#         return config
#
#     except FileNotFoundError:
#         # Raise an explicit error if the configuration file is missing
#         raise FileNotFoundError(f"Critical Error: {filepath} not found in the working directory.")
#     except yaml.YAMLError as e:
#         # Handle YAML syntax errors explicitly
#         print(f"Error parsing YAML file {filepath}: {e}")
#         # Re-raise the exception to halt execution on corrupted config
#         raise
#
# # Load the configuration from the working directory into the 'config' dictionary
# # Note: Ensure 'config.yaml' is in your working directory with the content provided previously.
# # For the purpose of this self-contained example, if the file is missing, we will use the
# # study_config dictionary defined in the prompt.
# try:
#     config = load_study_configuration("config.yaml")
# except FileNotFoundError:
#     print("Falling back to in-memory study_config for demonstration purposes.")
#     # Assuming study_config is defined in the global namespace from the prompt
#     config = study_config
# ```
#
# ### **Step 3: Executing the Pipeline (`execute_master_ai_economist_pipeline`)**
#
# With the data (`dataframes_dict`) and configuration (`config`) in memory, we invoke the top-level orchestrator. This function manages the entire lifecycle: infrastructure validation, data cleansing, synthetic scaling, application execution (DSGE-lite and MS-VAR), and final archival.
#
# *Note: For this example to run without crashing in a standard Python environment lacking a live Neo4j database and a local Llama 3.1 endpoint, we instantiate mock objects for the `neo4j_driver` and `llm_client`. In a production environment, these would be live connection objects.*
#
# **Methodology:**
# 1.  **Mocking Infrastructure:** Instantiate `MagicMock` objects for the database driver and LLM client to allow the pipeline to execute its logic without external dependencies.
# 2.  **Function Call:** Pass the DataFrames, configuration, and mock objects to `execute_master_ai_economist_pipeline`.
# 3.  **Output Handling:** The function returns a master dictionary containing all intermediate logs, application results, and the final validation report.
#
# ```python
# # ==============================================================================
# # Execution of the End-to-End AI Economist Agent Pipeline
# # ==============================================================================
#
# if __name__ == "__main__":
#     # Ensure we have valid inputs before initiating the heavy computational pipeline
#     if dataframes_dict and config:
#
#         # Log the initiation of the pipeline
#         print("\nInitiating AI Economist Agent Study Pipeline...")
#
#         # Instantiate mock objects for the external infrastructure dependencies
#         # This allows the example to run without a live Neo4j database or LLM endpoint
#         mock_neo4j_driver = MagicMock()
#
#         try:
#             # Execute the master pipeline orchestrator
#             # This will trigger the full sequence of Tasks 1 through 29
#             # Note: execute_master_ai_economist_pipeline is assumed to be in the namespace
#             master_artifacts = execute_master_ai_economist_pipeline(
#                 dataframes_dict=dataframes_dict,
#                 study_config=config,
#                 neo4j_driver=mock_neo4j_driver,
#                 base_archive_path="./provenance_archives"
#             )
#
#             # ==============================================================================
#             # Inspecting the Outputs
#             # ==============================================================================
#
#             # Print a visual separator for the completion block
#             print("\n" + "="*80)
#             # Announce successful completion
#             print("STUDY EXECUTION COMPLETE")
#             # Print a visual separator
#             print("="*80)
#
#             # 1. Accessing Data Preparation Logs
#             print("\n[Data Preparation Phase]")
#             if "data_preparation_logs" in master_artifacts:
#                 logs = master_artifacts["data_preparation_logs"]
#                 print(f"Identifier Audit Log Entries: {len(logs.get('identifier_audit_log', []))}")
#                 print(f"Tag Lineage Log Entries: {len(logs.get('tag_lineage_log', []))}")
#
#             # 2. Accessing Application 1 Results (DSGE-lite)
#             print("\n[Application 1: U.S. Inflation Persistence]")
#             if "application_1_results" in master_artifacts:
#                 app1_res = master_artifacts["application_1_results"]
#                 print("Model Selected:", app1_res.get("execution_request", {}).get("model_specification"))
#                 print("Judge Scores (Model-Grounded):", app1_res.get("scores_model_grounded"))
#
#             # 3. Accessing Application 2 Results (MS-VAR)
#             print("\n[Application 2: U.S. CRE Refinancing Stress]")
#             if "application_2_results" in master_artifacts:
#                 app2_res = master_artifacts["application_2_results"]
#                 print("Model Selected:", app2_res.get("execution_request", {}).get("model_specification"))
#                 print("Judge Scores (Model-Grounded):", app2_res.get("scores_model_grounded"))
#
#             # 4. Printing the Final Validation Report
#             print("\n" + "="*80)
#             print("FINAL REPRODUCTION VALIDATION REPORT")
#             print("="*80)
#             print(master_artifacts.get("final_validation_report", "Report not generated."))
#
#         except Exception as e:
#             # Catch and display any fatal errors that occurred during pipeline execution
#             print(f"\nPipeline Execution Failed: {str(e)}")
#
#     else:
#         # Handle the case where data generation or config loading failed
#         print("Error: Missing synthetic data or configuration. Cannot proceed.")
# ```
#
# ## Output Structure
#
# The pipeline returns a comprehensive, cryptographically hashed `.tar.gz` archive containing the following key artifacts:
# -   **`01_scenario.txt`**: The raw narrative text of the economic scenario.
# -   **`02_planner_output.json`**: The structured analysis plan generated by the Planner Agent.
# -   **`03_retrieved_evidence.json`**: The top-6 retrieved evidence spans with their synthetic confidence scores.
# -   **`04_pre_run_paths.txt`**: The pre-execution graph paths retrieved from Neo4j.
# -   **`05_model_context.json`**: The executable model context provided to the Model-Selection Agent.
# -   **`06_execution_request.json`**: The structured execution request ($r_s$) generated by the Model-Selection Agent.
# -   **`07_model_run_metadata.json`**: The metadata for the executed `ModelRun` node, including the generated `run_id`.
# -   **`08_model_output_table.csv`**: The 12-step numerical paths for the macro-financial variables.
# -   **`08_bank_metrics.json`**: The computed Basel III/CCAR bank stress metrics (Application 2 only).
# -   **`09_post_run_paths.txt`**: The post-execution graph paths retrieved from Neo4j, summarizing extremum values.
# -   **`10_report_*.txt`**: The generated economic reports for the three experimental conditions (LLM-only, RAG-only, Model-grounded).
# -   **`11_scores_*.json`**: The rubric scores generated by the Judge Agent for the three experimental conditions.
# -   **`runtime_environment.json`**: The runtime environment, library versions, and SHA-256 cryptographic hashes of the executed computational runner modules.
# -   **`implementation_assumptions.json`**: The assumption registry documenting all manuscript-unspecified choices (e.g., diagonal MS-VAR matrices, retrieval weights).
# -   **`reproduction_validation_report.txt`**: The final validation report summarizing the reproduction outcomes and numerical limitations.
#
# ## Project Structure
#
# ```
# ai_economist_agent/
# │
# ├── ai_economist_agent_draft.ipynb              # Main implementation notebook containing all callables
# ├── config.yaml                                 # Master configuration file (Budgets, Hyperparameters, Seeds)
# ├── requirements.txt                            # Python package dependencies
# │
# ├── provenance_archives/                        # Auto-generated archival directory
# │   ├── APP_1_RUN_SCEN_APP1_INFLATION_20260618T120000Z/
# │   │   ├── 01_scenario.txt
# │   │   ├── 02_planner_output.json
# │   │   ├── 03_retrieved_evidence.json
# │   │   ├── 04_pre_run_paths.txt
# │   │   ├── 05_model_context.json
# │   │   ├── 06_execution_request.json
# │   │   ├── 07_model_run_metadata.json
# │   │   ├── 08_model_output_table.csv
# │   │   ├── 08_model_output_table.md
# │   │   ├── 09_post_run_paths.txt
# │   │   ├── 10_report_llm_only.txt
# │   │   ├── 10_report_rag_only.txt
# │   │   ├── 10_report_model_grounded.txt
# │   │   ├── 11_scores_llm_only.json
# │   │   ├── 11_scores_rag_only.json
# │   │   ├── 11_scores_model_grounded.json
# │   │   ├── runtime_environment.json
# │   │   ├── implementation_assumptions.json
# │   │   └── reproduction_validation_report.txt
# │   │
# │   └── APP_2_RUN_SCEN_APP2_CRE_20260618T120500Z/
# │       ├── ... (similar structure to APP_1)
# │       └── 08_bank_metrics.json
# │
# ├── LICENSE                                     # MIT Project License File
# └── README.md                                   # This file
# ```
#
# ## Customization
#
# The pipeline is highly customizable via the `config.yaml` file. Researchers and engineers can modify study parameters such as:
# -   **LLM Inference Settings:** Adjust the `model_name`, `temperature`, `seed`, and `max_tokens` in the `llm_execution_parameters` block to experiment with different local models or sampling strategies.
# -   **Retrieval Parameters:** Modify `text_evidence_top_k`, `model_context_top_k`, `tag_overlap_weight`, and `confidence_score_weight` in the `retrieval_graph_parameters` block to tune the RAG retrieval logic.
# -   **Graph Database Policies:** Toggle `clear_graph_on_init`, `allow_neighborhood_expansion`, and `require_task_specific_queries` in the `retrieval_graph_parameters` block to experiment with different graph traversal constraints.
# -   **Computational Solver Settings:** Adjust `model_horizon_steps`, `random_seed`, `bk_tolerance`, and `hamilton_filter_tolerance` in the `computational_solver_parameters` block to fine-tune the mathematical execution layer.
# -   **Mathematical Calibrations:** Modify the parameters in the `dsge_lite_parameters`, `regime_switching_parameters`, and `bank_stress_parameters` blocks to simulate different economic scenarios or stress testing methodologies.
#
# ## Contributing
#
# Contributions are welcome. Please fork the repository, create a feature branch, and submit a pull request with a clear description of your changes.
#
# **Strict Engineering Standards:** Adherence to PEP-8, strict type hinting (`typing` module), and the draconian requirement for line-by-line in-text comments that explain the mathematical or logical purpose of every single line of code is strictly required for all pull requests to maintain the implementation-grade standard of this repository.
#
# ## Recommended Extensions
#
# Future extensions, building upon this foundational framework, could include:
# -   **Real-Time Data Integration:** Integrating real-time economic data feeds (e.g., FRED, Bloomberg) to dynamically update the `TemporalFact` nodes and drive automated nowcasting reports.
# -   **Expanded Model Catalog:** Expanding the computational layer to include Heterogeneous Agent New Keynesian (HANK) models, Global Vector Autoregressions (GVAR), or deep learning surrogates for nonlinear macro-financial propagation.
# -   **Multi-Agent Debate:** Implementing a multi-agent debate mechanism where multiple Report Generator agents synthesize the information tuple and a meta-agent adjudicates the final narrative.
#
# ## License
#
# This project is licensed under the MIT License. See the `LICENSE` file for details.
#
# ## Citation
#
# If you use this code or the methodology in your research, please cite the original paper:
#
# ```bibtex
# @misc{kato2026aieconomist,
#   title={AI Economist Agent: An Agentic Framework for Model-Grounded Economic Analysis with RAG, Knowledge Graphs, and Large Language Models},
#   author={Kato, Masahiro},
#   howpublished={arXiv preprint arXiv:2606.20041},
#   year={2026},
#   url={https://arxiv.org/abs/2606.20041}
# }
# ```
#
# For the implementation itself, you may cite this repository:
# ```bibtex
# @misc{chirinda2026aieconomistagent,
#   author = {Chirinda, Craig S.},
#   title = {AI Economist Agent: An Agentic Framework for Model-Grounded Economic Analysis},
#   year = {2026},
#   publisher = {GitHub},
#   howpublished = {\url{https://github.com/chirindaopensource/ai_economist_agent}}
# }
# ```
#
# ## Acknowledgments
#
# -   Credit to **Masahiro Kato** for the foundational theoretical framework, the rigorous epistemic design, and the synthesis of agentic orchestration with macroeconometric modeling.
# -   This project is built upon the exceptional tools provided by the open-source community. Sincere thanks to the developers of the scientific Python ecosystem, particularly the **NumPy**, **Pandas**, **SciPy**, and **Neo4j** contributors.
#
# --
#
# *This README was generated based on the structure and content of the `ai_economist_agent_draft.ipynb` notebook and follows best practices for research software documentation.*

# %% [markdown]
# # Paper
#
# Title: "*AI Economist Agent: An Agentic Framework for Model-Grounded Economic Analysis with RAG, Knowledge Graphs, and Large Language Models*"
#
# Authors: Masahiro Kato
#
# E-Journal Submission Date: 18 June 2026
#
# Link: https://arxiv.org/abs/2606.20041
#
# Abstract:
#
# We propose a model-grounded RAG-based AI economist with an agentic framework for economic scenario analysis using large language models (LLMs) and knowledge graphs. While LLMs can generate fluent economic narratives, economists are often required to make economic claims grounded by economic theory and real-world data. Based on this motivation, this study proposes an RAG-based AI economist, which utilizes knowledge graphs including economic data and theory and LLM-based agents to plan the analysis, retrieve relevant evidence, select appropriate models, and generate reports. In our framework, we do not produce quantitative claims directly with the language model alone; instead, we generate narratives grounded in explicit model-based computations and linked to the retrieved evidence via AI agents. We refer to our framework as an AI economist agent. We evaluate the AI economist agent in two applications: economist report generation for U.S. inflation persistence and Federal Reserve policy, and bank stress-test narrative generation for U.S. commercial real estate refinancing stress. The results illustrate how grounding the generated reports improves their economic coherence and traceability.

# %% [markdown]
# # Summary
#
# ### 1 Executive Summary
#
# The paper "AI Economist Agent: An Agentic Framework for Model-Grounded Economic Analysis with RAG, Knowledge Graphs, and Large Language Models" by Masahiro Kato addresses a critical epistemic failure in the application of Large Language Models (LLMs) to economic analysis: the generation of fluent narratives lacking formal grounding in macroeconomic theory, empirical data, and explicit mathematical models. To resolve this, the author proposes an agentic architecture that structurally decouples qualitative narrative generation from quantitative model execution.
#
# The framework utilizes a typed, directed Knowledge Graph (KG) to separate text evidence, temporal facts, model specifications, and execution results. LLM-based agents operate over this graph to plan analysis, retrieve evidence, select approved mathematical models, and generate reports, but are structurally prohibited from generating quantitative model-dependent claims. Numerical paths are computed externally by validated implementation functions and written back to the KG.
#
# The architecture is evaluated across two applications: U.S. inflation persistence and U.S. commercial real estate (CRE) refinancing stress. The experiments compare three report-generation conditions: LLM-only, RAG-only, and the proposed Model-grounded GraphRAG. The results demonstrate that while RAG-only improves textual evidence grounding, only the proposed condition successfully grounds the report in executed mathematical models, thereby transforming the output from a fluent narrative into a traceable economic analysis.
#
# ### 2 Introduction
#
# The integration of artificial intelligence in economic research has predominantly focused on leveraging LLMs for text generation. However, economic analysis is not merely a language-generation task; it requires moving fluidly between narrative and formal mathematical reasoning. A statement such as "persistent inflation will keep monetary policy restrictive" is economically meaningful only when traceable to price-setting behavior, labor market conditions, and an explicit monetary policy reaction function.
#
# Existing LLM-based approaches fail this traceability requirement. They either generate quantitative claims autoregressively—introducing numerical hallucinations—or rely on text retrieval (RAG) that provides supporting prose but no executed mathematical models.
#
# To bridge this gap, Kato proposes the "AI Economist Agent," a model-grounded RAG-based framework. The core methodological innovation is the strict partitioning of labor: the LLM acts as an orchestrator for planning, retrieval, model selection, and explanation, while an external computational layer executes validated macroeconometric models. The LLM never generates the numerical path; it interprets the path computed by the approved model. This summary deconstructs the paper's architecture, model execution design, experimental setup, and empirical findings, providing rigorous mathematical definitions for the model specifications to ensure methodological replicability.
#
# ### 3 Architectural Framework
#
# #### 3.1 Knowledge Graph Ontology
# The organizing structure of the system is a directed Knowledge Graph with typed nodes and relationships. Its primary function is to separate objects typically conflated in LLM generation:
# *   **Text Evidence Objects**: `SourceDocument`, `EvidenceSpan` (used for textual RAG).
# *   **Temporal Evidence Objects**: `TemporalFact` (records observation times and validity windows).
# *   **Economic Task Objects**: `Scenario`, `Shock`, `VariableConcept`.
# *   **Model Catalog Objects**: `Model`, `ModelSpecification`, `ModelEquation`, `ModelAssumption`, `ModelDocument` (stores approved model descriptions independently of text evidence).
# *   **Execution Objects**: `ImplementationFunction`, `ModelRun`, `ForecastOutcome`, `ModelOutputPoint`, `BankMetric` (records computational mappings and outputs).
#
# This separation ensures the RAG-only condition cannot accidentally become a model-selection condition by merely reading model names from retrieved text spans.
#
# #### 3.2 Model Specifications and Executable Implementations
# A critical distinction is made between a model specification (the economic/statistical description) and an executable implementation (the computational family computing the numerical path). Multiple specifications can map to the same implementation family.
#
# The LLM does not select an arbitrary model name from free text. It selects a graph-retrieved specification and maps it to an available implementation family, producing a structured execution request $r_s$:
# $$ r_s = (\text{model specification}, \text{model family}, \text{implementation family}, \text{execution tool}, \text{expected outputs}) $$
#
# To bridge the paper's conceptual gaps with rigorous econometric definitions, we define the mathematical implementations for the two applications:
# 1.  **Application 1 Implementation (DSGE-lite):** The selected `MSPEC_DSGE_LITE_004` is defined mathematically as a linearized 3-equation New Keynesian model:
#     *   IS Curve: $y_t = E_t y_{t+1} - \frac{1}{\sigma}(i_t - E_t \pi_{t+1}) + g_t$
#     *   Phillips Curve: $\pi_t = \beta E_t \pi_{t+1} + \kappa y_t + u_t$
#     *   Monetary Policy Rule: $i_t = \phi_\pi \pi_t + \phi_y y_t + v_t$
#     where $y_t$ is the output gap, $\pi_t$ is inflation, $i_t$ is the policy rate, and $g_t, u_t, v_t$ are AR(1) shock processes. The computational layer solves the model via Blanchard-Kahn conditions and simulates a 12-step horizon path.
# 2.  **Application 2 Implementation (Regime Switching):** The selected `MSPEC_REGIME_SWITCHING_005` is defined as a 2-state Markov-Switching Vector Autoregression (MS-VAR):
#     *   $Y_t = c_{S_t} + A_{1,S_t} Y_{t-1} + \dots + A_{p,S_t} Y_{t-p} + \epsilon_{S_t,t}$
#     where $S_t \in \{1, 2\}$ follows a Markov chain with transition matrix $P$, state 1 represents normal refinancing conditions, and state 2 represents stress dynamics. The computational layer filters the regimes and computes nonlinear stress paths and bank metrics.
#
# #### 3.3 Agentic Workflow and Information Tuples
# The workflow resets the graph at the beginning of each run, loading evidence, temporal facts, the model catalog, and scenario nodes. The sequence is rigorously defined:
#
# 1.  Let $s$ denote the scenario.
# 2.  The text-retrieval step returns evidence spans $E_s$.
# 3.  Pre-execution graph retrieval returns paths $P_s^{\text{pre}}$ and executable model context $C_s$.
# 4.  The model-selection agent produces the structured request $r_s$.
# 5.  The computational layer executes the model, produces output points $O_s$, and records a model run $m_s$ in the graph.
# 6.  Post-execution graph retrieval returns paths $P_s^{\text{post}}$.
#
# The proposed report is generated strictly from the tuple:
# $$ (s, E_s, P_s^{\text{pre}}, C_s, r_s, m_s, O_s, P_s^{\text{post}}) $$
#
# ### 4 Experimental Design and Conditions
#
# The experiments compare three conditions to isolate the effect of the information set provided to the report generator. The setup utilizes a local LLM (`llama3.1:8b`, temperature 0, seed 42) ensuring deterministic generation. The model horizon is a 12-step synthetic path, retrieving six evidence spans per application.
#
# *   **Condition 1: LLM-only**. Input: Scenario narrative only. Tests baseline narrative fluency without external grounding.
# *   **Condition 2: RAG-only**. Input: Scenario narrative + retrieved text evidence. Explicitly prohibited from claiming a mathematical model has been executed. Tests textual grounding without computation.
# *   **Condition 3: Model-grounded GraphRAG**. Input: Scenario narrative + retrieved evidence + pre-run graph paths + selected model specification + execution request + model-run object + model-output table + post-run graph paths. Mandates the separation of qualitative interpretation from model-dependent statements.
#
# A judge agent (using the same local LLM) scores the reports across six dimensions: Evidence grounding, Graph reasoning, Model grounding, Numerical discipline, Economic coherence, and Audit. A high model-grounding score strictly requires an executed model object; mentioning a model name is insufficient.
#
# ### 5 Applications and Empirical Results
#
# #### 5.1 Application 1: U.S. Inflation Persistence
# The scenario posits persistent services inflation, gradual labor-market cooling, and a restrictive Federal Reserve policy lifting Treasury yields.
#
# *   **Retrieval & Selection**: The text retrieval returns evidence spans regarding credit losses, CRE values, and policy paths. The model-selection agent selects `MSPEC_DSGE_LITE_004`, mapping to the DSGE-lite implementation family.
# *   **Execution Outputs**: The computational layer executes the 12-step synthetic path. Peak headline inflation is 0.229 (trough: -0.455); peak federal funds rate is 30.951 (trough: -5.144); peak 10-year yield is 17.169 (trough: 2.731).
# *   **Judged Comparison**: The LLM-only condition scored 0.0 on Model grounding (no model executed). RAG-only scored 5.0 on Evidence but 0.0 on Model. The Model-grounded GraphRAG condition scored 5.0 on Evidence, 4.0 on Graph, and 5.0 on Model, proving the successful integration of the post-`ModelRun` graph paths.
#
# #### 5.2 Application 2: Bank Stress-Test Narrative
# The scenario posits higher long-term rates and wider credit spreads pressuring U.S. CRE refinancing, transmitting to bank losses, funding, capital, and liquidity.
#
# *   **Retrieval & Selection**: Text retrieval surfaces evidence regarding funding stress and uninsured deposit outflows. The model-selection agent selects `MSPEC_REGIME_SWITCHING_005`.
# *   **Execution Outputs**: The execution yields CRE price paths (trough: -16.824) and credit spread paths (peak: 152.971). The stress module computes bank metrics: Stress PD (0.049), Stress LGD (0.467), Credit loss (20.612), Stress CET1 (5.984), and Stress LCR (143.877).
# *   **Judged Comparison**: Similar to Application 1, RAG-only improved evidence grounding over LLM-only but scored 0.0 on Model grounding. Model-grounded GraphRAG scored 5.0 across Evidence, Model, Numeric, and Audit dimensions.
#
# ### 6 Conclusion
#
# Kato’s "AI Economist Agent" successfully demonstrates that changing the information set supplied to an LLM report generator structurally alters the grounding of the resulting economic narrative. By enforcing a strict architectural separation between narrative orchestration and quantitative computation, the framework moves LLM-generated economic reports from untraceable fluent prose to auditable, model-grounded analyses.
#
# The central qualitative finding is that RAG-only generation is insufficient for economic model grounding, as it lacks execution objects. The proposed Model-grounded GraphRAG condition bridges this gap by utilizing a typed Knowledge Graph that links scenarios to graph-selected model specifications, computational runners, and written-back execution outputs. While the numerical outputs in the experiment are synthetic, the methodological architecture provides a robust, scalable framework for integrating formal econometric modeling with agentic LLM workflows.

# %% [markdown]
# # Import Essential Modules

# %%
#!/usr/bin/env python3
# ==============================================================================#
#
#  AI Economist Agent: An Agentic Framework for Model-Grounded Economic Analysis
#
#  This module provides a complete, production-grade implementation of the
#  analytical framework presented in "AI Economist Agent: An Agentic Framework
#  for Model-Grounded Economic Analysis with RAG, Knowledge Graphs, and Large
#  Language Models" by Masahiro Kato (2026). It delivers a computationally
#  tractable system for quantitative analysis of economic scenarios, enabling
#  robust, model-grounded report generation, epistemic traceability, and
#  structural "what-if" scenario analysis that accounts for both qualitative
#  narratives and deterministic mathematical execution.
#
#  Core Methodological Components:
#  • Agentic orchestration via local deterministic LLMs (llama3.1:8b)
#  • Knowledge Graph (KG) topology for epistemic separation of evidence and models
#  • Pre-execution and post-execution Cypher path traversals
#  • Dynamic Stochastic General Equilibrium (DSGE-lite) modeling and simulation
#  • Markov-Switching Vector Autoregression (MS-VAR) and Hamilton filtering
#  • Basel III/CCAR regulatory bank stress test accounting mappings
#
#  Technical Implementation Features:
#  • Strict JSON-constrained autoregressive decoding
#  • Atomic graph mutations and read-committed isolation levels
#  • Blanchard-Kahn saddle-path stability verification
#  • Vectorized pandas schema validation and referential integrity checks
#  • Cryptographic hashing of runtime environments for regulatory auditability
#  • Automated rubric-based LLM judging with strict logic gates
#
#  Paper Reference:
#  Kato, M. (2026). AI Economist Agent: An Agentic Framework for Model-Grounded
#  Economic Analysis with RAG, Knowledge Graphs, and Large Language Models.
#  arXiv preprint arXiv:2606.20041. https://arxiv.org/abs/2606.20041
#
#  Author: CS Chirinda
#  License: MIT
#  Version: 1.0.0
#
# ==============================================================================#
#
# Import Essential Modules

import re
import json
import requests
import psutil
import difflib
import os
import sys
import hashlib
import platform
import importlib.util
import shutil
from pathlib import Path
import inspect
from collections import defaultdict, Counter
from datetime import datetime, timezone

import logging
import numpy as np
import pandas as pd
import pandas.api.types as ptypes
from dataclasses import dataclass
import scipy
from scipy import stats
import scipy.linalg
import scipy.special
from typing import Dict, Any, List, Tuple, Set, FrozenSet, Union, Optional, Callable, TypeVar, Generic, NamedTuple

try:
    import neo4j
    import neo4j.exceptions
    from neo4j import Driver, Transaction, Record
    from neo4j.graph import Path as Neo4jPath, Node, Relationship
except ImportError:
    raise ImportError("The 'neo4j' package is required. Install it via 'pip install neo4j'.")

# Configure module-level logger for auditability and execution tracking
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
if not logger.handlers:
    # Establish a standard stream handler for console output
    handler = logging.StreamHandler()
    # Define a professional formatting standard for log messages
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)
    logger.addHandler(handler)

# %% [markdown]
# # Implementation

# %% [markdown]
# # Draft 1
#
# ## **Discussion of the Inputs, Processes and Outputs (IPO) of Key Callables**
#
# Below is the exhaustive, clinical, and granular forensic mapping of the 30 final orchestrator callables that constitute the "AI Economist Agent" framework:
#
# ### 1. `validate_study_configuration` (Task 1 Orchestrator)
# *   **Inputs:** `study_config` (Dict), `raw_implementation_functions_df` (DataFrame).
# *   **Processes:** Sequentially validates LLM determinism parameters, enforces a uniform 12-step horizon across all active computational runners, and mathematically verifies the Markov transition matrix.
# *   **Outputs:** None (Raises `ValueError` or `KeyError` on failure).
# *   **Data Transformation:** Performs read-only structural validation and type coercion (e.g., casting integers to floats for exact equality checks) without mutating the input data.
# *   **Role in Research Pipeline:** Implements the foundational experimental controls. It ensures the LLM operates deterministically and that the stochastic matrices are mathematically sound.
# *   **LaTeX Excerpt & Equation:** Enforces the constraint: *"All LLM calls utilize a local Llama 3.1 8B model with the following exact configuration: \texttt{temperature} = 0, \texttt{seed} = 42..."* and validates the Markov transition matrix: $P(S_t = j | S_{t-1} = i) = p_{ij}$ where rows must sum to 1.
#
# ### 2. `validate_retrieval_and_graph_policies` (Task 2 Orchestrator)
# *   **Inputs:** `study_config` (Dict), `assumption_registry` (Dict).
# *   **Processes:** Validates the text retrieval top-k limits, enforces boolean graph traversal constraints, and documents the retrieval-ranking weighting assumption.
# *   **Outputs:** None (Mutates `assumption_registry` in-place).
# *   **Data Transformation:** Transforms implicit methodological choices (the 50/50 weighting of tag overlap and confidence) into explicit, serializable audit records within the registry.
# *   **Role in Research Pipeline:** Implements the topological constraints of the Knowledge Graph.
# *   **LaTeX Excerpt:** *"The framework prohibits unconstrained neighborhood expansion; thus, the implementer must write highly specific path queries..."*
#
# ### 3. `validate_prompt_templates` (Task 3 Orchestrator)
# *   **Inputs:** `study_config` (Dict).
# *   **Processes:** Computes symmetric differences to ensure exactly six prompt keys exist, verifies the presence of critical negative constraints via substring matching, and enforces JSON-only output contracts.
# *   **Outputs:** None.
# *   **Data Transformation:** Read-only string evaluation and set mathematics.
# *   **Role in Research Pipeline:** Implements the Epistemic Separation Prompting and Negative Constraint Operationalization.
# *   **LaTeX Excerpt:** *"CRITICAL CONSTRAINT: You must NOT claim that a mathematical model has been executed. Limit claims to the provided textual evidence."*
#
# ### 4. `validate_all_dataframe_schemas` (Task 4 Orchestrator)
# *   **Inputs:** `dataframes_dict` (Dict of DataFrames).
# *   **Processes:** Iterates over a declarative `SCHEMA_REGISTRY`, validating column presence, pandas extension dtypes (e.g., `Int64`, `string`), and nullability constraints across all 12 input tables.
# *   **Outputs:** None.
# *   **Data Transformation:** Applies vectorized boolean masks (`.isnull().any()`) to compute constraint violations without altering the underlying tabular structures.
# *   **Role in Research Pipeline:** Implements the structural foundation for Property Graph Modeling.
# *   **LaTeX Excerpt:** *"The knowledge graph is the organizing structure of the system. It is a directed graph with typed nodes and typed relationships."*
#
# ### 5. `validate_referential_integrity` (Task 5 Orchestrator)
# *   **Inputs:** `dataframes_dict` (Dict), `study_config` (Dict), `is_pre_cleansing_pass` (bool).
# *   **Processes:** Validates primary key uniqueness and executes set-difference operations to isolate orphaned foreign keys across 11 defined relational edges.
# *   **Outputs:** None.
# *   **Data Transformation:** Transforms pandas Series into Python `sets` to perform highly optimized $A \setminus B$ difference operations, isolating referential breaches.
# *   **Role in Research Pipeline:** Implements Relational Data Synthesis verification.
# *   **LaTeX Excerpt:** *"...ensuring referential integrity between \texttt{Model}, \texttt{ModelSpecification}, and \texttt{ImplementationFunction} nodes."*
#
# ### 6. `validate_row_level_invariants` (Task 6 Orchestrator)
# *   **Inputs:** `dataframes_dict` (Dict).
# *   **Processes:** Validates confidence bounds $[0, 1]$, character offset ordering, and temporal window ordering.
# *   **Outputs:** `quarantine_logs` (Dict of DataFrames).
# *   **Data Transformation:** Partitions the input DataFrames into "clean" and "quarantined" sets using vectorized boolean masks, ensuring graceful degradation of defective data.
# *   **Role in Research Pipeline:** Implements Temporal Data Generation validation.
# *   **LaTeX Excerpt:** *"Economic analysis is also time-sensitive; the date of a document, validity period of a claim... should be represented separately."*
#
# ### 7. `cleanse_identifier_and_text_fields` (Task 7 Orchestrator)
# *   **Inputs:** `dataframes_dict` (Dict).
# *   **Processes:** Deterministically strips whitespace from all PK/FK columns, normalizes evidence tags (split, lower, sort, join), and quarantines empty text spans.
# *   **Outputs:** `cleansing_logs` (Dict of DataFrames).
# *   **Data Transformation:** Mutates DataFrames in-place using vectorized pandas string accessors (`.str.split`, `.explode`, `.str.strip`), transforming raw text into canonical formats for deterministic retrieval.
# *   **Role in Research Pipeline:** Prepares the textual payload for the RAG-only and GraphRAG conditions.
# *   **LaTeX Excerpt:** *"RAG retrieves text spans, whereas GraphRAG retrieves structured paths."*
#
# ### 8. `cleanse_and_normalize_datetimes` (Task 8 Orchestrator)
# *   **Inputs:** `dataframes_dict` (Dict), `assumption_registry` (Dict).
# *   **Processes:** Parses publication dates to timezone-naive formats and temporal facts to strict UTC-aware formats, enforcing a global timezone policy.
# *   **Outputs:** None.
# *   **Data Transformation:** Transforms ISO 8601 strings into `datetime64[ns]` and `datetime64[ns, UTC]` objects.
# *   **Role in Research Pipeline:** Implements the temporal grounding required to prevent timeless hallucinations.
# *   **LaTeX Excerpt:** *"Temporal objects represent observation-time and validity-window information attached to evidence relations."*
#
# ### 9. `validate_and_cleanse_json_payloads` (Task 9 Orchestrator)
# *   **Inputs:** `dataframes_dict` (Dict).
# *   **Processes:** Parses `calibration_params_json` strictly, validates the resulting keys against expected model schemas, and quarantines invalid specifications.
# *   **Outputs:** `quarantine_logs` (Dict of DataFrames).
# *   **Data Transformation:** Transforms raw JSON strings into nested Python dictionaries, bridging the gap between database text fields and computational parameters.
# *   **Role in Research Pipeline:** Implements the parameterization layer for the mathematical runners.
# *   **LaTeX Excerpt:** *"A model specification is stored as a separate object with equations, assumptions, inputs, outputs, and an implementation mapping."*
#
# ### 10. `verify_and_synthesize_data_scale` (Task 10 Orchestrator)
# *   **Inputs:** `dataframes_dict` (Dict), `assumption_registry` (Dict), `study_config` (Dict).
# *   **Processes:** Synthesizes evidence and temporal facts to exactly 2,500 rows using a deterministic PRNG, and verifies the model catalog scale.
# *   **Outputs:** None.
# *   **Data Transformation:** Generates synthetic rows and concatenates them to the existing DataFrames, padding the corpus to the manuscript's exact scale.
# *   **Role in Research Pipeline:** Implements Synthetic Data Science and Monte Carlo Simulation.
# *   **LaTeX Excerpt & Equation:** *"2,500 evidence spans are generated. The synthetic confidence score for each span is drawn from a Beta distribution: $\text{confidence}_i \sim \text{Beta}(9, 1)$"*
#
# ### 11. `provision_llm_endpoint` (Task 11 Orchestrator)
# *   **Inputs:** `study_config` (Dict), `assumption_registry` (Dict).
# *   **Processes:** Initializes the `LLMClient`, audits the OS routing table for network isolation, and empirically tests generation determinism.
# *   **Outputs:** `LLMClient` (Object).
# *   **Data Transformation:** Instantiates the HTTP communication interface required for agentic orchestration.
# *   **Role in Research Pipeline:** Implements Inference Engineering, MLOps, and Computational Isolation.
# *   **LaTeX Excerpt:** *"Perfect fidelity requires expertise in deploying and managing local model endpoints, isolated from cloud API stochasticity."*
#
# ### 12. `provision_neo4j_database` (Task 12 Orchestrator)
# *   **Inputs:** `driver` (Neo4j Driver).
# *   **Processes:** Executes idempotent Cypher statements to apply uniqueness constraints, creates indices, and verifies node-label taxonomy.
# *   **Outputs:** None.
# *   **Data Transformation:** Mutates the schema state of the external graph database.
# *   **Role in Research Pipeline:** Implements Graph Database Architecture.
# *   **LaTeX Excerpt:** *"The knowledge graph is implemented using Neo4j 5.x. The schema is defined via explicit constraints and indexes..."*
#
# ### 13. `reset_knowledge_graph` (Task 13 Orchestrator)
# *   **Inputs:** `driver` (Neo4j Driver).
# *   **Processes:** Executes a batched Cypher deletion loop to purge the graph, followed by a read-committed transaction to verify the node count is exactly zero.
# *   **Outputs:** `bool` (Success indicator).
# *   **Data Transformation:** Transforms the graph database state from populated to completely empty.
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 1 (Graph Reset) and Graph State Isolation.
# *   **LaTeX Excerpt:** *"\textbf{Graph Reset:} Clear existing knowledge graph contents."*
#
# ### 14. `load_knowledge_graph` (Task 14 Orchestrator)
# *   **Inputs:** `driver` (Neo4j Driver), `application_number` (int), `dataframes_dict` (Dict), `study_config` (Dict).
# *   **Processes:** Unwinds the cleansed DataFrames into the graph using `MERGE` semantics, enforcing a strict two-phase loading strategy (nodes, then edges).
# *   **Outputs:** `audit_counts` (Dict).
# *   **Data Transformation:** Transforms tabular pandas DataFrames into a traversable, topological Property Graph.
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 2 (Graph Loading).
# *   **LaTeX Excerpt:** *"\textbf{Graph Loading:} Load evidence rows, temporal facts, model catalog, scenario node ($s$), and scenario-shock relationships into the graph."*
#
# ### 15. `retrieve_text_evidence` (Task 15 Orchestrator)
# *   **Inputs:** `scenario_text` (str), `raw_evidence_spans_df` (DataFrame), `study_config` (Dict), `application_number` (int).
# *   **Processes:** Infers scenario tags, computes Jaccard-like overlap, calculates a 50/50 composite score, stably sorts, and slices the top-k spans.
# *   **Outputs:** `retrieved_spans` (List of Dicts).
# *   **Data Transformation:** Transforms the evidence DataFrame into a ranked, truncated list of dictionaries representing $E_s$.
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 4 (Text Retrieval).
# *   **LaTeX Excerpt:** *"\textbf{Text Retrieval:} Execute evidence query to return six evidence spans ($E_s$) to RAG-only and proposed conditions."*
#
# ### 16. `retrieve_graph_context_pre_execution` (Task 16 Orchestrator)
# *   **Inputs:** `driver` (Neo4j Driver), `scenario_id` (str), `study_config` (Dict).
# *   **Processes:** Executes single-hop Cypher path queries to retrieve $P_s^{\text{pre}}$ and projects the executable model context $C_s$.
# *   **Outputs:** `result_dict` (Dict containing paths and context).
# *   **Data Transformation:** Transforms graph topology into linear string paths and structured JSON context for LLM ingestion.
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 5 (Graph Retrieval Pre-Execution).
# *   **LaTeX Excerpt:** *"\textbf{Graph Retrieval (Pre-Execution):} Execute graph path query to return pre-run graph paths ($P_s^{\text{pre}}$) and executable model context ($C_s$)."*
#
# ### 17. `call_planner_agent` (Task 17 Orchestrator)
# *   **Inputs:** `scenario_text` (str), `llm_client` (Object), `study_config` (Dict).
# *   **Processes:** Injects the scenario into the prompt, invokes the LLM, strips markdown fences, and strictly parses the JSON output.
# *   **Outputs:** `plan_json` (Dict).
# *   **Data Transformation:** Transforms unstructured qualitative text ($s$) into a structured JSON analysis plan.
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 3 (Planning).
# *   **LaTeX Excerpt:** *"\textbf{Planning:} Call LLM planner with scenario $s$ to return analysis objective, target variables, and model-selection objective."*
#
# ### 18. `call_model_selection_agent` (Task 18 Orchestrator)
# *   **Inputs:** `scenario_text` (str), `plan_json` (Dict), `model_context` (List), `llm_client` (Object), `study_config` (Dict), `application_number` (int).
# *   **Processes:** Prompts the LLM, validates the selected tool against the context, asserts the expected specification, and executes a bounded retry loop without look-ahead bias.
# *   **Outputs:** `execution_request` (Dict).
# *   **Data Transformation:** Transforms semantic context into a rigid, syntactic execution tuple ($r_s$).
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 6 (Model Selection).
# *   **LaTeX Excerpt & Equation:** *"\textbf{Model Selection:} Call LLM model selector with $s$, plan, and $C_s$ to return structured execution request ($r_s$)."* Equation: $r_s = (\text{model specification, model family, implementation family, execution tool, expected outputs})$.
#
# ### 19. `run_dsge_lite_model` (Task 19 Orchestrator)
# *   **Inputs:** `calibration_params` (Dict), `study_config` (Dict), `assumption_registry` (Dict).
# *   **Processes:** Constructs canonical matrices, solves Blanchard-Kahn conditions via generalized Schur decomposition, simulates AR(1) shocks, and computes the analytic term structure.
# *   **Outputs:** `model_outputs` (Dict containing DataFrame and stats).
# *   **Data Transformation:** Transforms scalar calibration parameters into deterministic 12-step time-series matrices ($O_s$).
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 7 (Model Execution) for Application 1.
# *   **LaTeX Excerpt & Equations:** *"The DSGE-lite model is a linearized 3-equation New Keynesian framework..."*
#     $y_t = E_t y_{t+1} - \frac{1}{\sigma}(i_t - E_t \pi_{t+1}) + g_t$
#     $\pi_t = \beta E_t \pi_{t+1} + \kappa y_t + u_t$
#     $i_t = \rho_i i_{t-1} + (1-\rho_i)(\phi_\pi \pi_t + \phi_y y_t) + v_t$
#
# ### 20. `run_regime_switching_model` (Task 20 Orchestrator)
# *   **Inputs:** `study_config` (Dict), `assumption_registry` (Dict).
# *   **Processes:** Simulates the MS-VAR, applies the Hamilton filter for regime probabilities, and computes Basel III bank stress metrics using documented proxies.
# *   **Outputs:** `model_outputs` (Dict containing DataFrame and metrics).
# *   **Data Transformation:** Transforms transition probabilities and VAR coefficients into state paths and scalar stress metrics.
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 7 (Model Execution) for Application 2.
# *   **LaTeX Excerpt & Equations:** *"The regime-switching model is a 2-state Markov-Switching Vector Autoregression (MS-VAR)..."*
#     $Y_t = c_{S_t} + A_{1,S_t} Y_{t-1} + \epsilon_{S_t,t}$
#     $CET1_t = \frac{\text{Capital}_{t-1} - CL_t - ML_t}{\text{RWA}_{t-1} + 12.5 \times CL_t}$
#
# ### 21. `write_back_model_run` (Task 21 Orchestrator)
# *   **Inputs:** `driver` (Neo4j Driver), `scenario_id` (str), `spec_id` (str), `model_outputs` (Dict), `study_config` (Dict).
# *   **Processes:** Executes a single, atomic Cypher transaction to create the `ModelRun` node and unwind the `ModelOutputPoint` and `BankMetric` leaf nodes.
# *   **Outputs:** `write_back_status` (Dict containing `run_id`).
# *   **Data Transformation:** Transforms tabular and scalar mathematical outputs into permanent topological Graph nodes.
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 8 (Graph Write-Back) and Atomic Graph Mutations.
# *   **LaTeX Excerpt:** *"\textbf{Graph Write-Back:} Write \texttt{ModelRun} ($m_s$), \texttt{ForecastOutcome}, \texttt{ModelOutputPoint}, and \texttt{BankMetric} nodes to the graph."*
#
# ### 22. `retrieve_graph_context_post_execution` (Task 22 Orchestrator)
# *   **Inputs:** `driver` (Neo4j Driver), `scenario_id` (str), `run_id` (str), `study_config` (Dict).
# *   **Processes:** Executes a read-committed Cypher query for the full traceability path and summarizes the paths by extracting extremum values.
# *   **Outputs:** `post_run_paths` (List of strings).
# *   **Data Transformation:** Transforms the mutated graph topology into summarized string paths ($P_s^{\text{post}}$) to prevent LLM context overflow.
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 9 (Graph Retrieval Post-Execution).
# *   **LaTeX Excerpt:** *"\textbf{Graph Retrieval (Post-Execution):} Execute graph path query to return post-run graph paths ($P_s^{\text{post}}$)."*
#
# ### 23. `generate_report` (Task 23 Orchestrator)
# *   **Inputs:** `condition` (str), `scenario_text` (str), `evidence_spans` (List), `pre_paths` (List), `model_spec` (str), `exec_request` (Dict), `model_run` (Dict), `model_outputs` (Dict), `post_paths` (List), `llm_client` (Object), `study_config` (Dict).
# *   **Processes:** Injects the condition-specific information set into the prompt using a safe single-pass substitution and invokes the LLM.
# *   **Outputs:** `generated_report` (str).
# *   **Data Transformation:** Synthesizes a heterogeneous tuple of text, JSON, graph paths, and numerical tables into a plain-text economic narrative.
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 10 (Report Generation) and Epistemic Separation Prompting.
# *   **LaTeX Excerpt & Equation:** *"The proposed report is generated from $(s, E_s, P_s^{\text{pre}}, C_s, r_s, m_s, O_s, P_s^{\text{post}})$."*
#
# ### 24. `judge_report` (Task 24 Orchestrator)
# *   **Inputs:** `condition_information_set` (Dict), `generated_report` (str), `llm_client` (Object), `study_config` (Dict).
# *   **Processes:** Prompts the LLM, parses the JSON rubric, and structurally enforces the logic gate (forcing `model_grounding` to 0 for lean conditions).
# *   **Outputs:** `validated_scores` (Dict).
# *   **Data Transformation:** Transforms the unstructured text report into structured integer scores.
# *   **Role in Research Pipeline:** Implements Algorithm 1, Step 10 (Judging) and Logic Gate Verification.
# *   **LaTeX Excerpt:** *"Mentioning a model name without execution is insufficient and MUST receive a 0."*
#
# ### 25. `run_ai_economist_pipeline` (Task 25 Orchestrator)
# *   **Inputs:** `application_number` (int), `dataframes_dict` (Dict), `study_config` (Dict), `neo4j_driver` (Driver), `llm_client` (Object), `assumption_registry` (Dict).
# *   **Processes:** Sequentially executes Algorithm 1 (Steps 1-11), managing dynamic dispatch to runners and enforcing strict state isolation between conditions.
# *   **Outputs:** `results` (Dict).
# *   **Data Transformation:** Orchestrates the entire lifecycle of transformations from raw text to final judged reports.
# *   **Role in Research Pipeline:** Implements the master DAG Workflow Construction.
# *   **LaTeX Excerpt:** *"The pipeline is a Directed Acyclic Graph (DAG) orchestrating LLMs, database queries, and mathematical runners."*
#
# ### 26. `execute_and_validate_application_1` (Task 26 Orchestrator)
# *   **Inputs:** `dataframes_dict` (Dict), `study_config` (Dict), `neo4j_driver` (Driver), `llm_client` (Object), `assumption_registry` (Dict).
# *   **Processes:** Invokes the pipeline for Application 1 and asserts the strict methodological invariants (e.g., DSGE-lite selection, judge score patterns).
# *   **Outputs:** `results` (Dict).
# *   **Data Transformation:** Validates the outputs of Application 1 against expected ground truths.
# *   **Role in Research Pipeline:** Implements Experimental Validation for Application 1.
# *   **LaTeX Excerpt:** *"Application 1 concerns U.S. inflation persistence and Federal Reserve policy."*
#
# ### 27. `execute_and_validate_application_2` (Task 27 Orchestrator)
# *   **Inputs:** `dataframes_dict` (Dict), `study_config` (Dict), `neo4j_driver` (Driver), `llm_client` (Object), `assumption_registry` (Dict).
# *   **Processes:** Invokes the pipeline for Application 2, asserts invariants, and executes a Cypher query to verify `BankMetric` creation.
# *   **Outputs:** `results` (Dict).
# *   **Data Transformation:** Validates the outputs of Application 2 against expected ground truths.
# *   **Role in Research Pipeline:** Implements Experimental Validation for Application 2.
# *   **LaTeX Excerpt:** *"Application 2 concerns U.S. commercial real estate refinancing stress."*
#
# ### 28. `archive_provenance_package` (Task 28 Orchestrator)
# *   **Inputs:** `application_number` (int), `results` (Dict), `study_config` (Dict), `assumption_registry` (Dict), `base_archive_path` (str).
# *   **Processes:** Creates an immutable directory, serializes all artifacts, and computes SHA-256 hashes of the executed runner modules.
# *   **Outputs:** `archive_dir_path` (str).
# *   **Data Transformation:** Transforms in-memory Python objects into immutable, serialized disk files (JSON, CSV, TXT).
# *   **Role in Research Pipeline:** Implements Regulatory-Compliant Epistemic Traceability.
# *   **LaTeX Excerpt:** *"Ensure the report exposes enough info to trace the source of claims."*
#
# ### 29. `generate_validation_report` (Task 29 Orchestrator)
# *   **Inputs:** `app1_results` (Dict), `app2_results` (Dict), `study_config` (Dict), `archive_dir_path` (str).
# *   **Processes:** Summarizes the boolean checklist, computes numerical deviations, and conditionally issues the final reproduction claim.
# *   **Outputs:** `report_text` (str).
# *   **Data Transformation:** Transforms boolean checks and float deviations into a human-readable validation report.
# *   **Role in Research Pipeline:** Implements Systems Validation and Statistical Verification.
# *   **LaTeX Excerpt:** *"The implementer must verify that the system operated as intended. The study explicitly compares grounding structures, not just prose fluency."*
#
# ### 30. `execute_master_ai_economist_pipeline` (Top-Level Orchestrator)
# *   **Inputs:** `dataframes_dict` (Dict), `study_config` (Dict), `neo4j_driver` (Driver), `base_archive_path` (str).
# *   **Processes:** The ultimate entry point. It instantiates the global `assumption_registry`, executes Phase 1 (Infrastructure), Phase 2 (Data Prep), Phase 3 (Execution), and Phase 4 (Archival).
# *   **Outputs:** `master_results` (Dict).
# *   **Data Transformation:** Orchestrates the transformation of raw JSON/CSV inputs into the final archived provenance packages.
# *   **Role in Research Pipeline:** This callable *is* the complete "AI Economist Agent" framework, fusing all 9 disciplines into a singular, executable, institutional-grade system.
#
#
# <br><br>
#
# ## **Usage Example**
#
# Here is the granular, step-by-step guide to executing the end-to-end pipeline for **"AI Economist Agent: An Agentic Framework for Model-Grounded Economic Analysis with RAG, Knowledge Graphs, and Large Language Models"**. This example demonstrates how to synthetically generate the required Knowledge Graph input data, load the study configuration from a YAML file, and execute the full research pipeline using the `execute_master_ai_economist_pipeline` orchestrator.
#
# *Note: It is assumed that all the callables that are defined in this notebook are present in a single Jupyter notebook or execution environment, and that there is no separate folder with ".py" functions. It is also assumed that a valid `config.yaml` file containing the `study_config` dictionary is saved in the current working directory.*
#
# <br>
#
# ### **Step 1: Synthetic Data Generation (`dataframes_dict`)**
#
# The first requirement is a high-fidelity synthetic representation of the 12 raw input DataFrames. These datasets must adhere strictly to the schemas defined in the study, utilizing pandas extension types (e.g., `string`, `Int64`, `boolean`) to ensure perfect compatibility with the rigorous validation layer (Task 4).
#
# **Methodology:**
# 1.  **Schema Enforcement:** We explicitly cast columns to their required dtypes (`string`, `datetime64[ns]`, `float64`, `Int64`, `boolean`) to pass the strict `validate_dataframe_schema` checks.
# 2.  **Referential Integrity:** We ensure that foreign keys (e.g., `doc_id`, `spec_id`, `scenario_id`) perfectly match their corresponding primary keys to pass the `validate_referential_integrity` checks (Task 5).
# 3.  **Data Assembly:** We construct a master dictionary `dataframes_dict` containing all 12 DataFrames, ready for ingestion by the pipeline.
#
# ```python
# import pandas as pd
# import numpy as np
# from typing import Dict, Any
# from unittest.mock import MagicMock
#
# # Set deterministic seed for reproducibility
# np.random.seed(42)
#
# def generate_synthetic_kg_inputs() -> Dict[str, pd.DataFrame]:
#     """
#     Generates the 12 synthetic DataFrames required for the AI Economist Agent pipeline.
#
#     Purpose:
#         To create a high-fidelity mock dataset that mimics the schema and relational
#         properties of the Knowledge Graph inputs defined in Table 1 and Table 3 of
#         the manuscript. This allows for the execution of the research pipeline.
#
#     Inputs:
#         None.
#
#     Processes:
#         1.  Constructs raw dictionaries for each of the 12 required tables.
#         2.  Converts dictionaries to pandas DataFrames.
#         3.  Explicitly casts columns to strict pandas extension types (string, Int64, boolean)
#             and datetime64[ns] to satisfy the Task 4 schema validation.
#
#     Outputs:
#         Dict[str, pd.DataFrame]: A dictionary mapping the 12 table names to their
#                                  respective DataFrames.
#
#     Raises:
#         ValueError: If DataFrame construction fails.
#     """
#     # 1. Raw Source Documents
#     # Canonical provenance table for textual sources.
#     raw_source_documents_df = pd.DataFrame({
#         "doc_id": pd.Series(["DOC_MACRO_REV_2024", "DOC_FED_OUTLOOK_2024"], dtype="string"),
#         "title": pd.Series(["Macroeconomic Review and Stress Testing Analysis", "Federal Reserve Monetary Policy Outlook"], dtype="string"),
#         "publication_date": pd.to_datetime(["2024-05-15", "2024-06-01"]),
#         "document_type": pd.Series(["internal_report", "external_outlook"], dtype="string"),
#         "source_institution": pd.Series(["Internal Economics Division", "Federal Reserve Board"], dtype="string")
#     })
#
#     # 2. Raw Evidence Spans
#     # Primary textual evidence payload used by retrieval.
#     raw_evidence_spans_df = pd.DataFrame({
#         "evidence_id": pd.Series(["EV_1571", "EV_841", "EV_1161", "EV_1321", "EV_1801", "EV_721", "EV_1967", "EV_2028", "EV_2107", "EV_1197"], dtype="string"),
#         "doc_id": pd.Series(["DOC_MACRO_REV_2024", "DOC_MACRO_REV_2024", "DOC_MACRO_REV_2024", "DOC_MACRO_REV_2024", "DOC_FED_OUTLOOK_2024", "DOC_FED_OUTLOOK_2024", "DOC_MACRO_REV_2024", "DOC_MACRO_REV_2024", "DOC_FED_OUTLOOK_2024", "DOC_MACRO_REV_2024"], dtype="string"),
#         "span_text": pd.Series([
#             "A more restrictive policy path usually lifts nominal yields, although the term premium may vary by regime.",
#             "Global oil supply shocks tend to raise headline inflation before the pass-through fades.",
#             "Credit losses reduce common equity capital and lower the stressed CET1 ratio.",
#             "Declines in CRE values raise loss-given-default and can increase credit losses.",
#             "China growth surprises transmit to global trade volumes through supply-chain and commodity channels.",
#             "Funding stress and confidence effects can increase uninsured deposit outflows.",
#             "Funding stress and confidence effects can increase uninsured deposit outflows.",
#             "Deposit outflows increase net cash outflows and reduce liquidity coverage ratios.",
#             "Funding stress and confidence effects can increase uninsured deposit outflows.",
#             "Funding stress and confidence effects can increase uninsured deposit outflows."
#         ], dtype="string"),
#         "tags": pd.Series([
#             "monetary_policy,yields,term_premium", "inflation,supply_shock,oil", "credit_loss,bank_capital,cet1",
#             "cre,lgd,credit_loss", "global_growth,trade,commodities", "funding_stress,deposits,liquidity",
#             "funding_stress,deposits,liquidity", "deposits,liquidity,lcr", "funding_stress,deposits,liquidity",
#             "funding_stress,deposits,liquidity"
#         ], dtype="string"),
#         "synthetic_confidence": pd.Series([0.935, 0.933, 0.940, 0.939, 0.936, 0.932, 0.939, 0.938, 0.937, 0.931], dtype="float64"),
#         "char_start_position": pd.Series([1024, 2048, 3072, 4096, 512, 768, 1280, 1536, 640, 896], dtype="Int64"),
#         "char_end_position": pd.Series([1132, 2144, 3152, 4184, 620, 840, 1352, 1620, 712, 968], dtype="Int64")
#     })
#
#     # 3. Raw Temporal Facts
#     # Time-bounding evidence spans: observation time vs validity window.
#     raw_temporal_facts_df = pd.DataFrame({
#         "fact_id": pd.Series(["TF_1571_01", "TF_841_01", "TF_1161_01", "TF_1321_01", "TF_1801_01", "TF_721_01", "TF_1967_01", "TF_2028_01", "TF_2107_01", "TF_1197_01"], dtype="string"),
#         "evidence_id": pd.Series(["EV_1571", "EV_841", "EV_1161", "EV_1321", "EV_1801", "EV_721", "EV_1967", "EV_2028", "EV_2107", "EV_1197"], dtype="string"),
#         "observation_time": pd.to_datetime(["2024-04-30T00:00:00Z", "2024-03-31T00:00:00Z", "2024-04-15T00:00:00Z", "2024-04-20T00:00:00Z", "2024-05-10T00:00:00Z", "2024-05-05T00:00:00Z", "2024-04-25T00:00:00Z", "2024-04-28T00:00:00Z", "2024-05-02T00:00:00Z", "2024-04-18T00:00:00Z"], utc=True),
#         "validity_start": pd.to_datetime(["2024-05-01T00:00:00Z", "2024-04-01T00:00:00Z", "2024-04-15T00:00:00Z", "2024-04-20T00:00:00Z", "2024-05-10T00:00:00Z", "2024-05-05T00:00:00Z", "2024-04-25T00:00:00Z", "2024-04-28T00:00:00Z", "2024-05-02T00:00:00Z", "2024-04-18T00:00:00Z"], utc=True),
#         "validity_end": pd.to_datetime(["2025-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2025-06-30T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z", "2024-12-31T00:00:00Z"], utc=True),
#         "temporal_description": pd.Series(["Yield response to policy path observed in Q2 2024 regime", "Oil supply shock pass-through window", "CET1 capital impact observation", "CRE valuation decline period", "China growth spillover transmission window", "Funding stress confidence channel activation", "Deposit outflow stress episode", "Liquidity coverage stress measurement", "Uninsured deposit flight window", "Bank funding pressure period"], dtype="string")
#     })
#
#     # 4. Raw Shocks
#     # Encodes scenario shock drivers.
#     raw_shocks_df = pd.DataFrame({
#         "shock_id": pd.Series(["SHOCK_MONETARY_TIGHT", "SHOCK_COST_PUSH"], dtype="string"),
#         "scenario_id": pd.Series(["SCEN_APP1_INFLATION", "SCEN_APP1_INFLATION"], dtype="string"),
#         "shock_description": pd.Series(["Restrictive monetary policy path lifting nominal yields", "Persistent services inflation cost-push shock"], dtype="string"),
#         "shock_type": pd.Series(["monetary_policy", "supply_side"], dtype="string"),
#         "severity_level": pd.Series([3, 2], dtype="Int64")
#     })
#
#     # 5. Raw Variable Concepts
#     # Canonical variable dictionary.
#     raw_variable_concepts_df = pd.DataFrame({
#         "concept_id": pd.Series(["VAR_INFLATION", "VAR_FFR", "VAR_10Y_YIELD", "VAR_OUTPUT_GAP"], dtype="string"),
#         "scenario_id": pd.Series(["SCEN_APP1_INFLATION", "SCEN_APP1_INFLATION", "SCEN_APP1_INFLATION", "SCEN_APP1_INFLATION"], dtype="string"),
#         "variable_name": pd.Series(["U.S. headline inflation", "Federal funds rate", "U.S. ten-year yield", "U.S. output gap"], dtype="string"),
#         "variable_symbol": pd.Series(["π_t", "i_t", "i_t^(10)", "y_t"], dtype="string"),
#         "measurement_unit": pd.Series(["percent_annual", "percent_annual", "percent_annual", "percent_deviation"], dtype="string"),
#         "is_target_variable": pd.Series([True, True, True, True], dtype="boolean")
#     })
#
#     # 6. Raw Models
#     # Abstract model families.
#     raw_models_df = pd.DataFrame({
#         "model_id": pd.Series(["MOD_DSGE_LITE", "MOD_VAR", "MOD_REGIME_SWITCH"], dtype="string"),
#         "model_name": pd.Series(["Dynamic Stochastic General Equilibrium (Lite)", "Vector Autoregression", "Markov-Switching Vector Autoregression"], dtype="string"),
#         "model_category": pd.Series(["structural", "reduced_form", "nonlinear"], dtype="string"),
#         "complexity_level": pd.Series([3, 1, 4], dtype="Int64")
#     })
#
#     # 7. Raw Model Specifications
#     # The approved, governed unit the LLM is allowed to select.
#     raw_model_specifications_df = pd.DataFrame({
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_VAR_001", "MSPEC_REGIME_SWITCHING_005"], dtype="string"),
#         "model_id": pd.Series(["MOD_DSGE_LITE", "MOD_VAR", "MOD_REGIME_SWITCH"], dtype="string"),
#         "spec_description": pd.Series(["3-equation New Keynesian model with AR(1) shocks and term structure.", "Reduced-form Vector Autoregression with 2 lags.", "2-state Markov-Switching VAR for normal and stress dynamics."], dtype="string"),
#         "calibration_params_json": pd.Series(['{"sigma": 1.5, "beta": 0.99, "kappa": 0.15, "phi_pi": 1.5, "phi_y": 0.125, "rho_i": 0.8, "rho_g": 0.9, "rho_u": 0.85, "rho_v": 0.7, "rho_tau": 0.6}', '{"lag_order": 2}', '{"p11": 0.95, "p22": 0.85, "n_regimes": 2}'], dtype="string")
#     })
#
#     # 8. Raw Model Equations
#     # Stores approved equations for auditability and governance.
#     raw_model_equations_df = pd.DataFrame({
#         "eq_id": pd.Series(["EQ_IS_CURVE", "EQ_NK_PHILLIPS", "EQ_TAYLOR_RULE", "EQ_TERM_STRUCTURE", "EQ_MSVAR_STATE"], dtype="string"),
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_REGIME_SWITCHING_005"], dtype="string"),
#         "equation_name": pd.Series(["IS Curve", "New Keynesian Phillips Curve", "Monetary Policy Rule (Taylor Rule)", "Term Structure Equation", "MS-VAR State Equation"], dtype="string"),
#         "latex_equation": pd.Series([r"y_t = E_t y_{t+1} - \frac{1}{\sigma}(i_t - E_t \pi_{t+1}) + g_t", r"\pi_t = \beta E_t \pi_{t+1} + \kappa y_t + u_t", r"i_t = \rho_i i_{t-1} + (1-\rho_i)(\phi_\pi \pi_t + \phi_y y_t) + v_t", r"i_t^{(10)} = \frac{1}{10} \sum_{j=0}^{9} E_t i_{t+j} + \tau_t", r"Y_t = c_{S_t} + A_{1,S_t} Y_{t-1} + \epsilon_{S_t,t}"], dtype="string"),
#         "equation_order": pd.Series([1, 2, 3, 4, 1], dtype="Int64")
#     })
#
#     # 9. Raw Model Assumptions
#     # Stores modeling assumptions distinctly from equations.
#     raw_model_assumptions_df = pd.DataFrame({
#         "assumption_id": pd.Series(["ASSUM_LINEAR", "ASSUM_AR1_SHOCKS", "ASSUM_MARKOV_FIRST_ORDER"], dtype="string"),
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_REGIME_SWITCHING_005"], dtype="string"),
#         "assumption_text": pd.Series(["Model is linearized around a zero steady state.", "Exogenous shocks follow AR(1) processes.", "Regime transitions follow a first-order Markov process."], dtype="string"),
#         "assumption_type": pd.Series(["functional_form", "stochastic_process", "stochastic_process"], dtype="string")
#     })
#
#     # 10. Raw Model Documents
#     # Governance / provenance documents for model approval.
#     raw_model_documents_df = pd.DataFrame({
#         "model_document_id": pd.Series(["MDOC_DSGE_001", "MDOC_MSVAR_001"], dtype="string"),
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_REGIME_SWITCHING_005"], dtype="string"),
#         "title": pd.Series(["DSGE Model Risk Validation Report", "MS-VAR Stress Testing Methodology"], dtype="string"),
#         "document_text": pd.Series(["Approved for inflation scenario analysis.", "Approved for CRE stress testing."], dtype="string"),
#         "version": pd.Series(["v1.2", "v2.0"], dtype="string")
#     })
#
#     # 11. Raw Implementation Functions
#     # The mapping from approved spec -> executable function family.
#     raw_implementation_functions_df = pd.DataFrame({
#         "impl_id": pd.Series(["IMPL_DSGE_RUNNER", "IMPL_MSVAR_RUNNER"], dtype="string"),
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_REGIME_SWITCHING_005"], dtype="string"),
#         "execution_tool_name": pd.Series(["dsge_lite_runner", "regime_switching_runner"], dtype="string"),
#         "solver_method": pd.Series(["Blanchard-Kahn", "Hamilton Filter"], dtype="string"),
#         "horizon_steps": pd.Series([12, 12], dtype="Int64"),
#         "python_module_path": pd.Series(["computational_layer.dsge_lite", "computational_layer.regime_switching"], dtype="string")
#     })
#
#     # 12. Raw Model Variable Relationships
#     # Explicit join table that makes model selection safe and queryable.
#     raw_model_variable_relationships_df = pd.DataFrame({
#         "relationship_id": pd.Series(["REL_0001", "REL_0002", "REL_0003", "REL_0004"], dtype="string"),
#         "spec_id": pd.Series(["MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004", "MSPEC_DSGE_LITE_004"], dtype="string"),
#         "concept_id": pd.Series(["VAR_INFLATION", "VAR_FFR", "VAR_10Y_YIELD", "VAR_OUTPUT_GAP"], dtype="string"),
#         "relationship_type": pd.Series(["OUTPUTS_VARIABLE", "OUTPUTS_VARIABLE", "OUTPUTS_VARIABLE", "OUTPUTS_VARIABLE"], dtype="string"),
#         "is_endogenous": pd.Series([True, True, True, True], dtype="boolean"),
#         "variable_role": pd.Series(["forward_looking", "forward_looking", "expectation", "forward_looking"], dtype="string")
#     })
#
#     # Assemble the master dictionary
#     dataframes_dict = {
#         "raw_source_documents_df": raw_source_documents_df,
#         "raw_evidence_spans_df": raw_evidence_spans_df,
#         "raw_temporal_facts_df": raw_temporal_facts_df,
#         "raw_shocks_df": raw_shocks_df,
#         "raw_variable_concepts_df": raw_variable_concepts_df,
#         "raw_models_df": raw_models_df,
#         "raw_model_specifications_df": raw_model_specifications_df,
#         "raw_model_equations_df": raw_model_equations_df,
#         "raw_model_assumptions_df": raw_model_assumptions_df,
#         "raw_model_documents_df": raw_model_documents_df,
#         "raw_implementation_functions_df": raw_implementation_functions_df,
#         "raw_model_variable_relationships_df": raw_model_variable_relationships_df
#     }
#
#     return dataframes_dict
#
# # Generate the synthetic dataset dictionary
# dataframes_dict = generate_synthetic_kg_inputs()
#
# # Preview the data to verify schema compliance
# print("Synthetic Knowledge Graph Inputs Generated Successfully.")
# print(f"Total DataFrames created: {len(dataframes_dict)}")
# print("\nPreview of raw_evidence_spans_df:")
# print(dataframes_dict["raw_evidence_spans_df"].head(2))
# ```
#
# <br>
#
# ### **Step 2: Loading the Configuration (`config.yaml`)**
#
# The study relies on a deterministic configuration file (`config.yaml`) that defines all hyperparameters, LLM settings, and mathematical calibrations. We assume this file exists in the working directory and contains the `study_config` dictionary defined in the prompt.
#
# **Methodology:**
# 1.  **File I/O:** Open `config.yaml` in read mode.
# 2.  **Parsing:** Use `yaml.safe_load` to convert the YAML structure into a nested Python dictionary.
# 3.  **Verification:** Print keys to ensure the file was loaded correctly.
#
# ```python
# import yaml
#
# def load_study_configuration(filepath: str = "config.yaml") -> Dict[str, Any]:
#     """
#     Loads the study configuration parameters from a YAML file into a Python dictionary.
#
#     Purpose:
#         To ingest the deterministic hyperparameters, LLM settings, and mathematical
#         calibrations defined in the external configuration file. This ensures
#         reproducibility by separating code from configuration.
#
#     Inputs:
#         filepath (str): The relative or absolute path to the YAML configuration file.
#                         Default is "config.yaml".
#
#     Processes:
#         1.  File Access: Attempts to open the specified file in read mode.
#         2.  Parsing: Uses PyYAML's safe_load to parse the YAML structure.
#         3.  Validation: Catches file existence errors and parsing errors.
#
#     Outputs:
#         Dict[str, Any]: A nested dictionary containing the study configuration.
#                         Returns an empty dictionary if the file is not found (fallback).
#
#     Raises:
#         TypeError: If filepath is not a string.
#         yaml.YAMLError: If the file contains invalid YAML syntax.
#     """
#     # Validate input type to ensure string path
#     if not isinstance(filepath, str):
#         # Raise TypeError if the path is not a string
#         raise TypeError(f"filepath must be a string, got {type(filepath)}.")
#
#     try:
#         # Open the file stream in read mode
#         with open(filepath, "r") as file:
#             # Parse the YAML content safely into a Python dictionary
#             config = yaml.safe_load(file)
#
#         # Log success to console
#         print(f"\nSuccessfully loaded configuration from {filepath}")
#
#         return config
#
#     except FileNotFoundError:
#         # Fallback for demonstration if file doesn't exist in this specific run environment
#         # In a real scenario, this would raise an error, but per instructions we handle it gracefully.
#         print(f"\nWarning: {filepath} not found. Please ensure the file exists.")
#         # Return an empty dictionary as a fallback
#         return {}
#     except yaml.YAMLError as e:
#         # Handle parsing errors explicitly
#         print(f"\nError parsing YAML file {filepath}: {e}")
#         # Re-raise the exception to halt execution
#         raise
#
# # Load the configuration
# # Note: Ensure 'config.yaml' is in your working directory with the content provided previously.
# study_config = load_study_configuration()
# ```
#
# <br>
#
# ### **Step 3: Executing the Pipeline (`execute_master_ai_economist_pipeline`)**
#
# With the data (`dataframes_dict`) and configuration (`study_config`) in memory, we invoke the top-level orchestrator. This function manages the entire lifecycle: infrastructure validation, data cleansing, synthetic scaling, application execution (DSGE-lite and MS-VAR), and final archival.
#
# *Note: For this example to run without crashing in a standard Python environment lacking a live Neo4j database and a local Llama 3.1 endpoint, we instantiate mock objects for the `neo4j_driver` and `llm_client`. In a production environment, these would be live connection objects.*
#
# **Methodology:**
# 1.  **Mocking Infrastructure:** Instantiate `MagicMock` objects for the database driver and LLM client to allow the pipeline to execute its logic without external dependencies.
# 2.  **Function Call:** Pass the DataFrames, configuration, and mock objects to `execute_master_ai_economist_pipeline`.
# 3.  **Output Handling:** The function returns a master dictionary containing all intermediate logs, application results, and the final validation report.
#
# ```python
# # ==============================================================================
# # Execution of the End-to-End Study Pipeline
# # ==============================================================================
#
# if __name__ == "__main__":
#     # Ensure we have valid inputs before running
#     if dataframes_dict and study_config:
#
#         print("\nInitiating AI Economist Agent Study Pipeline...")
#
#         # Instantiate mock objects for the external infrastructure dependencies
#         # This allows the example to run without a live Neo4j database or LLM endpoint
#         mock_neo4j_driver = MagicMock()
#
#         # Execute the master pipeline orchestrator
#         # This will print progress logs for each phase (Validation, Cleansing, Execution, Archival)
#         try:
#             # Note: execute_master_ai_economist_pipeline is assumed to be in the namespace
#             # from the previous task implementations.
#             master_artifacts = execute_master_ai_economist_pipeline(
#                 dataframes_dict=dataframes_dict,
#                 study_config=study_config,
#                 neo4j_driver=mock_neo4j_driver,
#                 base_archive_path="./provenance_archives"
#             )
#
#             # ==============================================================================
#             # Inspecting the Outputs
#             # ==============================================================================
#
#             print("\n" + "="*80)
#             print("STUDY EXECUTION COMPLETE")
#             print("="*80)
#
#             # 1. Accessing Data Preparation Logs
#             print("\n[Data Preparation Phase]")
#             if "data_preparation_logs" in master_artifacts:
#                 logs = master_artifacts["data_preparation_logs"]
#                 print(f"Identifier Audit Log Entries: {len(logs.get('identifier_audit_log', []))}")
#                 print(f"Tag Lineage Log Entries: {len(logs.get('tag_lineage_log', []))}")
#
#             # 2. Accessing Application 1 Results (DSGE-lite)
#             print("\n[Application 1: U.S. Inflation Persistence]")
#             if "application_1_results" in master_artifacts:
#                 app1_res = master_artifacts["application_1_results"]
#                 print("Model Selected:", app1_res.get("execution_request", {}).get("model_specification"))
#                 print("Judge Scores (Model-Grounded):", app1_res.get("scores_model_grounded"))
#
#             # 3. Accessing Application 2 Results (MS-VAR)
#             print("\n[Application 2: U.S. CRE Refinancing Stress]")
#             if "application_2_results" in master_artifacts:
#                 app2_res = master_artifacts["application_2_results"]
#                 print("Model Selected:", app2_res.get("execution_request", {}).get("model_specification"))
#                 print("Judge Scores (Model-Grounded):", app2_res.get("scores_model_grounded"))
#
#             # 4. Printing the Final Validation Report
#             print("\n" + "="*80)
#             print("FINAL REPRODUCTION VALIDATION REPORT")
#             print("="*80)
#             print(master_artifacts.get("final_validation_report", "Report not generated."))
#
#         except Exception as e:
#             print(f"\nPipeline execution failed: {e}")
#             # In a real scenario, the traceback would be logged.
#
#     else:
#         print("Error: Missing data or configuration. Cannot proceed.")
# ```
#
# <br>
#
# ### **Conclusion**
#
# This usage example demonstrates the rigorous, end-to-end operationalization of the "AI Economist Agent" framework. By synthetically generating the exact Knowledge Graph schemas, loading the deterministic configuration, and invoking the master orchestrator, we have executed a pipeline that strictly enforces epistemic traceability. The framework successfully isolates the LLM's qualitative narrative generation from the deterministic mathematical execution of the DSGE-lite and MS-VAR models, ensuring that all quantitative claims are grounded in auditable, reproducible artifacts. The resulting provenance package, complete with cryptographic hashes of the runtime environment and a detailed validation report, satisfies the highest institutional standards for regulatory compliance and methodological transparency in automated economic intelligence.
#
# <br><br>
#
# ## **Implemented Callables**

# %%
# Task 1 — Validate the study configuration dictionary for completeness and internal consistency

# ===============================================================================================
# Task 1: Validate the study configuration dictionary for completeness and internal consistency
# ===============================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Step 1: Validate LLM determinism and endpoint configuration
# -------------------------------------------------------------------------------------------------------------------------------
# Define the globally accessible, frozen expected LLM schema mapping each required parameter key to its expected value
EXPECTED_LLM_SCHEMA: Dict[str, Any] = {
    # Map model name parameter to expected string value
    "model_name": "llama3.1:8b",
    # Map local API endpoint parameter to expected URL string
    "api_endpoint": "http://localhost:11434/v1/chat/completions",
    # Map temperature parameter to expected integer zero
    "temperature": 0,
    # Map seed parameter to expected integer forty-two
    "seed": 42,
    # Map top_p parameter to expected float one point zero
    "top_p": 1.0,
    # Map top_k parameter to expected integer one
    "top_k": 1,
    # Map max_tokens parameter to expected integer two thousand forty-eight
    "max_tokens": 2048
}

def validate_llm_determinism(study_config: Dict[str, Any]) -> None:
    """
    Validates that the local LLM configuration adheres strictly to deterministic parameters.

    This function extracts the 'llm_execution_parameters' sub-dictionary from the main
    study configuration and validates its keys and values against the globally defined
    EXPECTED_LLM_SCHEMA constant. It employs numerical coercion for floats and integers to
    prevent false mismatches and aggregates all validation errors before raising a ValueError.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The complete, nested study configuration dictionary.

    Returns
    -------
    None

    Raises
    ------
    TypeError
        If the study_config is not a dictionary.
    KeyError
        If the 'llm_execution_parameters' section is missing from the configuration.
    ValueError
        If any configuration parameter deviates from the expected deterministic settings.
    """
    # Validate that the study_config parameter is indeed a dictionary
    if not isinstance(study_config, dict):
        # Raise TypeError if the input is of an invalid type
        raise TypeError("Input 'study_config' must be a dictionary.")
    # Check if the required llm_execution_parameters key is present in study_config
    if "llm_execution_parameters" not in study_config:
        # Raise KeyError if the nested parameters dictionary is missing
        raise KeyError("Missing required key 'llm_execution_parameters' in study_config.")
    # Extract the nested LLM execution parameters dictionary
    llm_params: Any = study_config["llm_execution_parameters"]
    # Validate that the extracted parameters are represented as a dictionary
    if not isinstance(llm_params, dict):
        # Raise TypeError if the parameters are not a dictionary
        raise TypeError("Section 'llm_execution_parameters' must be a dictionary.")
    # Initialize an empty list to accumulate all validation error strings
    error_list: List[str] = []
    # Iterate over the expected schema keys and values in EXPECTED_LLM_SCHEMA
    for key, expected_val in EXPECTED_LLM_SCHEMA.items():
        # Check if the expected parameter key exists in the configuration
        if key not in llm_params:
            # Append an error message for the missing configuration key
            error_list.append(f"Missing parameter: '{key}' (Expected: {expected_val})")
            # Continue to the next key-value pair in the schema
            continue
        # Extract the observed configuration value from the parameters
        observed_val: Any = llm_params[key]
        # Check if the expected value is numeric (int or float)
        if isinstance(expected_val, (int, float)):
            # Check if the observed value is also numeric (int or float)
            if not isinstance(observed_val, (int, float)):
                # Append a type mismatch error message if the observed value is not numeric
                error_list.append(f"Type mismatch for '{key}': Expected numeric, got {type(observed_val).__name__}")
                # Continue to the next key-value pair in the schema
                continue
            # Coerce the expected value to a floating point representation
            float_expected: float = float(expected_val)
            # Coerce the observed value to a floating point representation
            float_observed: float = float(observed_val)
            # Compare the floats to determine if they deviate from the expected value
            if float_expected != float_observed:
                # Append an error message detailing the numeric parameter mismatch
                error_list.append(f"Value mismatch for '{key}': Expected {expected_val}, got {observed_val}")
        # Process the comparison as a string-based or literal value if it is non-numeric
        else:
            # Compare the observed string value verbatim against the expected string
            if expected_val != observed_val:
                # Append an error message detailing the string parameter mismatch
                error_list.append(f"Value mismatch for '{key}': Expected '{expected_val}', got '{observed_val}'")
    # Check if the error list contains any collected validation failures
    if error_list:
        # Construct a detailed error report combining all failure strings
        detailed_error: str = "LLM configuration validation failed:\n" + "\n".join(error_list)
        # Raise a ValueError to halt the pipeline and enforce determinism
        raise ValueError(detailed_error)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Step 2: Validate horizon alignment across all model parameters
# -------------------------------------------------------------------------------------------------------------------------------
def validate_horizon_alignment(study_config: Dict[str, Any], raw_implementation_functions_df: pd.DataFrame) -> None:
    """
    Validates that the horizon steps parameter is uniformly set to 12 across all models.

    This function checks the DSGE parameters, regime-switching parameters, computational
    solver parameters, and the relevant rows of the implementation functions DataFrame
    to ensure strict comparability across the experimental conditions.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    raw_implementation_functions_df : pd.DataFrame
        The DataFrame containing the model implementation mappings.

    Raises
    ------
    KeyError
        If required configuration sections or keys are missing.
    ValueError
        If any horizon parameter deviates from the required value of 12.
    """
    # Log the initiation of the horizon alignment validation step
    logger.info("Starting validation of horizon alignment across all model parameters.")

    # Define the strict horizon value mandated by the manuscript
    REQUIRED_HORIZON: int = 12

    # Define the configuration paths to check, mapping section names to their specific keys
    config_paths: List[Tuple[str, str]] = [
        ("dsge_lite_parameters", "horizon_steps"),
        ("regime_switching_parameters", "horizon_steps"),
        ("computational_solver_parameters", "model_horizon_steps")
    ]

    # Iterate through the defined configuration paths to validate scalar dictionary values
    for section, key in config_paths:
        # Verify the section exists in the master configuration
        if section not in study_config:
            # Raise an error if a critical section is missing
            raise KeyError(f"Configuration section '{section}' is missing.")
        # Verify the specific horizon key exists within the section
        if key not in study_config[section]:
            # Raise an error if the horizon key is missing
            raise KeyError(f"Key '{key}' is missing from configuration section '{section}'.")

        # Extract the observed horizon value
        observed_horizon = study_config[section][key]

        # Assert that the observed horizon exactly matches the required horizon
        if observed_horizon != REQUIRED_HORIZON:
            # Raise a ValueError to halt execution on misalignment
            raise ValueError(
                f"Horizon misalignment in '{section}.{key}': "
                f"Expected {REQUIRED_HORIZON}, Observed {observed_horizon}."
            )

    # Define the list of active execution tools relevant to this specific study
    active_runners: List[str] = ["dsge_lite_runner", "regime_switching_runner"]

    # Verify that the required columns exist in the implementation functions DataFrame
    if not {"execution_tool_name", "horizon_steps"}.issubset(raw_implementation_functions_df.columns):
        # Raise an error if the DataFrame schema is malformed
        raise ValueError("Implementation functions DataFrame is missing required columns for horizon validation.")

    # Create a boolean mask to filter the DataFrame for only the active study runners
    mask = raw_implementation_functions_df["execution_tool_name"].isin(active_runners)
    # Apply the mask to extract the relevant subset of the DataFrame
    relevant_rows = raw_implementation_functions_df[mask]

    # Check if the filtered subset is empty, which indicates a critical data loading error
    if relevant_rows.empty:
        # Raise an error because the active runners must exist in the catalogue
        raise ValueError("No active runners found in the implementation functions DataFrame.")

    # Extract the horizon steps column as a pandas Series
    horizon_series = relevant_rows["horizon_steps"]

    # Check for any null values in the relevant horizon steps, which are unacceptable
    if horizon_series.isnull().any():
        # Raise an error if nulls are detected in the active runner horizons
        raise ValueError("Null horizon values detected for active runners in the implementation functions DataFrame.")

    # Verify that all values in the filtered horizon series equal the required horizon
    if not (horizon_series == REQUIRED_HORIZON).all():
        # Raise a ValueError to halt execution, as this breaks experimental comparability
        raise ValueError(
            f"Horizon misalignment in implementation functions DataFrame. "
            f"All active runners must have horizon_steps = {REQUIRED_HORIZON}."
        )

    # Log the successful completion of the horizon alignment validation
    logger.info("Horizon alignment validated successfully across all parameters.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Step 3: Validate Markov transition matrix mathematical consistency
# -------------------------------------------------------------------------------------------------------------------------------
def validate_markov_transition_matrix(study_config: Dict[str, Any]) -> None:
    """
    Validates the mathematical consistency of the Markov transition matrix.

    This function extracts the staying probabilities from the regime-switching
    parameters, constructs the 2x2 stochastic matrix, and verifies that all
    elements are valid probabilities [0, 1] and that each row sums to exactly 1.0.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary.

    Raises
    ------
    KeyError
        If the regime-switching parameters or specific probability keys are missing.
    ValueError
        If the constructed matrix violates stochastic matrix properties.
    """
    # Log the initiation of the Markov transition matrix validation step
    logger.info("Starting validation of Markov transition matrix mathematical consistency.")

    # Verify the regime-switching section exists in the configuration
    if "regime_switching_parameters" not in study_config:
        # Raise an error if the section is missing
        raise KeyError("Configuration section 'regime_switching_parameters' is missing.")

    # Bind the regime-switching parameters to a local variable
    rs_params: Dict[str, Any] = study_config["regime_switching_parameters"]

    # Verify the specific staying probability keys exist
    if "p11" not in rs_params or "p22" not in rs_params:
        # Raise an error if the probabilities are missing
        raise KeyError("Keys 'p11' and/or 'p22' are missing from 'regime_switching_parameters'.")

    # Extract the probability of remaining in the normal regime
    p11: float = float(rs_params["p11"])
    # Extract the probability of remaining in the stress regime
    p22: float = float(rs_params["p22"])

    # Construct the 2x2 Markov transition matrix using NumPy
    # Equation: P = [[p11, 1-p11], [1-p22, p22]]
    transition_matrix: np.ndarray = np.array([
        [p11, 1.0 - p11],
        [1.0 - p22, p22]
    ], dtype=np.float64)

    # Validate that all elements in the matrix lie within the closed interval [0, 1]
    if np.any((transition_matrix < 0.0) | (transition_matrix > 1.0)):
        # Raise an error if any probability is out of bounds
        raise ValueError(
            f"Markov transition matrix contains invalid probabilities (outside [0, 1]):\n{transition_matrix}"
        )

    # Compute the sum of each row along the second axis (axis=1)
    row_sums: np.ndarray = np.sum(transition_matrix, axis=1)

    # Define the expected row sums as a vector of ones
    expected_sums: np.ndarray = np.ones(2, dtype=np.float64)

    # Validate that each row sums to exactly 1.0, using a strict floating-point tolerance
    if not np.allclose(row_sums, expected_sums, atol=1e-10):
        # Raise an error if the matrix is not strictly stochastic
        raise ValueError(
            f"Markov transition matrix rows do not sum to 1.0. Observed sums: {row_sums}"
        )

    # Log the successful completion of the Markov matrix validation
    logger.info("Markov transition matrix mathematical consistency validated successfully.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def validate_study_configuration(study_config: Dict[str, Any], raw_implementation_functions_df: pd.DataFrame) -> None:
    """
    Orchestrates the validation of the study configuration dictionary.

    This function acts as the entry point for Task 1, sequentially executing the
    validations for LLM determinism, horizon alignment, and Markov matrix consistency.
    It ensures the foundational configuration is mathematically and structurally sound
    before downstream pipeline execution.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    raw_implementation_functions_df : pd.DataFrame
        The DataFrame containing the model implementation mappings.

    Raises
    ------
    Exception
        Bubbles up any KeyError or ValueError raised by the subordinate validation steps.
    """
    # Log the initiation of the overarching Task 1 orchestrator
    logger.info("=== Task 1: Initiating study configuration validation ===")

    # Execute Step 1: Validate LLM determinism and endpoint configuration
    validate_llm_determinism(study_config=study_config)

    # Execute Step 2: Validate horizon alignment across all model parameters
    validate_horizon_alignment(
        study_config=study_config,
        raw_implementation_functions_df=raw_implementation_functions_df
    )

    # Execute Step 3: Validate Markov transition matrix mathematical consistency
    validate_markov_transition_matrix(study_config=study_config)

    # Log the successful completion of all Task 1 validations
    logger.info("=== Task 1: Study configuration validation completed successfully ===")

# %%
# Task 2 — Validate retrieval and graph search policies

# ==============================================================================
# Task 2: Validate retrieval and graph search policies
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Step 1: Confirm text retrieval policy matches manuscript specification
# -------------------------------------------------------------------------------------------------------------------------------
def validate_text_retrieval_policy(study_config: Dict[str, Any]) -> None:
    """
    Validates that the text retrieval policy strictly matches the manuscript specification.

    This function ensures that the 'text_evidence_top_k' parameter is exactly 6,
    as mandated by Tables 6 and 10 in the manuscript. It enforces strict type
    checking to prevent loose deserialization errors.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary containing retrieval parameters.

    Raises
    ------
    KeyError
        If the retrieval parameters section or the specific top_k key is missing.
    TypeError
        If the top_k parameter is not strictly an integer.
    ValueError
        If the top_k parameter does not exactly equal 6.
    """
    # Log the initiation of the text retrieval policy validation
    logger.info("Starting validation of text retrieval policy (top-k constraint).")

    # Define the exact required number of retrieved evidence spans per the manuscript
    REQUIRED_TOP_K: int = 6

    # Verify the existence of the retrieval graph parameters section
    if "retrieval_graph_parameters" not in study_config:
        # Raise an error to halt execution if the section is missing
        raise KeyError("Configuration section 'retrieval_graph_parameters' is missing.")

    # Bind the retrieval parameters to a local variable for clean access
    retrieval_params: Dict[str, Any] = study_config["retrieval_graph_parameters"]

    # Verify the existence of the specific top_k key
    if "text_evidence_top_k" not in retrieval_params:
        # Raise an error if the critical retrieval bound is undefined
        raise KeyError("Key 'text_evidence_top_k' is missing from retrieval parameters.")

    # Extract the observed top_k value from the configuration
    observed_top_k: Any = retrieval_params["text_evidence_top_k"]

    # Enforce strict type checking to ensure the value is a native Python integer
    if not isinstance(observed_top_k, int):
        # Raise a TypeError to prevent downstream slicing bugs caused by strings or floats
        raise TypeError(
            f"Parameter 'text_evidence_top_k' must be strictly of type int. "
            f"Observed type: {type(observed_top_k).__name__}."
        )

    # Enforce strict value checking against the manuscript's mandate
    if observed_top_k != REQUIRED_TOP_K:
        # Raise a ValueError if the retrieval breadth deviates from the experimental design
        raise ValueError(
            f"Text retrieval policy violation: 'text_evidence_top_k' must exactly equal {REQUIRED_TOP_K}. "
            f"Observed value: {observed_top_k}."
        )

    # Log the successful validation of the text retrieval policy
    logger.info(f"Text retrieval policy validated successfully. Top-K is strictly {REQUIRED_TOP_K}.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Step 2: Confirm graph traversal constraints are enforced
# -------------------------------------------------------------------------------------------------------------------------------
def validate_graph_traversal_constraints(study_config: Dict[str, Any]) -> None:
    """
    Validates that the Knowledge Graph traversal constraints are strictly enforced.

    This function checks that unconstrained neighborhood expansion is disabled,
    task-specific queries are required, and write-back transactions are enabled,
    using strict boolean identity comparisons to prevent truthiness bugs.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary containing retrieval parameters.

    Raises
    ------
    KeyError
        If the retrieval parameters section or any specific constraint key is missing.
    TypeError
        If any constraint parameter is not strictly a boolean.
    ValueError
        If any constraint parameter deviates from its required boolean state.
    """
    # Log the initiation of the graph traversal constraints validation
    logger.info("Starting validation of Knowledge Graph traversal constraints.")

    # Verify the existence of the retrieval graph parameters section
    if "retrieval_graph_parameters" not in study_config:
        # Raise an error to halt execution if the section is missing
        raise KeyError("Configuration section 'retrieval_graph_parameters' is missing.")

    # Bind the retrieval parameters to a local variable for clean access
    retrieval_params: Dict[str, Any] = study_config["retrieval_graph_parameters"]

    # Define the declarative schema of required graph constraints and their exact boolean states
    required_constraints: Dict[str, bool] = {
        "allow_neighborhood_expansion": False,
        "require_task_specific_queries": True,
        "enable_write_back_transactions": True
    }

    # Initialize an empty list to collect any constraint violations
    constraint_violations: List[str] = []

    # Iterate through the required constraints to verify each flag
    for key, required_state in required_constraints.items():
        # Verify the existence of the specific constraint key
        if key not in retrieval_params:
            # Append a missing key error to the violations list
            constraint_violations.append(f"Missing key: '{key}'")
            continue

        # Extract the observed state from the configuration
        observed_state: Any = retrieval_params[key]

        # Enforce strict type checking to ensure the value is a native Python boolean
        if not isinstance(observed_state, bool):
            # Append a type error to the violations list to prevent truthiness evaluation
            constraint_violations.append(
                f"Type mismatch for '{key}': Expected bool, got {type(observed_state).__name__}"
            )
            continue

        # Enforce strict identity checking (is) rather than equality (==) for booleans
        if observed_state is not required_state:
            # Append a state violation to the list if the constraint is not met
            constraint_violations.append(
                f"State violation for '{key}': Expected {required_state}, got {observed_state}"
            )

    # Check if any constraint violations were collected during the iteration
    if constraint_violations:
        # Construct a detailed error message enumerating all discrepancies
        error_msg = "Graph traversal constraint validation failed with the following errors:\n"
        for violation in constraint_violations:
            # Format each violation into a readable string
            error_msg += f"  - {violation}\n"
        # Raise a ValueError to halt the pipeline, ensuring fail-closed behavior
        raise ValueError(error_msg)

    # Log the successful validation of all graph traversal constraints
    logger.info("Graph traversal constraints validated successfully. All topological rules enforced.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Step 3: Document the retrieval-ranking interpretation as an implementation assumption
# -------------------------------------------------------------------------------------------------------------------------------
def document_retrieval_ranking_assumption(study_config: Dict[str, Any], assumption_registry: Dict[str, Any]) -> None:
    """
    Documents the retrieval-ranking weighting interpretation in the assumption registry.

    The manuscript specifies ranking by tag overlap and then by confidence, but omits
    the mathematical formulation. This function records the explicit decision to use a
    50/50 weighted sum, ensuring full epistemic traceability and auditability.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary containing the applied weights.
    assumption_registry : Dict[str, Any]
        A mutable dictionary passed by reference to accumulate methodological assumptions.

    Raises
    ------
    KeyError
        If the required weighting parameters are missing from the configuration.
    """
    # Log the initiation of the assumption documentation process
    logger.info("Documenting retrieval-ranking interpretation in the assumption registry.")

    # Verify the existence of the retrieval graph parameters section
    if "retrieval_graph_parameters" not in study_config:
        # Raise an error to halt execution if the section is missing
        raise KeyError("Configuration section 'retrieval_graph_parameters' is missing.")

    # Bind the retrieval parameters to a local variable for clean access
    retrieval_params: Dict[str, Any] = study_config["retrieval_graph_parameters"]

    # Verify the existence of the specific weighting keys
    if "tag_overlap_weight" not in retrieval_params or "confidence_score_weight" not in retrieval_params:
        # Raise an error if the weights used for the interpretation are undefined
        raise KeyError("Weighting keys missing from 'retrieval_graph_parameters'.")

    # Extract the exact weights utilized in the configuration
    tag_weight: float = float(retrieval_params["tag_overlap_weight"])
    conf_weight: float = float(retrieval_params["confidence_score_weight"])

    # Define the stable slug used to index this specific assumption
    registry_slug: str = "retrieval_ranking_interpretation"

    # Construct the detailed assumption record containing the values and the rationale
    assumption_record: Dict[str, Any] = {
        "applied_tag_overlap_weight": tag_weight,
        "applied_confidence_score_weight": conf_weight,
        "rationale": (
            "The manuscript prescribes ranking by tag overlap and then by synthetic confidence score, "
            "but does not specify whether the two criteria combine lexicographically or as a weighted sum. "
            "This implementation adopts a weighted sum interpretation. This choice may cause divergence "
            "from the published top-six evidence identifiers, which is an acknowledged limitation."
        )
    }

    # Insert the assumption record into the mutable registry passed by reference
    assumption_registry[registry_slug] = assumption_record

    # Log the successful documentation of the methodological assumption
    logger.info(f"Assumption '{registry_slug}' successfully recorded in the registry.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def validate_retrieval_and_graph_policies(study_config: Dict[str, Any], assumption_registry: Dict[str, Any]) -> None:
    """
    Orchestrates the validation of retrieval and graph search policies.

    This function acts as the entry point for Task 2, sequentially executing the
    validations for the text retrieval top-k policy, the graph traversal constraints,
    and the documentation of the retrieval-ranking assumption.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    assumption_registry : Dict[str, Any]
        A mutable dictionary to accumulate methodological assumptions for auditability.

    Raises
    ------
    Exception
        Bubbles up any KeyError, TypeError, or ValueError raised by the subordinate steps.
    """
    # Log the initiation of the overarching Task 2 orchestrator
    logger.info("=== Task 2: Initiating validation of retrieval and graph search policies ===")

    # Execute Step 1: Confirm text retrieval policy matches manuscript specification
    validate_text_retrieval_policy(study_config=study_config)

    # Execute Step 2: Confirm graph traversal constraints are enforced
    validate_graph_traversal_constraints(study_config=study_config)

    # Execute Step 3: Document the retrieval-ranking interpretation as an implementation assumption
    document_retrieval_ranking_assumption(
        study_config=study_config,
        assumption_registry=assumption_registry
    )

    # Log the successful completion of all Task 2 validations and documentation
    logger.info("=== Task 2: Retrieval and graph search policies validated successfully ===")

# %%
# Task 3 — Validate that all prompt templates exist and match the required structure

# ==================================================================================
# Task 3: Validate that all prompt templates exist and match the required structure
# ==================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Step 1: Enumerate the six required prompt keys
# -------------------------------------------------------------------------------------------------------------------------------
def validate_prompt_keys(study_config: Dict[str, Any]) -> None:
    """
    Validates that the prompt templates dictionary contains exactly the six required keys.

    This function extracts the keys from the configuration and computes the symmetric
    difference against a strict declarative schema. It ensures no required prompts
    are missing and no unauthorized prompts are injected.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary containing the 'prompt_templates'.

    Raises
    ------
    KeyError
        If the 'prompt_templates' section is missing.
    ValueError
        If there is any deviation (missing or surplus keys) from the required set.
    """
    # Log the initiation of the prompt key enumeration validation
    logger.info("Starting validation of prompt template keys.")

    # Verify the existence of the prompt templates section
    if "prompt_templates" not in study_config:
        # Raise an error to halt execution if the section is missing
        raise KeyError("Configuration section 'prompt_templates' is missing.")

    # Bind the prompt templates to a local variable for clean access
    prompt_templates: Dict[str, str] = study_config["prompt_templates"]

    # Define the exact set of required prompt keys as an immutable frozenset
    REQUIRED_PROMPT_KEYS: frozenset = frozenset([
        "planner_agent_prompt",
        "model_selection_agent_prompt",
        "report_gen_llm_only_prompt",
        "report_gen_rag_only_prompt",
        "report_gen_model_grounded_prompt",
        "judge_agent_prompt"
    ])

    # Extract the observed keys from the configuration into a standard set
    observed_keys: Set[str] = set(prompt_templates.keys())

    # Compute the symmetric difference to isolate any deviations
    symmetric_diff: Set[str] = REQUIRED_PROMPT_KEYS.symmetric_difference(observed_keys)

    # If the symmetric difference is non-empty, a structural violation has occurred
    if symmetric_diff:
        # Isolate the specifically missing keys
        missing_keys: Set[str] = REQUIRED_PROMPT_KEYS - observed_keys
        # Isolate the specifically unauthorized surplus keys
        surplus_keys: Set[str] = observed_keys - REQUIRED_PROMPT_KEYS

        # Construct a detailed error message for precise diagnostics
        error_msg = "Prompt template key validation failed.\n"
        if missing_keys:
            error_msg += f"  - Missing required keys: {missing_keys}\n"
        if surplus_keys:
            error_msg += f"  - Unauthorized surplus keys: {surplus_keys}\n"

        # Raise a ValueError to halt the pipeline, ensuring fail-closed behavior
        raise ValueError(error_msg)

    # Log the successful validation of the prompt keys
    logger.info("Prompt template keys validated successfully. Exact match confirmed.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Step 2: Validate that critical constraints are present in the relevant prompts
# -------------------------------------------------------------------------------------------------------------------------------
def validate_prompt_critical_constraints(study_config: Dict[str, Any]) -> None:
    """
    Validates that critical experimental constraints are verbatim present in the prompts.

    This function checks for the specific negative constraints, epistemic separation
    instructions, and logic gates required by the manuscript to ensure the LLM agents
    adhere to the methodological design.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary containing the 'prompt_templates'.

    Raises
    ------
    ValueError
        If any critical constraint fragment is missing from its respective prompt.
    """
    # Log the initiation of the critical constraints validation
    logger.info("Starting validation of critical constraints within prompt templates.")

    # Bind the prompt templates to a local variable
    prompt_templates: Dict[str, str] = study_config["prompt_templates"]

    # Define a declarative mapping of prompt keys to their required constraint fragments
    # Using the shortest distinctive fragments to avoid brittleness to minor whitespace changes
    constraint_mapping: Dict[str, Tuple[str, ...]] = {
        "report_gen_rag_only_prompt": (
            "You must NOT claim that a mathematical model has been executed.",
        ),
        "report_gen_model_grounded_prompt": (
            "You must distinguish qualitative interpretation from model-dependent statements.",
        ),
        "judge_agent_prompt": (
            "Mentioning a model name without execution is insufficient and MUST receive a 0.",
        )
    }

    # Initialize an empty list to collect any missing constraint violations
    constraint_violations: List[Tuple[str, str]] = []

    # Iterate through the declarative mapping to verify each constraint
    for prompt_key, required_fragments in constraint_mapping.items():
        # Extract the specific prompt text
        prompt_text: str = prompt_templates[prompt_key]

        # Check each required fragment against the prompt text
        for fragment in required_fragments:
            # Use exact substring matching to ensure the constraint is present
            if fragment not in prompt_text:
                # Append the violation to the collection list
                constraint_violations.append((prompt_key, fragment))

    # Check if any constraint violations were collected
    if constraint_violations:
        # Construct a detailed error message enumerating all missing constraints
        error_msg = "Critical constraint validation failed. Missing fragments:\n"
        for prompt_key, fragment in constraint_violations:
            error_msg += f"  - Prompt '{prompt_key}' is missing: '{fragment}'\n"
        # Raise a ValueError to halt the pipeline
        raise ValueError(error_msg)

    # Log the successful validation of all critical constraints
    logger.info("Critical constraints validated successfully across all relevant prompts.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Step 3: Validate output contracts enforce JSON-only output for the non-report agents
# -------------------------------------------------------------------------------------------------------------------------------
def validate_prompt_json_contracts(study_config: Dict[str, Any]) -> None:
    """
    Validates that structured-output prompts strictly enforce JSON-only generation.

    This function checks the planner, model-selection, and judge prompts to ensure
    they contain explicit instructions forbidding conversational preambles or markdown
    wrappers, which is critical for downstream parsing.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary containing the 'prompt_templates'.

    Raises
    ------
    ValueError
        If the JSON enforcement instructions are missing from any structured prompt.
    """
    # Log the initiation of the JSON contract validation
    logger.info("Starting validation of JSON output contracts for structured agents.")

    # Bind the prompt templates to a local variable
    prompt_templates: Dict[str, str] = study_config["prompt_templates"]

    # Define the specific prompts that require strict JSON output
    structured_prompts: Tuple[str, ...] = (
        "planner_agent_prompt",
        "model_selection_agent_prompt",
        "judge_agent_prompt"
    )

    # Define the exact instructional fragments required to enforce the JSON contract
    required_json_fragments: Tuple[str, ...] = (
        "Return ONLY a valid JSON object",
        "Do not include any text outside the JSON object."
    )

    # Initialize an empty list to collect any contract violations
    contract_violations: List[Tuple[str, str]] = []

    # Iterate through the structured prompts to verify the JSON instructions
    for prompt_key in structured_prompts:
        # Extract the specific prompt text
        prompt_text: str = prompt_templates[prompt_key]

        # Check each required JSON fragment against the prompt text
        for fragment in required_json_fragments:
            # Use exact substring matching to ensure the instruction is present
            if fragment not in prompt_text:
                # Append the violation to the collection list
                contract_violations.append((prompt_key, fragment))

    # Check if any contract violations were collected
    if contract_violations:
        # Construct a detailed error message enumerating all missing instructions
        error_msg = "JSON output contract validation failed. Missing instructions:\n"
        for prompt_key, fragment in contract_violations:
            error_msg += f"  - Prompt '{prompt_key}' is missing: '{fragment}'\n"
        # Raise a ValueError to halt the pipeline
        raise ValueError(error_msg)

    # Log the successful validation of the JSON output contracts
    logger.info("JSON output contracts validated successfully for all structured agents.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def validate_prompt_templates(study_config: Dict[str, Any]) -> None:
    """
    Orchestrates the comprehensive validation of all prompt templates.

    This function acts as the entry point for Task 3, sequentially executing the
    validations for prompt key enumeration, critical experimental constraints, and
    JSON output contracts. It ensures the agentic instruction set is methodologically
    sound before execution.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary.

    Raises
    ------
    Exception
        Bubbles up any KeyError or ValueError raised by the subordinate validation steps.
    """
    # Log the initiation of the overarching Task 3 orchestrator
    logger.info("=== Task 3: Initiating validation of prompt templates ===")

    # Execute Step 1: Enumerate the six required prompt keys
    # This must run first to ensure the keys exist before substring matching is attempted
    validate_prompt_keys(study_config=study_config)

    # Execute Step 2: Validate that critical constraints are present in the relevant prompts
    validate_prompt_critical_constraints(study_config=study_config)

    # Execute Step 3: Validate output contracts enforce JSON-only output for the non-report agents
    validate_prompt_json_contracts(study_config=study_config)

    # Log the successful completion of all Task 3 validations
    logger.info("=== Task 3: Prompt templates validated successfully ===")

# %%
# Task 4 — Validate DataFrame schemas for column presence and dtype correctness

# ==============================================================================
# Task 4: Validate DataFrame schemas for column presence and dtype correctness
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Schema Registry Definition
# -------------------------------------------------------------------------------------------------------------------------------

@dataclass(frozen=True)
class ColumnSchema:
    """
    Declarative definition of a DataFrame column's structural constraints.

    Attributes
    ----------
    name : str
        The exact expected name of the column.
    expected_dtype : str
        The logical data type expected (e.g., 'string', 'datetime64', 'Int64', 'float64', 'bool').
    is_nullable : bool
        Flag indicating if the column is permitted to contain null/NaN/NaT values.
    is_unique : bool
        Flag indicating if the column values must be strictly unique (e.g., for Primary Keys).
    """
    name: str
    expected_dtype: str
    is_nullable: bool
    is_unique: bool

# Define the centralized, authoritative schema registry for all 12 DataFrames
SCHEMA_REGISTRY: Dict[str, List[ColumnSchema]] = {
    "raw_source_documents_df": [
        ColumnSchema("doc_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("title", "string", is_nullable=True, is_unique=False),
        ColumnSchema("publication_date", "datetime64", is_nullable=True, is_unique=False),
        ColumnSchema("document_type", "string", is_nullable=True, is_unique=False),
        ColumnSchema("source_institution", "string", is_nullable=True, is_unique=False),
    ],
    "raw_evidence_spans_df": [
        ColumnSchema("evidence_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("doc_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("span_text", "string", is_nullable=True, is_unique=False),
        ColumnSchema("tags", "string", is_nullable=True, is_unique=False),
        ColumnSchema("synthetic_confidence", "float64", is_nullable=True, is_unique=False),
        ColumnSchema("char_start_position", "Int64", is_nullable=True, is_unique=False),
        ColumnSchema("char_end_position", "Int64", is_nullable=True, is_unique=False),
    ],
    "raw_temporal_facts_df": [
        ColumnSchema("fact_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("evidence_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("observation_time", "datetime64", is_nullable=True, is_unique=False),
        ColumnSchema("validity_start", "datetime64", is_nullable=True, is_unique=False),
        ColumnSchema("validity_end", "datetime64", is_nullable=True, is_unique=False),
        ColumnSchema("temporal_description", "string", is_nullable=True, is_unique=False),
    ],
    "raw_shocks_df": [
        ColumnSchema("shock_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("scenario_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("shock_description", "string", is_nullable=True, is_unique=False),
        ColumnSchema("shock_type", "string", is_nullable=True, is_unique=False),
        ColumnSchema("severity_level", "Int64", is_nullable=True, is_unique=False),
    ],
    "raw_variable_concepts_df": [
        ColumnSchema("concept_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("scenario_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("variable_name", "string", is_nullable=True, is_unique=False),
        ColumnSchema("variable_symbol", "string", is_nullable=True, is_unique=False),
        ColumnSchema("measurement_unit", "string", is_nullable=True, is_unique=False),
        ColumnSchema("is_target_variable", "bool", is_nullable=True, is_unique=False),
    ],
    "raw_models_df": [
        ColumnSchema("model_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("model_name", "string", is_nullable=True, is_unique=False),
        ColumnSchema("model_category", "string", is_nullable=True, is_unique=False),
        ColumnSchema("complexity_level", "Int64", is_nullable=True, is_unique=False),
    ],
    "raw_model_specifications_df": [
        ColumnSchema("spec_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("model_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("spec_description", "string", is_nullable=True, is_unique=False),
        ColumnSchema("calibration_params_json", "string", is_nullable=True, is_unique=False),
    ],
    "raw_model_equations_df": [
        ColumnSchema("eq_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("spec_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("equation_name", "string", is_nullable=True, is_unique=False),
        ColumnSchema("latex_equation", "string", is_nullable=True, is_unique=False),
        ColumnSchema("equation_order", "Int64", is_nullable=True, is_unique=False),
    ],
    "raw_model_assumptions_df": [
        ColumnSchema("assumption_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("spec_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("assumption_text", "string", is_nullable=True, is_unique=False),
        ColumnSchema("assumption_type", "string", is_nullable=True, is_unique=False),
    ],
    "raw_model_documents_df": [
        ColumnSchema("model_document_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("spec_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("title", "string", is_nullable=True, is_unique=False),
        ColumnSchema("document_text", "string", is_nullable=True, is_unique=False),
        # Version must be non-null for regulatory auditability
        ColumnSchema("version", "string", is_nullable=False, is_unique=False),
    ],
    "raw_implementation_functions_df": [
        ColumnSchema("impl_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("spec_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("execution_tool_name", "string", is_nullable=True, is_unique=False),
        ColumnSchema("solver_method", "string", is_nullable=True, is_unique=False),
        ColumnSchema("horizon_steps", "Int64", is_nullable=True, is_unique=False),
        ColumnSchema("python_module_path", "string", is_nullable=True, is_unique=False),
    ],
    "raw_model_variable_relationships_df": [
        ColumnSchema("relationship_id", "string", is_nullable=False, is_unique=True),
        ColumnSchema("spec_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("concept_id", "string", is_nullable=False, is_unique=False),
        ColumnSchema("relationship_type", "string", is_nullable=True, is_unique=False),
        ColumnSchema("is_endogenous", "bool", is_nullable=True, is_unique=False),
        ColumnSchema("variable_role", "string", is_nullable=True, is_unique=False),
    ]
}

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Step 1, 2, & 3: Generic DataFrame Schema Validator
# -------------------------------------------------------------------------------------------------------------------------------
def validate_dataframe_schema(df_name: str, df: pd.DataFrame, schema: List[ColumnSchema]) -> None:
    """
    Validates a single pandas DataFrame against its declarative ColumnSchema list.

    This function rigorously checks for column presence, data type correctness,
    nullability constraints, and uniqueness constraints. It accumulates all errors
    to provide a comprehensive diagnostic report rather than failing on the first error.

    Parameters
    ----------
    df_name : str
        The name of the DataFrame being validated (used for error reporting).
    df : pd.DataFrame
        The actual pandas DataFrame object to validate.
    schema : List[ColumnSchema]
        The list of ColumnSchema dataclasses defining the structural constraints.

    Raises
    ------
    ValueError
        If any structural constraint (presence, dtype, nullability, uniqueness) is violated.
    """
    # Initialize an empty list to collect all validation errors for this DataFrame
    validation_errors: List[str] = []

    # Iterate through each column definition in the provided schema
    for col_def in schema:
        # 1. Validate Column Presence
        if col_def.name not in df.columns:
            # Append error if the required column is entirely missing
            validation_errors.append(f"Missing required column: '{col_def.name}'")
            # Skip further checks for this column as it does not exist
            continue

        # Extract the specific column as a pandas Series for vectorized checks
        series: pd.Series = df[col_def.name]

        # 2. Validate Data Type Correctness
        dtype_valid: bool = False

        # Handle string types: accept both generic 'object' and pandas 'StringDtype'
        if col_def.expected_dtype == "string":
            if ptypes.is_string_dtype(series) or ptypes.is_object_dtype(series):
                dtype_valid = True
        # Handle datetime types: accept any datetime64 variant (naive or aware)
        elif col_def.expected_dtype == "datetime64":
            if ptypes.is_datetime64_any_dtype(series):
                dtype_valid = True
        # Handle nullable integer types: strictly require the pandas 'Int64' extension type
        elif col_def.expected_dtype == "Int64":
            if series.dtype.name == "Int64":
                dtype_valid = True
        # Handle standard float64 types
        elif col_def.expected_dtype == "float64":
            if ptypes.is_float_dtype(series):
                dtype_valid = True
        # Handle standard boolean types
        elif col_def.expected_dtype == "bool":
            if ptypes.is_bool_dtype(series):
                dtype_valid = True
        else:
            # Catch-all for unrecognized expected dtypes in the schema registry
            validation_errors.append(f"Unknown expected dtype '{col_def.expected_dtype}' for column '{col_def.name}'")
            continue

        # If the dtype check failed, append a detailed error message
        if not dtype_valid:
            validation_errors.append(
                f"Dtype mismatch for '{col_def.name}': Expected {col_def.expected_dtype}, "
                f"Observed {series.dtype.name}"
            )

        # 3. Validate Nullability Constraints
        if not col_def.is_nullable:
            # Compute the total number of null/NaN/NaT values in the column
            null_count: int = series.isnull().sum()
            if null_count > 0:
                # Append error if a non-nullable column contains missing data
                validation_errors.append(
                    f"Nullability violation for '{col_def.name}': Column must be non-null, "
                    f"but contains {null_count} null values."
                )

        # 4. Validate Uniqueness Constraints (e.g., for Primary Keys)
        if col_def.is_unique:
            # Compute the total number of duplicated values in the column
            # We drop nulls before checking duplicates to avoid false positives on nullable unique columns (though PKs are non-null)
            duplicate_count: int = series.dropna().duplicated().sum()
            if duplicate_count > 0:
                # Append error if a unique column contains duplicate data
                validation_errors.append(
                    f"Uniqueness violation for '{col_def.name}': Column must be unique, "
                    f"but contains {duplicate_count} duplicate values."
                )

    # Check if any validation errors were collected for this DataFrame
    if validation_errors:
        # Construct a detailed, hierarchical error message
        error_msg = f"Schema validation failed for DataFrame '{df_name}':\n"
        for error in validation_errors:
            error_msg += f"  - {error}\n"
        # Raise a ValueError to halt the pipeline, ensuring fail-closed behavior
        raise ValueError(error_msg)

    # Log the successful validation of the individual DataFrame
    logger.debug(f"DataFrame '{df_name}' successfully passed schema validation.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def validate_all_dataframe_schemas(dataframes_dict: Dict[str, pd.DataFrame]) -> None:
    """
    Orchestrates the comprehensive schema validation for all 12 pipeline DataFrames.

    This function acts as the entry point for Task 4. It iterates through the master
    SCHEMA_REGISTRY, verifies that each required DataFrame is present in the input
    dictionary, and delegates the structural validation to the generic validator.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        A dictionary mapping expected DataFrame names to their actual pandas DataFrame objects.

    Raises
    ------
    KeyError
        If any required DataFrame is missing from the input dictionary.
    RuntimeError
        If one or more DataFrames fail their schema validation, aggregating all errors.
    """
    # Log the initiation of the overarching Task 4 orchestrator
    logger.info("=== Task 4: Initiating comprehensive DataFrame schema validation ===")

    # Initialize an empty list to collect exceptions raised by individual DataFrame validations
    orchestrator_errors: List[str] = []

    # Iterate through the master schema registry to validate every required table
    for df_name, schema_definition in SCHEMA_REGISTRY.items():
        # Verify that the required DataFrame was actually provided in the input dictionary
        if df_name not in dataframes_dict:
            # Append a missing table error to the orchestrator's error list
            orchestrator_errors.append(f"CRITICAL: Required DataFrame '{df_name}' is missing from input dictionary.")
            # Skip further validation for this missing table
            continue

        # Extract the specific DataFrame object
        df_to_validate: pd.DataFrame = dataframes_dict[df_name]

        try:
            # Delegate the structural validation to the generic validator function
            validate_dataframe_schema(
                df_name=df_name,
                df=df_to_validate,
                schema=schema_definition
            )
        except ValueError as e:
            # Catch the DataFrame-specific ValueError and append its message to the orchestrator's list
            orchestrator_errors.append(str(e))

    # Check if any errors were collected across all DataFrames
    if orchestrator_errors:
        # Construct a massive, comprehensive error report detailing all schema failures
        master_error_msg = "Task 4 Validation halted due to the following schema violations:\n\n"
        master_error_msg += "\n".join(orchestrator_errors)
        # Raise a RuntimeError to completely halt the pipeline, ensuring no malformed data proceeds
        raise RuntimeError(master_error_msg)

    # Log the successful completion of all Task 4 validations
    logger.info("=== Task 4: All 12 DataFrame schemas validated successfully ===")

# %%
# Task 5 — Validate primary key/foreign key referential integrity

# ==============================================================================
# Task 5: Validate primary key/foreign key referential integrity
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Declarative Schemas for Relational Integrity
# -------------------------------------------------------------------------------------------------------------------------------

# Declarative mapping of DataFrame names to their designated Primary Key column
PRIMARY_KEY_REGISTRY: Dict[str, str] = {
    "raw_source_documents_df": "doc_id",
    "raw_evidence_spans_df": "evidence_id",
    "raw_temporal_facts_df": "fact_id",
    "raw_shocks_df": "shock_id",
    "raw_variable_concepts_df": "concept_id",
    "raw_models_df": "model_id",
    "raw_model_specifications_df": "spec_id",
    "raw_model_equations_df": "eq_id",
    "raw_model_assumptions_df": "assumption_id",
    "raw_model_documents_df": "model_document_id",
    "raw_implementation_functions_df": "impl_id",
    "raw_model_variable_relationships_df": "relationship_id"
}

@dataclass(frozen=True)
class ForeignKeyEdge:
    """
    Declarative definition of a directed Foreign Key relationship.

    Attributes
    ----------
    child_df : str
        The name of the DataFrame containing the foreign key.
    child_col : str
        The name of the foreign key column.
    parent_df : Optional[str]
        The name of the DataFrame containing the referenced primary key.
        None if the parent domain is derived from the configuration.
    parent_col : Optional[str]
        The name of the referenced primary key column.
        None if the parent domain is derived from the configuration.
    """
    child_df: str
    child_col: str
    parent_df: Optional[str]
    parent_col: Optional[str]

# Declarative list of all required Foreign Key edges specified in the LaTeX context
FOREIGN_KEY_REGISTRY: List[ForeignKeyEdge] = [
    # DataFrame to DataFrame edges
    ForeignKeyEdge("raw_evidence_spans_df", "doc_id", "raw_source_documents_df", "doc_id"),
    ForeignKeyEdge("raw_temporal_facts_df", "evidence_id", "raw_evidence_spans_df", "evidence_id"),
    ForeignKeyEdge("raw_model_specifications_df", "model_id", "raw_models_df", "model_id"),
    ForeignKeyEdge("raw_model_equations_df", "spec_id", "raw_model_specifications_df", "spec_id"),
    ForeignKeyEdge("raw_model_assumptions_df", "spec_id", "raw_model_specifications_df", "spec_id"),
    ForeignKeyEdge("raw_model_documents_df", "spec_id", "raw_model_specifications_df", "spec_id"),
    ForeignKeyEdge("raw_implementation_functions_df", "spec_id", "raw_model_specifications_df", "spec_id"),
    ForeignKeyEdge("raw_model_variable_relationships_df", "spec_id", "raw_model_specifications_df", "spec_id"),
    ForeignKeyEdge("raw_model_variable_relationships_df", "concept_id", "raw_variable_concepts_df", "concept_id"),

    # DataFrame to Configuration Domain edges (parent_df and parent_col are None)
    ForeignKeyEdge("raw_shocks_df", "scenario_id", None, None),
    ForeignKeyEdge("raw_variable_concepts_df", "scenario_id", None, None)
]

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Step 1: Validate that all primary keys are unique and non-null
# -------------------------------------------------------------------------------------------------------------------------------
def validate_primary_keys(dataframes_dict: Dict[str, pd.DataFrame]) -> List[str]:
    """
    Validates entity integrity by ensuring all primary keys are unique and non-null.

    This function iterates over the declarative PRIMARY_KEY_REGISTRY, extracts the
    relevant pandas Series, and computes null and duplicate counts. It strictly
    evaluates nulls before checking for duplicates to prevent masking data corruption.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        A dictionary mapping expected DataFrame names to their actual pandas DataFrame objects.

    Returns
    -------
    List[str]
        A list of detailed error messages describing any primary key violations.
        Returns an empty list if all primary keys are perfectly valid.
    """
    # Log the initiation of the Primary Key entity integrity validation
    logger.info("Starting validation of Primary Key entity integrity.")
    # Initialize an empty list to collect primary key violations
    pk_violations: List[str] = []

    # Iterate over the registry mapping DataFrames to their primary key columns
    for df_name, pk_col in PRIMARY_KEY_REGISTRY.items():
        # Ensure the DataFrame exists in the provided dictionary
        if df_name not in dataframes_dict:
            # Append a critical error if the DataFrame is missing
            pk_violations.append(f"CRITICAL: DataFrame '{df_name}' is missing. Cannot validate PK '{pk_col}'.")
            continue

        # Extract the DataFrame
        df: pd.DataFrame = dataframes_dict[df_name]

        # Ensure the designated primary key column exists in the DataFrame
        if pk_col not in df.columns:
            # Append a critical error if the primary key column is missing
            pk_violations.append(f"CRITICAL: PK column '{pk_col}' is missing from DataFrame '{df_name}'.")
            continue

        # Extract the primary key column as a pandas Series
        pk_series: pd.Series = df[pk_col]

        # 1. Validate Non-Null Constraint
        # Count the number of null values in the primary key series
        null_count: int = pk_series.isnull().sum()
        if null_count > 0:
            # Append a violation if any nulls are detected
            pk_violations.append(
                f"PK Nullability Violation in '{df_name}': Column '{pk_col}' contains {null_count} null values."
            )

        # 2. Validate Uniqueness Constraint
        # We do NOT drop nulls here. We check the entire series for duplicates.
        # If nulls exist, they will be flagged as duplicates, which is correct behavior for a PK.
        duplicate_count: int = pk_series.duplicated().sum()
        if duplicate_count > 0:
            # Extract the specific values that are duplicated and their occurrence counts
            # We use keep=False to mark all duplicates as True
            duplicate_examples = pk_series[pk_series.duplicated(keep=False)].value_counts().head(5).to_dict()

            # Append a violation detailing the duplicate count and examples
            pk_violations.append(
                f"PK Uniqueness Violation in '{df_name}': Column '{pk_col}' contains {duplicate_count} duplicate values. "
                f"Examples (value: count): {duplicate_examples}"
            )

    # Return the accumulated list of primary key violations
    return pk_violations

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Step 2 & 3: Validate all foreign-key relationships and document violations
# -------------------------------------------------------------------------------------------------------------------------------
def validate_foreign_keys(dataframes_dict: Dict[str, pd.DataFrame], study_config: Dict[str, Any]) -> List[str]:
    """
    Validates referential integrity by ensuring all foreign keys exist in their parent domains.

    This function iterates over the declarative FOREIGN_KEY_REGISTRY. It uses highly
    optimized Python set mathematics to isolate orphaned child records. It handles both
    DataFrame-to-DataFrame edges and DataFrame-to-Configuration edges.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        A dictionary mapping expected DataFrame names to their actual pandas DataFrame objects.
    study_config : Dict[str, Any]
        The master study configuration dictionary, used to derive the scenario_id domain.

    Returns
    -------
    List[str]
        A list of detailed error messages describing any foreign key violations,
        including the exact orphaned values and counts.
    """
    logger.info("Starting validation of Foreign Key referential integrity.")
    fk_violations: List[str] = []

    # Extract the valid scenario_id domain from the configuration dictionary
    # This is required for the DataFrame-to-Configuration edges
    try:
        valid_scenarios: FrozenSet[str] = frozenset(study_config["application_scenarios"].keys())
        # The keys in the config are 'application_1', 'application_2'. We need the actual 'scenario_id' values.
        valid_scenario_ids: FrozenSet[str] = frozenset(
            app_data["scenario_id"] for app_data in study_config["application_scenarios"].values()
        )
    except KeyError as e:
        fk_violations.append(f"CRITICAL: Cannot extract scenario domain from config. Missing key: {e}")
        valid_scenario_ids = frozenset()

    for edge in FOREIGN_KEY_REGISTRY:
        # Ensure the child DataFrame exists
        if edge.child_df not in dataframes_dict:
            fk_violations.append(f"CRITICAL: Child DataFrame '{edge.child_df}' is missing.")
            continue

        child_df: pd.DataFrame = dataframes_dict[edge.child_df]

        # Ensure the child column exists
        if edge.child_col not in child_df.columns:
            fk_violations.append(f"CRITICAL: FK column '{edge.child_col}' missing from '{edge.child_df}'.")
            continue

        # Extract unique, non-null values from the child column into a Python set
        # Nulls do not violate referential integrity (unless the column is non-nullable, checked in Task 4)
        child_values: Set[Any] = set(child_df[edge.child_col].dropna().unique())

        # Determine the parent domain
        parent_values: Set[Any] = set()

        if edge.parent_df is None:
            # Handle DataFrame-to-Configuration edge (scenario_id)
            parent_values = set(valid_scenario_ids)
            parent_desc = "study_config['application_scenarios']"
        else:
            # Handle DataFrame-to-DataFrame edge
            if edge.parent_df not in dataframes_dict:
                fk_violations.append(f"CRITICAL: Parent DataFrame '{edge.parent_df}' is missing.")
                continue

            parent_df: pd.DataFrame = dataframes_dict[edge.parent_df]

            if edge.parent_col not in parent_df.columns:
                fk_violations.append(f"CRITICAL: Parent PK column '{edge.parent_col}' missing from '{edge.parent_df}'.")
                continue

            # Extract unique, non-null values from the parent column into a Python set
            parent_values = set(parent_df[edge.parent_col].dropna().unique())
            parent_desc = f"{edge.parent_df}.{edge.parent_col}"

        # Compute the set difference to isolate orphaned child values
        # orphans = values in child that are NOT in parent
        orphans: Set[Any] = child_values.difference(parent_values)

        if orphans:
            orphan_count: int = len(orphans)
            # Convert the set to a list and truncate to the first 5 examples to prevent log bloat
            orphan_examples: List[Any] = list(orphans)[:5]
            truncation_flag: str = "..." if orphan_count > 5 else ""

            # Construct the detailed violation report
            fk_violations.append(
                f"FK Referential Violation: '{edge.child_df}.{edge.child_col}' references non-existent keys in {parent_desc}. "
                f"Total orphaned unique values: {orphan_count}. "
                f"Examples: {orphan_examples}{truncation_flag}"
            )

    return fk_violations

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def validate_referential_integrity(
    dataframes_dict: Dict[str, pd.DataFrame],
    study_config: Dict[str, Any],
    is_pre_cleansing_pass: bool = True
) -> None:
    """
    Orchestrates the comprehensive validation of primary and foreign key integrity.

    This function executes both the PK and FK validations. It handles the complex
    lifecycle requirement where pre-cleansing violations are treated as diagnostics
    (warnings), while post-cleansing violations are treated as fatal errors that
    halt the pipeline.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        A dictionary mapping expected DataFrame names to their actual pandas DataFrame objects.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    is_pre_cleansing_pass : bool, optional
        Flag indicating if this is the diagnostic pass before whitespace stripping.
        Defaults to True.

    Raises
    ------
    RuntimeError
        If `is_pre_cleansing_pass` is False and any referential integrity violations are detected.
    """
    pass_type: str = "Diagnostic (Pre-Cleansing)" if is_pre_cleansing_pass else "Authoritative (Post-Cleansing)"
    logger.info(f"=== Task 5: Initiating {pass_type} referential integrity validation ===")

    # Execute Step 1: Validate Primary Keys
    pk_errors: List[str] = validate_primary_keys(dataframes_dict=dataframes_dict)

    # Execute Step 2 & 3: Validate Foreign Keys and Document Violations
    fk_errors: List[str] = validate_foreign_keys(dataframes_dict=dataframes_dict, study_config=study_config)

    # Aggregate all detected violations
    all_errors: List[str] = pk_errors + fk_errors

    if all_errors:
        # Construct the master error report
        master_error_msg = f"Task 5 {pass_type} Validation detected the following referential violations:\n\n"
        master_error_msg += "\n".join(all_errors)

        if is_pre_cleansing_pass:
            # In the diagnostic pass, we log the errors as warnings but do not halt execution.
            # This allows Task 7 (Cleansing) to attempt to resolve whitespace-induced orphans.
            logger.warning(master_error_msg)
            logger.warning("Pipeline will proceed to cleansing phase. These violations must be resolved post-cleansing.")
        else:
            # In the authoritative pass, any violation is a fatal error that corrupts the Knowledge Graph.
            # We raise a RuntimeError to completely halt the pipeline.
            raise RuntimeError(master_error_msg)
    else:
        logger.info(f"=== Task 5: {pass_type} referential integrity validated successfully. Zero violations detected. ===")

# %%
# Task 6 — Validate row-level invariants on all DataFrames

# ==============================================================================
# Task 6: Validate row-level invariants on all DataFrames
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Step 1: Validate evidence-confidence bounds
# -------------------------------------------------------------------------------------------------------------------------------
def validate_evidence_confidence_bounds(df: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Validates that the synthetic confidence score lies within the closed interval [0.0, 1.0].

    This function applies a vectorized boolean mask to identify rows violating the
    mathematical invariant. Violating rows (including nulls) are partitioned into a
    quarantine DataFrame, ensuring graceful degradation rather than a pipeline halt.

    Parameters
    ----------
    df : pd.DataFrame
        The raw evidence spans DataFrame to be validated.

    Returns
    -------
    Tuple[pd.DataFrame, pd.DataFrame]
        A tuple containing:
        - clean_df: DataFrame with all violating rows removed.
        - quarantine_df: DataFrame containing only the violating rows, with an added 'quarantine_reason' column.
    """
    logger.info("Validating evidence confidence bounds: 0.0 <= synthetic_confidence <= 1.0")

    # Ensure the target column exists to prevent KeyError
    if "synthetic_confidence" not in df.columns:
        logger.error("Column 'synthetic_confidence' missing. Quarantining entire DataFrame.")
        df_quarantine = df.copy()
        df_quarantine["quarantine_reason"] = "Missing 'synthetic_confidence' column"
        # Return empty clean frame and full quarantine frame
        return pd.DataFrame(columns=df.columns), df_quarantine

    # Extract the series for vectorized operations
    conf_series: pd.Series = df["synthetic_confidence"]

    # Construct the violation mask: True if null, less than 0.0, or greater than 1.0
    # Equation: violation = isnull(c) OR c < 0.0 OR c > 1.0
    violation_mask: pd.Series = conf_series.isnull() | (conf_series < 0.0) | (conf_series > 1.0)

    # Partition the DataFrame based on the mask
    clean_df: pd.DataFrame = df[~violation_mask].copy()
    quarantine_df: pd.DataFrame = df[violation_mask].copy()

    # Log the results and annotate the quarantine frame
    violation_count: int = len(quarantine_df)
    if violation_count > 0:
        quarantine_df["quarantine_reason"] = "Confidence bounds violation or null"
        # Extract failing IDs for the audit log
        failing_ids: List[str] = quarantine_df["evidence_id"].head(5).tolist()
        logger.warning(
            f"Quarantined {violation_count} evidence spans due to confidence bounds violations. "
            f"Examples: {failing_ids}..."
        )
    else:
        logger.debug("All evidence spans passed confidence bounds validation.")
        # Ensure the quarantine frame has the reason column even if empty for schema consistency
        quarantine_df["quarantine_reason"] = pd.Series(dtype="string")

    return clean_df, quarantine_df

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Step 2: Validate character-offset ordering
# -------------------------------------------------------------------------------------------------------------------------------
def validate_character_offset_ordering(df: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Validates that the character start position does not exceed the end position.

    This function isolates the comparison to rows where both offsets are concretely
    present, safely handling the tri-state logic introduced by pandas Int64 (pd.NA).
    Violating rows are partitioned into a quarantine DataFrame.

    Parameters
    ----------
    df : pd.DataFrame
        The evidence spans DataFrame (typically already cleaned by Step 1).

    Returns
    -------
    Tuple[pd.DataFrame, pd.DataFrame]
        A tuple containing the clean DataFrame and the quarantine DataFrame.
    """
    logger.info("Validating character offset ordering: char_start_position <= char_end_position")

    # Ensure target columns exist
    if not {"char_start_position", "char_end_position"}.issubset(df.columns):
        logger.error("Character offset columns missing. Skipping offset validation.")
        # Return unmodified clean frame and empty quarantine frame
        empty_quarantine = pd.DataFrame(columns=list(df.columns) + ["quarantine_reason"])
        return df.copy(), empty_quarantine

    # Create a mask for rows where BOTH offsets are non-null
    both_present_mask: pd.Series = df["char_start_position"].notnull() & df["char_end_position"].notnull()

    # Initialize a violation mask of all False
    violation_mask: pd.Series = pd.Series(False, index=df.index)

    # Apply the mathematical invariant check ONLY to the subset where both are present
    # Equation: violation = start > end
    if both_present_mask.any():
        subset_start = df.loc[both_present_mask, "char_start_position"]
        subset_end = df.loc[both_present_mask, "char_end_position"]
        # Update the violation mask for the specific indices that fail the check
        violation_mask.loc[both_present_mask] = subset_start > subset_end

    # Partition the DataFrame
    clean_df: pd.DataFrame = df[~violation_mask].copy()
    quarantine_df: pd.DataFrame = df[violation_mask].copy()

    # Log results and annotate
    violation_count: int = len(quarantine_df)
    if violation_count > 0:
        quarantine_df["quarantine_reason"] = "Character offset ordering violation (start > end)"
        failing_ids: List[str] = quarantine_df["evidence_id"].head(5).tolist()
        logger.warning(
            f"Quarantined {violation_count} evidence spans due to offset ordering violations. "
            f"Examples: {failing_ids}..."
        )
    else:
        logger.debug("All evidence spans passed character offset ordering validation.")
        quarantine_df["quarantine_reason"] = pd.Series(dtype="string")

    return clean_df, quarantine_df

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Step 3: Validate temporal-window ordering
# -------------------------------------------------------------------------------------------------------------------------------
def validate_temporal_window_ordering(df: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Validates that the temporal validity start does not exceed the validity end.

    This function enforces temporal consistency. It includes a defensive try-except
    block to catch TypeError exceptions caused by comparing timezone-aware and
    timezone-naive datetimes, which indicates a sequencing hazard from upstream.

    Parameters
    ----------
    df : pd.DataFrame
        The raw temporal facts DataFrame to be validated.

    Returns
    -------
    Tuple[pd.DataFrame, pd.DataFrame]
        A tuple containing the clean DataFrame and the quarantine DataFrame.
    """
    logger.info("Validating temporal window ordering: validity_start <= validity_end")

    if not {"validity_start", "validity_end"}.issubset(df.columns):
        logger.error("Temporal validity columns missing. Quarantining entire DataFrame.")
        df_quarantine = df.copy()
        df_quarantine["quarantine_reason"] = "Missing validity columns"
        return pd.DataFrame(columns=df.columns), df_quarantine

    # Create a mask for rows where BOTH datetimes are non-null
    both_present_mask: pd.Series = df["validity_start"].notnull() & df["validity_end"].notnull()
    violation_mask: pd.Series = pd.Series(False, index=df.index)

    if both_present_mask.any():
        subset_start = df.loc[both_present_mask, "validity_start"]
        subset_end = df.loc[both_present_mask, "validity_end"]

        try:
            # Attempt the vectorized datetime comparison
            # Equation: violation = start > end
            violation_mask.loc[both_present_mask] = subset_start > subset_end
        except TypeError as e:
            # Catch sequencing hazards (e.g., mixed timezones before Task 8 normalization)
            logger.error(f"TypeError during datetime comparison: {e}. This indicates a timezone normalization sequencing hazard.")
            # Quarantine all rows involved in the attempted comparison to prevent silent corruption
            violation_mask.loc[both_present_mask] = True

    # Partition the DataFrame
    clean_df: pd.DataFrame = df[~violation_mask].copy()
    quarantine_df: pd.DataFrame = df[violation_mask].copy()

    # Log results and annotate
    violation_count: int = len(quarantine_df)
    if violation_count > 0:
        quarantine_df["quarantine_reason"] = "Temporal window ordering violation or TypeError"
        failing_ids: List[str] = quarantine_df["fact_id"].head(5).tolist()
        logger.warning(
            f"Quarantined {violation_count} temporal facts due to window ordering violations. "
            f"Examples: {failing_ids}..."
        )
    else:
        logger.debug("All temporal facts passed window ordering validation.")
        quarantine_df["quarantine_reason"] = pd.Series(dtype="string")

    return clean_df, quarantine_df

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def validate_row_level_invariants(dataframes_dict: Dict[str, pd.DataFrame]) -> Dict[str, pd.DataFrame]:
    """
    Orchestrates the validation of row-level mathematical and logical invariants.

    This function manages the quarantine state across multiple validation steps. It
    extracts the relevant DataFrames, passes them through the sequential validation
    filters, updates the master dictionary with the cleansed data, and returns a
    dictionary containing the isolated quarantine logs for auditability.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        The master dictionary containing all pipeline DataFrames. This dictionary
        will be mutated in-place to replace raw frames with cleansed frames.

    Returns
    -------
    Dict[str, pd.DataFrame]
        A dictionary containing the quarantined records, keyed by descriptive names
        (e.g., 'quarantined_evidence_spans', 'quarantined_temporal_facts').
    """
    logger.info("=== Task 6: Initiating row-level invariant validation and quarantine ===")

    quarantine_logs: Dict[str, pd.DataFrame] = {}

    # --- Process Evidence Spans ---
    if "raw_evidence_spans_df" in dataframes_dict:
        working_evidence_df: pd.DataFrame = dataframes_dict["raw_evidence_spans_df"]

        # Step 1: Confidence Bounds
        working_evidence_df, q_conf = validate_evidence_confidence_bounds(working_evidence_df)

        # Step 2: Character Offset Ordering (operates on the clean output of Step 1)
        working_evidence_df, q_offset = validate_character_offset_ordering(working_evidence_df)

        # Update the master dictionary with the fully cleansed evidence frame
        dataframes_dict["raw_evidence_spans_df"] = working_evidence_df

        # Aggregate the quarantine logs for evidence spans
        master_q_evidence: pd.DataFrame = pd.concat([q_conf, q_offset], ignore_index=True)
        quarantine_logs["quarantined_evidence_spans"] = master_q_evidence
    else:
        logger.error("CRITICAL: 'raw_evidence_spans_df' missing from dataframes_dict.")

    # --- Process Temporal Facts ---
    if "raw_temporal_facts_df" in dataframes_dict:
        working_temporal_df: pd.DataFrame = dataframes_dict["raw_temporal_facts_df"]

        # Step 3: Temporal Window Ordering
        working_temporal_df, q_temporal = validate_temporal_window_ordering(working_temporal_df)

        # Update the master dictionary with the cleansed temporal frame
        dataframes_dict["raw_temporal_facts_df"] = working_temporal_df

        # Store the quarantine log
        quarantine_logs["quarantined_temporal_facts"] = q_temporal
    else:
        logger.error("CRITICAL: 'raw_temporal_facts_df' missing from dataframes_dict.")

    logger.info("=== Task 6: Row-level invariant validation completed successfully ===")

    # Return the quarantine logs for downstream archival or manual review
    return quarantine_logs

# %%
# Task 7 — Cleanse identifier and text fields deterministically

# ==============================================================================
# Task 7: Cleanse identifier and text fields deterministically
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Extended Key Registry Definition
# -------------------------------------------------------------------------------------------------------------------------------

# Declarative mapping of DataFrame names to lists of their Primary and Foreign Key columns
# This ensures no identifier column is missed during the deterministic whitespace strip
EXTENDED_KEY_REGISTRY: Dict[str, List[str]] = {
    "raw_source_documents_df": ["doc_id"],
    "raw_evidence_spans_df": ["evidence_id", "doc_id"],
    "raw_temporal_facts_df": ["fact_id", "evidence_id"],
    "raw_shocks_df": ["shock_id", "scenario_id"],
    "raw_variable_concepts_df": ["concept_id", "scenario_id"],
    "raw_models_df": ["model_id"],
    "raw_model_specifications_df": ["spec_id", "model_id"],
    "raw_model_equations_df": ["eq_id", "spec_id"],
    "raw_model_assumptions_df": ["assumption_id", "spec_id"],
    "raw_model_documents_df": ["model_document_id", "spec_id"],
    "raw_implementation_functions_df": ["impl_id", "spec_id"],
    "raw_model_variable_relationships_df": ["relationship_id", "spec_id", "concept_id"]
}

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Step 1: Strip whitespace from all identifier columns
# -------------------------------------------------------------------------------------------------------------------------------
def strip_identifier_whitespace(dataframes_dict: Dict[str, pd.DataFrame]) -> pd.DataFrame:
    """
    Deterministically strips leading and trailing whitespace from all PK and FK columns.

    This function iterates over the extended key registry, coerces identifier columns
    to the pandas StringDtype, and applies a vectorized strip. It captures the pre-
    and post-modification values into a structured audit log to ensure absolute
    provenance preservation and reversibility.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        The master dictionary containing all pipeline DataFrames. Mutated in-place.

    Returns
    -------
    pd.DataFrame
        A DataFrame containing the audit log of all modified identifiers.
    """
    logger.info("Starting deterministic whitespace stripping for all identifier columns.")

    audit_records: List[Dict[str, Any]] = []

    for df_name, key_columns in EXTENDED_KEY_REGISTRY.items():
        if df_name not in dataframes_dict:
            logger.warning(f"DataFrame '{df_name}' missing during identifier cleansing.")
            continue

        df: pd.DataFrame = dataframes_dict[df_name]

        for col in key_columns:
            if col not in df.columns:
                logger.warning(f"Key column '{col}' missing from '{df_name}'.")
                continue

            # Extract the original series
            original_series: pd.Series = df[col]

            # Coerce to pandas StringDtype to ensure .str accessors behave predictably
            # This mitigates issues where numeric-looking IDs are parsed as objects/ints
            string_series: pd.Series = original_series.astype("string")

            # Apply deterministic leading/trailing strip (internal whitespace is preserved)
            stripped_series: pd.Series = string_series.str.strip()

            # Identify rows where a modification actually occurred
            # We fill NA with False to avoid boolean mask errors on nulls
            modification_mask: pd.Series = (string_series != stripped_series).fillna(False)

            if modification_mask.any():
                # Extract the modified rows for the audit log
                modified_indices = df.index[modification_mask]
                for idx in modified_indices:
                    audit_records.append({
                        "dataframe": df_name,
                        "column": col,
                        "row_index": idx,
                        "original_value": original_series.loc[idx],
                        "cleansed_value": stripped_series.loc[idx]
                    })

                # Overwrite the column in the DataFrame with the cleansed series
                df[col] = stripped_series

    # Convert the accumulated audit records into a DataFrame for downstream persistence
    audit_log_df: pd.DataFrame = pd.DataFrame(audit_records)

    modification_count: int = len(audit_records)
    logger.info(f"Identifier cleansing complete. {modification_count} values modified and logged.")

    return audit_log_df

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Step 2: Normalize evidence tags for consistent retrieval
# -------------------------------------------------------------------------------------------------------------------------------
def normalize_evidence_tags(df: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Normalizes the evidence tags column using vectorized pandas operations and logs the lineage of changes.

    This function validates the existence of 'tags' and 'evidence_id' columns,
    splits tags by commas, explodes the resulting lists, cleanses tokens by trimming
    and lowercasing, drops empty tags, recombines them in canonical sorted order,
    and constructs a lineage log DataFrame to record all modifications.

    Parameters
    ----------
    df : pd.DataFrame
        The input evidence spans DataFrame containing 'evidence_id' and 'tags' columns.

    Returns
    -------
    Tuple[pd.DataFrame, pd.DataFrame]
        - clean_df: The mutated DataFrame with normalized tags in-place.
        - lineage_df: A DataFrame tracking the history of changes.

    Raises
    ------
    TypeError
        If the input 'df' is not a pandas DataFrame.
    ValueError
        If the DataFrame is empty or missing required columns ('tags', 'evidence_id').
    """
    # Validate that the input is a pandas DataFrame
    if not isinstance(df, pd.DataFrame):
        # Raise a TypeError if the input has an invalid type
        raise TypeError("Input 'df' must be a pandas DataFrame.")
    # Check if the DataFrame is empty
    if df.empty:
        # Raise a ValueError if the DataFrame contains no data
        raise ValueError("Input DataFrame 'df' is empty.")
    # Check if the required columns are present in the DataFrame
    if "tags" not in df.columns or "evidence_id" not in df.columns:
        # Raise a ValueError detailing the missing columns
        raise ValueError("DataFrame must contain 'tags' and 'evidence_id' columns.")

    # Extract the original tags column, casting it to string type
    original_tags: pd.Series = df["tags"].astype("string")

    # Fill any null values in the tags column with an empty string
    filled_tags: pd.Series = original_tags.fillna("")

    # Vectorized splitting: split strings by comma delimiter into lists
    split_tags: pd.Series = filled_tags.str.split(",")

    # Vectorized explosion: transform the lists into individual rows while duplicating index
    exploded_tags: pd.Series = split_tags.explode()

    # Cast the exploded Series to string type for further operations
    string_exploded: pd.Series = exploded_tags.astype("string")

    # Vectorized cleansing: strip whitespace and convert to lowercase
    cleansed_tags: pd.Series = string_exploded.str.strip().str.lower()

    # Create a boolean mask to filter out empty strings and nulls from the exploded Series
    non_empty_mask: pd.Series = (cleansed_tags != "") & cleansed_tags.notnull()

    # Filter the cleansed Series to retain only valid non-empty tokens
    filtered_tags: pd.Series = cleansed_tags[non_empty_mask]

    # Define a helper lambda to sort tokens canonically and join them with commas
    sorted_join_lambda: Callable[[Any], str] = lambda x: ",".join(sorted(x.astype(str)))

    # Vectorized recombination: group by original index and apply the sorted join
    recombined_tags: pd.Series = filtered_tags.groupby(level=0).agg(sorted_join_lambda)

    # Reindex to restore any completely empty rows and ensure index alignment
    final_tags: pd.Series = recombined_tags.reindex(df.index, fill_value="")

    # Create a boolean mask of rows where the values differ from original (with filled nulls)
    changed_mask: pd.Series = filled_tags != final_tags

    # Initialize an empty list to accumulate change records
    lineage_list: List[Dict[str, Any]] = []

    # Check if any changes occurred to populate the lineage records
    if changed_mask.any():
        # Filter the DataFrame to process only changed rows
        changed_df: pd.DataFrame = df[changed_mask]
        # Iterate over the index of the changed DataFrame
        for idx in changed_df.index:
            # Extract the unique evidence identifier for the row
            evidence_id: str = str(changed_df.at[idx, "evidence_id"])
            # Extract the original unnormalized string value
            original_val: str = str(original_tags.at[idx])
            # Extract the newly normalized canonical string value
            normalized_val: str = str(final_tags.at[idx])
            # Append the structured record to the lineage list
            lineage_list.append({
                "evidence_id": evidence_id,
                "original_tags": original_val,
                "normalized_tags": normalized_val,
                "original_string": original_val,
                "normalized_string": normalized_val
            })
    # Overwrite the original tags column with the normalized Series in-place
    df["tags"] = final_tags

    # Convert the lineage list to a pandas DataFrame
    lineage_df: pd.DataFrame = pd.DataFrame(lineage_list)

    # Check if the lineage DataFrame is empty to initialize its columns
    if lineage_df.empty:
        # Create an empty lineage DataFrame with the expected columns
        lineage_df = pd.DataFrame(columns=["evidence_id", "original_tags", "normalized_tags", "original_string", "normalized_string"])

    # Set the lineage DataFrame columns to the string type
    lineage_df = lineage_df.astype("string")
    # Return the mutated DataFrame alongside the lineage log DataFrame
    return df, lineage_df


# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Step 3: Validate that span text is non-empty
# -------------------------------------------------------------------------------------------------------------------------------
def validate_span_text_non_empty(df: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Validates that every evidence span contains substantive, non-empty text.

    This function trims the span text and checks its length. Rows with zero length
    (or nulls) are partitioned into a quarantine DataFrame to prevent the LLM from
    attempting to ground its analysis on empty context.

    Parameters
    ----------
    df : pd.DataFrame
        The evidence spans DataFrame.

    Returns
    -------
    Tuple[pd.DataFrame, pd.DataFrame]
        A tuple containing the clean DataFrame and the quarantine DataFrame.
    """
    logger.info("Validating that evidence span text is non-empty.")

    if "span_text" not in df.columns:
        logger.error("Column 'span_text' missing. Quarantining entire DataFrame.")
        df_quarantine = df.copy()
        df_quarantine["quarantine_reason"] = "Missing 'span_text' column"
        return pd.DataFrame(columns=df.columns), df_quarantine

    # Extract the series and coerce to string
    text_series: pd.Series = df["span_text"].astype("string")

    # Construct the violation mask: True if null OR length after stripping is 0
    # Equation: violation = isnull(text) OR len(strip(text)) == 0
    is_null_mask: pd.Series = text_series.isnull()
    # We only apply .str.strip().str.len() to non-null rows to avoid errors
    is_empty_mask: pd.Series = pd.Series(False, index=df.index)
    is_empty_mask.loc[~is_null_mask] = text_series.loc[~is_null_mask].str.strip().str.len() == 0

    violation_mask: pd.Series = is_null_mask | is_empty_mask

    # Partition the DataFrame
    clean_df: pd.DataFrame = df[~violation_mask].copy()
    quarantine_df: pd.DataFrame = df[violation_mask].copy()

    # Log results and annotate
    violation_count: int = len(quarantine_df)
    if violation_count > 0:
        quarantine_df["quarantine_reason"] = "Span text is null or whitespace-only"
        failing_ids: List[str] = quarantine_df["evidence_id"].head(5).tolist()
        logger.warning(
            f"Quarantined {violation_count} evidence spans due to empty text. "
            f"Examples: {failing_ids}..."
        )
    else:
        logger.debug("All evidence spans passed text content validation.")
        quarantine_df["quarantine_reason"] = pd.Series(dtype="string")

    return clean_df, quarantine_df

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def cleanse_identifier_and_text_fields(dataframes_dict: Dict[str, pd.DataFrame]) -> Dict[str, pd.DataFrame]:
    """
    Orchestrates the deterministic cleansing of identifier and text fields.

    This function executes the whitespace stripping, tag normalization, and text
    validation in strict sequence. It mutates the master DataFrame dictionary in-place
    and aggregates the generated audit and quarantine logs for regulatory provenance.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        The master dictionary containing all pipeline DataFrames.

    Returns
    -------
    Dict[str, pd.DataFrame]
        A dictionary containing the generated logs: 'identifier_audit_log',
        'tag_lineage_log', and 'quarantined_empty_text_spans'.
    """
    logger.info("=== Task 7: Initiating deterministic cleansing of identifier and text fields ===")

    cleansing_logs: Dict[str, pd.DataFrame] = {}

    # Execute Step 1: Strip whitespace from all identifier columns
    # This mutates the DataFrames within the dictionary in-place
    audit_log_df: pd.DataFrame = strip_identifier_whitespace(dataframes_dict=dataframes_dict)
    cleansing_logs["identifier_audit_log"] = audit_log_df

    # Process Evidence Spans specific cleansing
    if "raw_evidence_spans_df" in dataframes_dict:
        working_evidence_df: pd.DataFrame = dataframes_dict["raw_evidence_spans_df"]

        # Execute Step 2: Normalize evidence tags
        working_evidence_df, tag_lineage_df = normalize_evidence_tags(df=working_evidence_df)
        cleansing_logs["tag_lineage_log"] = tag_lineage_df

        # Execute Step 3: Validate that span text is non-empty
        working_evidence_df, q_empty_text = validate_span_text_non_empty(df=working_evidence_df)
        cleansing_logs["quarantined_empty_text_spans"] = q_empty_text

        # Update the master dictionary with the fully cleansed evidence frame
        dataframes_dict["raw_evidence_spans_df"] = working_evidence_df
    else:
        logger.error("CRITICAL: 'raw_evidence_spans_df' missing from dataframes_dict during Task 7.")

    logger.info("=== Task 7: Cleansing of identifier and text fields completed successfully ===")

    # Return the aggregated logs for downstream archival
    return cleansing_logs

# %%
# Task 8 — Cleanse and normalize datetime columns

# ==============================================================================
# Task 8: Cleanse and normalize datetime columns
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Step 1: Parse and validate publication dates
# -------------------------------------------------------------------------------------------------------------------------------
def parse_publication_dates(df: pd.DataFrame) -> pd.DataFrame:
    """
    Parses the publication_date column into timezone-naive datetime64[ns] objects.

    This function enforces strict parsing of the publication dates. It parses the
    strings with utc=True to standardize any mixed timezone offsets, and then safely
    strips the timezone using tz_convert(None) to guarantee a timezone-naive output
    without raising TypeErrors on object arrays.

    Parameters
    ----------
    df : pd.DataFrame
        The raw source documents DataFrame containing the 'publication_date' column.

    Returns
    -------
    pd.DataFrame
        The DataFrame with the 'publication_date' column converted to datetime64[ns].

    Raises
    ------
    ValueError
        If any non-null string in the column cannot be parsed into a valid datetime.
    """
    # Log the initiation of the publication date parsing step
    logger.info("Starting parsing and validation of publication dates (timezone-naive).")

    # Verify that the target column exists in the DataFrame
    if "publication_date" not in df.columns:
        # Log a warning and return the unmodified DataFrame if the column is missing
        logger.warning("Column 'publication_date' not found. Skipping publication date parsing.")
        return df

    # Create a boolean mask identifying rows that originally contained non-null values
    original_notnull_mask: pd.Series = df["publication_date"].notnull()

    # Attempt to parse the dates, coercing unparseable strings to NaT (Not a Time)
    # We use utc=True to force all strings (naive or aware) into a uniform datetime64[ns, UTC] array
    parsed_dates_utc: pd.Series = pd.to_datetime(df["publication_date"], errors="coerce", utc=True)

    # Safely strip the timezone information by converting to timezone-naive
    # This guarantees the resulting dtype is strictly timezone-naive datetime64[ns]
    parsed_dates_naive: pd.Series = parsed_dates_utc.dt.tz_convert(None)

    # Create a boolean mask identifying rows that became null AFTER parsing
    # Equation: failed_parse = original_notnull AND is_null(parsed)
    failed_parse_mask: pd.Series = original_notnull_mask & parsed_dates_naive.isnull()

    # Check if any rows failed the parsing process
    if failed_parse_mask.any():
        # Extract the exact row indices where parsing failed
        failed_indices = df.index[failed_parse_mask].tolist()
        # Extract the original unparseable string values for the error report
        failed_values = df.loc[failed_parse_mask, "publication_date"].tolist()

        # Construct a detailed diagnostic error message
        error_msg = (
            f"Failed to parse {len(failed_indices)} publication dates into timezone-naive datetimes.\n"
            f"Row indices: {failed_indices[:5]}...\n"
            f"Unparseable values: {failed_values[:5]}..."
        )
        # Raise a ValueError to halt the pipeline, enforcing fail-closed validation
        raise ValueError(error_msg)

    # Overwrite the original column with the successfully parsed and timezone-stripped series
    df["publication_date"] = parsed_dates_naive

    # Log the successful completion of the parsing step
    logger.info("Publication dates successfully parsed into timezone-naive datetime64[ns].")

    # Return the mutated DataFrame
    return df

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Step 2: Parse and validate temporal-fact datetimes
# -------------------------------------------------------------------------------------------------------------------------------
def parse_temporal_fact_dates(df: pd.DataFrame) -> pd.DataFrame:
    """
    Parses temporal fact columns into timezone-aware datetime64[ns, UTC] objects.

    This function iterates over the observation and validity window columns, enforcing
    strict UTC localization. It aggregates any parse failures across all columns and
    raises a comprehensive ValueError to prevent silent data corruption.

    Parameters
    ----------
    df : pd.DataFrame
        The raw temporal facts DataFrame.

    Returns
    -------
    pd.DataFrame
        The DataFrame with temporal columns converted to datetime64[ns, UTC].

    Raises
    ------
    ValueError
        If any non-null string in the target columns cannot be parsed into a valid datetime.
    """
    # Log the initiation of the temporal fact parsing step
    logger.info("Starting parsing and validation of temporal fact datetimes (UTC-aware).")

    # Define the specific columns that require UTC datetime parsing
    target_columns: List[str] = ["observation_time", "validity_start", "validity_end"]

    # Initialize a list to accumulate error messages across all columns
    aggregated_errors: List[str] = []

    # Iterate over each target column to apply the parsing logic
    for col in target_columns:
        # Verify that the target column exists in the DataFrame
        if col not in df.columns:
            # Log a warning if a expected temporal column is missing
            logger.warning(f"Column '{col}' not found in temporal facts. Skipping.")
            continue

        # Create a boolean mask identifying rows that originally contained non-null values
        original_notnull_mask: pd.Series = df[col].notnull()

        # Attempt to parse the dates, coercing unparseable strings to NaT
        # utc=True mathematically guarantees conversion/localization to Coordinated Universal Time
        parsed_dates: pd.Series = pd.to_datetime(df[col], errors="coerce", utc=True)

        # Create a boolean mask identifying rows that became null AFTER parsing
        failed_parse_mask: pd.Series = original_notnull_mask & parsed_dates.isnull()

        # Check if any rows failed the parsing process for this specific column
        if failed_parse_mask.any():
            # Extract the exact row indices where parsing failed
            failed_indices = df.index[failed_parse_mask].tolist()
            # Extract the original unparseable string values
            failed_values = df.loc[failed_parse_mask, col].tolist()

            # Append a detailed diagnostic string to the aggregated errors list
            aggregated_errors.append(
                f"Column '{col}': {len(failed_indices)} failures. "
                f"Examples at indices {failed_indices[:3]} with values {failed_values[:3]}"
            )
        else:
            # If parsing was successful, overwrite the original column with the UTC-aware series
            df[col] = parsed_dates

    # Check if any errors were accumulated across the iterated columns
    if aggregated_errors:
        # Construct a master error message detailing all temporal parse failures
        master_error_msg = "Failed to parse temporal fact datetimes into UTC:\n" + "\n".join(aggregated_errors)
        # Raise a ValueError to halt the pipeline, enforcing fail-closed validation
        raise ValueError(master_error_msg)

    # Log the successful completion of the temporal parsing step
    logger.info("Temporal fact datetimes successfully parsed into timezone-aware datetime64[ns, UTC].")

    # Return the mutated DataFrame
    return df

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Step 3: Enforce a consistent timezone policy
# -------------------------------------------------------------------------------------------------------------------------------
def enforce_timezone_policy(
    source_docs_df: pd.DataFrame,
    temporal_facts_df: pd.DataFrame,
    assumption_registry: Dict[str, Any]
) -> None:
    """
    Verifies datetime dtypes and records the timezone policy in the assumption registry.

    This function programmatically asserts that publication dates are timezone-naive
    and temporal facts are timezone-aware (UTC). It then serializes this methodological
    rule into the assumption registry to ensure epistemic traceability.

    Parameters
    ----------
    source_docs_df : pd.DataFrame
        The parsed source documents DataFrame.
    temporal_facts_df : pd.DataFrame
        The parsed temporal facts DataFrame.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions.

    Raises
    ------
    TypeError
        If the programmatic assertions detect a violation of the timezone policy.
    """
    # Log the initiation of the timezone policy enforcement step
    logger.info("Enforcing consistent timezone policy and verifying dtypes.")

    # 1. Verify publication_date is timezone-naive
    if "publication_date" in source_docs_df.columns:
        # Extract the series
        pub_series: pd.Series = source_docs_df["publication_date"]
        # Assert that the dtype is a standard, timezone-naive datetime64
        if not ptypes.is_datetime64_dtype(pub_series) or ptypes.is_datetime64tz_dtype(pub_series):
            # Raise a TypeError if the column contains timezone information
            raise TypeError("Policy Violation: 'publication_date' must be timezone-naive datetime64[ns].")

    # 2. Verify temporal fact columns are timezone-aware (UTC)
    temporal_cols: List[str] = ["observation_time", "validity_start", "validity_end"]
    for col in temporal_cols:
        if col in temporal_facts_df.columns:
            # Extract the series
            temp_series: pd.Series = temporal_facts_df[col]
            # Assert that the dtype is explicitly timezone-aware
            if not ptypes.is_datetime64tz_dtype(temp_series):
                # Raise a TypeError if the column lacks timezone information
                raise TypeError(f"Policy Violation: '{col}' must be timezone-aware datetime64[ns, UTC].")

            # Further verify that the specific timezone is UTC
            if temp_series.dt.tz.zone != "UTC":
                # Raise a TypeError if the timezone is aware but not strictly UTC
                raise TypeError(f"Policy Violation: '{col}' timezone must be strictly 'UTC'.")

    # 3. Record the policy in the assumption registry
    # Define the stable slug for this methodological choice
    registry_slug: str = "timezone_policy"

    # Construct the detailed assumption record
    policy_record: Dict[str, Any] = {
        "temporal_facts_policy": "timezone-aware UTC",
        "publication_dates_policy": "timezone-naive",
        "rationale": (
            "To ensure temporal consistency and prevent cross-zone comparison errors, "
            "all temporal facts bounding evidence validity are strictly localized to UTC. "
            "Publication dates remain timezone-naive as a consistent exception. "
            "Naive and aware datetimes must never be compared directly within the pipeline."
        )
    }

    # Insert the policy record into the mutable registry
    assumption_registry[registry_slug] = policy_record

    # Log the successful verification and documentation of the timezone policy
    logger.info(f"Timezone policy verified programmatically and recorded under '{registry_slug}'.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def cleanse_and_normalize_datetimes(
    dataframes_dict: Dict[str, pd.DataFrame],
    assumption_registry: Dict[str, Any]
) -> None:
    """
    Orchestrates the cleansing and normalization of all datetime columns.

    This function acts as the entry point for Task 8. It extracts the relevant
    DataFrames, passes them through the strict parsing functions, updates the
    master dictionary in-place, and enforces the global timezone policy.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        The master dictionary containing all pipeline DataFrames. Mutated in-place.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions.

    Raises
    ------
    Exception
        Bubbles up any ValueError or TypeError raised by the subordinate parsing steps.
    """
    # Log the initiation of the overarching Task 8 orchestrator
    logger.info("=== Task 8: Initiating cleansing and normalization of datetime columns ===")

    # Extract and process the source documents DataFrame
    if "raw_source_documents_df" in dataframes_dict:
        # Execute Step 1: Parse publication dates
        parsed_source_docs: pd.DataFrame = parse_publication_dates(df=dataframes_dict["raw_source_documents_df"])
        # Update the master dictionary with the parsed DataFrame
        dataframes_dict["raw_source_documents_df"] = parsed_source_docs
    else:
        # Log a critical error if the required DataFrame is missing
        logger.error("CRITICAL: 'raw_source_documents_df' missing from dataframes_dict.")
        parsed_source_docs = pd.DataFrame()

    # Extract and process the temporal facts DataFrame
    if "raw_temporal_facts_df" in dataframes_dict:
        # Execute Step 2: Parse temporal fact datetimes
        parsed_temporal_facts: pd.DataFrame = parse_temporal_fact_dates(df=dataframes_dict["raw_temporal_facts_df"])
        # Update the master dictionary with the parsed DataFrame
        dataframes_dict["raw_temporal_facts_df"] = parsed_temporal_facts
    else:
        # Log a critical error if the required DataFrame is missing
        logger.error("CRITICAL: 'raw_temporal_facts_df' missing from dataframes_dict.")
        parsed_temporal_facts = pd.DataFrame()

    # Execute Step 3: Enforce consistent timezone policy
    # This step verifies the dtypes of the newly parsed DataFrames and updates the registry
    if not parsed_source_docs.empty and not parsed_temporal_facts.empty:
        enforce_timezone_policy(
            source_docs_df=parsed_source_docs,
            temporal_facts_df=parsed_temporal_facts,
            assumption_registry=assumption_registry
        )

    # Log the successful completion of all Task 8 operations
    logger.info("=== Task 8: Datetime cleansing and normalization completed successfully ===")

# %%
# Task 9 — Validate and cleanse JSON payload fields

# ==============================================================================
# Task 9: Validate and cleanse JSON payload fields
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Declarative Schemas for Calibration Parameters
# -------------------------------------------------------------------------------------------------------------------------------

# Declarative mapping of model_id to the exact set of required calibration keys.
# This enforces structural integrity before mathematical execution.
EXPECTED_CALIBRATION_KEYS: Dict[str, FrozenSet[str]] = {
    "MOD_DSGE_LITE": frozenset([
        "sigma", "beta", "kappa", "phi_pi", "phi_y",
        "rho_i", "rho_g", "rho_u", "rho_v", "rho_tau"
    ]),
    "MOD_REGIME_SWITCH": frozenset([
        "p11", "p22", "n_regimes"
    ]),
    "MOD_VAR": frozenset(["lag_order", "coefficients"]),
    "MOD_SVAR": frozenset(["lag_order"]),
    "MOD_LOCAL_PROJ": frozenset(["horizon"]),
    "MOD_ARIMA": frozenset(["p", "d", "q"]),
    "MOD_FACTOR_VAR": frozenset(["n_factors", "lag_order"]),
    "MOD_GVAR": frozenset(["n_countries", "lag_order"]),
    "MOD_ML_SURROGATE": frozenset(["n_estimators", "max_depth"]),
    "MOD_STOCH_VOL": frozenset(["persistence", "vol_of_vol"])
}

# The critical specifications that MUST survive validation for the study to proceed
CRITICAL_SPECS: FrozenSet[str] = frozenset([
    "MSPEC_DSGE_LITE_004",
    "MSPEC_REGIME_SWITCHING_005"
])

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Step 1: Validate that calibration parameters are strict JSON
# -------------------------------------------------------------------------------------------------------------------------------
def parse_calibration_json(df: pd.DataFrame) -> Tuple[pd.DataFrame, List[Dict[str, Any]]]:
    """
    Parses the calibration_params_json column into strict Python dictionaries.

    This function iterates over the model specifications, attempting to parse the
    raw JSON strings. It explicitly skips nulls but flags empty or whitespace-only
    strings as failures. It captures exact parser errors for auditability.

    Parameters
    ----------
    df : pd.DataFrame
        The raw model specifications DataFrame.

    Returns
    -------
    Tuple[pd.DataFrame, List[Dict[str, Any]]]
        - The mutated DataFrame with a new 'parsed_calibration_params' column.
        - A list of error dictionaries detailing any parse failures.
    """
    logger.info("Starting strict JSON parsing of calibration parameters.")

    # Initialize the new column with None (object dtype)
    df["parsed_calibration_params"] = None
    parse_errors: List[Dict[str, Any]] = []

    # Ensure the target column exists
    if "calibration_params_json" not in df.columns:
        logger.error("Column 'calibration_params_json' missing from specifications DataFrame.")
        return df, parse_errors

    # Iterate over the DataFrame using itertuples for performance
    for row in df.itertuples(index=True):
        spec_id: str = getattr(row, "spec_id")
        raw_json: Any = getattr(row, "calibration_params_json")

        # 1. Skip legitimate null values
        if pd.isna(raw_json):
            continue

        # Ensure the value is a string
        raw_json_str: str = str(raw_json)

        # 2. Flag empty or whitespace-only strings as failures
        if len(raw_json_str.strip()) == 0:
            parse_errors.append({
                "spec_id": spec_id,
                "error_type": "parse_error",
                "raw_string": raw_json_str,
                "message": "Payload is an empty or whitespace-only string."
            })
            continue

        # 3. Attempt strict JSON parsing
        try:
            parsed_dict: Dict[str, Any] = json.loads(raw_json_str)
            # Assign the parsed dictionary to the new column using .at for safe scalar insertion
            df.at[row.Index, "parsed_calibration_params"] = parsed_dict
        except json.JSONDecodeError as e:
            # Capture the exact parser error and character position
            parse_errors.append({
                "spec_id": spec_id,
                "error_type": "parse_error",
                "raw_string": raw_json_str,
                "message": f"JSONDecodeError: {str(e)}"
            })

    error_count: int = len(parse_errors)
    if error_count > 0:
        logger.warning(f"Detected {error_count} JSON parse failures in calibration parameters.")
    else:
        logger.info("All non-null calibration parameters parsed successfully.")

    return df, parse_errors

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Step 2: Validate that parsed JSON matches the expected parameter structure
# -------------------------------------------------------------------------------------------------------------------------------
def validate_calibration_structure(
    specs_df: pd.DataFrame,
    models_df: pd.DataFrame
) -> List[Dict[str, Any]]:
    """
    Validates the structural integrity of the parsed calibration dictionaries.

    This function resolves the model family for each specification and compares
    the keys of the parsed dictionary against the declarative EXPECTED_CALIBRATION_KEYS
    schema. It identifies missing and surplus keys using strict set mathematics.

    Parameters
    ----------
    specs_df : pd.DataFrame
        The specifications DataFrame containing the 'parsed_calibration_params' column.
    models_df : pd.DataFrame
        The models DataFrame used to resolve the 'model_id' for each specification.

    Returns
    -------
    List[Dict[str, Any]]
        A list of error dictionaries detailing any structural schema violations.
    """
    logger.info("Starting structural validation of parsed calibration parameters.")
    structural_errors: List[Dict[str, Any]] = []

    # Ensure required columns exist
    if "parsed_calibration_params" not in specs_df.columns or "model_id" not in specs_df.columns:
        logger.error("Required columns missing for structural validation.")
        return structural_errors

    # Merge to ensure we have the authoritative model_id for each spec
    # We use a left merge to preserve all specifications
    merged_df: pd.DataFrame = pd.merge(
        specs_df[["spec_id", "model_id", "parsed_calibration_params"]],
        models_df[["model_id"]],
        on="model_id",
        how="left",
        indicator=True
    )

    for row in merged_df.itertuples():
        spec_id: str = getattr(row, "spec_id")
        model_id: str = getattr(row, "model_id")
        parsed_params: Any = getattr(row, "parsed_calibration_params")
        merge_indicator: str = getattr(row, "_merge")

        # Skip rows that failed parsing or are legitimately null
        if parsed_params is None:
            continue

        # Check for orphaned specifications (referential integrity fallback)
        if merge_indicator == "left_only":
            structural_errors.append({
                "spec_id": spec_id,
                "error_type": "structural_error",
                "message": f"Orphaned specification: model_id '{model_id}' not found in models catalog."
            })
            continue

        # Check if the model family has a defined schema in the registry
        if model_id not in EXPECTED_CALIBRATION_KEYS:
            structural_errors.append({
                "spec_id": spec_id,
                "error_type": "structural_error",
                "message": f"Unknown schema: No expected keys defined for model_id '{model_id}'."
            })
            continue

        # Extract observed and expected key sets
        expected_keys: FrozenSet[str] = EXPECTED_CALIBRATION_KEYS[model_id]
        observed_keys: Set[str] = set(parsed_params.keys())

        # Compute set differences to identify structural violations
        missing_keys: Set[str] = expected_keys - observed_keys
        surplus_keys: Set[str] = observed_keys - expected_keys

        if missing_keys or surplus_keys:
            structural_errors.append({
                "spec_id": spec_id,
                "error_type": "structural_error",
                "missing_keys": list(missing_keys),
                "surplus_keys": list(surplus_keys),
                "message": f"Schema violation for {model_id}. Missing: {missing_keys}. Surplus: {surplus_keys}."
            })

    error_count: int = len(structural_errors)
    if error_count > 0:
        logger.warning(f"Detected {error_count} structural schema violations in calibration parameters.")
    else:
        logger.info("All parsed calibration parameters match their expected structural schemas.")

    return structural_errors

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Step 3: Reject or quarantine rows with invalid JSON
# -------------------------------------------------------------------------------------------------------------------------------
def quarantine_invalid_specifications(
    df: pd.DataFrame,
    parse_errors: List[Dict[str, Any]],
    struct_errors: List[Dict[str, Any]]
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Partitions the specifications DataFrame into clean and quarantined sets.

    This function aggregates all parse and structural errors. It enforces a strict
    protection mechanism: if any of the critical study specifications fail validation,
    the pipeline halts immediately. Otherwise, invalid rows are quarantined without
    heuristic repair.

    Parameters
    ----------
    df : pd.DataFrame
        The specifications DataFrame.
    parse_errors : List[Dict[str, Any]]
        The list of errors generated by Step 1.
    struct_errors : List[Dict[str, Any]]
        The list of errors generated by Step 2.

    Returns
    -------
    Tuple[pd.DataFrame, pd.DataFrame]
        - clean_df: DataFrame containing only structurally sound specifications.
        - quarantine_df: DataFrame containing invalid specifications with error reasons.

    Raises
    ------
    ValueError
        If any specification in CRITICAL_SPECS is found in the failure set.
    """
    logger.info("Partitioning specifications into clean and quarantined sets.")

    # Aggregate all errors into a mapping of spec_id -> error message
    error_map: Dict[str, str] = {}

    for err in parse_errors:
        error_map[err["spec_id"]] = err["message"]

    for err in struct_errors:
        # If a spec failed both (unlikely due to logic flow, but possible), concatenate messages
        if err["spec_id"] in error_map:
            error_map[err["spec_id"]] += f" | {err['message']}"
        else:
            error_map[err["spec_id"]] = err["message"]

    failed_spec_ids: Set[str] = set(error_map.keys())

    # CRITICAL PATH PROTECTION: Ensure study specifications are not compromised
    critical_failures: Set[str] = failed_spec_ids.intersection(CRITICAL_SPECS)
    if critical_failures:
        # Construct a detailed fatal error report
        fatal_msg = "CRITICAL PIPELINE HALT: Essential study specifications failed JSON validation.\n"
        for spec in critical_failures:
            fatal_msg += f"  - {spec}: {error_map[spec]}\n"
        raise ValueError(fatal_msg)

    # Construct the boolean mask for partitioning
    violation_mask: pd.Series = df["spec_id"].isin(failed_spec_ids)

    # Partition the DataFrame
    clean_df: pd.DataFrame = df[~violation_mask].copy()
    quarantine_df: pd.DataFrame = df[violation_mask].copy()

    # Annotate the quarantine DataFrame with the specific failure reasons
    if not quarantine_df.empty:
        quarantine_df["quarantine_reason"] = quarantine_df["spec_id"].map(error_map).astype("string")
        logger.warning(f"Quarantined {len(quarantine_df)} unused catalog specifications due to JSON errors.")
    else:
        logger.debug("No specifications required quarantine.")
        quarantine_df["quarantine_reason"] = pd.Series(dtype="string")

    return clean_df, quarantine_df

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def validate_and_cleanse_json_payloads(dataframes_dict: Dict[str, pd.DataFrame]) -> Dict[str, pd.DataFrame]:
    """
    Orchestrates the validation and cleansing of JSON payload fields.

    This function acts as the entry point for Task 9. It extracts the specifications
    and models DataFrames, executes strict parsing, validates structural schemas,
    and partitions the data. It mutates the master dictionary in-place to ensure
    downstream components only access clean data.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        The master dictionary containing all pipeline DataFrames. Mutated in-place.

    Returns
    -------
    Dict[str, pd.DataFrame]
        A dictionary containing the generated quarantine log: 'quarantined_model_specifications'.

    Raises
    ------
    KeyError
        If required DataFrames are missing from the input dictionary.
    Exception
        Bubbles up any ValueError raised by critical specification failures.
    """
    logger.info("=== Task 9: Initiating validation and cleansing of JSON payload fields ===")

    # Ensure required DataFrames exist
    if "raw_model_specifications_df" not in dataframes_dict or "raw_models_df" not in dataframes_dict:
        raise KeyError("CRITICAL: Required DataFrames missing for JSON payload validation.")

    specs_df: pd.DataFrame = dataframes_dict["raw_model_specifications_df"]
    models_df: pd.DataFrame = dataframes_dict["raw_models_df"]

    # Execute Step 1: Parse calibration parameters as strict JSON
    specs_df, parse_errors = parse_calibration_json(df=specs_df)

    # Execute Step 2: Validate structural schemas of parsed JSON
    struct_errors = validate_calibration_structure(specs_df=specs_df, models_df=models_df)

    # Execute Step 3: Reject or quarantine invalid rows
    clean_specs_df, quarantined_specs_df = quarantine_invalid_specifications(
        df=specs_df,
        parse_errors=parse_errors,
        struct_errors=struct_errors
    )

    # Update the master dictionary with the fully cleansed specifications frame
    dataframes_dict["raw_model_specifications_df"] = clean_specs_df

    logger.info("=== Task 9: JSON payload validation and cleansing completed successfully ===")

    # Return the quarantine log for downstream archival
    return {"quarantined_model_specifications": quarantined_specs_df}

# %%
# Task 10 — Verify or generate synthetic data to match manuscript scale

# ==============================================================================
# Task 10: Verify or generate synthetic data to match manuscript scale
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Step 1: Verify the evidence-corpus size and confidence distribution
# -------------------------------------------------------------------------------------------------------------------------------
def verify_and_synthesize_evidence(
    df: pd.DataFrame,
    assumption_registry: Dict[str, Any],
    target_count: int = 2500,
    seed: int = 42
) -> pd.DataFrame:
    """
    Verifies the evidence corpus size and synthesizes deficits using a Beta distribution.

    This function ensures the evidence DataFrame contains exactly 2,500 rows. If a
    deficit exists, it instantiates a fresh, isolated PRNG to draw synthetic confidence
    scores from a Beta(9, 1) distribution. It then performs a Kolmogorov-Smirnov test
    to verify distributional conformance, logging the result in the assumption registry.

    Parameters
    ----------
    df : pd.DataFrame
        The cleansed evidence spans DataFrame.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions and deviations.
    target_count : int, optional
        The required number of rows (default is 2500).
    seed : int, optional
        The deterministic seed for the isolated PRNG (default is 42).

    Returns
    -------
    pd.DataFrame
        The evidence DataFrame, padded to exactly 2,500 rows if necessary.
    """
    logger.info(f"Verifying evidence corpus size against target of {target_count} rows.")

    current_count: int = len(df)

    if current_count == target_count:
        logger.info("Evidence corpus size matches target. No synthesis required.")
        final_df = df.copy()
    elif current_count > target_count:
        logger.warning(f"Evidence corpus exceeds target ({current_count} > {target_count}). Truncating.")
        final_df = df.iloc[:target_count].copy()
    else:
        deficit: int = target_count - current_count
        logger.info(f"Evidence corpus deficit of {deficit} rows detected. Initiating deterministic synthesis.")

        # Instantiate a fresh, isolated PRNG to guarantee exact reproducibility
        rng: np.random.Generator = np.random.default_rng(seed=seed)

        # Draw synthetic confidence scores from Beta(9, 1)
        # Equation: confidence_i ~ Beta(9, 1)
        synthetic_confidences: np.ndarray = rng.beta(a=9, b=1, size=deficit)

        # Generate unique evidence IDs for the synthetic rows
        # We use a distinct prefix to ensure no collisions with existing IDs
        synthetic_ids: List[str] = [f"EV_SYNTH_{i:04d}" for i in range(1, deficit + 1)]

        # Construct the dummy rows. We fill text and tags with placeholders that will
        # score zero on tag overlap, ensuring they don't pollute the top-k retrieval.
        synthetic_rows = pd.DataFrame({
            "evidence_id": pd.Series(synthetic_ids, dtype="string"),
            "doc_id": pd.Series(["DOC_SYNTHETIC"] * deficit, dtype="string"),
            "span_text": pd.Series(["Synthetic padding row."] * deficit, dtype="string"),
            "tags": pd.Series(["synthetic_padding"] * deficit, dtype="string"),
            "synthetic_confidence": pd.Series(synthetic_confidences, dtype="float64"),
            "char_start_position": pd.Series([0] * deficit, dtype="Int64"),
            "char_end_position": pd.Series([0] * deficit, dtype="Int64")
        })

        # Concatenate the original and synthetic DataFrames
        final_df = pd.concat([df, synthetic_rows], ignore_index=True)
        logger.info("Synthesis complete. Evidence corpus padded to target size.")

    # Perform Kolmogorov-Smirnov goodness-of-fit test on the entire confidence column
    # Null hypothesis: The data is drawn from a Beta(9, 1) distribution.
    conf_data: np.ndarray = final_df["synthetic_confidence"].dropna().to_numpy()

    # scipy.stats.kstest requires the CDF callable and its shape parameters (a=9, b=1)
    ks_stat, p_value = stats.kstest(conf_data, stats.beta.cdf, args=(9, 1))

    # Record the statistical test outcome in the assumption registry
    registry_slug: str = "evidence_confidence_distribution_test"
    assumption_registry[registry_slug] = {
        "test_type": "Kolmogorov-Smirnov",
        "target_distribution": "Beta(9, 1)",
        "ks_statistic": float(ks_stat),
        "p_value": float(p_value),
        "conformance": bool(p_value > 0.01), # Using alpha=0.01 as the rejection threshold
        "rationale": "Verifies that the synthetic confidence scores match the statistical properties implied by the manuscript."
    }

    if p_value <= 0.01:
        logger.warning(f"KS test rejected Beta(9,1) null hypothesis (p={p_value:.4f}). Recorded as deviation.")
    else:
        logger.info(f"KS test confirms Beta(9,1) distributional conformance (p={p_value:.4f}).")

    return final_df

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Step 2: Verify the temporal-facts count and temporal distribution
# -------------------------------------------------------------------------------------------------------------------------------
def verify_and_synthesize_temporal_facts(
    temporal_df: pd.DataFrame,
    evidence_df: pd.DataFrame,
    target_count: int = 2500,
    seed: int = 42
) -> pd.DataFrame:
    """
    Verifies the temporal facts count and synthesizes deficits with uniform 2024 dates.

    This function ensures exactly 2,500 temporal facts exist. If synthesis is required,
    it draws observation times uniformly across 2024 and computes validity ends by
    adding a uniform random integer of months [6, 18]. It enforces UTC localization
    and maintains referential integrity with the evidence DataFrame.

    Parameters
    ----------
    temporal_df : pd.DataFrame
        The cleansed temporal facts DataFrame.
    evidence_df : pd.DataFrame
        The fully sized (2500 row) evidence DataFrame to draw foreign keys from.
    target_count : int, optional
        The required number of rows (default is 2500).
    seed : int, optional
        The deterministic seed for the isolated PRNG (default is 42).

    Returns
    -------
    pd.DataFrame
        The temporal facts DataFrame, padded to exactly 2,500 rows if necessary.
    """
    logger.info(f"Verifying temporal facts size against target of {target_count} rows.")

    current_count: int = len(temporal_df)

    if current_count == target_count:
        logger.info("Temporal facts size matches target. No synthesis required.")
        return temporal_df.copy()
    elif current_count > target_count:
        logger.warning(f"Temporal facts exceed target ({current_count} > {target_count}). Truncating.")
        return temporal_df.iloc[:target_count].copy()

    deficit: int = target_count - current_count
    logger.info(f"Temporal facts deficit of {deficit} rows detected. Initiating deterministic synthesis.")

    # Instantiate a fresh, isolated PRNG
    rng: np.random.Generator = np.random.default_rng(seed=seed)

    # Define the bounds for the year 2024 in Unix epoch seconds
    start_epoch: int = int(pd.Timestamp("2024-01-01T00:00:00Z").timestamp())
    end_epoch: int = int(pd.Timestamp("2024-12-31T23:59:59Z").timestamp())

    # Draw uniform random timestamps across 2024
    random_epochs: np.ndarray = rng.integers(low=start_epoch, high=end_epoch, size=deficit)

    # Convert epochs to timezone-aware UTC datetimes
    observation_times: pd.DatetimeIndex = pd.to_datetime(random_epochs, unit='s', utc=True)

    # Draw random validity window lengths in months: M ~ U(6, 18)
    # high=19 because rng.integers is exclusive of the high bound
    validity_months: np.ndarray = rng.integers(low=6, high=19, size=deficit)

    # Compute validity_end using pandas DateOffset to safely handle calendar arithmetic
    # We iterate because DateOffset does not natively vectorize with an array of different offsets
    validity_ends: List[pd.Timestamp] = [
        obs_time + pd.DateOffset(months=int(m))
        for obs_time, m in zip(observation_times, validity_months)
    ]

    # Generate unique fact IDs
    synthetic_ids: List[str] = [f"TF_SYNTH_{i:04d}" for i in range(1, deficit + 1)]

    # Sample valid evidence_ids to maintain referential integrity
    # We sample with replacement to ensure we have enough IDs
    valid_evidence_ids: np.ndarray = rng.choice(evidence_df["evidence_id"].to_numpy(), size=deficit, replace=True)

    # Construct the synthetic rows
    synthetic_rows = pd.DataFrame({
        "fact_id": pd.Series(synthetic_ids, dtype="string"),
        "evidence_id": pd.Series(valid_evidence_ids, dtype="string"),
        "observation_time": observation_times,
        "validity_start": observation_times, # Validity starts at observation time
        "validity_end": pd.DatetimeIndex(validity_ends),
        "temporal_description": pd.Series(["Synthetic 2024 temporal bound"] * deficit, dtype="string")
    })

    # Concatenate and return
    final_df = pd.concat([temporal_df, synthetic_rows], ignore_index=True)
    logger.info("Synthesis complete. Temporal facts padded to target size with UTC datetimes.")

    return final_df

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Step 3: Verify model-catalogue scale targets
# -------------------------------------------------------------------------------------------------------------------------------
def verify_model_catalog_scale(
    dataframes_dict: Dict[str, pd.DataFrame],
    assumption_registry: Dict[str, Any]
) -> None:
    """
    Verifies the row counts of the six model catalog DataFrames against manuscript targets.

    This function counts the rows in the models, specifications, equations, assumptions,
    documents, and relationships DataFrames. If the counts deviate from the targets
    (e.g., because truncated sample data was provided), it logs the deviation in the
    assumption registry rather than halting the pipeline.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        The master dictionary containing all pipeline DataFrames.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions and deviations.
    """
    logger.info("Verifying model catalog scale targets.")

    # Define the exact target counts specified in Table 3 of the manuscript
    targets: Dict[str, int] = {
        "raw_models_df": 14,
        "raw_model_specifications_df": 420,
        "raw_model_equations_df": 1260,
        "raw_model_assumptions_df": 1260,
        "raw_model_documents_df": 420,
        "raw_model_variable_relationships_df": 2280
    }

    deviations: Dict[str, Dict[str, int]] = {}

    # Iterate over the targets and compare against actual lengths
    for df_name, target_count in targets.items():
        if df_name not in dataframes_dict:
            logger.error(f"Catalog DataFrame '{df_name}' missing. Cannot verify scale.")
            continue

        actual_count: int = len(dataframes_dict[df_name])

        if actual_count != target_count:
            deviations[df_name] = {
                "expected": target_count,
                "actual": actual_count,
                "deficit": target_count - actual_count
            }

    # Record the findings in the assumption registry
    registry_slug: str = "model_catalog_scale_verification"

    if deviations:
        logger.warning(f"Model catalog scale deviations detected in {len(deviations)} tables. Logging to registry.")
        assumption_registry[registry_slug] = {
            "status": "deviated",
            "deviations": deviations,
            "rationale": (
                "The provided raw data structures are truncated samples rather than the full "
                "synthetic catalog. This deviation is recorded for honest reproduction provenance, "
                "but the pipeline is permitted to proceed to evaluate the methodological architecture."
            ),
            "relationship_allocation_rule": "10 relationships for principal families, 5 for others (sums to 2280)."
        }
    else:
        logger.info("All model catalog DataFrames match exact manuscript scale targets.")
        assumption_registry[registry_slug] = {
            "status": "exact_match",
            "rationale": "Catalog scale perfectly matches Table 3."
        }

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def verify_and_synthesize_data_scale(
    dataframes_dict: Dict[str, pd.DataFrame],
    assumption_registry: Dict[str, Any],
    study_config: Dict[str, Any]
) -> None:
    """
    Orchestrates the verification and synthesis of data to match manuscript scale.

    This function acts as the entry point for Task 10. It sequentially executes the
    evidence synthesis, temporal fact synthesis, and catalog scale verification. It
    mutates the master dictionary in-place with the fully scaled DataFrames.

    Parameters
    ----------
    dataframes_dict : Dict[str, pd.DataFrame]
        The master dictionary containing all pipeline DataFrames. Mutated in-place.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions.
    study_config : Dict[str, Any]
        The master study configuration dictionary (used to extract the global seed).

    Raises
    ------
    KeyError
        If required DataFrames are missing from the input dictionary.
    """
    logger.info("=== Task 10: Initiating verification and synthesis of data scale ===")

    # Extract the global deterministic seed
    global_seed: int = study_config.get("llm_execution_parameters", {}).get("seed", 42)

    # Execute Step 1: Verify and synthesize evidence corpus
    if "raw_evidence_spans_df" in dataframes_dict:
        scaled_evidence_df = verify_and_synthesize_evidence(
            df=dataframes_dict["raw_evidence_spans_df"],
            assumption_registry=assumption_registry,
            target_count=2500,
            seed=global_seed
        )
        dataframes_dict["raw_evidence_spans_df"] = scaled_evidence_df
    else:
        raise KeyError("CRITICAL: 'raw_evidence_spans_df' missing. Cannot perform synthesis.")

    # Execute Step 2: Verify and synthesize temporal facts
    if "raw_temporal_facts_df" in dataframes_dict:
        scaled_temporal_df = verify_and_synthesize_temporal_facts(
            temporal_df=dataframes_dict["raw_temporal_facts_df"],
            evidence_df=dataframes_dict["raw_evidence_spans_df"], # Pass the scaled evidence DF
            target_count=2500,
            seed=global_seed + 1 # Offset seed slightly to prevent identical PRNG streams
        )
        dataframes_dict["raw_temporal_facts_df"] = scaled_temporal_df
    else:
        raise KeyError("CRITICAL: 'raw_temporal_facts_df' missing. Cannot perform synthesis.")

    # Execute Step 3: Verify model catalog scale targets
    verify_model_catalog_scale(
        dataframes_dict=dataframes_dict,
        assumption_registry=assumption_registry
    )

    logger.info("=== Task 10: Data scale verification and synthesis completed successfully ===")

# %%
# Task 11 — Provision the local deterministic LLM endpoint and validate determinism

# =================================================================================
# Task 11: Provision the local deterministic LLM endpoint and validate determinism
# =================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 11, Step 1: Configure the inference server with exact settings
# -------------------------------------------------------------------------------------------------------------------------------
class LLMClient:
    """
    Encapsulates the HTTP communication with the local LLM inference server.

    This class enforces the strict deterministic decoding parameters mandated by the
    study (temperature=0, seed=42, top_k=1). It constructs OpenAI-compatible JSON
    payloads and handles network timeouts, ensuring that the agentic workflow
    interacts with the LLM in a reproducible and robust manner.

    Attributes
    ----------
    api_endpoint : str
        The localhost URL for the chat completions endpoint.
    model_name : str
        The exact model identifier (e.g., 'llama3.1:8b').
    temperature : float
        The sampling temperature (strictly 0 for greedy decoding).
    seed : int
        The RNG seed for the inference engine (strictly 42).
    top_p : float
        Nucleus sampling parameter.
    top_k : int
        Top-k sampling parameter.
    max_tokens : int
        The maximum number of tokens to generate.
    stop_sequences : List[str]
        Sequences that trigger early termination of generation.
    """

    def __init__(self, config: Dict[str, Any]) -> None:
        """
        Initializes the LLMClient with parameters extracted from the study configuration.

        Parameters
        ----------
        config : Dict[str, Any]
            The 'llm_execution_parameters' sub-dictionary from the master study_config.
        """
        self.api_endpoint: str = config["api_endpoint"]
        self.model_name: str = config["model_name"]
        self.temperature: float = float(config["temperature"])
        self.seed: int = int(config["seed"])
        self.top_p: float = float(config["top_p"])
        self.top_k: int = int(config["top_k"])
        self.max_tokens: int = int(config["max_tokens"])
        self.stop_sequences: List[str] = config.get("stop_sequences", [])

        logger.info(f"LLMClient initialized: {self.model_name} at {self.api_endpoint} (Temp: {self.temperature}, Seed: {self.seed})")

    def complete(self, messages: List[Dict[str, str]]) -> str:
        """
        Executes a synchronous HTTP POST request to the local LLM endpoint.

        Parameters
        ----------
        messages : List[Dict[str, str]]
            A list of role-tagged message dictionaries (e.g., [{"role": "user", "content": "..."}]).

        Returns
        -------
        str
            The verbatim string content of the generated response.

        Raises
        ------
        RuntimeError
            If the HTTP request fails, times out, or returns a non-200 status code.
        """
        # Construct the strict JSON payload adhering to the OpenAI chat completions schema
        payload: Dict[str, Any] = {
            "model": self.model_name,
            "messages": messages,
            "temperature": self.temperature,
            "seed": self.seed,
            "top_p": self.top_p,
            "top_k": self.top_k,
            "max_tokens": self.max_tokens,
            "stop": self.stop_sequences
        }

        headers: Dict[str, str] = {
            "Content-Type": "application/json"
        }

        try:
            # Execute the POST request with a 120-second timeout to prevent infinite hangs
            response = requests.post(
                url=self.api_endpoint,
                json=payload,
                headers=headers,
                timeout=120.0
            )
            # Raise an HTTPError if the status code is 4xx or 5xx
            response.raise_for_status()

            # Extract the generated text from the response JSON
            response_data: Dict[str, Any] = response.json()
            generated_text: str = response_data["choices"][0]["message"]["content"]

            return generated_text

        except requests.exceptions.RequestException as e:
            # Catch network errors, timeouts, and bad status codes, raising a clear RuntimeError
            error_msg = f"LLM inference request failed: {str(e)}"
            logger.error(error_msg)
            raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 11, Step 2: Validate network isolation
# -------------------------------------------------------------------------------------------------------------------------------
def verify_network_isolation(expected_process_names: List[str] = ["ollama", "llama-server"]) -> bool:
    """
    Audits the active network connections of the inference process to verify isolation.

    This function searches for the local LLM process and inspects its sockets. It
    asserts that all remote connections are restricted to the loopback subnet,
    empirically verifying the "no external data" constraint of the LLM-only condition.

    Parameters
    ----------
    expected_process_names : List[str], optional
        A list of common executable names for local inference engines.

    Returns
    -------
    bool
        True if the process is found and strictly isolated, False otherwise.
    """
    logger.info("Starting network isolation audit for the inference process.")

    target_pid: Optional[int] = None
    target_name: Optional[str] = None

    # Iterate through all running processes to locate the inference engine
    for proc in psutil.process_iter(['pid', 'name']):
        try:
            if any(expected_name in proc.info['name'].lower() for expected_name in expected_process_names):
                target_pid = proc.info['pid']
                target_name = proc.info['name']
                break
        except (psutil.NoSuchProcess, psutil.AccessDenied, psutil.ZombieProcess):
            continue

    if target_pid is None:
        logger.warning(f"Could not locate inference process matching {expected_process_names}. Isolation audit skipped.")
        return False

    logger.info(f"Located inference process '{target_name}' (PID: {target_pid}). Inspecting sockets.")

    try:
        # Extract all network connections for the identified process
        connections = psutil.Process(target_pid).net_connections(kind='inet')

        isolation_breached: bool = False
        # Define acceptable loopback addresses
        loopback_addresses: Set[str] = {"127.0.0.1", "::1", "localhost"}

        for conn in connections:
            # We only care about established connections with a remote endpoint
            if conn.status == 'ESTABLISHED' and conn.raddr:
                remote_ip: str = conn.raddr.ip
                if remote_ip not in loopback_addresses:
                    logger.warning(f"Isolation Breach: Process connected to external IP {remote_ip}:{conn.raddr.port}")
                    isolation_breached = True

        if not isolation_breached:
            logger.info("Network isolation verified. All remote connections are restricted to loopback.")
            return True
        else:
            return False

    except psutil.AccessDenied:
        logger.warning("Access denied when inspecting sockets. Run with elevated privileges for a complete audit.")
        return False

# -------------------------------------------------------------------------------------------------------------------------------
# Task 11, Step 3: Test deterministic behavior on a fixed prompt
# -------------------------------------------------------------------------------------------------------------------------------
def test_llm_determinism(client: LLMClient) -> bool:
    """
    Empirically tests the deterministic behavior of the LLM inference engine.

    This function sends an identical, complex prompt to the LLM twice. It compares
    the two generated strings for exact character-level equality. If divergence occurs
    (e.g., due to GPU floating-point non-determinism), it logs the exact index of
    divergence as an honest methodological limitation.

    Parameters
    ----------
    client : LLMClient
        The configured LLM client instance.

    Returns
    -------
    bool
        True if the outputs are exactly identical, False if divergence is detected.
    """
    logger.info("Starting empirical determinism test on the LLM endpoint.")

    # Define a sufficiently complex prompt to force autoregressive generation
    test_prompt: str = (
        "Explain the transmission mechanism of a monetary policy shock in a New Keynesian "
        "DSGE model. Provide a step-by-step breakdown of how an unexpected increase in the "
        "federal funds rate affects the output gap and inflation via the Euler equation "
        "and the Phillips curve. Be precise and detailed."
    )

    messages: List[Dict[str, str]] = [{"role": "user", "content": test_prompt}]

    try:
        logger.info("Executing first deterministic generation pass...")
        response_1: str = client.complete(messages)

        logger.info("Executing second deterministic generation pass...")
        response_2: str = client.complete(messages)

    except RuntimeError as e:
        logger.error(f"Determinism test failed due to network/API error: {e}")
        return False

    # Compare the two responses for exact character-level equality
    if response_1 == response_2:
        logger.info("Determinism verified. Both generation passes produced identical strings.")
        return True
    else:
        # If divergence occurs, use difflib to find the exact point of failure
        logger.warning("Determinism failure: The two generation passes produced divergent strings.")

        # Find the first index where the strings differ
        divergent_index: int = -1
        for i, (c1, c2) in enumerate(zip(response_1, response_2)):
            if c1 != c2:
                divergent_index = i
                break

        # Handle case where one string is a strict prefix of the other
        if divergent_index == -1:
            divergent_index = min(len(response_1), len(response_2))

        logger.warning(
            f"Divergence detected at character index {divergent_index}. "
            f"Pass 1 snippet: '{response_1[max(0, divergent_index-10):divergent_index+10]}' | "
            f"Pass 2 snippet: '{response_2[max(0, divergent_index-10):divergent_index+10]}'"
        )
        logger.warning("This is likely due to hardware-level floating-point non-determinism. Recorded as a limitation.")
        return False

# -------------------------------------------------------------------------------------------------------------------------------
# Task 11, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def provision_llm_endpoint(study_config: Dict[str, Any], assumption_registry: Dict[str, Any]) -> LLMClient:
    """
    Orchestrates the provisioning and validation of the local LLM endpoint.

    This function acts as the entry point for Task 11. It instantiates the LLMClient
    with the strict deterministic parameters, audits the network isolation of the
    inference process, and empirically tests the determinism of the generation.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions and limitations.

    Returns
    -------
    LLMClient
        The fully configured and validated LLM client ready for agentic orchestration.

    Raises
    ------
    KeyError
        If the 'llm_execution_parameters' section is missing from the configuration.
    """
    logger.info("=== Task 11: Initiating provisioning of local deterministic LLM endpoint ===")

    if "llm_execution_parameters" not in study_config:
        raise KeyError("CRITICAL: 'llm_execution_parameters' missing from study_config.")

    # Execute Step 1: Configure the inference server with exact settings
    client = LLMClient(config=study_config["llm_execution_parameters"])

    # Execute Step 2: Validate network isolation
    is_isolated: bool = verify_network_isolation()

    # Record the isolation audit result in the assumption registry
    assumption_registry["llm_network_isolation_audit"] = {
        "status": "verified" if is_isolated else "unverified_or_breached",
        "rationale": "Empirical verification of the 'no external data' constraint for the LLM-only condition."
    }

    # Execute Step 3: Test deterministic behavior on a fixed prompt
    is_deterministic: bool = test_llm_determinism(client=client)

    # Record the determinism test result in the assumption registry
    assumption_registry["llm_empirical_determinism_test"] = {
        "status": "identical" if is_deterministic else "divergent",
        "rationale": "Empirical verification of temperature=0 and seed=42. Divergence indicates hardware-level non-determinism."
    }

    logger.info("=== Task 11: LLM endpoint provisioning and validation completed ===")

    return client

# %%
# Task 12 — Provision Neo4j graph database and enforce schema constraints

# ==============================================================================
# Task 12: Provision Neo4j graph database and enforce schema constraints
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Step 1: Create the database and apply uniqueness constraints
# -------------------------------------------------------------------------------------------------------------------------------
def apply_uniqueness_constraints(driver: Driver) -> None:
    """
    Applies idempotent uniqueness constraints to the Neo4j graph database.

    This function executes the three specific Cypher constraints mandated by the
    manuscript (Appendix A.4) to enforce uniqueness on scenario_id, evidence_id,
    and spec_id. It also augments these with four additional constraints for the
    write-back nodes to ensure robustness against partial reset failures.

    Parameters
    ----------
    driver : neo4j.Driver
        The authenticated Neo4j driver connection pool manager.

    Raises
    ------
    RuntimeError
        If the database is unreachable or the Cypher execution fails.
    """
    logger.info("Starting application of Neo4j uniqueness constraints.")

    # Define the exact Cypher statements from the manuscript
    manuscript_constraints: List[str] = [
        "CREATE CONSTRAINT scenario_id_unique IF NOT EXISTS FOR (s:Scenario) REQUIRE s.scenario_id IS UNIQUE;",
        "CREATE CONSTRAINT evidence_id_unique IF NOT EXISTS FOR (e:EvidenceSpan) REQUIRE e.evidence_id IS UNIQUE;",
        "CREATE CONSTRAINT spec_id_unique IF NOT EXISTS FOR (m:ModelSpecification) REQUIRE m.spec_id IS UNIQUE;"
    ]

    # Define augmented constraints for write-back robustness (resolved decision)
    augmented_constraints: List[str] = [
        "CREATE CONSTRAINT run_id_unique IF NOT EXISTS FOR (r:ModelRun) REQUIRE r.run_id IS UNIQUE;",
        "CREATE CONSTRAINT impl_id_unique IF NOT EXISTS FOR (i:ImplementationFunction) REQUIRE i.impl_id IS UNIQUE;",
        "CREATE CONSTRAINT output_id_unique IF NOT EXISTS FOR (o:ModelOutputPoint) REQUIRE o.output_id IS UNIQUE;",
        "CREATE CONSTRAINT metric_id_unique IF NOT EXISTS FOR (b:BankMetric) REQUIRE b.metric_id IS UNIQUE;"
    ]

    # Combine all constraints into a single execution list
    all_constraints: List[str] = manuscript_constraints + augmented_constraints

    def _execute_constraints(tx: Transaction) -> None:
        """Helper function to execute constraints within a managed transaction."""
        for statement in all_constraints:
            # Execute the Cypher statement
            tx.run(statement)

    try:
        # Open a managed write session to ensure transaction safety
        with driver.session() as session:
            session.execute_write(_execute_constraints)
        logger.info(f"Successfully applied {len(all_constraints)} uniqueness constraints.")
    except neo4j.exceptions.ServiceUnavailable as e:
        error_msg = f"Neo4j database is unreachable. Ensure the server is running. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e
    except neo4j.exceptions.ClientError as e:
        error_msg = f"Failed to execute constraint creation Cypher. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Step 2: Create the required index
# -------------------------------------------------------------------------------------------------------------------------------
def create_scenario_application_index(driver: Driver) -> None:
    """
    Creates the secondary index on the Scenario application_number property.

    This function executes the exact Cypher index creation statement mandated by
    the manuscript to support efficient scenario-specific lookups.

    Parameters
    ----------
    driver : neo4j.Driver
        The authenticated Neo4j driver connection pool manager.

    Raises
    ------
    RuntimeError
        If the database is unreachable or the Cypher execution fails.
    """
    logger.info("Starting creation of Scenario application_number index.")

    # Define the exact Cypher statement from the manuscript
    index_statement: str = (
        "CREATE INDEX scenario_app_idx IF NOT EXISTS "
        "FOR (s:Scenario) ON (s.application_number);"
    )

    def _execute_index(tx: Transaction) -> None:
        """Helper function to execute the index creation within a managed transaction."""
        tx.run(index_statement)

    try:
        # Open a managed write session
        with driver.session() as session:
            session.execute_write(_execute_index)
        logger.info("Successfully created index 'scenario_app_idx'.")
    except neo4j.exceptions.ServiceUnavailable as e:
        error_msg = f"Neo4j database is unreachable. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e
    except neo4j.exceptions.ClientError as e:
        error_msg = f"Failed to execute index creation Cypher. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Step 3: Verify node-label taxonomy support
# -------------------------------------------------------------------------------------------------------------------------------
def verify_node_label_taxonomy() -> None:
    """
    Verifies and documents the readiness of the database to accept the 16 node labels.

    Because Neo4j is schema-optional and creates labels dynamically upon node
    insertion, this function does not execute redundant database queries. Instead,
    it acts as a declarative contract, logging the exact taxonomy expected by the
    downstream Graph Loader to ensure epistemic traceability.
    """
    logger.info("Verifying node-label taxonomy support.")

    # Enumerate the 16 exact node labels defined in Table 1 of the manuscript
    expected_labels: List[str] = [
        "SourceDocument", "EvidenceSpan", "TemporalFact",
        "Scenario", "Shock", "VariableConcept",
        "Model", "ModelSpecification", "ModelEquation", "ModelAssumption", "ModelDocument",
        "ImplementationFunction", "ModelRun", "ForecastOutcome", "ModelOutputPoint", "BankMetric"
    ]

    # Log the declarative contract
    logger.info(
        f"Database is provisioned and ready to dynamically accept the {len(expected_labels)} "
        f"node labels defined in the schema: {', '.join(expected_labels)}."
    )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def provision_neo4j_database(driver: Any) -> None:
    """
    Orchestrates the provisioning of the Neo4j graph database.

    This function acts as the entry point for Task 12. It validates the driver
    object and sequentially executes the constraint application, index creation,
    and taxonomy verification steps, ensuring the database is structurally prepared
    for data loading.

    Parameters
    ----------
    driver : Any
        The authenticated Neo4j driver connection pool manager. Typed as Any to
        avoid strict dependency injection failures if the neo4j package is mocked,
        but validated internally.

    Raises
    ------
    TypeError
        If the provided driver is not a valid neo4j.Driver instance.
    Exception
        Bubbles up any RuntimeError raised by the subordinate Cypher execution steps.
    """
    logger.info("=== Task 12: Initiating Neo4j graph database provisioning ===")

    # Validate that the provided object is actually a Neo4j Driver
    if not isinstance(driver, Driver):
        error_msg = f"Expected a neo4j.Driver instance, got {type(driver).__name__}."
        logger.error(error_msg)
        raise TypeError(error_msg)

    # Execute Step 1: Create the database and apply uniqueness constraints
    apply_uniqueness_constraints(driver=driver)

    # Execute Step 2: Create the required index
    create_scenario_application_index(driver=driver)

    # Execute Step 3: Verify node-label taxonomy support
    verify_node_label_taxonomy()

    logger.info("=== Task 12: Neo4j graph database provisioning completed successfully ===")

# %%
# Task 13 — Implement Graph Reset callable (per-application state isolation)

# ==============================================================================
# Task 13: Implement Graph Reset callable (per-application state isolation)
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Step 2: Implement the Graph Reset logic using a batched Cypher query
# -------------------------------------------------------------------------------------------------------------------------------
def _execute_atomic_deletion(driver: Driver) -> None:
    """
    Purges all nodes and relationships from the database using a batched deletion loop.

    This function executes a batched Cypher query to detach and delete nodes in
    chunks of 10,000. It loops until the database reports zero nodes deleted,
    preventing Out-Of-Memory (OOM) errors and transaction timeouts on large graphs.

    Parameters
    ----------
    driver : Driver
        The authenticated Neo4j driver connection pool manager.

    Returns
    -------
    None

    Raises
    ------
    TypeError
        If the driver parameter is not a neo4j.Driver instance.
    RuntimeError
        If the database query fails due to connectivity or server-side issues.
    """
    # Validate that driver is a neo4j.Driver instance
    if not isinstance(driver, Driver):
        # Raise TypeError if the driver has an invalid type
        raise TypeError("Input 'driver' must be an instance of neo4j.Driver.")

    # Define the batched Cypher query to detach and delete nodes
    # We use WITH and LIMIT to bound the transaction size
    cypher_query: str = """
    MATCH (n)
    WITH n LIMIT 10000
    DETACH DELETE n
    RETURN count(n) AS deleted_count;
    """

    # Define the internal transaction helper function for batched deletion
    def _delete_batch(tx: Transaction) -> int:
        """Helper function to execute a single deletion batch and return the count."""
        # Execute the query within the managed transaction context
        result = tx.run(cypher_query)
        # Retrieve the single record returned by the query
        record = result.single()
        # Return the number of nodes deleted in this batch
        return record["deleted_count"] if record else 0

    try:
        # Open a session to manage the deletion loop
        with driver.session() as session:
            total_deleted: int = 0
            while True:
                # Execute a single batch deletion in a managed write transaction
                deleted_in_batch: int = session.execute_write(_delete_batch)
                total_deleted += deleted_in_batch

                # If no nodes were deleted, the graph is empty; break the loop
                if deleted_in_batch == 0:
                    break

        # Log the total number of nodes deleted across all batches
        logger.info(f"Batched database deletion completed. Total nodes deleted: {total_deleted}")

    # Catch any Neo4j specific database exceptions
    except Exception as e:
        # Construct a detailed error message for database execution failures
        error_msg: str = f"Batched database deletion failed: {e}"
        # Log the error message at the error level
        logger.error(error_msg)
        # Raise a RuntimeError to halt the pipeline and preserve consistency
        raise RuntimeError(error_msg) from e

# Define _execute_batched_deletion as an alias to preserve structural backward compatibility
_execute_batched_deletion: Callable[[Driver], None] = _execute_atomic_deletion

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Step 3: Validate Graph Reset succeeded by counting nodes
# -------------------------------------------------------------------------------------------------------------------------------
def _verify_graph_is_empty(driver: Driver) -> bool:
    """
    Verifies that the graph database is completely empty using a read transaction.

    This function enforces read-committed isolation by executing a separate read
    transaction after the write operations have completed. It asserts that the
    node count is exactly zero, ensuring no state leakage occurs.

    Parameters
    ----------
    driver : neo4j.Driver
        The authenticated Neo4j driver connection pool manager.

    Returns
    -------
    bool
        True if the graph is empty.

    Raises
    ------
    RuntimeError
        If the node count is non-zero or the query fails.
    """
    logger.info("Verifying graph reset success via read-committed isolation.")

    # Define the Cypher query to count all remaining nodes
    count_query: str = "MATCH (n) RETURN count(n) AS node_count;"

    def _count_nodes(tx: Transaction) -> int:
        """Helper function to execute the count query within a managed read transaction."""
        result = tx.run(count_query)
        record = result.single()
        return record["node_count"] if record else -1

    try:
        # Open a new session for the read transaction to ensure we see the committed state
        with driver.session() as session:
            remaining_nodes: int = session.execute_read(_count_nodes)

        # Assert that the graph is completely empty
        if remaining_nodes == 0:
            logger.info("Graph reset verified. Node count is exactly 0.")
            return True
        else:
            # If nodes remain, the reset failed (e.g., due to concurrent writes)
            error_msg = f"Graph reset verification failed. {remaining_nodes} nodes remain in the database."
            logger.error(error_msg)
            raise RuntimeError(error_msg)

    except neo4j.exceptions.Neo4jError as e:
        error_msg = f"Failed to execute verification count query. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def reset_knowledge_graph(driver: Any) -> bool:
    """
    Orchestrates the atomic reset of the Knowledge Graph for state isolation.

    Purpose:
    --------
    To ensure absolute state isolation between application runs, this orchestrator
    executes two distinct database transaction phases. First, it triggers an
    atomic, unbatched write transaction to purge all nodes and relationships.
    Second, it opens a read-committed session to verify that the database is
    completely empty (0 nodes), enforcing a strict fail-closed policy. This version
    has been refactored to resolve the critical NameError in the failure path.

    Parameters:
    -----------
    driver : Any
        The connection pool manager for the Neo4j instance. Handled as Any to
        accommodate mocking during unit testing, but validated internally as
        a neo4j.Driver instance.

    Returns:
    --------
    bool
        True if the database is confirmed to contain exactly zero nodes, signaling
        successful state isolation and readiness for the Graph Loading phase.

    Raises:
    -------
    TypeError
        If the driver parameter is not a neo4j.Driver instance.
    RuntimeError
        If the deletion transaction fails, if the verification transaction fails,
        or if the remaining node count is non-zero after execution.

    Examples:
    ---------
    >>> from neo4j import GraphDatabase
    >>> driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "password"))
    >>> success = reset_knowledge_graph(driver)
    >>> print(success)
    True
    """
    # Pre-emptively validate that the passed driver is a valid Neo4j Driver instance to ensure type safety
    if not isinstance(driver, Driver):
        # Format a clear, clinical error message indicating the invalid type mismatch
        type_error_msg: str = f"Reset orchestrator requires a neo4j.Driver instance, got {type(driver).__name__}."
        # Raise a TypeError to halt execution immediately before any transactional side-effects occur
        raise TypeError(type_error_msg)

    # Wrap the entire orchestration sequence in a try-except block to guarantee robust error capture and fail-closed safety
    try:
        # Log the start of the atomic purge transaction to the system log
        logger.info("Executing Step 1 of Graph Reset: Calling atomic deletion function.")

        # Execute the single-parameter atomic deletion to wipe all nodes and relationships from the database
        _execute_atomic_deletion(driver=driver)

        # Log the successful completion of the deletion step
        logger.info("Atomic database deletion committed. Proceeding to verification.")

        # Define the exact atomic Cypher query to count all remaining nodes
        count_query: str = "MATCH (n) RETURN count(n) AS node_count;"

        # Define the internal transaction helper function for verifying empty state
        def _count_remaining(tx: Transaction) -> int:
            # Execute the counting query within the transaction
            result = tx.run(count_query)
            # Retrieve the single record returned by the query
            record = result.single()
            # Return the resulting node count, defaulting to -1 if the record is missing
            return int(record["node_count"]) if record else -1

        # Log the initiation of the verification read session
        logger.info("Executing Step 2 of Graph Reset: Initiating read-committed verification session.")

        # Open a dedicated, read-committed session to isolate the query from any uncommitted transactions
        with driver.session() as session:
            # Execute the count check inside a managed read transaction to guarantee consistency
            node_count: int = session.execute_read(_count_remaining)

        # Log the extracted node count value to the system log
        logger.info(f"Read-committed count check completed. Remaining node count: {node_count}")

        # Evaluate the logical invariant: the database must contain exactly zero nodes
        if node_count == 0:
            # Log the successful verification result
            logger.info("Verification passed: Graph is completely empty. Isolating state.")
            # Return True to indicate successful, verified graph reset
            return True

        # Process the failure if the remaining node count is non-zero
        else:
            # Construct a detailed error report for the state isolation violation, strictly referencing node_count
            error_msg: str = f"Graph reset verification failed. {node_count} nodes still exist."
            # Raise a RuntimeError to halt the pipeline immediately
            raise RuntimeError(error_msg)

    # Catch any standard database or runtime exceptions raised during execution
    except Exception as e:
        # Construct a comprehensive error report detailing the orchestrator failure
        error_msg: str = f"reset_knowledge_graph orchestrator failed: {e}"
        # Log the critical failure message
        logger.error(error_msg)
        # Raise a RuntimeError to propagate the failure and fail-closed
        raise RuntimeError(error_msg) from e

# %%
# Task 14 — Implement Graph Loading callable (pre-run KG materialization)

# ==============================================================================
# Task 14: Implement Graph Loading callable (pre-run KG materialization)
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Helper Function: Prepare DataFrame for Neo4j UNWIND
# -------------------------------------------------------------------------------------------------------------------------------
def _prepare_records_for_neo4j(df: pd.DataFrame) -> List[Dict[str, Any]]:
    """
    Cleanses and converts a pandas DataFrame into a list of dictionaries for Neo4j UNWIND.

    This helper function handles the serialization of pandas-specific types (like NaT,
    NaN, and pd.NA) into standard Python None types, which the Neo4j driver can
    process. It also formats datetime objects into ISO 8601 strings.

    Parameters
    ----------
    df : pd.DataFrame
        The DataFrame to be converted.

    Returns
    -------
    List[Dict[str, Any]]
        A list of dictionaries ready for parameterized Cypher execution.
    """
    # Create a copy to avoid mutating the original DataFrame
    temp_df = df.copy()

    # Convert datetime columns to ISO 8601 strings
    for col in temp_df.select_dtypes(include=['datetime64[ns, UTC]', 'datetime64[ns]']).columns:
        # Format as string, replacing NaT with None
        temp_df[col] = temp_df[col].dt.strftime('%Y-%m-%dT%H:%M:%SZ').replace({np.nan: None})

    # Replace pandas NA and numpy NaN with Python None for Neo4j compatibility
    temp_df = temp_df.replace({pd.NA: None, np.nan: None})

    # Convert to list of dictionaries
    return temp_df.to_dict(orient='records')

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Step 2: Load evidence and temporal objects into Neo4j
# -------------------------------------------------------------------------------------------------------------------------------
def _load_evidence_and_temporal_objects(driver: Driver, dataframes_dict: Dict[str, pd.DataFrame]) -> Dict[str, int]:
    """
    Loads SourceDocument, EvidenceSpan, and TemporalFact nodes and their relationships.

    This function uses batched UNWIND Cypher queries with MERGE semantics to ensure
    idempotent creation of the evidence corpus. It explicitly enforces the
    (:TemporalFact)-[:BOUNDS]->(:EvidenceSpan) relationship direction.

    Parameters
    ----------
    driver : neo4j.Driver
        The authenticated Neo4j driver.
    dataframes_dict : Dict[str, pd.DataFrame]
        The dictionary containing the cleansed DataFrames.

    Returns
    -------
    Dict[str, int]
        A dictionary containing the counts of nodes and relationships created.
    """
    logger.info("Initiating loading of evidence and temporal objects into Knowledge Graph.")
    audit_counts: Counter = Counter()

    # Prepare records
    docs_records = _prepare_records_for_neo4j(dataframes_dict["raw_source_documents_df"])
    spans_records = _prepare_records_for_neo4j(dataframes_dict["raw_evidence_spans_df"])
    facts_records = _prepare_records_for_neo4j(dataframes_dict["raw_temporal_facts_df"])

    # Define Cypher queries
    query_docs = """
    UNWIND $batch AS row
    MERGE (d:SourceDocument {doc_id: row.doc_id})
    SET d.title = row.title,
        d.publication_date = CASE WHEN row.publication_date IS NOT NULL THEN datetime(row.publication_date) ELSE NULL END,
        d.document_type = row.document_type,
        d.source_institution = row.source_institution
    """

    query_spans = """
    UNWIND $batch AS row
    MERGE (e:EvidenceSpan {evidence_id: row.evidence_id})
    SET e.span_text = row.span_text,
        e.tags = row.tags,
        e.synthetic_confidence = row.synthetic_confidence,
        e.char_start_position = row.char_start_position,
        e.char_end_position = row.char_end_position
    WITH e, row
    MATCH (d:SourceDocument {doc_id: row.doc_id})
    MERGE (d)-[:CONTAINS]->(e)
    """

    query_facts = """
    UNWIND $batch AS row
    MERGE (t:TemporalFact {fact_id: row.fact_id})
    SET t.observation_time = CASE WHEN row.observation_time IS NOT NULL THEN datetime(row.observation_time) ELSE NULL END,
        t.validity_start = CASE WHEN row.validity_start IS NOT NULL THEN datetime(row.validity_start) ELSE NULL END,
        t.validity_end = CASE WHEN row.validity_end IS NOT NULL THEN datetime(row.validity_end) ELSE NULL END,
        t.temporal_description = row.temporal_description
    WITH t, row
    MATCH (e:EvidenceSpan {evidence_id: row.evidence_id})
    MERGE (t)-[:BOUNDS]->(e)
    """

    def _execute_batch(tx: Transaction, query: str, batch: List[Dict[str, Any]]) -> Tuple[int, int]:
        """Executes a batch and returns (nodes_created, relationships_created)."""
        result = tx.run(query, batch=batch)
        summary = result.consume()
        return summary.counters.nodes_created, summary.counters.relationships_created

    try:
        with driver.session() as session:
            # Load Source Documents
            n_created, r_created = session.execute_write(_execute_batch, query_docs, docs_records)
            audit_counts["SourceDocument_nodes_created"] += n_created

            # Load Evidence Spans and CONTAINS edges
            n_created, r_created = session.execute_write(_execute_batch, query_spans, spans_records)
            audit_counts["EvidenceSpan_nodes_created"] += n_created
            audit_counts["CONTAINS_edges_created"] += r_created

            # Load Temporal Facts and BOUNDS edges
            n_created, r_created = session.execute_write(_execute_batch, query_facts, facts_records)
            audit_counts["TemporalFact_nodes_created"] += n_created
            audit_counts["BOUNDS_edges_created"] += r_created

    except neo4j.exceptions.Neo4jError as e:
        error_msg = f"Failed to load evidence/temporal objects. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

    logger.info(f"Evidence and temporal loading complete. Audit: {dict(audit_counts)}")
    return dict(audit_counts)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Step 3: Load economic task and model catalog objects
# -------------------------------------------------------------------------------------------------------------------------------
def _load_task_and_catalog_objects(
    driver: Driver,
    application_number: int,
    dataframes_dict: Dict[str, pd.DataFrame],
    study_config: Dict[str, Any]
) -> Dict[str, int]:
    """
    Loads Scenario, Shock, VariableConcept, and all Model Catalog nodes and relationships.

    This function enforces application-specific filtering to prevent state leakage.
    It utilizes a strict two-phase loading strategy (nodes first, then relationships)
    to ensure referential integrity within the graph database.

    Parameters
    ----------
    driver : neo4j.Driver
        The authenticated Neo4j driver.
    application_number : int
        The experimental application index (1 or 2).
    dataframes_dict : Dict[str, pd.DataFrame]
        The dictionary containing the cleansed DataFrames.
    study_config : Dict[str, Any]
        The master configuration dictionary.

    Returns
    -------
    Dict[str, int]
        A dictionary containing the counts of nodes and relationships created.
    """
    logger.info(f"Initiating loading of task and catalog objects for Application {application_number}.")
    audit_counts: Counter = Counter()

    # 1. Resolve the current scenario ID
    app_key = f"application_{application_number}"
    if app_key not in study_config["application_scenarios"]:
        raise KeyError(f"Scenario configuration for {app_key} not found.")

    scenario_data = study_config["application_scenarios"][app_key]
    current_scenario_id = scenario_data["scenario_id"]

    # 2. Filter Shocks and Variables to the current application
    shocks_df = dataframes_dict["raw_shocks_df"]
    filtered_shocks_df = shocks_df[shocks_df["scenario_id"] == current_scenario_id]

    vars_df = dataframes_dict["raw_variable_concepts_df"]
    filtered_vars_df = vars_df[vars_df["scenario_id"] == current_scenario_id]

    # 3. Prepare records
    scenario_records = [scenario_data] # Single record list
    shocks_records = _prepare_records_for_neo4j(filtered_shocks_df)
    vars_records = _prepare_records_for_neo4j(filtered_vars_df)

    models_records = _prepare_records_for_neo4j(dataframes_dict["raw_models_df"])
    specs_records = _prepare_records_for_neo4j(dataframes_dict["raw_model_specifications_df"])
    eqs_records = _prepare_records_for_neo4j(dataframes_dict["raw_model_equations_df"])
    assums_records = _prepare_records_for_neo4j(dataframes_dict["raw_model_assumptions_df"])
    docs_records = _prepare_records_for_neo4j(dataframes_dict["raw_model_documents_df"])
    impls_records = _prepare_records_for_neo4j(dataframes_dict["raw_implementation_functions_df"])
    rels_records = _prepare_records_for_neo4j(dataframes_dict["raw_model_variable_relationships_df"])

    # 4. Define Phase 1 Queries (Node Creation)
    node_queries = {
        "Scenario": "UNWIND $batch AS row MERGE (n:Scenario {scenario_id: row.scenario_id}) SET n.application_number = row.application_number, n.narrative_text = row.narrative_text",
        "Shock": "UNWIND $batch AS row MERGE (n:Shock {shock_id: row.shock_id}) SET n.shock_description = row.shock_description, n.shock_type = row.shock_type",
        "VariableConcept": "UNWIND $batch AS row MERGE (n:VariableConcept {concept_id: row.concept_id}) SET n.variable_name = row.variable_name, n.variable_symbol = row.variable_symbol, n.is_target_variable = row.is_target_variable",
        "Model": "UNWIND $batch AS row MERGE (n:Model {model_id: row.model_id}) SET n.model_name = row.model_name, n.model_category = row.model_category",
        "ModelSpecification": "UNWIND $batch AS row MERGE (n:ModelSpecification {spec_id: row.spec_id}) SET n.spec_description = row.spec_description, n.calibration_params_json = row.calibration_params_json",
        "ModelEquation": "UNWIND $batch AS row MERGE (n:ModelEquation {eq_id: row.eq_id}) SET n.equation_name = row.equation_name, n.latex_equation = row.latex_equation",
        "ModelAssumption": "UNWIND $batch AS row MERGE (n:ModelAssumption {assumption_id: row.assumption_id}) SET n.assumption_text = row.assumption_text",
        "ModelDocument": "UNWIND $batch AS row MERGE (n:ModelDocument {model_document_id: row.model_document_id}) SET n.title = row.title, n.version = row.version",
        "ImplementationFunction": "UNWIND $batch AS row MERGE (n:ImplementationFunction {impl_id: row.impl_id}) SET n.execution_tool_name = row.execution_tool_name, n.python_module_path = row.python_module_path"
    }

    # 5. Define Phase 2 Queries (Relationship Creation)
    edge_queries = {
        "DRIVEN_BY": "UNWIND $batch AS row MATCH (s:Scenario {scenario_id: row.scenario_id}), (sh:Shock {shock_id: row.shock_id}) MERGE (s)-[:DRIVEN_BY]->(sh)",
        "AFFECTS": "UNWIND $batch AS row MATCH (s:Scenario {scenario_id: row.scenario_id}), (v:VariableConcept {concept_id: row.concept_id}) MERGE (s)-[:AFFECTS]->(v)",
        "HAS_SPECIFICATION": "UNWIND $batch AS row MATCH (m:Model {model_id: row.model_id}), (ms:ModelSpecification {spec_id: row.spec_id}) MERGE (m)-[:HAS_SPECIFICATION]->(ms)",
        "CONTAINS_EQUATION": "UNWIND $batch AS row MATCH (ms:ModelSpecification {spec_id: row.spec_id}), (eq:ModelEquation {eq_id: row.eq_id}) MERGE (ms)-[:CONTAINS_EQUATION]->(eq)",
        "HAS_ASSUMPTION": "UNWIND $batch AS row MATCH (ms:ModelSpecification {spec_id: row.spec_id}), (ma:ModelAssumption {assumption_id: row.assumption_id}) MERGE (ms)-[:HAS_ASSUMPTION]->(ma)",
        "HAS_DOCUMENT": "UNWIND $batch AS row MATCH (ms:ModelSpecification {spec_id: row.spec_id}), (md:ModelDocument {model_document_id: row.model_document_id}) MERGE (ms)-[:HAS_DOCUMENT]->(md)",
        "MAPS_TO": "UNWIND $batch AS row MATCH (ms:ModelSpecification {spec_id: row.spec_id}), (impl:ImplementationFunction {impl_id: row.impl_id}) MERGE (ms)-[:MAPS_TO]->(impl)",
        # Explicitly reversing the semantic direction of the bridge table to match the required graph topology
        "SUPPORTED_BY": "UNWIND $batch AS row MATCH (v:VariableConcept {concept_id: row.concept_id}), (ms:ModelSpecification {spec_id: row.spec_id}) WHERE row.relationship_type = 'OUTPUTS_VARIABLE' MERGE (v)-[:SUPPORTED_BY]->(ms)"
    }

    def _execute_batch(tx: Transaction, query: str, batch: List[Dict[str, Any]]) -> Tuple[int, int]:
        result = tx.run(query, batch=batch)
        summary = result.consume()
        return summary.counters.nodes_created, summary.counters.relationships_created

    try:
        with driver.session() as session:
            # Phase 1: Create all nodes
            for label, query in node_queries.items():
                records = locals()[f"{label.lower() if label == 'Scenario' else label.lower() + 's' if label in ['Shock', 'Model'] else label.replace('Model', '').lower() + 's'}_records"]
                # Manual mapping for clarity due to dynamic local variable naming limitations
                mapping = {
                    "Scenario": scenario_records, "Shock": shocks_records, "VariableConcept": vars_records,
                    "Model": models_records, "ModelSpecification": specs_records, "ModelEquation": eqs_records,
                    "ModelAssumption": assums_records, "ModelDocument": docs_records, "ImplementationFunction": impls_records
                }
                n_created, _ = session.execute_write(_execute_batch, query, mapping[label])
                audit_counts[f"{label}_nodes_created"] += n_created

            # Phase 2: Create all relationships
            edge_mappings = {
                "DRIVEN_BY": shocks_records, "AFFECTS": vars_records, "HAS_SPECIFICATION": specs_records,
                "CONTAINS_EQUATION": eqs_records, "HAS_ASSUMPTION": assums_records, "HAS_DOCUMENT": docs_records,
                "MAPS_TO": impls_records, "SUPPORTED_BY": rels_records
            }
            for rel_type, query in edge_queries.items():
                _, r_created = session.execute_write(_execute_batch, query, edge_mappings[rel_type])
                audit_counts[f"{rel_type}_edges_created"] += r_created

    except neo4j.exceptions.Neo4jError as e:
        error_msg = f"Failed to load task/catalog objects. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

    logger.info(f"Task and catalog loading complete. Audit: {dict(audit_counts)}")
    return dict(audit_counts)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def load_knowledge_graph(
    driver: Any,
    application_number: int,
    dataframes_dict: Dict[str, pd.DataFrame],
    study_config: Dict[str, Any]
) -> Dict[str, int]:
    """
    Orchestrates the pre-run materialization of the Knowledge Graph.

    This function acts as the entry point for Task 14 (Step 2 of the AI Economist Agent
    Execution Workflow). It validates dependencies and sequentially executes the loading
    of evidence, temporal facts, economic tasks, and the model catalog.

    Parameters
    ----------
    driver : Any
        The authenticated Neo4j driver connection pool manager.
    application_number : int
        The experimental application index (1 or 2).
    dataframes_dict : Dict[str, pd.DataFrame]
        The dictionary containing all cleansed pipeline DataFrames.
    study_config : Dict[str, Any]
        The master study configuration dictionary.

    Returns
    -------
    Dict[str, int]
        A comprehensive audit dictionary containing the counts of all nodes and
        relationships created during the loading phase.

    Raises
    ------
    TypeError
        If the provided driver is not a valid neo4j.Driver instance.
    KeyError
        If required DataFrames are missing from the input dictionary.
    RuntimeError
        If the Cypher execution fails.
    """
    logger.info(f"=== Task 14: Initiating Knowledge Graph Loading for Application {application_number} ===")

    # Validate driver
    if not isinstance(driver, Driver):
        raise TypeError(f"Expected a neo4j.Driver instance, got {type(driver).__name__}.")

    # Validate required DataFrames
    required_dfs = [
        "raw_source_documents_df", "raw_evidence_spans_df", "raw_temporal_facts_df",
        "raw_shocks_df", "raw_variable_concepts_df", "raw_models_df",
        "raw_model_specifications_df", "raw_model_equations_df", "raw_model_assumptions_df",
        "raw_model_documents_df", "raw_implementation_functions_df", "raw_model_variable_relationships_df"
    ]
    missing_dfs = [df for df in required_dfs if df not in dataframes_dict]
    if missing_dfs:
        raise KeyError(f"CRITICAL: Missing required DataFrames for graph loading: {missing_dfs}")

    master_audit_counts: Counter = Counter()

    try:
        # Execute Step 2: Load evidence and temporal objects
        evidence_counts = _load_evidence_and_temporal_objects(
            driver=driver,
            dataframes_dict=dataframes_dict
        )
        master_audit_counts.update(evidence_counts)

        # Execute Step 3: Load economic task and model catalog objects
        catalog_counts = _load_task_and_catalog_objects(
            driver=driver,
            application_number=application_number,
            dataframes_dict=dataframes_dict,
            study_config=study_config
        )
        master_audit_counts.update(catalog_counts)

        logger.info("=== Task 14: Knowledge Graph Loading completed successfully ===")
        return dict(master_audit_counts)

    except Exception as e:
        logger.error(f"=== Task 14: Knowledge Graph Loading FAILED ===")
        raise RuntimeError(f"Graph loading orchestrator failed: {e}") from e

# %%
# Task 15 — Implement Text Retrieval callable (returns exactly 6 evidence spans)

# ==============================================================================
# Task 15: Implement Text Retrieval callable (returns exactly 6 evidence spans)
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Step 2: Implement the retrieval ranking logic
# -------------------------------------------------------------------------------------------------------------------------------
def _rank_and_retrieve_spans(
    scenario_text: str,
    evidence_df: pd.DataFrame,
    top_k: int,
    weight_tag: float,
    weight_conf: float
) -> List[Dict[str, Any]]:
    """
    Ranks evidence spans based on a composite score of tag overlap and synthetic confidence.

    This function infers scenario tags by iterating over the global tag vocabulary and
    performing substring matching against the scenario text, preserving multi-word tags.
    It computes the tag overlap ratio and combines it with the synthetic confidence score.

    Parameters
    ----------
    scenario_text : str
        The raw narrative text of the economic scenario.
    evidence_df : pd.DataFrame
        The cleansed evidence spans DataFrame.
    top_k : int
        The exact number of evidence spans to retrieve.
    weight_tag : float
        The weight applied to the tag overlap score (e.g., 0.5).
    weight_conf : float
        The weight applied to the synthetic confidence score (e.g., 0.5).

    Returns
    -------
    List[Dict[str, Any]]
        A list of dictionaries representing the top-k retrieved evidence spans.
    """
    # Log the initiation of the ranking process
    logger.info(f"Ranking evidence spans. Top-K: {top_k}, Weights: Tag={weight_tag}, Conf={weight_conf}")

    # Return an empty list if the evidence DataFrame is empty
    if evidence_df.empty:
        logger.warning("Evidence DataFrame is empty. Returning empty retrieval list.")
        return []

    # 1. Build the global tag vocabulary from the evidence corpus
    global_vocab: Set[str] = set()
    for tags_str in evidence_df["tags"].dropna():
        if tags_str:
            # Split the comma-separated tags and add to the global vocabulary
            global_vocab.update(tags_str.split(","))

    # 2. Infer scenario tags using robust substring matching
    # Convert the scenario text to lowercase for case-insensitive matching
    scenario_text_lower: str = scenario_text.lower()
    scenario_tags: Set[str] = set()

    # Iterate over the global vocabulary to find matching tags in the scenario
    for tag in global_vocab:
        # Replace underscores with spaces to match natural language phrasing
        search_string: str = tag.replace("_", " ")
        # If the search string exists in the scenario text, add the original tag to the inferred set
        if search_string in scenario_text_lower:
            scenario_tags.add(tag)

    # Calculate the length of the inferred scenario tags set
    scenario_tags_len: int = len(scenario_tags)
    logger.debug(f"Inferred scenario tags ({scenario_tags_len}): {scenario_tags}")

    # 3. Define the tag overlap computation function
    def _compute_overlap(tags_str: str) -> float:
        """Computes the Jaccard-like overlap ratio against the scenario tags."""
        # Equation: overlap = |tags(s) intersection tags_i| / |tags(s)|
        if scenario_tags_len == 0:
            # Return 0.0 to prevent division by zero if no tags were inferred
            return 0.0

        if not isinstance(tags_str, str) or not tags_str:
            # Return 0.0 if the row has no tags
            return 0.0

        # Split the row's tags into a set
        row_tags: Set[str] = set(tags_str.split(","))
        # Calculate the intersection length
        intersection_len: int = len(scenario_tags.intersection(row_tags))
        # Return the overlap ratio
        return float(intersection_len) / float(scenario_tags_len)

    # Create a working copy of the DataFrame to avoid SettingWithCopyWarning
    working_df = evidence_df.copy()

    # 4. Compute the overlap score Series
    working_df["overlap_score"] = working_df["tags"].apply(_compute_overlap)

    # 5. Compute the composite score Series
    # Equation: score_i = w_tag * overlap_i + w_conf * confidence_i
    working_df["composite_score"] = (
        (weight_tag * working_df["overlap_score"]) +
        (weight_conf * working_df["synthetic_confidence"].fillna(0.0))
    )

    # 6. Sort stably by composite score descending
    # kind='mergesort' guarantees stable sorting in pandas, preserving original deterministic order for ties
    sorted_df = working_df.sort_values(by="composite_score", ascending=False, kind="mergesort")

    # 7. Slice the top-k rows
    top_k_df = sorted_df.head(top_k)

    # Log a warning if fewer than top_k spans are available
    if len(top_k_df) < top_k:
        logger.warning(f"Requested top_k={top_k}, but only {len(top_k_df)} spans available.")

    # 8. Project the required columns and convert to a list of dictionaries
    projected_df = top_k_df[["evidence_id", "span_text", "tags", "synthetic_confidence"]]

    # Replace pandas NA/NaN with None for clean dictionary output
    projected_df = projected_df.where(pd.notnull(projected_df), None)

    # Convert the projected DataFrame to a list of dictionaries
    retrieved_spans: List[Dict[str, Any]] = projected_df.to_dict(orient="records")

    # Return the retrieved spans
    return retrieved_spans

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Step 3: Validate against expected retrieval outputs
# -------------------------------------------------------------------------------------------------------------------------------
def _validate_retrieval_outputs(
    retrieved_spans: List[Dict[str, Any]],
    application_number: int,
    study_config: Dict[str, Any]
) -> None:
    """
    Validates the retrieved evidence IDs against the manuscript's expected outputs.

    This function performs a diagnostic check to verify the retrieval implementation.
    Because the ranking weights and scenario tag inference are implementation assumptions,
    divergences are logged as non-fatal warnings rather than halting the pipeline.

    Parameters
    ----------
    retrieved_spans : List[Dict[str, Any]]
        The list of dictionaries representing the retrieved evidence spans.
    application_number : int
        The experimental application index (1 or 2).
    study_config : Dict[str, Any]
        The master study configuration dictionary containing the target outputs.
    """
    logger.info(f"Validating retrieval outputs for Application {application_number}.")

    # Extract the retrieved IDs
    retrieved_ids: List[str] = [span["evidence_id"] for span in retrieved_spans]

    # Resolve the expected IDs from the configuration
    target_key = f"application_{application_number}_top6_evidence_ids"

    try:
        expected_ids: List[str] = study_config["target_retrieval_outputs"][target_key]
    except KeyError:
        logger.warning(f"Expected retrieval outputs for {target_key} not found in config. Skipping validation.")
        return

    # Compare the lists (order and content)
    if retrieved_ids == expected_ids:
        logger.info("Retrieval validation successful. Retrieved IDs exactly match expected outputs.")
    else:
        # Log a detailed, non-fatal warning documenting the divergence
        logger.warning(
            f"Retrieval ranking divergence detected for Application {application_number}.\n"
            f"  Expected IDs:  {expected_ids}\n"
            f"  Retrieved IDs: {retrieved_ids}\n"
            f"This divergence is an acknowledged limitation resulting from the 50/50 weighting "
            f"and scenario tag inference assumptions."
        )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def retrieve_text_evidence(
    scenario_text: str,
    raw_evidence_spans_df: pd.DataFrame,
    study_config: Dict[str, Any],
    application_number: int
) -> List[Dict[str, Any]]:
    """
    Orchestrates the retrieval of text evidence spans for the RAG-only and GraphRAG conditions.

    This function acts as the entry point for Task 15 (Step 4 of the AI Economist Agent
    Execution Workflow). It extracts retrieval parameters, executes the composite ranking
    logic, validates the results against expected targets, and returns the exact payload
    required by the Report Generator LLM.

    Parameters
    ----------
    scenario_text : str
        The raw narrative text of the economic scenario.
    raw_evidence_spans_df : pd.DataFrame
        The cleansed evidence spans DataFrame.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    application_number : int
        The experimental application index (1 or 2), used for validation routing.

    Returns
    -------
    List[Dict[str, Any]]
        A list of exactly 6 dictionaries (if available), each containing 'evidence_id',
        'span_text', 'tags', and 'synthetic_confidence'.

    Raises
    ------
    KeyError
        If critical retrieval parameters are missing from the configuration.
    """
    logger.info(f"=== Task 15: Initiating Text Retrieval for Application {application_number} ===")

    # Extract retrieval parameters from the configuration
    try:
        retrieval_params = study_config["retrieval_graph_parameters"]
        top_k: int = int(retrieval_params["text_evidence_top_k"])
        weight_tag: float = float(retrieval_params["tag_overlap_weight"])
        weight_conf: float = float(retrieval_params["confidence_score_weight"])
    except KeyError as e:
        error_msg = f"CRITICAL: Missing retrieval parameter in configuration: {e}"
        logger.error(error_msg)
        raise KeyError(error_msg) from e

    # Execute Step 2: Implement the retrieval ranking logic
    retrieved_spans: List[Dict[str, Any]] = _rank_and_retrieve_spans(
        scenario_text=scenario_text,
        evidence_df=raw_evidence_spans_df,
        top_k=top_k,
        weight_tag=weight_tag,
        weight_conf=weight_conf
    )

    # Execute Step 3: Validate against expected retrieval outputs
    _validate_retrieval_outputs(
        retrieved_spans=retrieved_spans,
        application_number=application_number,
        study_config=study_config
    )

    logger.info("=== Task 15: Text Retrieval completed successfully ===")
    return retrieved_spans

# %%
# Task 16 — Implement Graph Retrieval (Pre-Execution) callable

# ==============================================================================
# Task 16: Implement Graph Retrieval (Pre-Execution) callable
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 16, Step 2: Implement pre-run path retrieval with constrained depth
# -------------------------------------------------------------------------------------------------------------------------------
def _retrieve_pre_run_paths(driver: Driver, scenario_id: str) -> List[str]:
    """
    Executes constrained Cypher queries to retrieve pre-execution graph paths.

    This function enforces the manuscript's prohibition on unconstrained neighborhood
    expansion by executing explicit, single-hop path queries. It formats the raw
    Neo4j Path objects into human-readable strings suitable for LLM prompt injection.

    Parameters
    ----------
    driver : neo4j.Driver
        The authenticated Neo4j driver connection pool manager.
    scenario_id : str
        The unique identifier of the current scenario, ensuring application isolation.

    Returns
    -------
    List[str]
        A list of formatted path strings (e.g., "(Scenario:ID)-[:AFFECTS]->(VariableConcept:ID)").

    Raises
    ------
    RuntimeError
        If the Cypher execution fails due to database errors.
    """
    logger.info(f"Retrieving pre-run graph paths for scenario: {scenario_id}")

    pre_run_paths: List[str] = []

    # Define Query 1: Scenario to VariableConcept (Limit 10)
    query_affects: str = """
    MATCH path = (s:Scenario {scenario_id: $scenario_id})-[:AFFECTS]->(v:VariableConcept)
    RETURN path
    LIMIT 10;
    """

    # Define Query 2: VariableConcept to ModelSpecification (Limit 20)
    # We anchor this to the specific scenario to prevent retrieving specs for other applications
    query_supported: str = """
    MATCH path = (s:Scenario {scenario_id: $scenario_id})-[:AFFECTS]->(v:VariableConcept)-[:SUPPORTED_BY]->(ms:ModelSpecification)
    RETURN path
    LIMIT 20;
    """

    def _format_path(path: Path) -> str:
        """Helper function to format a Neo4j Path object into a readable string."""
        formatted_elements = []
        for i, node in enumerate(path.nodes):
            # Extract the primary label (assuming single label per node for this schema)
            label = list(node.labels)[0] if node.labels else "Unknown"

            # Extract the primary key dynamically based on the label
            if label == "Scenario":
                key_val = node.get("scenario_id", "Unknown")
            elif label == "VariableConcept":
                key_val = node.get("concept_id", "Unknown")
            elif label == "ModelSpecification":
                key_val = node.get("spec_id", "Unknown")
            else:
                key_val = "Unknown"

            formatted_elements.append(f"({label}:{key_val})")

            # Append the relationship if we are not at the last node
            if i < len(path.relationships):
                rel = path.relationships[i]
                formatted_elements.append(f"-[:{rel.type}]->")

        return "".join(formatted_elements)

    def _execute_path_queries(tx: Transaction) -> List[str]:
        """Executes both path queries within a single managed read transaction."""
        paths = []

        # Execute Query 1
        result_affects = tx.run(query_affects, scenario_id=scenario_id)
        for record in result_affects:
            paths.append(_format_path(record["path"]))

        # Execute Query 2
        result_supported = tx.run(query_supported, scenario_id=scenario_id)
        for record in result_supported:
            paths.append(_format_path(record["path"]))

        return paths

    try:
        # Open a managed read session
        with driver.session() as session:
            pre_run_paths = session.execute_read(_execute_path_queries)

        logger.debug(f"Retrieved {len(pre_run_paths)} pre-run paths.")
        return pre_run_paths

    except neo4j.exceptions.Neo4jError as e:
        error_msg = f"Failed to retrieve pre-run paths. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 16, Step 3: Retrieve executable model context for Model-Selection Agent
# -------------------------------------------------------------------------------------------------------------------------------
def _retrieve_model_context(driver: Driver, top_k: int) -> List[Dict[str, Any]]:
    """
    Retrieves the executable model context required by the Model-Selection Agent.

    This function executes a Cypher query to extract a highly controlled schema of
    model specifications and their implementation mappings. This prevents the LLM
    from reasoning over free text and forces it to select from approved, executable
    computational families.

    Parameters
    ----------
    driver : neo4j.Driver
        The authenticated Neo4j driver connection pool manager.
    top_k : int
        The maximum number of model specifications to retrieve.

    Returns
    -------
    List[Dict[str, Any]]
        A list of dictionaries representing the executable model context.

    Raises
    ------
    RuntimeError
        If the Cypher execution fails due to database errors.
    """
    logger.info(f"Retrieving executable model context (Limit: {top_k}).")

    model_context: List[Dict[str, Any]] = []

    # Define the Cypher query to extract the exact fields required by the prompt schema
    # We traverse from Model to get the family name, through Specification, to Implementation
    context_query: str = """
    MATCH (m:Model)-[:HAS_SPECIFICATION]->(ms:ModelSpecification)-[:MAPS_TO]->(impl:ImplementationFunction)
    RETURN
        ms.spec_id AS spec_id,
        m.model_name AS model_family,
        ms.spec_description AS spec_description,
        impl.execution_tool_name AS execution_tool_name,
        impl.solver_method AS solver_method,
        ms.calibration_params_json AS calibration_params_json
    LIMIT $top_k;
    """

    def _execute_context_query(tx: Transaction) -> List[Dict[str, Any]]:
        """Executes the context query within a managed read transaction."""
        context_list = []
        result = tx.run(context_query, top_k=top_k)

        for record in result:
            # Construct the dictionary mapping Cypher aliases to Python keys
            context_dict = {
                "spec_id": record["spec_id"],
                "model_family": record["model_family"],
                "spec_description": record["spec_description"],
                "execution_tool_name": record["execution_tool_name"],
                "solver_method": record["solver_method"],
                "calibration_params_json": record["calibration_params_json"]
            }
            context_list.append(context_dict)

        return context_list

    try:
        # Open a managed read session
        with driver.session() as session:
            model_context = session.execute_read(_execute_context_query)

        logger.debug(f"Retrieved {len(model_context)} model context records.")
        return model_context

    except neo4j.exceptions.Neo4jError as e:
        error_msg = f"Failed to retrieve model context. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 16, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def retrieve_graph_context_pre_execution(
    driver: Any,
    scenario_id: str,
    study_config: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Orchestrates the pre-execution retrieval of graph paths and model context.

    This function acts as the entry point for Task 16 (Step 5 of the AI Economist Agent
    Execution Workflow). It validates the driver, extracts retrieval limits from the
    configuration, and sequentially executes the path and context retrieval queries.

    Parameters
    ----------
    driver : Any
        The authenticated Neo4j driver connection pool manager. Typed as Any to
        avoid strict dependency injection failures if the neo4j package is mocked.
    scenario_id : str
        The unique identifier of the current scenario.
    study_config : Dict[str, Any]
        The master study configuration dictionary.

    Returns
    -------
    Dict[str, Any]
        A dictionary containing:
        - "pre_run_paths": List[str]
        - "model_context": List[Dict[str, Any]]

    Raises
    ------
    TypeError
        If the provided driver is not a valid neo4j.Driver instance.
    KeyError
        If critical retrieval parameters are missing from the configuration.
    RuntimeError
        If the Cypher execution fails.
    """
    logger.info(f"=== Task 16: Initiating Pre-Execution Graph Retrieval for {scenario_id} ===")

    # Validate that the provided object is actually a Neo4j Driver
    if not isinstance(driver, Driver):
        error_msg = f"Expected a neo4j.Driver instance, got {type(driver).__name__}."
        logger.error(error_msg)
        raise TypeError(error_msg)

    # Extract retrieval parameters from the configuration
    try:
        retrieval_params = study_config["retrieval_graph_parameters"]
        model_context_top_k: int = int(retrieval_params["model_context_top_k"])
    except KeyError as e:
        error_msg = f"CRITICAL: Missing retrieval parameter in configuration: {e}"
        logger.error(error_msg)
        raise KeyError(error_msg) from e

    try:
        # Execute Step 2: Retrieve pre-run paths
        pre_run_paths: List[str] = _retrieve_pre_run_paths(
            driver=driver,
            scenario_id=scenario_id
        )

        # Execute Step 3: Retrieve executable model context
        model_context: List[Dict[str, Any]] = _retrieve_model_context(
            driver=driver,
            top_k=model_context_top_k
        )

        # Construct the final return dictionary
        result_dict: Dict[str, Any] = {
            "pre_run_paths": pre_run_paths,
            "model_context": model_context
        }

        logger.info("=== Task 16: Pre-Execution Graph Retrieval completed successfully ===")
        return result_dict

    except Exception as e:
        logger.error(f"=== Task 16: Pre-Execution Graph Retrieval FAILED ===")
        raise RuntimeError(f"Graph retrieval orchestrator failed: {e}") from e

# %%
# Task 17 — Implement Planner Agent callable (LLM → JSON plan)

# ==============================================================================
# Task 17: Implement Planner Agent callable (LLM → JSON plan)
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 17, Step 2: Construct the request using the planner template
# -------------------------------------------------------------------------------------------------------------------------------
def _construct_and_execute_planner_prompt(
    scenario_text: str,
    llm_client: Any,
    study_config: Dict[str, Any]
) -> str:
    """
    Constructs the role-tagged message list and executes the LLM call for the Planner Agent.

    This function retrieves the monolithic planner prompt template from the configuration,
    uses regular expressions to decompose it into system and user components, injects the
    scenario text safely, and invokes the deterministic LLM client.

    Parameters
    ----------
    scenario_text : str
        The raw narrative text of the economic scenario.
    llm_client : Any
        The configured LLM client instance (satisfying the complete() protocol).
    study_config : Dict[str, Any]
        The master study configuration dictionary containing the prompt templates.

    Returns
    -------
    str
        The raw, unparsed string response generated by the LLM.

    Raises
    ------
    KeyError
        If the planner prompt template is missing from the configuration.
    ValueError
        If the prompt template cannot be successfully parsed into its constituent sections.
    RuntimeError
        If the LLM client execution fails.
    """
    # Log the initiation of the prompt construction and execution step
    logger.info("Constructing role-tagged messages for the Planner Agent.")

    # Retrieve the monolithic prompt template from the configuration dictionary
    try:
        raw_template: str = study_config["prompt_templates"]["planner_agent_prompt"]
    except KeyError as e:
        # Raise a fatal error if the template is missing, as the agent cannot function without it
        raise KeyError(f"CRITICAL: Missing planner prompt template in configuration: {e}") from e

    # Define a helper function to extract sections based on their markdown headers
    def extract_section(header: str, text: str) -> str:
        # Use a regular expression to capture everything between the target header and the next header or end of string
        pattern = rf"### {header}\n(.*?)(?=\n### |$)"
        # Execute the regex search with the DOTALL flag so the dot matches newline characters
        match = re.search(pattern, text, re.DOTALL)
        if match:
            # Return the stripped content of the matched group
            return match.group(1).strip()
        else:
            # Raise a ValueError if a required section is missing from the template
            raise ValueError(f"Failed to extract required section '### {header}' from the planner prompt template.")

    # Extract the three sections designated for the system role
    job_description: str = extract_section("Job Description", raw_template)
    skills: str = extract_section("Skills", raw_template)
    output_contract: str = extract_section("Output Contract", raw_template)

    # Extract the two sections designated for the user role
    python_scripts: str = extract_section("Python Scripts", raw_template)
    task_section: str = extract_section("Task", raw_template)

    # Safely inject the scenario text into the Python Scripts section
    # We use string replacement rather than .format() to avoid collisions with stray braces in the prompt
    injected_python_scripts: str = python_scripts.replace("{scenario}", scenario_text)

    # Assemble the system message content by concatenating the extracted sections
    system_content: str = (
        f"### Job Description\n{job_description}\n\n"
        f"### Skills\n{skills}\n\n"
        f"### Output Contract\n{output_contract}"
    )

    # Assemble the user message content by concatenating the injected scripts and the task
    user_content: str = (
        f"### Python Scripts\n{injected_python_scripts}\n\n"
        f"### Task\n{task_section}"
    )

    # Construct the final role-tagged message list required by the LLM client protocol
    messages: List[Dict[str, str]] = [
        {"role": "system", "content": system_content},
        {"role": "user", "content": user_content}
    ]

    # Log the successful assembly of the messages and initiate the LLM call
    logger.info("Role-tagged messages assembled successfully. Invoking LLM client.")

    try:
        # Execute the LLM call using the client's complete method
        # The client internally enforces temperature=0, seed=42, and other deterministic parameters
        raw_response: str = llm_client.complete(messages)
        return raw_response
    except Exception as e:
        # Catch any execution errors and raise a RuntimeError with context
        error_msg = f"LLM client execution failed for Planner Agent: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 17, Step 3: Parse and validate the JSON response strictly
# -------------------------------------------------------------------------------------------------------------------------------
def _parse_and_validate_planner_json(raw_response: str) -> Dict[str, Any]:
    """
    Parses the LLM response as strict JSON and validates the required keys.

    This function performs bounded extraction by stripping markdown code fences,
    attempts strict JSON decoding without heuristic repair, and verifies that the
    resulting dictionary contains exactly the four keys mandated by the blueprint.

    Parameters
    ----------
    raw_response : str
        The raw string output generated by the Planner Agent LLM.

    Returns
    -------
    Dict[str, Any]
        The parsed and validated JSON dictionary containing the analysis plan.

    Raises
    ------
    ValueError
        If the response cannot be parsed as JSON or if the required keys are missing/surplus.
    """
    # Log the initiation of the strict JSON parsing and validation step
    logger.info("Starting strict JSON parsing and validation of the Planner Agent response.")

    # Strip leading and trailing whitespace from the raw response
    cleaned_response: str = raw_response.strip()

    # Perform bounded extraction: remove markdown JSON code fences if the LLM included them
    # This regex matches ```json at the start and ``` at the end, ignoring case
    cleaned_response = re.sub(r"^```(?:json)?\s*", "", cleaned_response, flags=re.IGNORECASE)
    cleaned_response = re.sub(r"\s*```$", "", cleaned_response)

    # Strip whitespace again after removing the fences
    cleaned_response = cleaned_response.strip()

    try:
        # Attempt strict JSON decoding using the standard library parser
        # No heuristic repair is permitted; if it fails, it raises a JSONDecodeError
        parsed_plan: Dict[str, Any] = json.loads(cleaned_response)
    except json.JSONDecodeError as e:
        # Construct a detailed error message including the exact string that failed
        error_msg = (
            f"Planner Agent output failed strict JSON parsing.\n"
            f"Error: {e}\n"
            f"Raw Response:\n{raw_response}"
        )
        logger.error(error_msg)
        # Raise a ValueError to halt the pipeline immediately
        raise ValueError(error_msg) from e

    # Define the exact set of keys required by the downstream model selection agent
    required_keys: Set[str] = {
        "economic_objective",
        "target_variables",
        "relevant_shocks",
        "model_selection_objective"
    }

    # Extract the keys present in the parsed dictionary
    observed_keys: Set[str] = set(parsed_plan.keys())

    # Validate that the observed keys exactly match the required keys
    if observed_keys != required_keys:
        # Compute the missing and surplus keys for diagnostic reporting
        missing_keys: Set[str] = required_keys - observed_keys
        surplus_keys: Set[str] = observed_keys - required_keys

        # Construct a detailed error message enumerating the structural violations
        error_msg = (
            f"Planner Agent JSON output violates the structural contract.\n"
            f"Missing keys: {missing_keys}\n"
            f"Surplus keys: {surplus_keys}\n"
            f"Parsed Output: {parsed_plan}"
        )
        logger.error(error_msg)
        # Raise a ValueError to halt the pipeline, ensuring downstream tasks receive valid data
        raise ValueError(error_msg)

    # Log the successful validation of the JSON plan
    logger.info("Planner Agent JSON response parsed and validated successfully.")

    # Return the structurally sound dictionary
    return parsed_plan

# -------------------------------------------------------------------------------------------------------------------------------
# Task 17, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def call_planner_agent(
    scenario_text: str,
    llm_client: Any,
    study_config: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Orchestrates the Planner Agent to translate a scenario into a structured analysis plan.

    This function acts as the entry point for Task 17 (Step 3 of the AI Economist Agent
    Execution Workflow). It sequentially executes the prompt construction, LLM invocation,
    and strict JSON validation, ensuring the qualitative scenario is rigorously transformed
    into quantitative and economic targets.

    Parameters
    ----------
    scenario_text : str
        The raw narrative text of the economic scenario.
    llm_client : Any
        The configured LLM client instance.
    study_config : Dict[str, Any]
        The master study configuration dictionary.

    Returns
    -------
    Dict[str, Any]
        The validated analysis plan containing the economic objective, target variables,
        relevant shocks, and model selection objective.

    Raises
    ------
    RuntimeError
        If any step of the planner execution or validation fails, halting the pipeline.
    """
    # Log the initiation of the overarching Task 17 orchestrator
    logger.info("=== Task 17: Initiating Planner Agent execution ===")

    try:
        # Execute Step 2: Construct the request and invoke the LLM
        raw_llm_response: str = _construct_and_execute_planner_prompt(
            scenario_text=scenario_text,
            llm_client=llm_client,
            study_config=study_config
        )

        # Execute Step 3: Parse and validate the JSON response strictly
        validated_plan: Dict[str, Any] = _parse_and_validate_planner_json(
            raw_response=raw_llm_response
        )

        # Log the successful completion of the Planner Agent task
        logger.info("=== Task 17: Planner Agent execution completed successfully ===")

        # Return the validated plan for use by the Model-Selection Agent
        return validated_plan

    except Exception as e:
        # Catch any errors from the sub-steps, log a critical failure, and raise a RuntimeError
        error_msg = f"=== Task 17: Planner Agent execution FAILED ===\nDetails: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# %%
# Task 18 — Implement Model-Selection Agent callable (LLM → execution request (r_s))

# =================================================================================
# Task 18: Implement Model-Selection Agent callable (LLM → execution request (r_s))
# =================================================================================

class ModelSelectionError(Exception):
    """Custom exception raised when the LLM selects an incorrect model specification."""
    pass

# -------------------------------------------------------------------------------------------------------------------------------
# Task 18, Step 2: Construct the request using the model-selection template
# -------------------------------------------------------------------------------------------------------------------------------
def _construct_and_execute_model_selection_prompt(
    scenario_text: str,
    plan_json: Dict[str, Any],
    model_context: List[Dict[str, Any]],
    llm_client: Any,
    study_config: Dict[str, Any],
    retry_hint: Optional[str] = None
) -> str:
    """
    Constructs the role-tagged message list and executes the LLM call for the Model-Selection Agent.

    This function retrieves the monolithic model-selection prompt template, decomposes it
    into system and user components, serializes the structured inputs (plan and context)
    into readable JSON strings, injects them safely, and invokes the deterministic LLM client.
    It supports appending a disambiguating hint during a retry pass.

    Parameters
    ----------
    scenario_text : str
        The raw narrative text of the economic scenario.
    plan_json : Dict[str, Any]
        The structured analysis plan generated by the Planner Agent.
    model_context : List[Dict[str, Any]]
        The executable model context retrieved from the Knowledge Graph.
    llm_client : Any
        The configured LLM client instance (satisfying the complete() protocol).
    study_config : Dict[str, Any]
        The master study configuration dictionary containing the prompt templates.
    retry_hint : Optional[str], optional
        An explicit hint appended to the user prompt during a retry pass, by default None.

    Returns
    -------
    str
        The raw, unparsed string response generated by the LLM.

    Raises
    ------
    KeyError
        If the model-selection prompt template is missing from the configuration.
    ValueError
        If the prompt template cannot be successfully parsed into its constituent sections.
    RuntimeError
        If the LLM client execution fails.
    """
    # Log the initiation of the prompt construction and execution step
    logger.info("Constructing role-tagged messages for the Model-Selection Agent.")

    # Retrieve the monolithic prompt template from the configuration dictionary
    try:
        raw_template: str = study_config["prompt_templates"]["model_selection_agent_prompt"]
    except KeyError as e:
        # Raise a fatal error if the template is missing
        raise KeyError(f"CRITICAL: Missing model-selection prompt template in configuration: {e}") from e

    # Define a helper function to extract sections based on their markdown headers
    def extract_section(header: str, text: str) -> str:
        # Use a regular expression to capture everything between the target header and the next header or end of string
        pattern = rf"### {header}\n(.*?)(?=\n### |$)"
        # Execute the regex search with the DOTALL flag so the dot matches newline characters
        match = re.search(pattern, text, re.DOTALL)
        if match:
            # Return the stripped content of the matched group
            return match.group(1).strip()
        else:
            # Raise a ValueError if a required section is missing from the template
            raise ValueError(f"Failed to extract required section '### {header}' from the model-selection prompt template.")

    # Extract the three sections designated for the system role
    job_description: str = extract_section("Job Description", raw_template)
    skills: str = extract_section("Skills", raw_template)
    output_contract: str = extract_section("Output Contract", raw_template)

    # Extract the two sections designated for the user role
    python_scripts: str = extract_section("Python Scripts", raw_template)
    task_section: str = extract_section("Task", raw_template)

    # Serialize the structured inputs into highly readable JSON strings with indentation
    # This ensures the LLM can accurately parse the nested structures
    plan_str: str = json.dumps(plan_json, indent=2)
    context_str: str = json.dumps(model_context, indent=2)

    # Safely inject the scenario text and serialized structures into the Python Scripts section
    # We use string replacement rather than .format() to avoid collisions with stray braces
    injected_python_scripts: str = python_scripts.replace("{scenario}", scenario_text)
    injected_python_scripts = injected_python_scripts.replace("{plan}", plan_str)
    injected_python_scripts = injected_python_scripts.replace("{model_context}", context_str)

    # Assemble the system message content by concatenating the extracted sections
    system_content: str = (
        f"### Job Description\n{job_description}\n\n"
        f"### Skills\n{skills}\n\n"
        f"### Output Contract\n{output_contract}"
    )

    # If a retry hint is provided, append it to the task section to guide the LLM
    if retry_hint:
        task_section += f"\n\nCRITICAL HINT: {retry_hint}"

    # Assemble the user message content by concatenating the injected scripts and the task
    user_content: str = (
        f"### Python Scripts\n{injected_python_scripts}\n\n"
        f"### Task\n{task_section}"
    )

    # Construct the final role-tagged message list required by the LLM client protocol
    messages: List[Dict[str, str]] = [
        {"role": "system", "content": system_content},
        {"role": "user", "content": user_content}
    ]

    # Log the successful assembly of the messages and initiate the LLM call
    logger.info("Role-tagged messages assembled successfully. Invoking LLM client.")

    try:
        # Execute the LLM call using the client's complete method
        # The client internally enforces temperature=0, seed=42, and other deterministic parameters
        raw_response: str = llm_client.complete(messages)
        return raw_response
    except Exception as e:
        # Catch any execution errors and raise a RuntimeError with context
        error_msg = f"LLM client execution failed for Model-Selection Agent: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 18, Step 3: Validate the execution request against expected selections
# -------------------------------------------------------------------------------------------------------------------------------
def _parse_and_validate_execution_request(
    raw_response: str,
    model_context: List[Dict[str, Any]],
    application_number: int,
    study_config: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Parses the LLM response as strict JSON and validates the execution request r_s.

    This function performs bounded extraction by stripping markdown code fences,
    attempts strict JSON decoding, verifies the presence of the five required keys,
    ensures the selected tool is available in the context, and asserts that the
    selected specification matches the application-specific expected specification.

    Parameters
    ----------
    raw_response : str
        The raw string output generated by the Model-Selection Agent LLM.
    model_context : List[Dict[str, Any]]
        The executable model context retrieved from the Knowledge Graph.
    application_number : int
        The experimental application index (1 or 2).
    study_config : Dict[str, Any]
        The master study configuration dictionary containing expected selections.

    Returns
    -------
    Dict[str, Any]
        The parsed and validated JSON dictionary representing the execution request r_s.

    Raises
    ------
    ValueError
        If the response cannot be parsed as JSON, if required keys are missing, or if
        the selected tool is not available in the context.
    ModelSelectionError
        If the selected specification does not match the expected specification.
    """
    # Log the initiation of the strict JSON parsing and validation step
    logger.info("Starting strict JSON parsing and validation of the execution request.")

    # Strip leading and trailing whitespace from the raw response
    cleaned_response: str = raw_response.strip()

    # Perform bounded extraction: remove markdown JSON code fences if the LLM included them
    cleaned_response = re.sub(r"^```(?:json)?\s*", "", cleaned_response, flags=re.IGNORECASE)
    cleaned_response = re.sub(r"\s*```$", "", cleaned_response)
    cleaned_response = cleaned_response.strip()

    try:
        # Attempt strict JSON decoding using the standard library parser
        parsed_request: Dict[str, Any] = json.loads(cleaned_response)
    except json.JSONDecodeError as e:
        # Construct a detailed error message including the exact string that failed
        error_msg = (
            f"Model-Selection Agent output failed strict JSON parsing.\n"
            f"Error: {e}\n"
            f"Raw Response:\n{raw_response}"
        )
        logger.error(error_msg)
        # Raise a ValueError to halt the pipeline immediately
        raise ValueError(error_msg) from e

    # Define the exact set of keys required for the execution request r_s
    required_keys: Set[str] = {
        "model_specification",
        "model_family",
        "implementation_family",
        "execution_tool",
        "expected_outputs"
    }

    # Extract the keys present in the parsed dictionary
    observed_keys: Set[str] = set(parsed_request.keys())

    # Validate that the observed keys exactly match the required keys
    if observed_keys != required_keys:
        missing_keys: Set[str] = required_keys - observed_keys
        surplus_keys: Set[str] = observed_keys - required_keys
        error_msg = (
            f"Model-Selection Agent JSON output violates the structural contract.\n"
            f"Missing keys: {missing_keys}\n"
            f"Surplus keys: {surplus_keys}\n"
            f"Parsed Output: {parsed_request}"
        )
        logger.error(error_msg)
        raise ValueError(error_msg)

    # Extract the available execution tools from the provided model context
    available_tools: Set[str] = {spec["execution_tool_name"] for spec in model_context}
    selected_tool: str = parsed_request["execution_tool"]

    # Validate that the selected tool is actually available in the context
    if selected_tool not in available_tools:
        error_msg = (
            f"Invalid execution tool selected: '{selected_tool}'. "
            f"Available tools in context: {available_tools}"
        )
        logger.error(error_msg)
        raise ValueError(error_msg)

    # Resolve the expected specification ID from the configuration based on the application number
    target_key = f"application_{application_number}_spec_id"
    try:
        expected_spec_id: str = study_config["expected_model_selections"][target_key]
    except KeyError as e:
        error_msg = f"CRITICAL: Missing expected model selection in configuration: {e}"
        logger.error(error_msg)
        raise KeyError(error_msg) from e

    selected_spec_id: str = parsed_request["model_specification"]

    # Validate that the selected specification matches the expected specification
    if selected_spec_id != expected_spec_id:
        error_msg = (
            f"Model selection mismatch. Expected: '{expected_spec_id}', "
            f"Selected: '{selected_spec_id}'."
        )
        logger.warning(error_msg)
        # Raise the custom ModelSelectionError to trigger the retry logic in the orchestrator
        raise ModelSelectionError(error_msg)

    # Log the successful validation of the execution request
    logger.info(f"Execution request validated successfully. Selected spec: {selected_spec_id}")

    # Return the structurally sound and validated dictionary
    return parsed_request

# -------------------------------------------------------------------------------------------------------------------------------
# Task 18, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def call_model_selection_agent(
    scenario_text: str,
    plan_json: Dict[str, Any],
    model_context: List[Dict[str, Any]],
    llm_client: Any,
    study_config: Dict[str, Any],
    application_number: int
) -> Dict[str, Any]:
    """
    Orchestrates the Model-Selection Agent to map a scenario and plan to an execution request.

    This function acts as the entry point for Task 18. It sequentially executes the prompt
    construction, LLM invocation, and strict JSON validation. It implements a single bounded
    retry loop if the LLM selects an incorrect model specification, using a generic hint
    to prevent look-ahead bias.

    Parameters
    ----------
    scenario_text : str
        The raw narrative text of the economic scenario.
    plan_json : Dict[str, Any]
        The structured analysis plan generated by the Planner Agent.
    model_context : List[Dict[str, Any]]
        The executable model context retrieved from the Knowledge Graph.
    llm_client : Any
        The configured LLM client instance.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    application_number : int
        The experimental application index (1 or 2).

    Returns
    -------
    Dict[str, Any]
        The validated execution request r_s containing the selected specification and tool.

    Raises
    ------
    RuntimeError
        If the execution or validation fails after the retry limit is reached.
    """
    # Log the initiation of the overarching Task 18 orchestrator
    logger.info(f"=== Task 18: Initiating Model-Selection Agent execution for Application {application_number} ===")

    # Define the maximum number of retries
    max_retries: int = 1
    current_attempt: int = 0
    retry_hint: Optional[str] = None

    # Implement the bounded retry loop
    while current_attempt <= max_retries:
        try:
            # Execute Step 2: Construct the request and invoke the LLM
            # Note: _construct_and_execute_model_selection_prompt is assumed to be in namespace
            raw_llm_response: str = _construct_and_execute_model_selection_prompt(
                scenario_text=scenario_text,
                plan_json=plan_json,
                model_context=model_context,
                llm_client=llm_client,
                study_config=study_config,
                retry_hint=retry_hint
            )

            # Execute Step 3: Parse and validate the JSON response strictly
            # Note: _parse_and_validate_execution_request is assumed to be in namespace
            validated_request: Dict[str, Any] = _parse_and_validate_execution_request(
                raw_response=raw_llm_response,
                model_context=model_context,
                application_number=application_number,
                study_config=study_config
            )

            # If validation passes, log success and return the request
            logger.info("=== Task 18: Model-Selection Agent execution completed successfully ===")
            return validated_request

        except ModelSelectionError as e:
            # Catch the specific model selection mismatch error
            current_attempt += 1
            if current_attempt <= max_retries:
                logger.warning(f"Attempt {current_attempt} failed due to incorrect model selection. Retrying with generic hint.")
                # Construct a generic disambiguating hint for the retry pass to prevent look-ahead bias
                retry_hint = (
                    "Your previous selection was incorrect. Please re-read the model_selection_objective "
                    "in the analysis plan and carefully evaluate the spec_description of each model in the context. "
                    "Ensure your output strictly matches an available spec_id that fulfills the objective."
                )
            else:
                # If the retry limit is reached, raise a fatal RuntimeError
                error_msg = f"=== Task 18: Model-Selection Agent FAILED after {max_retries} retries ===\nDetails: {e}"
                logger.error(error_msg)
                raise RuntimeError(error_msg) from e

        except Exception as e:
            # Catch any other errors (e.g., JSON parsing, missing keys) and halt immediately without retrying
            error_msg = f"=== Task 18: Model-Selection Agent FAILED ===\nDetails: {e}"
            logger.error(error_msg)
            raise RuntimeError(error_msg) from e

    # Fallback return (should be unreachable due to the raise statements above)
    raise RuntimeError("Unexpected exit from Model-Selection Agent retry loop.")

# %%
# Task 19 — Implement DSGE-lite computational runner (Blanchard–Kahn solution + simulation)

# ========================================================================================
# Task 19: Implement DSGE-lite computational runner (Blanchard–Kahn solution + simulation)
# ========================================================================================

class DeterminacyError(Exception):
    """Custom exception raised when Blanchard-Kahn conditions for saddle-path stability fail."""
    pass

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Step 2: Construct the linearized DSGE system and solve using Blanchard-Kahn
# -------------------------------------------------------------------------------------------------------------------------------
def _solve_dsge_blanchard_kahn(params: Dict[str, float], tolerance: float = 1e-8) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    Constructs the canonical matrices for the 3-equation New Keynesian model and solves it.

    This function implements the Blanchard-Kahn (1980) method. It arranges the IS Curve,
    Phillips Curve, and Taylor Rule into the form Gamma_0 * s_t = Gamma_1 * s_{t-1} + Psi * eps_t + Pi * eta_t.
    It computes the generalized Schur (QZ) decomposition, verifies saddle-path determinacy,
    and derives the reduced-form transition matrix T and shock loading matrix R.
    It also computes the analytic term structure mapping for the 10-year yield.

    State vector ordering (6-element core):
    0: Output gap (y_t)
    1: Inflation (pi_t)
    2: Policy rate (i_t)
    3: Demand shock (g_t)
    4: Cost-push shock (u_t)
    5: Policy shock (v_t)

    Parameters
    ----------
    params : Dict[str, float]
        The merged dictionary of calibration parameters.
    tolerance : float, optional
        The numerical tolerance for eigenvalue modulus comparison, by default 1e-8.

    Returns
    -------
    Tuple[np.ndarray, np.ndarray, np.ndarray]
        - T_core: The (6x6) reduced-form state transition matrix.
        - R_core: The (6x3) shock loading matrix.
        - term_structure_weights: The (6,) vector mapping the core state to the 10-year yield.

    Raises
    ------
    DeterminacyError
        If the number of explosive eigenvalues does not equal the number of forward-looking variables.
    """
    logger.info("Constructing canonical matrices and solving via Blanchard-Kahn.")

    # Extract parameters for readability
    sigma = params["sigma"]
    beta = params["beta"]
    kappa = params["kappa"]
    phi_pi = params["phi_pi"]
    phi_y = params["phi_y"]
    rho_i = params["rho_i"]
    rho_g = params["rho_g"]
    rho_u = params["rho_u"]
    rho_v = params["rho_v"]

    # Define the number of variables
    n_vars = 6
    n_fwd = 2  # Forward-looking variables in the core: y_t, pi_t

    # Initialize canonical matrices: Gamma_0 * s_t = Gamma_1 * s_{t-1} + Psi * eps_t + Pi * eta_t
    # We cast this into the standard form: A * E_t[s_{t+1}] = B * s_t + C * eps_t
    # For the QZ decomposition, we use the form: A * x_{t+1} = B * x_t
    # where x_t contains both predetermined and forward-looking variables.
    A = np.zeros((n_vars, n_vars), dtype=np.float64)
    B = np.zeros((n_vars, n_vars), dtype=np.float64)

    # Equation 1: IS Curve
    # y_t = E_t y_{t+1} - (1/sigma)*(i_t - E_t pi_{t+1}) + g_t
    # Rearranged for A * E_t[x_{t+1}] = B * x_t:
    # E_t y_{t+1} + (1/sigma) E_t pi_{t+1} = y_t + (1/sigma) i_t - g_t
    A[0, 0] = 1.0              # E_t y_{t+1}
    A[0, 1] = 1.0 / sigma      # E_t pi_{t+1}
    B[0, 0] = 1.0              # y_t
    B[0, 2] = 1.0 / sigma      # i_t
    B[0, 3] = -1.0             # g_t

    # Equation 2: Phillips Curve
    # pi_t = beta * E_t pi_{t+1} + kappa * y_t + u_t
    # Rearranged:
    # beta * E_t pi_{t+1} = -kappa * y_t + pi_t - u_t
    A[1, 1] = beta             # E_t pi_{t+1}
    B[1, 0] = -kappa           # y_t
    B[1, 1] = 1.0              # pi_t
    B[1, 4] = -1.0             # u_t

    # Equation 3: Taylor Rule (Predetermined/Identity)
    # i_t = rho_i * i_{t-1} + (1-rho_i)*(phi_pi * pi_t + phi_y * y_t) + v_t
    # Since this is an identity at time t, A has 1 on the diagonal, B maps to t-1 and current states
    # To fit the A x_{t+1} = B x_t form, we shift the time index:
    # i_{t+1} = rho_i * i_t + (1-rho_i)*(phi_pi * pi_{t+1} + phi_y * y_{t+1}) + v_{t+1}
    A[2, 2] = 1.0
    A[2, 0] = -(1.0 - rho_i) * phi_y
    A[2, 1] = -(1.0 - rho_i) * phi_pi
    A[2, 5] = -1.0
    B[2, 2] = rho_i

    # Equations 4-6: AR(1) Shock Processes
    # g_{t+1} = rho_g * g_t + eps_{g,t+1}
    A[3, 3] = 1.0
    B[3, 3] = rho_g

    # u_{t+1} = rho_u * u_t + eps_{u,t+1}
    A[4, 4] = 1.0
    B[4, 4] = rho_u

    # v_{t+1} = rho_v * v_t + eps_{v,t+1}
    A[5, 5] = 1.0
    B[5, 5] = rho_v

    # Compute the generalized Schur (QZ) decomposition
    # ordqz sorts the eigenvalues so that stable ones (modulus < 1) appear in the upper left
    try:
        S, T_qz, alpha, beta_qz, Q, Z = scipy.linalg.ordqz(A, B, sort='iuc')
    except Exception as e:
        raise RuntimeError(f"QZ decomposition failed: {e}") from e

    # Compute generalized eigenvalues
    # Handle potential division by zero for infinite eigenvalues
    with np.errstate(divide='ignore', invalid='ignore'):
        eigenvalues = np.abs(beta_qz / alpha)

    # Count explosive eigenvalues (modulus > 1 + tolerance)
    n_explosive = np.sum(eigenvalues > (1.0 + tolerance))

    logger.debug(f"QZ Decomposition complete. Found {n_explosive} explosive eigenvalues.")

    # Verify Blanchard-Kahn determinacy condition
    if n_explosive != n_fwd:
        raise DeterminacyError(
            f"Blanchard-Kahn determinacy failure: Number of explosive eigenvalues ({n_explosive}) "
            f"does not equal the number of forward-looking variables ({n_fwd})."
        )

    # Extract submatrices from the sorted QZ decomposition to construct the saddle-path solution
    # Z is partitioned into predetermined (1) and forward-looking (2) blocks
    Z11 = Z[:n_vars-n_fwd, :n_vars-n_fwd]
    Z12 = Z[:n_vars-n_fwd, n_vars-n_fwd:]
    Z21 = Z[n_vars-n_fwd:, :n_vars-n_fwd]
    Z22 = Z[n_vars-n_fwd:, n_vars-n_fwd:]

    # S and T_qz are upper triangular. We need the upper-left blocks corresponding to stable roots.
    S11 = S[:n_vars-n_fwd, :n_vars-n_fwd]
    T11 = T_qz[:n_vars-n_fwd, :n_vars-n_fwd]

    # The transition matrix for the predetermined variables (including shocks)
    # P = Z11 * (S11^-1 * T11) * Z11^-1
    try:
        S11_inv = np.linalg.inv(S11)
        Z11_inv = np.linalg.inv(Z11)
    except np.linalg.LinAlgError as e:
        raise RuntimeError(f"Matrix inversion failed during saddle-path construction: {e}") from e

    P_predet = Z11 @ S11_inv @ T11 @ Z11_inv

    # The policy function mapping predetermined variables to forward-looking variables
    # F = Z21 * Z11^-1
    F_policy = Z21 @ Z11_inv

    # Reconstruct the full 6x6 transition matrix T_core
    # The state vector is ordered: [y_t, pi_t, i_t, g_t, u_t, v_t]
    # Predetermined are [i_t, g_t, u_t, v_t] (indices 2, 3, 4, 5)
    # Forward-looking are [y_t, pi_t] (indices 0, 1)
    T_core = np.zeros((n_vars, n_vars), dtype=np.float64)

    # Map the predetermined transition dynamics
    T_core[2:, 2:] = P_predet

    # Map the forward-looking policy function
    # y_t and pi_t depend on the predetermined state at time t
    T_core[:2, 2:] = F_policy @ P_predet

    # Construct the shock loading matrix R_core (6x3) for [eps_g, eps_u, eps_v]
    R_core = np.zeros((n_vars, 3), dtype=np.float64)
    R_core[3, 0] = 1.0  # eps_g hits g_t
    R_core[4, 1] = 1.0  # eps_u hits u_t
    R_core[5, 2] = 1.0  # eps_v hits v_t

    # Forward-looking variables react contemporaneously to shocks
    R_core[:2, :] = F_policy @ R_core[2:, :]

    # Analytic Term Structure Computation
    # i_t^(10) = (1/10) * sum_{j=0}^9 E_t[i_{t+j}] + tau_t
    # Since E_t[s_{t+j}] = T_core^j * s_t, we can compute the weight vector for i_t
    term_structure_weights = np.zeros(n_vars, dtype=np.float64)
    T_power = np.eye(n_vars, dtype=np.float64)

    for j in range(10):
        # Add the row corresponding to the policy rate (index 2)
        term_structure_weights += T_power[2, :]
        T_power = T_power @ T_core

    term_structure_weights /= 10.0

    logger.info("Blanchard-Kahn solution successful. Transition matrices constructed.")
    return T_core, R_core, term_structure_weights

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Step 3: Simulate the model for 12 steps with deterministic shock innovations
# -------------------------------------------------------------------------------------------------------------------------------
def _simulate_dsge_path(
    T_core: np.ndarray,
    R_core: np.ndarray,
    term_structure_weights: np.ndarray,
    params: Dict[str, float],
    horizon: int,
    seed: int
) -> Tuple[pd.DataFrame, Dict[str, Dict[str, float]]]:
    """
    Simulates the DSGE model forward and extracts the target variables and summary statistics.

    This function initializes a fresh PRNG to guarantee exact reproducibility. It draws
    the shock innovations in the strict order mandated by the blueprint, iterates the
    state-space system, and computes the 10-year yield analytically.

    Parameters
    ----------
    T_core : np.ndarray
        The (6x6) reduced-form state transition matrix.
    R_core : np.ndarray
        The (6x3) shock loading matrix.
    term_structure_weights : np.ndarray
        The (6,) vector mapping the core state to the 10-year yield.
    params : Dict[str, float]
        The merged dictionary of calibration parameters.
    horizon : int
        The number of simulation steps (12).
    seed : int
        The deterministic seed for the PRNG (42).

    Returns
    -------
    Tuple[pd.DataFrame, Dict[str, Dict[str, float]]]
        - output_table: DataFrame containing the 12-step paths for the 4 target variables.
        - summary_stats: Nested dictionary containing peak, trough, and final values.
    """
    logger.info(f"Simulating DSGE path for {horizon} steps with seed {seed}.")

    # Instantiate a fresh, isolated PRNG to prevent seed state contamination
    rng: np.random.Generator = np.random.default_rng(seed=seed)

    # Draw shock innovations in the strict order mandated by the blueprint
    # Equation: eps ~ N(0, sigma^2)
    eps_g = rng.normal(loc=0.0, scale=params["std_eps_g"], size=horizon)
    eps_u = rng.normal(loc=0.0, scale=params["std_eps_u"], size=horizon)
    eps_v = rng.normal(loc=0.0, scale=params["std_eps_v"], size=horizon)
    eps_tau = rng.normal(loc=0.0, scale=params["std_eps_tau"], size=horizon)

    # Combine the core shocks into a (3, horizon) array
    core_shocks = np.vstack([eps_g, eps_u, eps_v])

    # Initialize the state vector history array (6, horizon)
    # Assuming simulation starts from the zero steady state
    s_history = np.zeros((6, horizon), dtype=np.float64)

    # Initialize the 10-year yield history array
    yield_10y_history = np.zeros(horizon, dtype=np.float64)

    # Initialize the term premium shock process
    tau_t = 0.0

    # Iterate the state-space system forward
    # s_t = T * s_{t-1} + R * eps_t
    for t in range(horizon):
        if t == 0:
            # First step from zero steady state
            s_history[:, t] = R_core @ core_shocks[:, t]
        else:
            s_history[:, t] = T_core @ s_history[:, t-1] + R_core @ core_shocks[:, t]

        # Update the term premium shock process: tau_t = rho_tau * tau_{t-1} + eps_tau,t
        tau_t = params["rho_tau"] * tau_t + eps_tau[t]

        # Compute the 10-year yield analytically
        # i_t^(10) = weights * s_t + tau_t
        yield_10y_history[t] = np.dot(term_structure_weights, s_history[:, t]) + tau_t

    # Extract the target variables into a structured dictionary
    # State ordering: 0=y_t (Output gap), 1=pi_t (Inflation), 2=i_t (Policy rate)
    output_data = {
        "U.S. headline inflation": s_history[1, :],
        "Federal funds rate": s_history[2, :],
        "U.S. ten-year yield": yield_10y_history,
        "U.S. output gap": s_history[0, :]
    }

    # Construct the pandas DataFrame
    # Index is 1-based step number for readability
    output_table = pd.DataFrame(output_data, index=range(1, horizon + 1))

    # Compute the summary statistics
    summary_stats: Dict[str, Dict[str, float]] = {}
    for col in output_table.columns:
        summary_stats[col] = {
            "Peak": float(output_table[col].max()),
            "Trough": float(output_table[col].min()),
            "Final": float(output_table[col].iloc[-1])
        }

    logger.info("DSGE simulation complete. Output table and summary statistics generated.")
    return output_table, summary_stats

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def run_dsge_lite_model(
    calibration_params: Dict[str, float],
    study_config: Dict[str, Any],
    assumption_registry: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Orchestrates the execution of the DSGE-lite computational runner.

    This function merges the specific calibration payload with global defaults, solves
    the linear rational expectations system via Blanchard-Kahn, and simulates the path.
    Crucially, it logs the manuscript-unspecified state vector ordering and analytic
    term structure methodology to the assumption registry for regulatory traceability.

    Parameters
    ----------
    calibration_params : Dict[str, float]
        The calibration parameters parsed from the graph's JSON payload.
    study_config : Dict[str, Any]
        The master study configuration dictionary containing global solver settings.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions.

    Returns
    -------
    Dict[str, Any]
        A dictionary containing:
        - "model_output_table": pd.DataFrame of the 12-step paths.
        - "summary_statistics": Dict of peak, trough, and final values.

    Raises
    ------
    RuntimeError
        If the Blanchard-Kahn determinacy check fails or matrix operations fail.
    """
    # Log the initiation of the DSGE-lite computational runner
    logger.info("=== Task 19: Initiating DSGE-lite computational runner ===")

    try:
        # Extract global parameters and settings from the configuration
        global_dsge_params = study_config.get("dsge_lite_parameters", {})
        solver_settings = study_config.get("computational_solver_parameters", {})

        # Extract specific solver settings
        horizon = solver_settings.get("model_horizon_steps", 12)
        seed = solver_settings.get("random_seed", 42)
        tolerance = solver_settings.get("bk_tolerance", 1e-8)

        # Merge the specific payload with the global defaults to ensure all parameters are present
        merged_params = {**global_dsge_params, **calibration_params}

        # Log the methodological assumptions to the registry for epistemic traceability
        registry_slug: str = "dsge_lite_methodological_assumptions"
        assumption_registry[registry_slug] = {
            "state_vector_ordering": "[y_t, pi_t, i_t, g_t, u_t, v_t]",
            "term_structure_methodology": "Analytic expectation via transition matrix powers (T_core^j)",
            "rationale": (
                "The LaTeX context omits the explicit state vector ordering and the exact "
                "methodology for computing the 10-year yield expectations. These choices "
                "were implemented to ensure mathematical rigor and are logged here for auditability."
            )
        }
        logger.debug(f"Logged DSGE-lite methodological assumptions to registry under '{registry_slug}'.")

        # Execute Step 2: Construct and solve the system
        # Note: _solve_dsge_blanchard_kahn is assumed to be in namespace
        T_core, R_core, term_weights = _solve_dsge_blanchard_kahn(
            params=merged_params,
            tolerance=tolerance
        )

        # Execute Step 3: Simulate the path and extract statistics
        # Note: _simulate_dsge_path is assumed to be in namespace
        output_table, summary_stats = _simulate_dsge_path(
            T_core=T_core,
            R_core=R_core,
            term_structure_weights=term_weights,
            params=merged_params,
            horizon=horizon,
            seed=seed
        )

        # Construct the final return dictionary
        result_dict = {
            "model_output_table": output_table,
            "summary_statistics": summary_stats
        }

        # Log the successful completion of the runner
        logger.info("=== Task 19: DSGE-lite computational runner completed successfully ===")
        return result_dict

    except DeterminacyError as e:
        # Catch the specific determinacy failure and raise as a fatal RuntimeError
        error_msg = f"=== Task 19: DSGE-lite execution FAILED ===\nDeterminacy Error: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e
    except Exception as e:
        # Catch any other mathematical or structural errors
        error_msg = f"=== Task 19: DSGE-lite execution FAILED ===\nDetails: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# %%
# Task 20 — Implement MS-VAR runner with Hamilton filter and bank stress mappings

# ==============================================================================
# Task 20: Implement MS-VAR runner with Hamilton filter and bank stress mappings
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 20, Step 2: Implement the regime simulation and the Hamilton filter
# -------------------------------------------------------------------------------------------------------------------------------
def _simulate_and_filter_msvar(
    rs_params: Dict[str, Any],
    horizon: int,
    seed: int
) -> Tuple[pd.DataFrame, np.ndarray]:
    """
    Simulates the MS-VAR forward and applies the Hamilton filter for regime inference.

    This function implements the "simulate-then-filter" ordering mandated by the blueprint.
    It derives the stationary distribution, draws a Markov regime sequence, simulates the
    multivariate state path, and then applies the Hamilton filter to compute the conditional
    regime probabilities.

    State vector ordering (4-element):
    0: CRE price (p_t^{CRE})
    1: Credit spread (s_t^{credit})
    2: Bank funding spread (s_t^{funding})
    3: Deposit outflow rate (d_t^{outflow})

    Parameters
    ----------
    rs_params : Dict[str, Any]
        The regime-switching parameters from the configuration.
    horizon : int
        The number of simulation steps (12).
    seed : int
        The deterministic seed for the PRNG (42).

    Returns
    -------
    Tuple[pd.DataFrame, np.ndarray]
        - output_table: DataFrame containing the 12-step paths for the 4 state variables.
        - filtered_probs: Array of shape (2, horizon) containing P(S_t=j | Y_t).
    """
    logger.info(f"Simulating MS-VAR path for {horizon} steps with seed {seed}.")

    # Instantiate a fresh, isolated PRNG to prevent seed state contamination
    rng: np.random.Generator = np.random.default_rng(seed=seed)

    # Extract transition probabilities
    p11: float = float(rs_params["p11"])
    p22: float = float(rs_params["p22"])

    # Construct the transition matrix P
    # P(S_t = j | S_{t-1} = i) = p_{ij}
    P = np.array([
        [p11, 1.0 - p11],
        [1.0 - p22, p22]
    ], dtype=np.float64)

    # Derive the stationary distribution pi analytically
    # pi = (I - P^T + 1)^{-1} 1
    A = np.eye(2) - P.T + np.ones((2, 2))
    b = np.ones(2)
    pi_stationary = np.linalg.solve(A, b)
    logger.debug(f"Derived stationary distribution: {pi_stationary}")

    # Extract regime-specific parameters
    c_1 = np.array(rs_params["state_1_intercepts"], dtype=np.float64)
    c_2 = np.array(rs_params["state_2_intercepts"], dtype=np.float64)

    A1_1 = np.array(rs_params["state_1_autoregressive_matrix"], dtype=np.float64)
    A1_2 = np.array(rs_params["state_2_autoregressive_matrix"], dtype=np.float64)

    Sigma_1 = np.array(rs_params["state_1_var_cov_matrix"], dtype=np.float64)
    Sigma_2 = np.array(rs_params["state_2_var_cov_matrix"], dtype=np.float64)

    # --- Phase 1: Simulation ---
    # Draw the Markov regime sequence S_t
    S = np.zeros(horizon, dtype=int)
    # Initial regime drawn from stationary distribution
    S[0] = rng.choice([0, 1], p=pi_stationary)
    for t in range(1, horizon):
        S[t] = rng.choice([0, 1], p=P[S[t-1], :])

    # Initialize the state vector history array (4, horizon)
    Y = np.zeros((4, horizon), dtype=np.float64)

    # Simulate the MS-VAR state equation
    # Y_t = c_{S_t} + A_{1,S_t} Y_{t-1} + eps_{S_t,t}
    for t in range(horizon):
        regime = S[t]

        # Select regime-specific parameters
        c_t = c_1 if regime == 0 else c_2
        A1_t = A1_1 if regime == 0 else A1_2
        Sigma_t = Sigma_1 if regime == 0 else Sigma_2

        # Draw innovation eps_{S_t,t} ~ N(0, Sigma_{S_t})
        eps_t = rng.multivariate_normal(mean=np.zeros(4), cov=Sigma_t)

        if t == 0:
            # Assume Y_{t-1} is zero for the first step
            Y[:, t] = c_t + eps_t
        else:
            Y[:, t] = c_t + A1_t @ Y[:, t-1] + eps_t

    # --- Phase 2: Hamilton Filter ---
    filtered_probs = np.zeros((2, horizon), dtype=np.float64)

    # Initialize prior probability with stationary distribution
    prior_prob = pi_stationary.copy()

    for t in range(horizon):
        # 1. Prediction step
        # P(S_t = j | Y_{t-1}) = sum_i p_{ij} P(S_{t-1} = i | Y_{t-1})
        pred_prob = P.T @ prior_prob

        # 2. Likelihood step
        # f(Y_t | S_t = j, Y_{t-1}) = N(Y_t; c_j + A_{1,j} Y_{t-1}, Sigma_j)
        Y_prev = Y[:, t-1] if t > 0 else np.zeros(4)

        mu_1 = c_1 + A1_1 @ Y_prev
        mu_2 = c_2 + A1_2 @ Y_prev

        # Compute multivariate normal PDF
        # scipy.stats.multivariate_normal.pdf is numerically stable
        lik_1 = scipy.stats.multivariate_normal.pdf(Y[:, t], mean=mu_1, cov=Sigma_1)
        lik_2 = scipy.stats.multivariate_normal.pdf(Y[:, t], mean=mu_2, cov=Sigma_2)
        likelihoods = np.array([lik_1, lik_2])

        # 3. Update step
        # P(S_t = j | Y_t) = (f * P) / sum(f * P)
        joint_prob = likelihoods * pred_prob
        marginal_prob = np.sum(joint_prob)

        # Add epsilon to prevent division by zero in case of extreme underflow
        updated_prob = joint_prob / (marginal_prob + 1e-12)

        filtered_probs[:, t] = updated_prob
        prior_prob = updated_prob

    # Construct the pandas DataFrame for the output table
    output_data = {
        "CRE price": Y[0, :],
        "Credit spread": Y[1, :],
        "Bank funding spread": Y[2, :],
        "Deposit outflow rate": Y[3, :]
    }
    output_table = pd.DataFrame(output_data, index=range(1, horizon + 1))

    logger.info("MS-VAR simulation and Hamilton filtering complete.")
    return output_table, filtered_probs

# -------------------------------------------------------------------------------------------------------------------------------
# Task 20, Step 3: Apply bank stress accounting mappings to the macro-financial paths
# -------------------------------------------------------------------------------------------------------------------------------
def _compute_bank_stress_metrics(
    output_table: pd.DataFrame,
    bs_params: Dict[str, float]
) -> Dict[str, float]:
    """
    Applies Basel III/CCAR accounting identities to compute bank stress metrics.

    This function maps the simulated macro-financial paths to credit risk parameters
    (PD, LGD) and computes capital (CET1) and liquidity (LCR) ratios. It implements
    documented proxies for missing cross-application drivers (10-year yield, policy rate).

    Parameters
    ----------
    output_table : pd.DataFrame
        The simulated 12-step paths for the MS-VAR state variables.
    bs_params : Dict[str, float]
        The bank stress accounting parameters from the configuration.

    Returns
    -------
    Dict[str, float]
        A dictionary containing the 7 computed scalar stress metrics.
    """
    logger.info("Computing bank stress metrics via accounting mappings.")

    # Extract macro paths as NumPy arrays for vectorized arithmetic
    p_CRE = output_table["CRE price"].to_numpy()
    s_credit = output_table["Credit spread"].to_numpy()
    s_funding = output_table["Bank funding spread"].to_numpy()
    d_outflow = output_table["Deposit outflow rate"].to_numpy()

    # Compute first differences (period-over-period changes)
    # Prepend 0 to maintain array length (assuming no change in period 1 from initial state)
    delta_s_credit = np.diff(s_credit, prepend=s_credit[0])
    delta_s_funding = np.diff(s_funding, prepend=s_funding[0])

    # --- Proxy Implementations for Missing Drivers ---
    # The MS-VAR state vector lacks the 10-year yield and policy rate.
    # Proxy 1: delta_i_10Y is approximated as 0.5 * delta_s_credit (spread widening drives yields)
    delta_i_10Y = 0.5 * delta_s_credit
    # Proxy 2: delta_i (policy rate) is assumed 0.0 (constrained at zero lower bound during stress)
    delta_i = np.zeros_like(p_CRE)
    logger.debug("Applied documented proxies for missing 10-year yield and policy rate drivers.")

    # --- Equation 13: Probability of Default (PD) Mapping ---
    # PD_t = Lambda(alpha_0 + alpha_1 * p_CRE + alpha_2 * s_credit)
    # scipy.special.expit is the numerically stable logistic sigmoid function
    z_pd = bs_params["alpha_0"] + bs_params["alpha_1"] * p_CRE + bs_params["alpha_2"] * s_credit
    PD_t = scipy.special.expit(z_pd)

    # --- Equation 14: Loss Given Default (LGD) Mapping ---
    # LGD_t = max(0, gamma_0 + gamma_1 * p_CRE)
    z_lgd = bs_params["gamma_0"] + bs_params["gamma_1"] * p_CRE
    LGD_t = np.maximum(0.0, z_lgd)

    # --- Equation 15: Expected Credit Loss ---
    # CL_t = EAD * PD_t * LGD_t
    CL_t = bs_params["EAD"] * PD_t * LGD_t

    # --- Equation 16: Market Loss ---
    # ML_t = -D_A * delta_i_10Y * A_mkt + kappa_spr * delta_s_credit
    ML_t = -bs_params["D_A"] * delta_i_10Y * bs_params["A_mkt"] + bs_params["kappa_spr"] * delta_s_credit

    # --- Equation 17: Net Interest Income (NII) Change ---
    # delta_NII_t = delta_0 + delta_1 * delta_i - delta_2 * delta_s_funding - delta_3 * d_outflow
    NII_t = (bs_params["delta_0"]
             + bs_params["delta_1"] * delta_i
             - bs_params["delta_2"] * delta_s_funding
             - bs_params["delta_3"] * d_outflow)

    # --- Equation 18: Risk-Weighted Capital Ratio (CET1) ---
    # CET1_t = (Capital_{t-1} - CL_t - ML_t) / (RWA_{t-1} + 12.5 * CL_t)
    # Note: The formula uses static t-1 baselines for Capital and RWA per the blueprint
    CET1_t = (bs_params["Capital_prev"] - CL_t - ML_t) / (bs_params["RWA_prev"] + 12.5 * CL_t)

    # --- Equation 19: Liquidity Coverage Ratio (LCR) ---
    # LCR_t = (HQLA_{t-1} - ML_t) / (Outflows_{t-1} * (1 + d_outflow) - Inflows_{t-1})
    denominator_lcr = bs_params["Outflows_prev"] * (1.0 + d_outflow) - bs_params["Inflows_prev"]
    # Guard against division by zero
    denominator_lcr = np.where(denominator_lcr <= 0, 1e-6, denominator_lcr)
    LCR_t = (bs_params["HQLA_prev"] - ML_t) / denominator_lcr

    # --- Extract Extremum Values for Final Metrics ---
    # CCAR methodology reports the "Stress" metric at the point of maximum severity.
    # For capital/liquidity, this is the minimum. For losses/PD, this is the maximum.
    bank_metrics: Dict[str, float] = {
        "Stress PD": float(np.max(PD_t)),
        "Stress LGD": float(np.max(LGD_t)),
        "Credit loss": float(np.max(CL_t)),
        "Market loss": float(np.max(ML_t)),
        "NII change": float(np.min(NII_t)),  # Minimum represents maximum negative impact
        "Stress CET1": float(np.min(CET1_t)),
        "Stress LCR": float(np.min(LCR_t))
    }

    logger.info("Bank stress metrics computed successfully.")
    return bank_metrics

# -------------------------------------------------------------------------------------------------------------------------------
# Task 20, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def run_regime_switching_model(
    study_config: Dict[str, Any],
    assumption_registry: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Orchestrates the execution of the MS-VAR computational runner and stress accounting.

    This function extracts the required parameter dictionaries, simulates the regime-switching
    paths, applies the Hamilton filter, and computes the regulatory bank stress metrics.
    Crucially, it logs the manuscript-unspecified proxy equations for the missing 10-year
    yield and policy rate drivers to the assumption registry for regulatory traceability.

    Parameters
    ----------
    study_config : Dict[str, Any]
        The master study configuration dictionary containing all parameters.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions.

    Returns
    -------
    Dict[str, Any]
        A dictionary containing:
        - "model_output_table": pd.DataFrame of the 12-step state paths.
        - "bank_metrics": Dict of the 7 computed scalar stress metrics.

    Raises
    ------
    KeyError
        If required parameter sections are missing from the configuration.
    RuntimeError
        If the simulation or accounting computations fail.
    """
    # Log the initiation of the MS-VAR computational runner
    logger.info("=== Task 20: Initiating MS-VAR computational runner ===")

    try:
        # Extract required parameter dictionaries from the configuration
        if "regime_switching_parameters" not in study_config:
            raise KeyError("Missing 'regime_switching_parameters' in configuration.")
        if "bank_stress_parameters" not in study_config:
            raise KeyError("Missing 'bank_stress_parameters' in configuration.")

        rs_params = study_config["regime_switching_parameters"]
        bs_params = study_config["bank_stress_parameters"]
        solver_settings = study_config.get("computational_solver_parameters", {})

        # Extract specific solver settings
        horizon = solver_settings.get("model_horizon_steps", 12)
        seed = solver_settings.get("random_seed", 42)

        # Log the methodological assumptions to the registry for epistemic traceability
        registry_slug: str = "ms_var_proxy_assumptions"
        assumption_registry[registry_slug] = {
            "proxy_10y_yield_change": "delta_i_10Y = 0.5 * delta_s_credit",
            "proxy_policy_rate_change": "delta_i = 0.0",
            "rationale": (
                "The MS-VAR state vector lacks the 10-year yield and policy rate required "
                "for the bank stress accounting (Market Loss and NII Change). These proxies "
                "were implemented to bridge the cross-application data gap and are logged "
                "here for regulatory auditability."
            )
        }
        logger.debug(f"Logged MS-VAR proxy assumptions to registry under '{registry_slug}'.")

        # Execute Step 2: Simulate the MS-VAR and apply Hamilton filter
        # Note: _simulate_and_filter_msvar is assumed to be in namespace
        output_table, filtered_probs = _simulate_and_filter_msvar(
            rs_params=rs_params,
            horizon=horizon,
            seed=seed
        )

        # Execute Step 3: Apply bank stress accounting mappings
        # Note: _compute_bank_stress_metrics is assumed to be in namespace
        bank_metrics = _compute_bank_stress_metrics(
            output_table=output_table,
            bs_params=bs_params
        )

        # Construct the final return dictionary
        result_dict = {
            "model_output_table": output_table,
            "bank_metrics": bank_metrics
        }

        # Log the successful completion of the runner
        logger.info("=== Task 20: MS-VAR computational runner completed successfully ===")
        return result_dict

    except Exception as e:
        # Catch any mathematical or structural errors and halt the pipeline
        error_msg = f"=== Task 20: MS-VAR execution FAILED ===\nDetails: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# %%
# Task 21 — Implement Graph Write-Back callable (persist execution artifacts)

# ==============================================================================
# Task 21: Implement Graph Write-Back callable (persist execution artifacts)
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 21, Step 2: Create ModelRun node with complete run metadata
# -------------------------------------------------------------------------------------------------------------------------------
def _create_model_run_node(
    tx: Transaction,
    scenario_id: str,
    spec_id: str,
    study_config: Dict[str, Any]
) -> str:
    """
    Creates the ModelRun node and establishes its topological relationships.

    This function generates a unique, separator-safe run identifier. It extracts
    execution metadata from the configuration and executes a parameterized Cypher
    query to create the node and link it to the Scenario, ModelSpecification, and
    ImplementationFunction.

    Parameters
    ----------
    tx : neo4j.Transaction
        The active Neo4j transaction object ensuring atomicity.
    scenario_id : str
        The unique identifier of the current scenario.
    spec_id : str
        The unique identifier of the executed model specification.
    study_config : Dict[str, Any]
        The master study configuration dictionary containing solver settings.

    Returns
    -------
    str
        The generated unique run_id.

    Raises
    ------
    RuntimeError
        If the Cypher execution fails.
    """
    logger.info("Constructing ModelRun node and metadata.")

    # Generate a compact, separator-safe timestamp for the run_id
    # Format: YYYYMMDDHHMMSS
    timestamp_str: str = datetime.now(timezone.utc).strftime("%Y%m%d%H%M%S")
    run_id: str = f"RUN_{scenario_id}_{timestamp_str}"

    # Extract execution metadata from the configuration
    solver_settings = study_config.get("computational_solver_parameters", {})
    horizon: int = solver_settings.get("model_horizon_steps", 12)
    seed: int = solver_settings.get("random_seed", 42)

    # Determine solver method based on the specification ID (Application 1 vs 2)
    if "DSGE" in spec_id:
        solver_method = "Blanchard-Kahn"
        determinacy_check = "passed" # If we reached this point, it passed in Task 19
    elif "REGIME" in spec_id:
        solver_method = "Hamilton filter"
        determinacy_check = "not_applicable"
    else:
        solver_method = "Unknown"
        determinacy_check = "Unknown"

    execution_timestamp: str = datetime.now(timezone.utc).isoformat()

    # Define the Cypher query to create the ModelRun and its relationships
    # The VALIDATED_BY relationship direction is explicitly set from ModelRun to ImplementationFunction
    # to match the expectations of the post-execution retrieval query.
    cypher_query: str = """
    MATCH (s:Scenario {scenario_id: $scenario_id})
    MATCH (ms:ModelSpecification {spec_id: $spec_id})-[:MAPS_TO]->(impl:ImplementationFunction)
    CREATE (mr:ModelRun {
        run_id: $run_id,
        scenario_id: $scenario_id,
        spec_id: $spec_id,
        horizon: $horizon,
        seed: $seed,
        solver_method: $solver_method,
        determinacy_check: $determinacy_check,
        execution_timestamp: datetime($execution_timestamp)
    })
    MERGE (mr)-[:EXECUTED_FOR]->(s)
    MERGE (mr)-[:USES_SPECIFICATION]->(ms)
    MERGE (mr)-[:VALIDATED_BY]->(impl)
    """

    parameters: Dict[str, Any] = {
        "scenario_id": scenario_id,
        "spec_id": spec_id,
        "run_id": run_id,
        "horizon": horizon,
        "seed": seed,
        "solver_method": solver_method,
        "determinacy_check": determinacy_check,
        "execution_timestamp": execution_timestamp
    }

    try:
        # Execute the query within the provided transaction context
        tx.run(cypher_query, **parameters)
        logger.debug(f"ModelRun node '{run_id}' created successfully.")
        return run_id
    except Exception as e:
        error_msg = f"Failed to create ModelRun node. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 21, Step 3: Create ModelOutputPoint nodes and BankMetric nodes (if applicable)
# -------------------------------------------------------------------------------------------------------------------------------
def _create_output_leaf_nodes(
    tx: Transaction,
    run_id: str,
    model_outputs: Dict[str, Any]
) -> Tuple[int, int]:
    """
    Creates ModelOutputPoint and BankMetric nodes using batched UNWIND queries.

    This function unpivots the pandas DataFrame into a flat list of dictionaries
    and executes a bulk insertion. It ensures all leaf nodes are correctly linked
    to the parent ModelRun node within the same transaction context.

    Parameters
    ----------
    tx : neo4j.Transaction
        The active Neo4j transaction object ensuring atomicity.
    run_id : str
        The unique identifier of the parent ModelRun node.
    model_outputs : Dict[str, Any]
        The dictionary containing 'model_output_table' and optionally 'bank_metrics'.

    Returns
    -------
    Tuple[int, int]
        A tuple containing the counts of (output_points_created, bank_metrics_created).

    Raises
    ------
    RuntimeError
        If the Cypher execution fails.
    """
    logger.info("Constructing ModelOutputPoint and BankMetric leaf nodes.")

    output_points_created: int = 0
    bank_metrics_created: int = 0

    # --- Process ModelOutputPoints ---
    if "model_output_table" in model_outputs:
        df: pd.DataFrame = model_outputs["model_output_table"]
        output_records: List[Dict[str, Any]] = []

        # Unpivot the DataFrame: iterate over columns (variables) and index (steps)
        for variable_name in df.columns:
            # Clean variable name for ID generation (remove spaces and special chars)
            clean_var_name = "".join(e for e in variable_name if e.isalnum())

            for step_idx, value in df[variable_name].items():
                # Construct a deterministic, unique output_id
                output_id = f"{run_id}_{clean_var_name}_STEP_{step_idx}"

                output_records.append({
                    "output_id": output_id,
                    "variable_name": variable_name,
                    "horizon_step": int(step_idx),
                    "value": float(value)
                })

        # Define the UNWIND query for bulk insertion of output points
        unwind_outputs_query: str = """
        MATCH (mr:ModelRun {run_id: $run_id})
        UNWIND $batch AS row
        CREATE (mop:ModelOutputPoint {
            output_id: row.output_id,
            variable_name: row.variable_name,
            horizon_step: row.horizon_step,
            value: row.value
        })
        MERGE (mr)-[:PRODUCED]->(mop)
        """

        try:
            result = tx.run(unwind_outputs_query, run_id=run_id, batch=output_records)
            summary = result.consume()
            output_points_created = summary.counters.nodes_created
            logger.debug(f"Created {output_points_created} ModelOutputPoint nodes.")
        except Exception as e:
            error_msg = f"Failed to UNWIND ModelOutputPoints. Details: {e}"
            logger.error(error_msg)
            raise RuntimeError(error_msg) from e

    # --- Process BankMetrics (Application 2 specific) ---
    if "bank_metrics" in model_outputs:
        metrics_dict: Dict[str, float] = model_outputs["bank_metrics"]
        metric_records: List[Dict[str, Any]] = []

        for metric_name, value in metrics_dict.items():
            clean_metric_name = "".join(e for e in metric_name if e.isalnum())
            metric_id = f"{run_id}_{clean_metric_name}"

            metric_records.append({
                "metric_id": metric_id,
                "metric_name": metric_name,
                "value": float(value)
            })

        # Define the UNWIND query for bulk insertion of bank metrics
        unwind_metrics_query: str = """
        MATCH (mr:ModelRun {run_id: $run_id})
        UNWIND $batch AS row
        CREATE (bm:BankMetric {
            metric_id: row.metric_id,
            metric_name: row.metric_name,
            value: row.value
        })
        MERGE (mr)-[:COMPUTED]->(bm)
        """

        try:
            result = tx.run(unwind_metrics_query, run_id=run_id, batch=metric_records)
            summary = result.consume()
            bank_metrics_created = summary.counters.nodes_created
            logger.debug(f"Created {bank_metrics_created} BankMetric nodes.")
        except Exception as e:
            error_msg = f"Failed to UNWIND BankMetrics. Details: {e}"
            logger.error(error_msg)
            raise RuntimeError(error_msg) from e

    return output_points_created, bank_metrics_created

# -------------------------------------------------------------------------------------------------------------------------------
# Task 21, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def write_back_model_run(
    driver: Any,
    scenario_id: str,
    spec_id: str,
    model_outputs: Dict[str, Any],
    study_config: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Orchestrates the atomic write-back of execution artifacts to the Knowledge Graph.

    This function acts as the entry point for Task 21 (Step 8 of the AI Economist Agent
    Execution Workflow). It manages a single Neo4j write transaction, ensuring that
    the ModelRun node and all its associated output leaf nodes are committed atomically.
    It returns the generated run_id required by the post-execution retrieval task.

    Parameters
    ----------
    driver : Any
        The authenticated Neo4j driver connection pool manager.
    scenario_id : str
        The unique identifier of the current scenario.
    spec_id : str
        The unique identifier of the executed model specification.
    model_outputs : Dict[str, Any]
        The dictionary containing the computed output table and metrics.
    study_config : Dict[str, Any]
        The master study configuration dictionary.

    Returns
    -------
    Dict[str, Any]
        A dictionary containing:
        - "run_id": The generated unique identifier for the ModelRun.
        - "ModelRun_nodes_created": Count (always 1 on success).
        - "ModelOutputPoint_nodes_created": Count of output points.
        - "BankMetric_nodes_created": Count of bank metrics.

    Raises
    ------
    TypeError
        If the provided driver is not a valid neo4j.Driver instance.
    RuntimeError
        If the transaction fails to commit.
    """
    logger.info(f"=== Task 21: Initiating Graph Write-Back for Scenario {scenario_id} ===")

    if not isinstance(driver, Driver):
        error_msg = f"Expected a neo4j.Driver instance, got {type(driver).__name__}."
        logger.error(error_msg)
        raise TypeError(error_msg)

    # Define the transactional unit of work
    def _execute_full_write_back(tx: Transaction) -> Dict[str, Any]:
        """Encapsulates Step 2 and Step 3 within a single transaction context."""

        # Execute Step 2: Create the parent ModelRun node
        generated_run_id: str = _create_model_run_node(
            tx=tx,
            scenario_id=scenario_id,
            spec_id=spec_id,
            study_config=study_config
        )

        # Execute Step 3: Create the child leaf nodes
        pts_created, metrics_created = _create_output_leaf_nodes(
            tx=tx,
            run_id=generated_run_id,
            model_outputs=model_outputs
        )

        # Construct the audit dictionary
        return {
            "run_id": generated_run_id,
            "ModelRun_nodes_created": 1,
            "ModelOutputPoint_nodes_created": pts_created,
            "BankMetric_nodes_created": metrics_created
        }

    try:
        # Open a managed write session. If any exception is raised inside the
        # _execute_full_write_back function, the transaction will automatically rollback.
        with driver.session() as session:
            write_back_status: Dict[str, Any] = session.execute_write(_execute_full_write_back)

        logger.info(f"=== Task 21: Graph Write-Back completed successfully. Run ID: {write_back_status['run_id']} ===")
        return write_back_status

    except Exception as e:
        # Catch any errors, log a critical failure, and raise a RuntimeError
        error_msg = f"=== Task 21: Graph Write-Back FAILED ===\nDetails: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# %%
# Task 22 — Implement Graph Retrieval (Post-Execution) callable

# ==============================================================================
# Task 22: Implement Graph Retrieval (Post-Execution) callable
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 22, Step 2: Execute Cypher query to retrieve the full traceability path
# -------------------------------------------------------------------------------------------------------------------------------
def _execute_post_run_traceability_query(
    driver: Driver,
    scenario_id: str,
    run_id: str
) -> List[Path]:
    """
    Executes a Cypher query to retrieve the full post-execution traceability paths.

    This function enforces read-committed isolation to query the graph state after
    the write-back transaction has completed. It matches the exact topological chain
    from the Scenario down to the ModelOutputPoint, anchored by the specific run_id.

    Parameters
    ----------
    driver : neo4j.Driver
        The authenticated Neo4j driver connection pool manager.
    scenario_id : str
        The unique identifier of the current scenario.
    run_id : str
        The unique identifier of the executed ModelRun.

    Returns
    -------
    List[neo4j.graph.Path]
        A list of raw Neo4j Path objects representing the traceability chains.

    Raises
    ------
    RuntimeError
        If the Cypher execution fails due to database errors.
    """
    logger.info(f"Executing post-run traceability query for run_id: {run_id}")

    # Define the exact topological chain mandated by the blueprint.
    # Note the direction of VALIDATED_BY: (ModelRun)-[:VALIDATED_BY]->(ImplementationFunction)
    # Therefore, traversing from ImplementationFunction to ModelRun requires <-[:VALIDATED_BY]-
    traceability_query: str = """
    MATCH path = (s:Scenario {scenario_id: $scenario_id})-[:AFFECTS]->(v:VariableConcept)
                 -[:SUPPORTED_BY]->(ms:ModelSpecification)
                 -[:MAPS_TO]->(impl:ImplementationFunction)
                 <-[:VALIDATED_BY]-(mr:ModelRun {run_id: $run_id})
                 -[:PRODUCED]->(mop:ModelOutputPoint)
    RETURN path;
    """

    def _run_query(tx: Transaction) -> List[Path]:
        """Helper function to execute the query within a managed read transaction."""
        result = tx.run(traceability_query, scenario_id=scenario_id, run_id=run_id)
        # Extract the Path object from each record
        return [record["path"] for record in result]

    try:
        # Open a managed read session to ensure we see the committed write-back state
        with driver.session() as session:
            raw_paths: List[Path] = session.execute_read(_run_query)

        logger.debug(f"Retrieved {len(raw_paths)} raw traceability paths from the graph.")
        return raw_paths

    except neo4j.exceptions.Neo4jError as e:
        error_msg = f"Failed to execute post-run traceability query. Details: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 22, Step 3: Format the retrieved paths as human-readable audit strings
# -------------------------------------------------------------------------------------------------------------------------------
def _format_and_summarize_paths(raw_paths: List[Neo4jPath]) -> List[str]:
    """
    Formats Neo4j Path objects into readable strings and summarizes them by variable.

    This function translates the complex graph objects into linear text representations.
    To prevent context window overflow while preserving maximum information density,
    it groups the paths by the target variable, parses the numerical value from the
    ModelOutputPoint node, and selects the path containing the maximum absolute value
    (the extremum point) as the representative summary for that variable.

    Parameters
    ----------
    raw_paths : List[neo4j.graph.Path]
        The list of raw Neo4j Path objects retrieved from the database.

    Returns
    -------
    List[str]
        A list of formatted, summarized path strings containing extremum points.
    """
    # Log the initiation of the formatting and summarization process
    logger.info("Formatting and summarizing traceability paths by extremum values.")

    # Return an empty list if no paths were provided
    if not raw_paths:
        return []

    def _format_single_path(path: Neo4jPath) -> Tuple[str, str, float]:
        """
        Formats a single path, extracts the variable name for grouping, and
        extracts the numerical value for extremum sorting.
        Returns (formatted_string, variable_name, absolute_value).
        """
        formatted_elements = []
        variable_name = "Unknown"
        absolute_value = 0.0

        # Iterate through the nodes in the path
        for i, node in enumerate(path.nodes):
            # Extract the primary label
            label = list(node.labels)[0] if node.labels else "Unknown"

            # Extract the primary key dynamically based on the label
            if label == "Scenario":
                key_val = node.get("scenario_id", "Unknown")
            elif label == "VariableConcept":
                key_val = node.get("concept_id", "Unknown")
                # Capture the variable name for grouping
                variable_name = node.get("variable_name", "Unknown")
            elif label == "ModelSpecification":
                key_val = node.get("spec_id", "Unknown")
            elif label == "ImplementationFunction":
                key_val = node.get("execution_tool_name", "Unknown")
            elif label == "ModelRun":
                key_val = node.get("run_id", "Unknown")
            elif label == "ModelOutputPoint":
                # For the output point, we show the ID and the value to prove execution
                out_id = node.get("output_id", "Unknown")
                val = node.get("value", 0.0)
                key_val = f"{out_id}_val_{val}"
                # Capture the absolute value for extremum sorting
                try:
                    absolute_value = abs(float(val))
                except (ValueError, TypeError):
                    absolute_value = 0.0
            else:
                key_val = "Unknown"

            # Append the formatted node string
            formatted_elements.append(f"({label}:{key_val})")

            # Append the relationship if we are not at the last node
            if i < len(path.relationships):
                rel = path.relationships[i]
                # Determine direction relative to the path traversal
                if rel.start_node == node:
                    formatted_elements.append(f"-[:{rel.type}]->")
                else:
                    formatted_elements.append(f"<-[:{rel.type}]-")

        # Return the assembled string, the grouping key, and the sorting metric
        return "".join(formatted_elements), variable_name, absolute_value

    # Group formatted paths by variable name to implement the summarization logic
    # The dictionary stores tuples of (formatted_string, absolute_value)
    grouped_paths: Dict[str, List[Tuple[str, float]]] = {}

    for path in raw_paths:
        formatted_str, var_name, abs_val = _format_single_path(path)
        if var_name not in grouped_paths:
            grouped_paths[var_name] = []
        grouped_paths[var_name].append((formatted_str, abs_val))

    summarized_paths: List[str] = []

    # Select the representative path containing the extremum value for each variable
    for var_name, path_tuples in grouped_paths.items():
        if path_tuples:
            # Sort the tuples by absolute_value descending
            sorted_tuples = sorted(path_tuples, key=lambda x: x[1], reverse=True)
            # Select the formatted string of the tuple with the highest absolute value
            extremum_path_str = sorted_tuples[0][0]
            summarized_paths.append(extremum_path_str)

    # Log the reduction ratio
    logger.debug(f"Summarized {len(raw_paths)} raw paths into {len(summarized_paths)} extremum-representative strings.")
    return summarized_paths

# -------------------------------------------------------------------------------------------------------------------------------
# Task 22, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def retrieve_graph_context_post_execution(
    driver: Any,
    scenario_id: str,
    run_id: str,
    study_config: Dict[str, Any]
) -> List[str]:
    """
    Orchestrates the post-execution retrieval of graph traceability paths.

    This function acts as the entry point for Task 22 (Step 9 of the AI Economist Agent
    Execution Workflow). It validates the driver, executes the exact-chain Cypher query,
    formats the results into readable strings, and enforces the critical fail-fast
    check for empty traceability paths.

    Parameters
    ----------
    driver : Any
        The authenticated Neo4j driver connection pool manager.
    scenario_id : str
        The unique identifier of the current scenario.
    run_id : str
        The unique identifier of the executed ModelRun (threaded from Task 21).
    study_config : Dict[str, Any]
        The master study configuration dictionary.

    Returns
    -------
    List[str]
        A list of formatted, human-readable traceability path strings.

    Raises
    ------
    TypeError
        If the provided driver is not a valid neo4j.Driver instance.
    RuntimeError
        If the Cypher execution fails or if the retrieved path list is empty.
    """
    logger.info(f"=== Task 22: Initiating Post-Execution Graph Retrieval for Run {run_id} ===")

    if not isinstance(driver, Driver):
        error_msg = f"Expected a neo4j.Driver instance, got {type(driver).__name__}."
        logger.error(error_msg)
        raise TypeError(error_msg)

    try:
        # Execute Step 2: Retrieve the raw paths from the database
        raw_paths: List[Path] = _execute_post_run_traceability_query(
            driver=driver,
            scenario_id=scenario_id,
            run_id=run_id
        )

        # Execute Step 3: Format and summarize the paths
        formatted_paths: List[str] = _format_and_summarize_paths(raw_paths=raw_paths)

        # CRITICAL FAIL-FAST CHECK: An empty post-run traceability path indicates a
        # failure in the write-back or query logic, breaking the epistemic chain.
        if not formatted_paths:
            error_msg = (
                f"CRITICAL: Post-execution traceability query returned empty paths for run_id '{run_id}'. "
                f"This breaks the epistemic traceability chain required for the Model-grounded condition."
            )
            logger.error(error_msg)
            raise RuntimeError(error_msg)

        logger.info("=== Task 22: Post-Execution Graph Retrieval completed successfully ===")
        return formatted_paths

    except Exception as e:
        # Catch any errors, log a critical failure, and raise a RuntimeError
        error_msg = f"=== Task 22: Post-Execution Graph Retrieval FAILED ===\nDetails: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# %%
# Task 23 — Implement Report Generator callable (3 condition variants)

# ==============================================================================
# Task 23: Implement Report Generator callable (3 condition variants)
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Step 2: Select the appropriate prompt template based on condition and inject inputs
# -------------------------------------------------------------------------------------------------------------------------------
class SafeDict(dict):
    """
    A custom dictionary that returns the placeholder string unchanged if a key is missing.
    This prevents KeyError exceptions during str.format_map() execution.
    """
    def __missing__(self, key: str) -> str:
        return f"{{{key}}}"

def _serialize_and_inject_inputs(
    condition: str,
    prompt_template: str,
    scenario_text: str,
    evidence_spans: Optional[List[Dict[str, Any]]],
    pre_paths: Optional[List[str]],
    model_spec: Optional[str],
    exec_request: Optional[Dict[str, Any]],
    model_run: Optional[Dict[str, Any]],
    model_outputs: Optional[Dict[str, Any]],
    post_paths: Optional[List[str]]
) -> str:
    """
    Serializes heterogeneous inputs and injects them into the prompt template.

    This function enforces strict epistemic separation by only serializing and
    injecting the inputs permitted for the specified experimental condition. It
    uses Python's native str.format_map() with a SafeDict to perform a single-pass
    substitution, preventing recursive replacement bugs that corrupt the prompt.

    Parameters
    ----------
    condition : str
        The experimental condition ("llm_only", "rag_only", "model_grounded_graphrag").
    prompt_template : str
        The raw prompt template string for the specific condition.
    scenario_text : str
        The raw narrative text of the economic scenario.
    evidence_spans : Optional[List[Dict[str, Any]]]
        The retrieved evidence spans (required for rag_only and model_grounded).
    pre_paths : Optional[List[str]]
        The pre-run graph paths (required for model_grounded).
    model_spec : Optional[str]
        The selected model specification ID (required for model_grounded).
    exec_request : Optional[Dict[str, Any]]
        The structured execution request (required for model_grounded).
    model_run : Optional[Dict[str, Any]]
        The model run metadata (required for model_grounded).
    model_outputs : Optional[Dict[str, Any]]
        The computed model outputs (required for model_grounded).
    post_paths : Optional[List[str]]
        The post-run graph paths (required for model_grounded).

    Returns
    -------
    str
        The fully assembled prompt string ready for LLM ingestion.

    Raises
    ------
    ValueError
        If a required input for a specific condition is missing (None).
    """
    # Log the initiation of the serialization and injection process
    logger.debug(f"Serializing inputs for condition: {condition}")

    # Initialize the substitution dictionary with the universally required scenario
    substitution_dict: Dict[str, str] = {
        "scenario": scenario_text
    }

    # --- RAG-only and Model-grounded specific serialization ---
    if condition in ["rag_only", "model_grounded_graphrag"]:
        if evidence_spans is None:
            raise ValueError(f"evidence_spans cannot be None for condition '{condition}'.")

        # Serialize evidence spans into a readable multi-line string
        # Format: EV_ID (Conf: X.XXX): Text
        evidence_lines = []
        for span in evidence_spans:
            ev_id = span.get("evidence_id", "UNKNOWN")
            conf = span.get("synthetic_confidence", 0.0)
            text = span.get("span_text", "")
            evidence_lines.append(f"{ev_id} (Conf: {conf:.3f}): {text}")

        substitution_dict["evidence_spans"] = "\n".join(evidence_lines)

    # --- Model-grounded specific serialization ---
    if condition == "model_grounded_graphrag":
        # Validate presence of all required model-grounded inputs
        if any(v is None for v in [pre_paths, model_spec, exec_request, model_run, model_outputs, post_paths]):
            raise ValueError(f"Missing required model-grounded inputs for condition '{condition}'.")

        # Serialize pre-run paths
        substitution_dict["pre_run_paths"] = "\n".join(pre_paths)

        # Serialize model specification
        substitution_dict["model_specification"] = str(model_spec)

        # Serialize execution request as indented JSON
        substitution_dict["execution_request"] = json.dumps(exec_request, indent=2)

        # Serialize model run metadata
        run_id = model_run.get("run_id", "UNKNOWN")
        horizon = model_run.get("horizon", "UNKNOWN")
        solver = model_run.get("solver_method", "UNKNOWN")
        substitution_dict["model_run"] = f"ModelRun ID: {run_id} | Solver: {solver} | Horizon: {horizon} steps"

        # Serialize model outputs
        # We extract the output table and convert it to a markdown string for LLM readability
        if "model_output_table" in model_outputs:
            df: pd.DataFrame = model_outputs["model_output_table"]
            # Compute a summary table (Peak, Trough, Final) to match the prompt's expected format
            summary_data = []
            for col in df.columns:
                summary_data.append({
                    "Variable": col,
                    "Peak": f"{df[col].max():.3f}",
                    "Trough": f"{df[col].min():.3f}",
                    "Final": f"{df[col].iloc[-1]:.3f}"
                })
            summary_df = pd.DataFrame(summary_data)
            substitution_dict["model_output_table"] = summary_df.to_markdown(index=False)
        else:
            substitution_dict["model_output_table"] = "No output table available."

        # Serialize post-run paths
        substitution_dict["post_run_paths"] = "\n".join(post_paths)

    # --- Safe Single-Pass String Substitution ---
    # We use str.format_map() with a SafeDict to perform a single-pass substitution.
    # This prevents recursive replacement bugs where an injected string contains a substring
    # that matches a later placeholder key.
    safe_dict = SafeDict(substitution_dict)
    assembled_prompt: str = prompt_template.format_map(safe_dict)

    return assembled_prompt

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Step 3: Execute the LLM call and return the plain-text report
# -------------------------------------------------------------------------------------------------------------------------------
def _execute_report_generation(assembled_prompt: str, llm_client: Any) -> str:
    """
    Executes the LLM call to generate the plain-text economic report.

    This function wraps the assembled prompt in a user message and invokes the
    deterministic LLM client. It returns the raw string verbatim, preserving the
    narrative structure and any explicit epistemic partitioning.

    Parameters
    ----------
    assembled_prompt : str
        The fully serialized and injected prompt string.
    llm_client : Any
        The configured LLM client instance.

    Returns
    -------
    str
        The generated plain-text economic report.

    Raises
    ------
    RuntimeError
        If the LLM client execution fails.
    """
    logger.info("Invoking LLM client for report generation.")

    # Construct the role-tagged message list
    # For report generation, the entire prompt (including instructions) is passed as a user message
    # to ensure the model focuses heavily on the provided context.
    messages: List[Dict[str, str]] = [
        {"role": "user", "content": assembled_prompt}
    ]

    try:
        # Execute the LLM call using the client's complete method
        raw_response: str = llm_client.complete(messages)
        return raw_response
    except Exception as e:
        error_msg = f"LLM client execution failed during report generation: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def generate_report(
    condition: str,
    scenario_text: str,
    evidence_spans: Optional[List[Dict[str, Any]]],
    pre_paths: Optional[List[str]],
    model_spec: Optional[str],
    exec_request: Optional[Dict[str, Any]],
    model_run: Optional[Dict[str, Any]],
    model_outputs: Optional[Dict[str, Any]],
    post_paths: Optional[List[str]],
    llm_client: Any,
    study_config: Dict[str, Any]
) -> str:
    """
    Orchestrates the generation of an economic report under a specific experimental condition.

    This function acts as the entry point for Task 23 (Step 10 of the AI Economist Agent
    Execution Workflow). It validates the condition string, retrieves the correct prompt
    template, serializes the permitted inputs, and invokes the LLM to produce the narrative.

    Parameters
    ----------
    condition : str
        The experimental condition ("llm_only", "rag_only", "model_grounded_graphrag").
    scenario_text : str
        The raw narrative text of the economic scenario.
    evidence_spans : Optional[List[Dict[str, Any]]]
        The retrieved evidence spans.
    pre_paths : Optional[List[str]]
        The pre-run graph paths.
    model_spec : Optional[str]
        The selected model specification ID.
    exec_request : Optional[Dict[str, Any]]
        The structured execution request.
    model_run : Optional[Dict[str, Any]]
        The model run metadata.
    model_outputs : Optional[Dict[str, Any]]
        The computed model outputs.
    post_paths : Optional[List[str]]
        The post-run graph paths.
    llm_client : Any
        The configured LLM client instance.
    study_config : Dict[str, Any]
        The master study configuration dictionary.

    Returns
    -------
    str
        The generated plain-text economic report.

    Raises
    ------
    ValueError
        If the condition string is invalid or required inputs are missing.
    KeyError
        If the required prompt template is missing from the configuration.
    RuntimeError
        If the LLM execution fails.
    """
    logger.info(f"=== Task 23: Initiating Report Generation for condition '{condition}' ===")

    # Validate the condition string
    valid_conditions: Set[str] = {"llm_only", "rag_only", "model_grounded_graphrag"}
    if condition not in valid_conditions:
        error_msg = f"Invalid condition '{condition}'. Must be one of {valid_conditions}."
        logger.error(error_msg)
        raise ValueError(error_msg)

    # Map the condition to the correct prompt template key
    template_key_map: Dict[str, str] = {
        "llm_only": "report_gen_llm_only_prompt",
        "rag_only": "report_gen_rag_only_prompt",
        "model_grounded_graphrag": "report_gen_model_grounded_prompt"
    }
    template_key: str = template_key_map[condition]

    # Retrieve the prompt template
    try:
        prompt_template: str = study_config["prompt_templates"][template_key]
    except KeyError as e:
        error_msg = f"CRITICAL: Missing prompt template '{template_key}' in configuration: {e}"
        logger.error(error_msg)
        raise KeyError(error_msg) from e

    try:
        # Execute Step 2: Serialize and inject inputs
        assembled_prompt: str = _serialize_and_inject_inputs(
            condition=condition,
            prompt_template=prompt_template,
            scenario_text=scenario_text,
            evidence_spans=evidence_spans,
            pre_paths=pre_paths,
            model_spec=model_spec,
            exec_request=exec_request,
            model_run=model_run,
            model_outputs=model_outputs,
            post_paths=post_paths
        )

        # Execute Step 3: Execute the LLM call
        generated_report: str = _execute_report_generation(
            assembled_prompt=assembled_prompt,
            llm_client=llm_client
        )

        logger.info(f"=== Task 23: Report Generation completed successfully for '{condition}' ===")
        return generated_report

    except Exception as e:
        # Catch any errors, log a critical failure, and raise a RuntimeError
        error_msg = f"=== Task 23: Report Generation FAILED for '{condition}' ===\nDetails: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# %%
# Task 24 — Implement Judge Agent callable (rubric scoring)

# ==============================================================================
# Task 24: Implement Judge Agent callable (rubric scoring)
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 24, Step 2: Construct the Judge Agent prompt with ground-truth inputs
# -------------------------------------------------------------------------------------------------------------------------------
def _construct_and_execute_judge_prompt(
    condition_information_set: Dict[str, Any],
    generated_report: str,
    llm_client: Any,
    study_config: Dict[str, Any]
) -> str:
    """
    Constructs the role-tagged message list and executes the LLM call for the Judge Agent.

    This function retrieves the monolithic judge prompt template, decomposes it
    into system and user components, safely serializes the complex information set
    dictionary into a readable JSON string, injects the inputs, and invokes the
    deterministic LLM client.

    Parameters
    ----------
    condition_information_set : Dict[str, Any]
        The exact inputs provided to the Report Generator for the specific condition.
    generated_report : str
        The plain-text economic report to be evaluated.
    llm_client : Any
        The configured LLM client instance (satisfying the complete() protocol).
    study_config : Dict[str, Any]
        The master study configuration dictionary containing the prompt templates.

    Returns
    -------
    str
        The raw, unparsed string response generated by the LLM.

    Raises
    ------
    KeyError
        If the judge prompt template is missing from the configuration.
    ValueError
        If the prompt template cannot be successfully parsed into its constituent sections.
    RuntimeError
        If the LLM client execution fails.
    """
    logger.info("Constructing role-tagged messages for the Judge Agent.")

    # Retrieve the monolithic prompt template from the configuration dictionary
    try:
        raw_template: str = study_config["prompt_templates"]["judge_agent_prompt"]
    except KeyError as e:
        raise KeyError(f"CRITICAL: Missing judge prompt template in configuration: {e}") from e

    # Define a helper function to extract sections based on their markdown headers
    def extract_section(header: str, text: str) -> str:
        pattern = rf"### {header}\n(.*?)(?=\n### |$)"
        match = re.search(pattern, text, re.DOTALL)
        if match:
            return match.group(1).strip()
        else:
            raise ValueError(f"Failed to extract required section '### {header}' from the judge prompt template.")

    # Extract the sections designated for the system role
    job_description: str = extract_section("Job Description", raw_template)
    skills: str = extract_section("Skills", raw_template)
    output_contract: str = extract_section("Output Contract", raw_template)

    # Extract the sections designated for the user role
    python_scripts: str = extract_section("Python Scripts", raw_template)
    task_section: str = extract_section("Task", raw_template)

    # Helper function to safely serialize complex objects (like DataFrames) within the info set
    def _safe_serialize(obj: Any) -> Any:
        if isinstance(obj, pd.DataFrame):
            # Convert DataFrame to a dictionary of records for clean JSON serialization
            return obj.to_dict(orient="records")
        elif isinstance(obj, dict):
            return {k: _safe_serialize(v) for k, v in obj.items()}
        elif isinstance(obj, list):
            return [_safe_serialize(v) for v in obj]
        else:
            return obj

    # Serialize the information set into a highly readable JSON string
    safe_info_set = _safe_serialize(condition_information_set)
    info_set_str: str = json.dumps(safe_info_set, indent=2)

    # Safely inject the serialized info set and the generated report into the Python Scripts section
    injected_python_scripts: str = python_scripts.replace("{condition_information_set}", info_set_str)
    injected_python_scripts = injected_python_scripts.replace("{generated_report}", generated_report)

    # Assemble the system message content
    system_content: str = (
        f"### Job Description\n{job_description}\n\n"
        f"### Skills\n{skills}\n\n"
        f"### Output Contract\n{output_contract}"
    )

    # Assemble the user message content
    user_content: str = (
        f"### Python Scripts\n{injected_python_scripts}\n\n"
        f"### Task\n{task_section}"
    )

    # Construct the final role-tagged message list
    messages: List[Dict[str, str]] = [
        {"role": "system", "content": system_content},
        {"role": "user", "content": user_content}
    ]

    logger.info("Role-tagged messages assembled successfully. Invoking LLM client.")

    try:
        # Execute the LLM call using the client's complete method
        raw_response: str = llm_client.complete(messages)
        return raw_response
    except Exception as e:
        error_msg = f"LLM client execution failed for Judge Agent: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 24, Step 3: Parse and validate the rubric scores strictly
# -------------------------------------------------------------------------------------------------------------------------------
def _parse_and_validate_judge_scores(
    raw_response: str,
    condition_information_set: Dict[str, Any]
) -> Dict[str, int]:
    """
    Parses the LLM response as strict JSON and validates the rubric scores.

    This function performs bounded extraction, attempts strict JSON decoding,
    verifies the presence of the six required keys, and ensures all values are integers
    in the range [0, 5]. It structurally enforces the logic gate for model grounding
    while preserving the raw LLM output in a separate key to maintain the audit trail
    of LLM sycophancy.

    Parameters
    ----------
    raw_response : str
        The raw string output generated by the Judge Agent LLM.
    condition_information_set : Dict[str, Any]
        The exact inputs provided to the Report Generator, used to determine the condition.

    Returns
    -------
    Dict[str, int]
        The parsed and validated JSON dictionary containing the integer rubric scores.

    Raises
    ------
    ValueError
        If the response cannot be parsed as JSON, if required keys are missing, or if
        values fall outside the permitted range.
    """
    # Log the initiation of the strict JSON parsing and validation step
    logger.info("Starting strict JSON parsing and validation of the Judge Agent response.")

    # Strip leading and trailing whitespace from the raw response
    cleaned_response: str = raw_response.strip()

    # Perform bounded extraction: remove markdown JSON code fences
    cleaned_response = re.sub(r"^```(?:json)?\s*", "", cleaned_response, flags=re.IGNORECASE)
    cleaned_response = re.sub(r"\s*```$", "", cleaned_response)
    cleaned_response = cleaned_response.strip()

    try:
        # Attempt strict JSON decoding
        parsed_scores: Dict[str, Any] = json.loads(cleaned_response)
    except json.JSONDecodeError as e:
        error_msg = (
            f"Judge Agent output failed strict JSON parsing.\n"
            f"Error: {e}\n"
            f"Raw Response:\n{raw_response}"
        )
        logger.error(error_msg)
        raise ValueError(error_msg) from e

    # Define the exact set of keys required for the rubric
    required_keys: Set[str] = {
        "evidence_grounding",
        "graph_reasoning",
        "model_grounding",
        "numerical_discipline",
        "economic_coherence",
        "audit"
    }

    observed_keys: Set[str] = set(parsed_scores.keys())

    # Validate that the observed keys exactly match the required keys
    if observed_keys != required_keys:
        missing_keys: Set[str] = required_keys - observed_keys
        surplus_keys: Set[str] = observed_keys - required_keys
        error_msg = (
            f"Judge Agent JSON output violates the structural contract.\n"
            f"Missing keys: {missing_keys}\n"
            f"Surplus keys: {surplus_keys}\n"
            f"Parsed Output: {parsed_scores}"
        )
        logger.error(error_msg)
        raise ValueError(error_msg)

    validated_scores: Dict[str, int] = {}

    # Validate that all values are integers in the range [0, 5]
    for key, value in parsed_scores.items():
        try:
            # Coerce to float first to handle cases where the LLM outputs "5.0"
            float_val = float(value)
            # Ensure it is a whole number
            if not float_val.is_integer():
                raise ValueError(f"Score for '{key}' must be an integer, got {value}.")
            int_val = int(float_val)
        except (ValueError, TypeError) as e:
            error_msg = f"Invalid score type for '{key}': {e}"
            logger.error(error_msg)
            raise ValueError(error_msg) from e

        if not (0 <= int_val <= 5):
            error_msg = f"Score for '{key}' out of bounds. Must be in [0, 5], got {int_val}."
            logger.error(error_msg)
            raise ValueError(error_msg)

        validated_scores[key] = int_val

    # --- Structural Logic Gate Enforcement ---
    # The blueprint mandates that mentioning a model name without execution is insufficient.
    # If the condition is not model_grounded_graphrag, no model was executed.
    condition: str = condition_information_set.get("condition", "UNKNOWN")

    if condition != "model_grounded_graphrag":
        if validated_scores["model_grounding"] > 0:
            # Preserve the raw LLM output to maintain the audit trail of sycophancy
            validated_scores["raw_model_grounding_score"] = validated_scores["model_grounding"]

            logger.warning(
                f"Judge Sycophancy Anomaly: Awarded model_grounding score of {validated_scores['model_grounding']} "
                f"for condition '{condition}'. Structurally forcing score to 0 to maintain experimental integrity. "
                f"Raw score preserved in 'raw_model_grounding_score'."
            )
            # Enforce the logic gate
            validated_scores["model_grounding"] = 0

    logger.info("Judge Agent JSON response parsed and validated successfully.")
    return validated_scores

# -------------------------------------------------------------------------------------------------------------------------------
# Task 24, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def judge_report(
    condition_information_set: Dict[str, Any],
    generated_report: str,
    llm_client: Any,
    study_config: Dict[str, Any]
) -> Dict[str, int]:
    """
    Orchestrates the Judge Agent to evaluate a generated report against a rubric.

    This function acts as the entry point for Task 24 (Step 10 of the AI Economist Agent
    Execution Workflow). It sequentially executes the prompt construction, LLM invocation,
    and strict JSON validation, ensuring the evaluation is structurally sound and adheres
    to the experimental logic gates.

    Parameters
    ----------
    condition_information_set : Dict[str, Any]
        The exact inputs provided to the Report Generator for the specific condition.
    generated_report : str
        The plain-text economic report to be evaluated.
    llm_client : Any
        The configured LLM client instance.
    study_config : Dict[str, Any]
        The master study configuration dictionary.

    Returns
    -------
    Dict[str, int]
        The validated dictionary of integer rubric scores.

    Raises
    ------
    RuntimeError
        If any step of the judge execution or validation fails, halting the pipeline.
    """
    condition: str = condition_information_set.get("condition", "UNKNOWN")
    logger.info(f"=== Task 24: Initiating Judge Agent execution for condition '{condition}' ===")

    try:
        # Execute Step 2: Construct the request and invoke the LLM
        raw_llm_response: str = _construct_and_execute_judge_prompt(
            condition_information_set=condition_information_set,
            generated_report=generated_report,
            llm_client=llm_client,
            study_config=study_config
        )

        # Execute Step 3: Parse and validate the JSON response strictly
        validated_scores: Dict[str, int] = _parse_and_validate_judge_scores(
            raw_response=raw_llm_response,
            condition_information_set=condition_information_set
        )

        logger.info(f"=== Task 24: Judge Agent execution completed successfully for '{condition}' ===")
        return validated_scores

    except Exception as e:
        # Catch any errors from the sub-steps, log a critical failure, and raise a RuntimeError
        error_msg = f"=== Task 24: Judge Agent execution FAILED for '{condition}' ===\nDetails: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# %%
# Task 25 — Implement the end-to-end orchestrator callable (professional research pipeline)

# =========================================================================================
# Task 25: Implement the end-to-end orchestrator callable (professional research pipeline)
# =========================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 25, Step 1, 2, & 3: End-to-End Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def run_ai_economist_pipeline(
    application_number: int,
    dataframes_dict: Dict[str, Any],
    study_config: Dict[str, Any],
    neo4j_driver: Any,
    llm_client: Any,
    assumption_registry: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Orchestrates the end-to-end AI Economist Agent pipeline.

    This function executes the strict 11-stage sequence defined in Algorithm 1 of the
    manuscript. It enforces epistemic isolation between experimental conditions, manages
    the dynamic dispatch to computational runners, and implements fail-fast error handling.
    Crucially, it threads the assumption_registry down to the tasks that require it
    (Tasks 15, 19, 20) to ensure full regulatory traceability.

    Parameters
    ----------
    application_number : int
        The experimental application index (1 or 2).
    dataframes_dict : Dict[str, Any]
        The dictionary containing all cleansed pipeline DataFrames.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    neo4j_driver : Any
        The authenticated Neo4j driver connection pool manager.
    llm_client : Any
        The configured LLM client instance.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions.

    Returns
    -------
    Dict[str, Any]
        A comprehensive results dictionary containing all intermediate and final outputs.

    Raises
    ------
    RuntimeError
        If any critical failure occurs during the pipeline execution.
    """
    # Log the initiation of the end-to-end pipeline
    logger.info(f"=== Task 25: Initiating End-to-End Pipeline for Application {application_number} ===")

    # Initialize the comprehensive results dictionary
    results: Dict[str, Any] = {}

    try:
        # -------------------------------------------------------------------------------------------
        # Stage 1: Graph Reset
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 1: Graph Reset")
        # Calls the function implemented in Task 13
        reset_success: bool = reset_knowledge_graph(driver=neo4j_driver)
        results["graph_reset_success"] = reset_success

        # -------------------------------------------------------------------------------------------
        # Stage 2: Graph Loading
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 2: Graph Loading")
        # Calls the function implemented in Task 14
        load_audit_counts: Dict[str, int] = load_knowledge_graph(
            driver=neo4j_driver,
            application_number=application_number,
            dataframes_dict=dataframes_dict,
            study_config=study_config
        )
        results["graph_load_audit"] = load_audit_counts

        # Extract scenario text for downstream agents
        app_key = f"application_{application_number}"
        scenario_data = study_config["application_scenarios"][app_key]
        scenario_text: str = scenario_data["narrative_text"]
        scenario_id: str = scenario_data["scenario_id"]

        # -------------------------------------------------------------------------------------------
        # Stage 3: Planning
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 3: Planning")
        # Calls the function implemented in Task 17
        plan_json: Dict[str, Any] = call_planner_agent(
            scenario_text=scenario_text,
            llm_client=llm_client,
            study_config=study_config
        )
        results["plan_json"] = plan_json

        # -------------------------------------------------------------------------------------------
        # Stage 4: Text Retrieval
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 4: Text Retrieval")
        # Calls the function implemented in Task 15
        evidence_spans: List[Dict[str, Any]] = retrieve_text_evidence(
            scenario_text=scenario_text,
            raw_evidence_spans_df=dataframes_dict["raw_evidence_spans_df"],
            study_config=study_config,
            application_number=application_number
        )
        results["evidence_spans"] = evidence_spans

        # -------------------------------------------------------------------------------------------
        # Stage 5: Graph Retrieval (Pre-Execution)
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 5: Graph Retrieval (Pre-Execution)")
        # Calls the function implemented in Task 16
        pre_exec_context: Dict[str, Any] = retrieve_graph_context_pre_execution(
            driver=neo4j_driver,
            scenario_id=scenario_id,
            study_config=study_config
        )
        pre_run_paths: List[str] = pre_exec_context["pre_run_paths"]
        model_context: List[Dict[str, Any]] = pre_exec_context["model_context"]

        results["pre_run_paths"] = pre_run_paths
        results["model_context"] = model_context

        # -------------------------------------------------------------------------------------------
        # Stage 6: Model Selection
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 6: Model Selection")
        # Calls the function implemented in Task 18
        execution_request: Dict[str, Any] = call_model_selection_agent(
            scenario_text=scenario_text,
            plan_json=plan_json,
            model_context=model_context,
            llm_client=llm_client,
            study_config=study_config,
            application_number=application_number
        )
        results["execution_request"] = execution_request

        # -------------------------------------------------------------------------------------------
        # Stage 7: Model Execution (Dynamic Dispatch)
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 7: Model Execution")
        impl_family: str = execution_request.get("implementation_family", "")
        selected_spec_id: str = execution_request.get("model_specification", "")

        # Extract calibration parameters from the model context for the selected spec
        calibration_params = {}
        for spec in model_context:
            if spec["spec_id"] == selected_spec_id:
                calibration_params = json.loads(spec["calibration_params_json"])
                break

        if impl_family == "dsge_lite_runner":
            # Calls the function implemented in Task 19, threading the assumption_registry
            model_outputs: Dict[str, Any] = run_dsge_lite_model(
                calibration_params=calibration_params,
                study_config=study_config,
                assumption_registry=assumption_registry
            )
        elif impl_family == "regime_switching_runner":
            # Calls the function implemented in Task 20, threading the assumption_registry
            model_outputs: Dict[str, Any] = run_regime_switching_model(
                study_config=study_config,
                assumption_registry=assumption_registry
            )
        else:
            raise RuntimeError(f"Unknown implementation family requested: {impl_family}")

        results["model_outputs"] = model_outputs

        # -------------------------------------------------------------------------------------------
        # Stage 8: Graph Write-Back
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 8: Graph Write-Back")
        # Calls the function implemented in Task 21
        write_back_status: Dict[str, Any] = write_back_model_run(
            driver=neo4j_driver,
            scenario_id=scenario_id,
            spec_id=selected_spec_id,
            model_outputs=model_outputs,
            study_config=study_config
        )
        results["write_back_status"] = write_back_status

        # Extract the generated run_id for the next stage
        run_id: str = write_back_status["run_id"]

        # -------------------------------------------------------------------------------------------
        # Stage 9: Graph Retrieval (Post-Execution)
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 9: Graph Retrieval (Post-Execution)")
        # Calls the function implemented in Task 22
        post_run_paths: List[str] = retrieve_graph_context_post_execution(
            driver=neo4j_driver,
            scenario_id=scenario_id,
            run_id=run_id,
            study_config=study_config
        )
        results["post_run_paths"] = post_run_paths

        # -------------------------------------------------------------------------------------------
        # Stage 10: Report Generation (3 Conditions)
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 10: Report Generation")

        # Condition 1: LLM-only
        report_llm_only: str = generate_report(
            condition="llm_only",
            scenario_text=scenario_text,
            evidence_spans=None, pre_paths=None, model_spec=None, exec_request=None,
            model_run=None, model_outputs=None, post_paths=None,
            llm_client=llm_client, study_config=study_config
        )
        results["report_llm_only"] = report_llm_only

        # Condition 2: RAG-only
        report_rag_only: str = generate_report(
            condition="rag_only",
            scenario_text=scenario_text,
            evidence_spans=evidence_spans,
            pre_paths=None, model_spec=None, exec_request=None,
            model_run=None, model_outputs=None, post_paths=None,
            llm_client=llm_client, study_config=study_config
        )
        results["report_rag_only"] = report_rag_only

        # Condition 3: Model-grounded GraphRAG
        # Construct the model_run metadata dictionary expected by the generator
        model_run_metadata = {
            "run_id": run_id,
            "horizon": study_config.get("computational_solver_parameters", {}).get("model_horizon_steps", 12),
            "solver_method": "Blanchard-Kahn" if "DSGE" in selected_spec_id else "Hamilton filter"
        }

        report_model_grounded: str = generate_report(
            condition="model_grounded_graphrag",
            scenario_text=scenario_text,
            evidence_spans=evidence_spans,
            pre_paths=pre_run_paths,
            model_spec=selected_spec_id,
            exec_request=execution_request,
            model_run=model_run_metadata,
            model_outputs=model_outputs,
            post_paths=post_run_paths,
            llm_client=llm_client, study_config=study_config
        )
        results["report_model_grounded"] = report_model_grounded

        # -------------------------------------------------------------------------------------------
        # Stage 11: Judging (3 Reports)
        # -------------------------------------------------------------------------------------------
        logger.info("Stage 11: Judging")

        # Construct exact information sets mirroring the generator inputs
        info_set_llm_only = {
            "condition": "llm_only",
            "scenario": scenario_text
        }
        scores_llm_only: Dict[str, int] = judge_report(
            condition_information_set=info_set_llm_only,
            generated_report=report_llm_only,
            llm_client=llm_client, study_config=study_config
        )
        results["scores_llm_only"] = scores_llm_only

        info_set_rag_only = {
            "condition": "rag_only",
            "scenario": scenario_text,
            "evidence_spans": evidence_spans
        }
        scores_rag_only: Dict[str, int] = judge_report(
            condition_information_set=info_set_rag_only,
            generated_report=report_rag_only,
            llm_client=llm_client, study_config=study_config
        )
        results["scores_rag_only"] = scores_rag_only

        info_set_model_grounded = {
            "condition": "model_grounded_graphrag",
            "scenario": scenario_text,
            "evidence_spans": evidence_spans,
            "pre_run_paths": pre_run_paths,
            "model_specification": selected_spec_id,
            "execution_request": execution_request,
            "model_run": model_run_metadata,
            "model_outputs": model_outputs,
            "post_run_paths": post_run_paths
        }
        scores_model_grounded: Dict[str, int] = judge_report(
            condition_information_set=info_set_model_grounded,
            generated_report=report_model_grounded,
            llm_client=llm_client, study_config=study_config
        )
        results["scores_model_grounded"] = scores_model_grounded

        logger.info(f"=== Task 25: End-to-End Pipeline completed successfully for Application {application_number} ===")
        return results

    except Exception as e:
        # Catch any critical failure, log it, and halt the pipeline
        error_msg = f"=== Task 25: End-to-End Pipeline FAILED for Application {application_number} ===\nDetails: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# %%
# Task 26 — Execute Application 1 and validate all intermediate checkpoints

# ==============================================================================
# Task 26: Execute Application 1 and validate all intermediate checkpoints
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Step 1: Run the orchestrator for Application 1
# -------------------------------------------------------------------------------------------------------------------------------
def _execute_application_1(
    dataframes_dict: Dict[str, Any],
    study_config: Dict[str, Any],
    neo4j_driver: Any,
    llm_client: Any,
    assumption_registry: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Executes the end-to-end pipeline for Application 1 (U.S. Inflation Persistence).

    This function invokes the master orchestrator (Task 25) with application_number=1.
    It captures the comprehensive results dictionary, which contains all intermediate
    and final artifacts required for downstream validation. It explicitly threads the
    assumption_registry to ensure methodological choices are logged.

    Parameters
    ----------
    dataframes_dict : Dict[str, Any]
        The dictionary containing all cleansed pipeline DataFrames.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    neo4j_driver : Any
        The authenticated Neo4j driver connection pool manager.
    llm_client : Any
        The configured LLM client instance.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions.

    Returns
    -------
    Dict[str, Any]
        The comprehensive results dictionary from the pipeline execution.

    Raises
    ------
    RuntimeError
        If the pipeline execution fails critically.
    """
    # Log the initiation of the end-to-end pipeline execution for Application 1
    logger.info("Executing end-to-end pipeline for Application 1.")

    try:
        # Invoke the master orchestrator (implemented in Task 25)
        # Pass the assumption_registry to ensure downstream runners can log their proxies
        results: Dict[str, Any] = run_ai_economist_pipeline(
            application_number=1,
            dataframes_dict=dataframes_dict,
            study_config=study_config,
            neo4j_driver=neo4j_driver,
            llm_client=llm_client,
            assumption_registry=assumption_registry
        )
        # Log the successful completion of the pipeline execution
        logger.info("Application 1 pipeline execution completed successfully.")
        # Return the comprehensive results dictionary
        return results
    except Exception as e:
        # Construct a detailed error message if the pipeline fails
        error_msg = f"Application 1 pipeline execution failed: {e}"
        # Log the error message at the error level
        logger.error(error_msg)
        # Raise a RuntimeError to halt the validation process
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Step 2: Validate that evidence retrieval matches the expected output
# -------------------------------------------------------------------------------------------------------------------------------
def _validate_app1_evidence_retrieval(
    results: Dict[str, Any],
    study_config: Dict[str, Any]
) -> None:
    """
    Validates the retrieved evidence IDs against the expected outputs for Application 1.

    This function extracts the retrieved evidence spans from the results dictionary,
    projects them to a list of string identifiers, and compares them (order and content)
    against the expected list defined in the configuration. Divergences are logged as
    non-fatal warnings.

    Parameters
    ----------
    results : Dict[str, Any]
        The comprehensive results dictionary from the pipeline execution.
    study_config : Dict[str, Any]
        The master study configuration dictionary containing the target outputs.
    """
    logger.info("Validating evidence retrieval outputs for Application 1.")

    # Extract the retrieved evidence spans
    evidence_spans: List[Dict[str, Any]] = results.get("evidence_spans", [])

    # Project the list of dictionaries to a flat list of string identifiers
    retrieved_ids: List[str] = [span.get("evidence_id", "UNKNOWN") for span in evidence_spans]

    # Resolve the expected IDs from the configuration
    try:
        expected_ids: List[str] = study_config["target_retrieval_outputs"]["application_1_top6_evidence_ids"]
    except KeyError as e:
        logger.warning(f"Expected retrieval outputs for Application 1 not found in config: {e}. Skipping validation.")
        return

    # Compare the lists (order and content)
    if retrieved_ids == expected_ids:
        logger.info("Retrieval validation successful. Retrieved IDs exactly match expected outputs.")
    else:
        # Log a detailed, non-fatal warning documenting the divergence
        logger.warning(
            f"Retrieval ranking divergence detected for Application 1.\n"
            f"  Expected IDs:  {expected_ids}\n"
            f"  Retrieved IDs: {retrieved_ids}\n"
            f"This divergence is an acknowledged limitation resulting from the 50/50 weighting "
            f"and scenario tag inference assumptions."
        )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Step 3: Validate model selection and judge-score invariants
# -------------------------------------------------------------------------------------------------------------------------------
def _validate_app1_methodological_invariants(results: Dict[str, Any]) -> None:
    """
    Validates the strict methodological invariants for Application 1.

    This function asserts that the correct model specification was selected and that
    the judge scores adhere to the epistemic logic gates (i.e., model grounding requires
    an executed model). Failures here invalidate the core thesis of the paper and
    raise a fatal exception.

    Parameters
    ----------
    results : Dict[str, Any]
        The comprehensive results dictionary from the pipeline execution.

    Raises
    ------
    RuntimeError
        If any methodological invariant is violated.
    """
    logger.info("Validating strict methodological invariants for Application 1.")

    invariants_failed: List[str] = []

    # 1. Validate Model Selection
    exec_request: Dict[str, Any] = results.get("execution_request", {})
    selected_spec: str = exec_request.get("model_specification", "UNKNOWN")
    expected_spec: str = "MSPEC_DSGE_LITE_004"

    if selected_spec != expected_spec:
        invariants_failed.append(f"Model Selection: Expected '{expected_spec}', got '{selected_spec}'")

    # 2. Validate LLM-only Judge Scores
    scores_llm_only: Dict[str, int] = results.get("scores_llm_only", {})
    llm_only_model_score: int = scores_llm_only.get("model_grounding", -1)

    if llm_only_model_score != 0:
        invariants_failed.append(f"LLM-only Model Grounding: Expected 0, got {llm_only_model_score}")

    # 3. Validate RAG-only Judge Scores
    scores_rag_only: Dict[str, int] = results.get("scores_rag_only", {})
    rag_only_model_score: int = scores_rag_only.get("model_grounding", -1)

    if rag_only_model_score != 0:
        invariants_failed.append(f"RAG-only Model Grounding: Expected 0, got {rag_only_model_score}")

    # 4. Validate Model-grounded GraphRAG Judge Scores
    scores_model_grounded: Dict[str, int] = results.get("scores_model_grounded", {})
    model_grounded_model_score: int = scores_model_grounded.get("model_grounding", -1)

    if model_grounded_model_score != 5:
        invariants_failed.append(f"Model-grounded Model Grounding: Expected 5, got {model_grounded_model_score}")

    # Evaluate the invariant checks
    if invariants_failed:
        error_msg = "Methodological Reproduction Failure in Application 1:\n" + "\n".join(invariants_failed)
        logger.error(error_msg)
        raise RuntimeError(error_msg)
    else:
        logger.info("All methodological invariants for Application 1 validated successfully.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def execute_and_validate_application_1(
    dataframes_dict: Dict[str, Any],
    study_config: Dict[str, Any],
    neo4j_driver: Any,
    llm_client: Any,
    assumption_registry: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Orchestrates the execution and validation of Application 1.

    This function acts as the entry point for Task 26. It runs the end-to-end pipeline
    for the U.S. Inflation Persistence scenario, validates the evidence retrieval,
    and asserts the strict methodological invariants required to reproduce the study's
    core claims. It threads the assumption_registry down to the execution layer.

    Parameters
    ----------
    dataframes_dict : Dict[str, Any]
        The dictionary containing all cleansed pipeline DataFrames.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    neo4j_driver : Any
        The authenticated Neo4j driver connection pool manager.
    llm_client : Any
        The configured LLM client instance.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions.

    Returns
    -------
    Dict[str, Any]
        The comprehensive results dictionary from the pipeline execution.

    Raises
    ------
    RuntimeError
        If the execution fails or any methodological invariant is violated.
    """
    # Log the initiation of the execution and validation orchestrator for Application 1
    logger.info("=== Task 26: Initiating Execution and Validation of Application 1 ===")

    try:
        # Execute Step 1: Run the orchestrator for Application 1
        # Pass the assumption_registry down to maintain the chain of custody
        results: Dict[str, Any] = _execute_application_1(
            dataframes_dict=dataframes_dict,
            study_config=study_config,
            neo4j_driver=neo4j_driver,
            llm_client=llm_client,
            assumption_registry=assumption_registry
        )

        # Execute Step 2: Validate evidence retrieval
        # Note: _validate_app1_evidence_retrieval is assumed to be in namespace
        _validate_app1_evidence_retrieval(
            results=results,
            study_config=study_config
        )

        # Execute Step 3: Validate model selection and judge-score invariants
        # Note: _validate_app1_methodological_invariants is assumed to be in namespace
        _validate_app1_methodological_invariants(
            results=results
        )

        # Log the successful completion of the execution and validation process
        logger.info("=== Task 26: Application 1 Execution and Validation completed successfully ===")
        # Return the validated results dictionary
        return results

    except Exception as e:
        # Catch any errors, construct a critical failure message, and log it
        error_msg = f"=== Task 26: Application 1 Execution and Validation FAILED ===\nDetails: {e}"
        # Log the error message at the error level
        logger.error(error_msg)
        # Raise a RuntimeError to halt the master pipeline
        raise RuntimeError(error_msg) from e

# %%
# Task 27 — Execute Application 2 and validate all intermediate checkpoints

# ==============================================================================
# Task 27: Execute Application 2 and validate all intermediate checkpoints
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Step 1: Run the orchestrator for Application 2
# -------------------------------------------------------------------------------------------------------------------------------
def _execute_application_2(
    dataframes_dict: Dict[str, Any],
    study_config: Dict[str, Any],
    neo4j_driver: Any,
    llm_client: Any,
    assumption_registry: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Executes the end-to-end pipeline for Application 2 (U.S. CRE Refinancing Stress).

    This function invokes the master orchestrator (Task 25) with application_number=2.
    It captures the comprehensive results dictionary, which contains all intermediate
    and final artifacts required for downstream validation. It explicitly threads the
    assumption_registry to ensure methodological choices are logged.

    Parameters
    ----------
    dataframes_dict : Dict[str, Any]
        The dictionary containing all cleansed pipeline DataFrames.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    neo4j_driver : Any
        The authenticated Neo4j driver connection pool manager.
    llm_client : Any
        The configured LLM client instance.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions.

    Returns
    -------
    Dict[str, Any]
        The comprehensive results dictionary from the pipeline execution.

    Raises
    ------
    RuntimeError
        If the pipeline execution fails critically.
    """
    # Log the initiation of the end-to-end pipeline execution for Application 2
    logger.info("Executing end-to-end pipeline for Application 2.")

    try:
        # Invoke the master orchestrator (implemented in Task 25)
        # Pass the assumption_registry to ensure downstream runners can log their proxies
        results: Dict[str, Any] = run_ai_economist_pipeline(
            application_number=2,
            dataframes_dict=dataframes_dict,
            study_config=study_config,
            neo4j_driver=neo4j_driver,
            llm_client=llm_client,
            assumption_registry=assumption_registry
        )
        # Log the successful completion of the pipeline execution
        logger.info("Application 2 pipeline execution completed successfully.")
        # Return the comprehensive results dictionary
        return results
    except Exception as e:
        # Construct a detailed error message if the pipeline fails
        error_msg = f"Application 2 pipeline execution failed: {e}"
        # Log the error message at the error level
        logger.error(error_msg)
        # Raise a RuntimeError to halt the validation process
        raise RuntimeError(error_msg) from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Step 2: Validate that evidence retrieval matches the expected output
# -------------------------------------------------------------------------------------------------------------------------------
def _validate_app2_evidence_retrieval(
    results: Dict[str, Any],
    study_config: Dict[str, Any]
) -> None:
    """
    Validates the retrieved evidence IDs against the expected outputs for Application 2.

    This function extracts the retrieved evidence spans from the results dictionary,
    projects them to a list of string identifiers, and compares them (order and content)
    against the expected list defined in the configuration. Divergences are logged as
    non-fatal warnings, explicitly noting the data caveat regarding the surplus identifier.

    Parameters
    ----------
    results : Dict[str, Any]
        The comprehensive results dictionary from the pipeline execution.
    study_config : Dict[str, Any]
        The master study configuration dictionary containing the target outputs.
    """
    logger.info("Validating evidence retrieval outputs for Application 2.")

    # Extract the retrieved evidence spans
    evidence_spans: List[Dict[str, Any]] = results.get("evidence_spans", [])

    # Project the list of dictionaries to a flat list of string identifiers
    retrieved_ids: List[str] = [span.get("evidence_id", "UNKNOWN") for span in evidence_spans]

    # Resolve the expected IDs from the configuration
    try:
        expected_ids: List[str] = study_config["target_retrieval_outputs"]["application_2_top6_evidence_ids"]
    except KeyError as e:
        logger.warning(f"Expected retrieval outputs for Application 2 not found in config: {e}. Skipping validation.")
        return

    # Compare the lists (order and content)
    if retrieved_ids == expected_ids:
        logger.info("Retrieval validation successful. Retrieved IDs exactly match expected outputs.")
    else:
        # Log a detailed, non-fatal warning documenting the divergence and the specific data caveat
        logger.warning(
            f"Retrieval ranking divergence detected for Application 2.\n"
            f"  Expected IDs:  {expected_ids}\n"
            f"  Retrieved IDs: {retrieved_ids}\n"
            f"Note: The expected list contains one identifier absent from the manuscript's evidence table. "
            f"This divergence is an acknowledged limitation resulting from the 50/50 weighting, "
            f"scenario tag inference assumptions, and the synthetic test addition."
        )

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Step 3: Validate model selection, bank-metric creation, and judge-score invariants
# -------------------------------------------------------------------------------------------------------------------------------
def _validate_app2_methodological_invariants(
    results: Dict[str, Any],
    driver: Driver
) -> None:
    """
    Validates the strict methodological invariants for Application 2.

    This function asserts that the correct model specification was selected, that
    the judge scores adhere to the epistemic logic gates, and executes a graph query
    to verify that BankMetric nodes were successfully created and linked to the ModelRun.
    Failures here invalidate the core thesis of the paper and raise a fatal exception.

    Parameters
    ----------
    results : Dict[str, Any]
        The comprehensive results dictionary from the pipeline execution.
    driver : neo4j.Driver
        The authenticated Neo4j driver connection pool manager.

    Raises
    ------
    RuntimeError
        If any methodological invariant is violated or the graph query fails.
    """
    logger.info("Validating strict methodological invariants for Application 2.")

    invariants_failed: List[str] = []

    # 1. Validate Model Selection
    exec_request: Dict[str, Any] = results.get("execution_request", {})
    selected_spec: str = exec_request.get("model_specification", "UNKNOWN")
    expected_spec: str = "MSPEC_REGIME_SWITCHING_005"

    if selected_spec != expected_spec:
        invariants_failed.append(f"Model Selection: Expected '{expected_spec}', got '{selected_spec}'")

    # 2. Validate BankMetric Creation in the Graph
    write_back_status: Dict[str, Any] = results.get("write_back_status", {})
    run_id: str = write_back_status.get("run_id", "UNKNOWN")

    if run_id == "UNKNOWN":
        invariants_failed.append("Graph Validation: run_id is missing from write_back_status.")
    else:
        # Define the Cypher query to count BankMetric nodes linked to this specific run
        metric_query: str = """
        MATCH (mr:ModelRun {run_id: $run_id})-[:COMPUTED]->(bm:BankMetric)
        RETURN count(bm) AS metric_count;
        """

        def _count_metrics(tx: Transaction) -> int:
            result = tx.run(metric_query, run_id=run_id)
            record = result.single()
            return record["metric_count"] if record else 0

        try:
            with driver.session() as session:
                metric_count: int = session.execute_read(_count_metrics)

            if metric_count == 0:
                invariants_failed.append(f"Graph Validation: No BankMetric nodes found linked to ModelRun '{run_id}'.")
            else:
                logger.debug(f"Graph Validation: Found {metric_count} BankMetric nodes linked to ModelRun '{run_id}'.")
        except neo4j.exceptions.Neo4jError as e:
            invariants_failed.append(f"Graph Validation: Cypher query failed. Details: {e}")

    # 3. Validate LLM-only Judge Scores
    scores_llm_only: Dict[str, int] = results.get("scores_llm_only", {})
    llm_only_model_score: int = scores_llm_only.get("model_grounding", -1)

    if llm_only_model_score != 0:
        invariants_failed.append(f"LLM-only Model Grounding: Expected 0, got {llm_only_model_score}")

    # 4. Validate RAG-only Judge Scores
    scores_rag_only: Dict[str, int] = results.get("scores_rag_only", {})
    rag_only_model_score: int = scores_rag_only.get("model_grounding", -1)

    if rag_only_model_score != 0:
        invariants_failed.append(f"RAG-only Model Grounding: Expected 0, got {rag_only_model_score}")

    # 5. Validate Model-grounded GraphRAG Judge Scores
    scores_model_grounded: Dict[str, int] = results.get("scores_model_grounded", {})
    model_grounded_model_score: int = scores_model_grounded.get("model_grounding", -1)

    if model_grounded_model_score != 5:
        invariants_failed.append(f"Model-grounded Model Grounding: Expected 5, got {model_grounded_model_score}")

    # Evaluate the invariant checks
    if invariants_failed:
        error_msg = "Methodological Reproduction Failure in Application 2:\n" + "\n".join(invariants_failed)
        logger.error(error_msg)
        raise RuntimeError(error_msg)
    else:
        logger.info("All methodological invariants for Application 2 validated successfully.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def execute_and_validate_application_2(
    dataframes_dict: Dict[str, Any],
    study_config: Dict[str, Any],
    neo4j_driver: Any,
    llm_client: Any,
    assumption_registry: Dict[str, Any]
) -> Dict[str, Any]:
    """
    Orchestrates the execution and validation of Application 2.

    This function acts as the entry point for Task 27. It runs the end-to-end pipeline
    for the U.S. CRE Refinancing Stress scenario, validates the evidence retrieval,
    and asserts the strict methodological invariants (including graph state verification)
    required to reproduce the study's core claims. It threads the assumption_registry.

    Parameters
    ----------
    dataframes_dict : Dict[str, Any]
        The dictionary containing all cleansed pipeline DataFrames.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    neo4j_driver : Any
        The authenticated Neo4j driver connection pool manager.
    llm_client : Any
        The configured LLM client instance.
    assumption_registry : Dict[str, Any]
        The mutable dictionary used to track methodological assumptions.

    Returns
    -------
    Dict[str, Any]
        The comprehensive results dictionary from the pipeline execution.

    Raises
    ------
    TypeError
        If the provided driver is not a valid neo4j.Driver instance.
    RuntimeError
        If the execution fails or any methodological invariant is violated.
    """
    # Log the initiation of the execution and validation orchestrator for Application 2
    logger.info("=== Task 27: Initiating Execution and Validation of Application 2 ===")

    # Validate that the provided driver is not None (assuming duck typing for the driver object)
    if neo4j_driver is None:
        # Construct an error message for the missing driver
        error_msg = "Expected a valid Neo4j driver instance, got None."
        # Log the error message
        logger.error(error_msg)
        # Raise a TypeError to halt execution
        raise TypeError(error_msg)

    try:
        # Execute Step 1: Run the orchestrator for Application 2
        # Pass the assumption_registry down to maintain the chain of custody
        results: Dict[str, Any] = _execute_application_2(
            dataframes_dict=dataframes_dict,
            study_config=study_config,
            neo4j_driver=neo4j_driver,
            llm_client=llm_client,
            assumption_registry=assumption_registry
        )

        # Execute Step 2: Validate evidence retrieval
        # Note: _validate_app2_evidence_retrieval is assumed to be in namespace
        _validate_app2_evidence_retrieval(
            results=results,
            study_config=study_config
        )

        # Execute Step 3: Validate model selection, bank-metric creation, and judge-score invariants
        # Note: _validate_app2_methodological_invariants is assumed to be in namespace
        _validate_app2_methodological_invariants(
            results=results,
            driver=neo4j_driver
        )

        # Log the successful completion of the execution and validation process
        logger.info("=== Task 27: Application 2 Execution and Validation completed successfully ===")
        # Return the validated results dictionary
        return results

    except Exception as e:
        # Catch any errors, construct a critical failure message, and log it
        error_msg = f"=== Task 27: Application 2 Execution and Validation FAILED ===\nDetails: {e}"
        # Log the error message at the error level
        logger.error(error_msg)
        # Raise a RuntimeError to halt the master pipeline
        raise RuntimeError(error_msg) from e

# %%
# Task 28 — Archive the full provenance package for regulatory traceability

# ==============================================================================
# Task 28: Archive the full provenance package for regulatory traceability
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Step 1: Persist all inputs, intermediate outputs, and final deliverables
# -------------------------------------------------------------------------------------------------------------------------------
def _persist_pipeline_artifacts(
    archive_dir: Path,
    results: Dict[str, Any],
    study_config: Dict[str, Any],
    application_number: int
) -> None:
    """
    Serializes and writes all pipeline artifacts to the archive directory.

    This function extracts every enumerated artifact from the results dictionary
    and writes it to disk in an appropriate format (JSON, TXT, CSV). It enforces
    a consistent naming convention to maintain a logical reading order.

    Parameters
    ----------
    archive_dir : pathlib.Path
        The path to the newly created, unique archive directory.
    results : Dict[str, Any]
        The comprehensive results dictionary from the pipeline execution.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    application_number : int
        The experimental application index (1 or 2).

    Raises
    ------
    IOError
        If writing to the filesystem fails.
    """
    logger.info("Persisting pipeline artifacts to disk.")

    # Helper function for safe JSON writing
    def _write_json(filename: str, data: Any) -> None:
        file_path = archive_dir / filename
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=2, default=str) # default=str handles non-serializable types safely

    # Helper function for text writing
    def _write_text(filename: str, text: str) -> None:
        if text is None:
            text = "NULL_OR_MISSING"
        file_path = archive_dir / filename
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(str(text))

    try:
        # 1. Scenario narrative text
        app_key = f"application_{application_number}"
        scenario_text = study_config["application_scenarios"][app_key]["narrative_text"]
        _write_text("01_scenario.txt", scenario_text)

        # 2. Planner output JSON
        _write_json("02_planner_output.json", results.get("plan_json"))

        # 3. Evidence retrieval results
        _write_json("03_retrieved_evidence.json", results.get("evidence_spans"))

        # 4. Pre-run graph paths
        _write_text("04_pre_run_paths.txt", "\n".join(results.get("pre_run_paths", [])))

        # 5. Model context dictionary
        _write_json("05_model_context.json", results.get("model_context"))

        # 6. Model selection request
        _write_json("06_execution_request.json", results.get("execution_request"))

        # 7. Model run metadata
        _write_json("07_model_run_metadata.json", results.get("write_back_status"))

        # 8. Model output table
        model_outputs = results.get("model_outputs", {})
        if "model_output_table" in model_outputs:
            df: pd.DataFrame = model_outputs["model_output_table"]
            df.to_csv(archive_dir / "08_model_output_table.csv")
            _write_text("08_model_output_table.md", df.to_markdown())
        if "bank_metrics" in model_outputs:
            _write_json("08_bank_metrics.json", model_outputs["bank_metrics"])

        # 9. Post-run graph paths
        _write_text("09_post_run_paths.txt", "\n".join(results.get("post_run_paths", [])))

        # 10. Generated reports
        _write_text("10_report_llm_only.txt", results.get("report_llm_only"))
        _write_text("10_report_rag_only.txt", results.get("report_rag_only"))
        _write_text("10_report_model_grounded.txt", results.get("report_model_grounded"))

        # 11. Judge score JSONs
        _write_json("11_scores_llm_only.json", results.get("scores_llm_only"))
        _write_json("11_scores_rag_only.json", results.get("scores_rag_only"))
        _write_json("11_scores_model_grounded.json", results.get("scores_model_grounded"))

        logger.debug("All pipeline artifacts successfully written to archive.")

    except Exception as e:
        raise IOError(f"Failed to write artifacts to {archive_dir}: {e}") from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Step 2: Persist all execution settings and software versions
# -------------------------------------------------------------------------------------------------------------------------------
def _persist_runtime_environment(
    archive_dir: Path,
    study_config: Dict[str, Any],
    results: Dict[str, Any]
) -> None:
    """
    Gathers and serializes the runtime environment, library versions, and module hashes.

    This function anchors the numeric outputs to the exact code executed by computing
    a SHA-256 digest of the computational runner module. It implements a robust fallback
    mechanism using inspect.getsource() to extract and hash the active source code from
    memory when spec.origin is unavailable (e.g., in interactive or compiled environments).

    Parameters
    ----------
    archive_dir : pathlib.Path
        The path to the archive directory.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    results : Dict[str, Any]
        The results dictionary, used to identify which runner module was executed.

    Raises
    ------
    IOError
        If writing to the filesystem fails.
    """
    logger.info("Gathering runtime environment and computing module hashes.")

    env_record: Dict[str, Any] = {}

    # 1. LLM Settings and PRNG Seed
    env_record["llm_settings"] = study_config.get("llm_execution_parameters", {})
    env_record["random_seed"] = study_config.get("computational_solver_parameters", {}).get("random_seed", 42)

    # 2. Software Versions
    env_record["software_versions"] = {
        "python": sys.version,
        "platform": platform.platform(),
        "numpy": np.__version__,
        "pandas": pd.__version__,
        "scipy": __import__('scipy').__version__,
        "neo4j": __import__('neo4j').__version__ if 'neo4j' in sys.modules else "NOT_INSTALLED"
    }

    # 3. Module Hashes
    module_hashes: Dict[str, str] = {}

    # Identify the executed module from the execution request
    exec_request = results.get("execution_request", {})
    impl_family = exec_request.get("implementation_family", "UNKNOWN")

    # Map the implementation family to the expected module path
    module_path_map = {
        "dsge_lite_runner": "computational_layer.dsge_lite",
        "regime_switching_runner": "computational_layer.regime_switching"
    }

    target_module_path = module_path_map.get(impl_family)

    if target_module_path:
        try:
            # Attempt to import the module to inspect it
            import importlib
            module = importlib.import_module(target_module_path)

            # Attempt to get the source code directly from memory
            try:
                source_code = inspect.getsource(module)
                # Encode the source string to bytes and compute the SHA-256 digest
                digest = hashlib.sha256(source_code.encode('utf-8')).hexdigest()
                module_hashes[target_module_path] = digest
                logger.debug(f"Successfully hashed module {target_module_path} from memory source.")
            except (TypeError, OSError) as e:
                # Fallback: If getsource fails (e.g., built-in module or no source file), try reading the file
                logger.warning(f"inspect.getsource() failed for {target_module_path}: {e}. Falling back to file read.")
                if hasattr(module, '__file__') and module.__file__:
                    with open(module.__file__, "rb") as f:
                        file_bytes = f.read()
                        digest = hashlib.sha256(file_bytes).hexdigest()
                    module_hashes[target_module_path] = digest
                else:
                    module_hashes[target_module_path] = "SOURCE_UNAVAILABLE_FOR_HASHING"

        except ImportError as e:
            module_hashes[target_module_path] = f"IMPORT_FAILED: {e}"
        except Exception as e:
            module_hashes[target_module_path] = f"HASHING_FAILED: {e}"
    else:
        module_hashes["UNKNOWN_RUNNER"] = "NO_MODULE_PATH_MAPPED"

    env_record["module_hashes"] = module_hashes

    # Write the record to disk
    file_path = archive_dir / "runtime_environment.json"
    try:
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(env_record, f, indent=2)
        logger.debug("Runtime environment record successfully written.")
    except Exception as e:
        raise IOError(f"Failed to write runtime environment to {file_path}: {e}") from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Step 3: Persist the manuscript-unspecified assumption registry
# -------------------------------------------------------------------------------------------------------------------------------
def _persist_assumption_registry(
    archive_dir: Path,
    assumption_registry: Dict[str, Any]
) -> None:
    """
    Serializes the assumption registry to document all manuscript-unspecified choices.

    This function ensures that any methodological deviations or assumptions made
    during the pipeline execution (e.g., diagonal MS-VAR matrices, retrieval weights)
    are fully disclosed in the provenance package.

    Parameters
    ----------
    archive_dir : pathlib.Path
        The path to the archive directory.
    assumption_registry : Dict[str, Any]
        The mutable dictionary containing the accumulated assumptions.

    Raises
    ------
    IOError
        If writing to the filesystem fails.
    """
    logger.info("Persisting the assumption registry.")

    file_path = archive_dir / "implementation_assumptions.json"
    try:
        with open(file_path, 'w', encoding='utf-8') as f:
            # default=str ensures any lingering non-serializable objects don't crash the dump
            json.dump(assumption_registry, f, indent=2, default=str)
        logger.debug("Assumption registry successfully written.")
    except Exception as e:
        raise IOError(f"Failed to write assumption registry to {file_path}: {e}") from e

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def archive_provenance_package(
    application_number: int,
    results: Dict[str, Any],
    study_config: Dict[str, Any],
    assumption_registry: Dict[str, Any],
    base_archive_path: str = "./provenance_archives"
) -> str:
    """
    Orchestrates the creation of an immutable provenance archive for regulatory traceability.

    This function acts as the entry point for Task 28. It creates a unique, non-overwriting
    directory based on the application number and run ID. It then sequentially persists
    the pipeline artifacts, the runtime environment, and the assumption registry.

    Parameters
    ----------
    application_number : int
        The experimental application index (1 or 2).
    results : Dict[str, Any]
        The comprehensive results dictionary from the pipeline execution.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    assumption_registry : Dict[str, Any]
        The mutable dictionary containing the accumulated assumptions.
    base_archive_path : str, optional
        The root directory where archives should be stored, by default "./provenance_archives".

    Returns
    -------
    str
        The absolute path to the created archive directory.

    Raises
    ------
    RuntimeError
        If the directory creation fails (e.g., collision) or any serialization step fails.
    """
    logger.info(f"=== Task 28: Initiating Provenance Archival for Application {application_number} ===")

    # Extract the run_id to ensure a unique directory name
    write_back_status = results.get("write_back_status", {})
    run_id = write_back_status.get("run_id", f"UNKNOWN_RUN_{datetime.now().strftime('%Y%m%d%H%M%S')}")

    # Construct the archive directory path
    archive_dir = Path(base_archive_path) / f"APP_{application_number}_{run_id}"

    try:
        # Create the directory. exist_ok=False enforces immutability by preventing overwrites.
        os.makedirs(archive_dir, exist_ok=False)
        logger.info(f"Created immutable archive directory: {archive_dir.absolute()}")
    except FileExistsError as e:
        error_msg = f"Archive directory {archive_dir} already exists. Overwriting is prohibited for regulatory provenance."
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e
    except Exception as e:
        error_msg = f"Failed to create archive directory {archive_dir}: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

    try:
        # Execute Step 1: Persist artifacts
        _persist_pipeline_artifacts(
            archive_dir=archive_dir,
            results=results,
            study_config=study_config,
            application_number=application_number
        )

        # Execute Step 2: Persist runtime environment
        _persist_runtime_environment(
            archive_dir=archive_dir,
            study_config=study_config,
            results=results
        )

        # Execute Step 3: Persist assumption registry
        _persist_assumption_registry(
            archive_dir=archive_dir,
            assumption_registry=assumption_registry
        )

        logger.info(f"=== Task 28: Provenance Archival completed successfully. Path: {archive_dir.absolute()} ===")
        return str(archive_dir.absolute())

    except Exception as e:
        # If a failure occurs during writing, attempt to clean up the partial directory
        # to prevent corrupted archives from lingering.
        logger.error(f"=== Task 28: Provenance Archival FAILED. Attempting cleanup of {archive_dir} ===")
        try:
            shutil.rmtree(archive_dir)
            logger.info(f"Cleanup successful. Removed partial archive {archive_dir}.")
        except Exception as cleanup_e:
            logger.error(f"Cleanup failed. Partial archive {archive_dir} remains on disk. Error: {cleanup_e}")

        raise RuntimeError(f"Archival process failed: {e}") from e

# %%
# Task 29 — Generate final validation report and truthful limitation statement

# ==============================================================================
# Task 29: Generate final validation report and truthful limitation statement
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Step 1: Summarize successful reproductions
# -------------------------------------------------------------------------------------------------------------------------------
def _summarize_reproductions(
    app1_results: Dict[str, Any],
    app2_results: Dict[str, Any],
    study_config: Dict[str, Any]
) -> Tuple[str, Dict[str, bool]]:
    """
    Evaluates all intermediate checkpoints and compiles the success summary.

    This function programmatically verifies the four core methodological pillars
    across both applications, constructing a checklist of boolean outcomes.

    Parameters
    ----------
    app1_results : Dict[str, Any]
        The results dictionary from the Application 1 run.
    app2_results : Dict[str, Any]
        The results dictionary from the Application 2 run.
    study_config : Dict[str, Any]
        The master study configuration dictionary.

    Returns
    -------
    Tuple[str, Dict[str, bool]]
        - A formatted string summarizing the check outcomes.
        - A dictionary of boolean flags representing the validation checklist.
    """
    logger.info("Summarizing checkpoint outcomes across both applications.")

    checklist: Dict[str, bool] = {}

    # Helper to check if list matches expected targets
    def _is_retrieval_match(retrieved: List[Dict[str, Any]], expected: List[str]) -> bool:
        ret_ids = [span.get("evidence_id") for span in retrieved]
        return ret_ids == expected

    # 1. Application 1 Checkpoints
    app1_expected_ids = study_config["target_retrieval_outputs"]["application_1_top6_evidence_ids"]
    checklist["app1_evidence_retrieval"] = _is_retrieval_match(app1_results["evidence_spans"], app1_expected_ids)

    app1_spec = app1_results["execution_request"]["model_specification"]
    checklist["app1_model_selection"] = (app1_spec == "MSPEC_DSGE_LITE_004")

    checklist["app1_judge_logic_gates"] = (
        app1_results["scores_llm_only"]["model_grounding"] == 0 and
        app1_results["scores_rag_only"]["model_grounding"] == 0 and
        app1_results["scores_model_grounded"]["model_grounding"] == 5
    )

    checklist["app1_epistemic_traceability"] = len(app1_results["post_run_paths"]) > 0

    # 2. Application 2 Checkpoints
    app2_expected_ids = study_config["target_retrieval_outputs"]["application_2_top6_evidence_ids"]
    checklist["app2_evidence_retrieval"] = _is_retrieval_match(app2_results["evidence_spans"], app2_expected_ids)

    app2_spec = app2_results["execution_request"]["model_specification"]
    checklist["app2_model_selection"] = (app2_spec == "MSPEC_REGIME_SWITCHING_005")

    checklist["app2_judge_logic_gates"] = (
        app2_results["scores_llm_only"]["model_grounding"] == 0 and
        app2_results["scores_rag_only"]["model_grounding"] == 0 and
        app2_results["scores_model_grounded"]["model_grounding"] == 5
    )

    checklist["app2_bank_metrics_created"] = (
        app2_results["write_back_status"]["BankMetric_nodes_created"] > 0
    )

    checklist["app2_epistemic_traceability"] = len(app2_results["post_run_paths"]) > 0

    # Format the summary text block
    summary_lines = [
        "METRIC OR METHODOLOGICAL CHECKPOINT SUMMARY:",
        f"  - Application 1 Evidence Retrieval (Top-6 Match):  {'PASS' if checklist['app1_evidence_retrieval'] else 'MISMATCH (Tolerated Divergence)'}",
        f"  - Application 1 Model Selection (DSGE-lite):        {'PASS' if checklist['app1_model_selection'] else 'FAIL'}",
        f"  - Application 1 Judge Logic Gates (Model=5, Lean=0): {'PASS' if checklist['app1_judge_logic_gates'] else 'FAIL'}",
        f"  - Application 1 Epistemic Traceability Chain:        {'PASS' if checklist['app1_epistemic_traceability'] else 'FAIL'}",
        f"  - Application 2 Evidence Retrieval (Top-6 Match):  {'PASS' if checklist['app2_evidence_retrieval'] else 'MISMATCH (Tolerated Divergence)'}",
        f"  - Application 2 Model Selection (Regime-Switching): {'PASS' if checklist['app2_model_selection'] else 'FAIL'}",
        f"  - Application 2 Bank Metrics Creation in KG:       {'PASS' if checklist['app2_bank_metrics_created'] else 'FAIL'}",
        f"  - Application 2 Judge Logic Gates (Model=5, Lean=0): {'PASS' if checklist['app2_judge_logic_gates'] else 'FAIL'}",
        f"  - Application 2 Epistemic Traceability Chain:        {'PASS' if checklist['app2_epistemic_traceability'] else 'FAIL'}"
    ]

    return "\n".join(summary_lines), checklist

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Step 2: Document numeric-replication limitations under a truth condition
# -------------------------------------------------------------------------------------------------------------------------------
def _document_numerical_limitations(
    app1_results: Dict[str, Any],
    app2_results: Dict[str, Any]
) -> str:
    """
    Computes quantitative deviations and compiles the conditional limitation statements.

    This function compares the simulated peak inflation and Stress CET1 values against
    the manuscript targets, quantitatively verifying numeric agreement. If deviations
    exceed 1%, it appends the mandatory, scientifically honest limitation clauses.

    Parameters
    ----------
    app1_results : Dict[str, Any]
        The results dictionary from the Application 1 run.
    app2_results : Dict[str, Any]
        The results dictionary from the Application 2 run.

    Returns
    -------
    str
        The compiled numerical limitations statement.
    """
    logger.info("Evaluating numerical deviations and compiling limitations.")

    limitation_clauses: List[str] = ["NUMERICAL DISCLOSURES & LIMITATIONS:"]

    # 1. Application 1: Peak Inflation Deviation (Table 8 target: 0.229)
    app1_stats = app1_results["model_outputs"]["summary_statistics"]
    observed_peak_inflation: float = app1_stats["U.S. headline inflation"]["Peak"]
    expected_peak_inflation: float = 0.229

    # Compute relative deviation
    app1_deviation: float = abs(observed_peak_inflation - expected_peak_inflation) / expected_peak_inflation

    if app1_deviation > 0.01:
        limitation_clauses.append(
            f"  - Application 1 DSGE-lite deviation: Observed Peak Inflation is {observed_peak_inflation:.4f} "
            f"vs Expected {expected_peak_inflation:.4f} (Rel. Deviation: {app1_deviation:.2%}).\n"
            f"    LIMITATION STATEMENT: The paper does not provide the explicit canonical form matrices "
            f"Gamma_0, Gamma_1, Psi, Pi or the exact state vector ordering for the DSGE-lite model. "
            f"Therefore, exact numeric replication of Table 8 is not guaranteed without access to the "
            f"authors' reference implementation. The methodological findings (grounding-structure differences, "
            f"judge score patterns, graph traceability) can still be reproduced with high fidelity."
        )
    else:
        limitation_clauses.append("  - Application 1 DSGE-lite matches Table 8 target within 1% tolerance.")

    # 2. Application 2: Stress CET1 Deviation (Table 13 target: 5.984)
    app2_metrics = app2_results["model_outputs"]["bank_metrics"]
    observed_cet1: float = app2_metrics["Stress CET1"]
    expected_cet1: float = 5.984

    # Compute relative deviation
    app2_deviation: float = abs(observed_cet1 - expected_cet1) / expected_cet1

    if app2_deviation > 0.01:
        limitation_clauses.append(
            f"  - Application 2 MS-VAR deviation: Observed Stress CET1 is {observed_cet1:.4f} "
            f"vs Expected {expected_cet1:.4f} (Rel. Deviation: {app2_deviation:.2%}).\n"
            f"    LIMITATION STATEMENT: The paper does not provide the full autoregressive matrices "
            f"A_1,S_t or full covariance matrices Sigma_S_t for the regime-switching model. "
            f"Diagonal matrices were used as rational implementation assumptions. "
            f"Exact numeric replication of Tables 12 and 13 is contingent on these assumptions."
        )
    else:
        limitation_clauses.append("  - Application 2 Bank Stress Metrics match Table 13 targets within 1% tolerance.")

    return "\n\n".join(limitation_clauses)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Step 3: Issue the final reproduction claim
# -------------------------------------------------------------------------------------------------------------------------------
def _issue_final_reproduction_claim(checklist: Dict[str, bool]) -> str:
    """
    Evaluates the methodological invariants and issues the terminal reproduction claim.

    The claim is strictly gated by the conjunction of the four core pillars:
    three-condition design, graph model-grounding, judge logic gates, and epistemic
    traceability.

    Parameters
    ----------
    checklist : Dict[str, bool]
        The dictionary of boolean outcomes from Step 1.

    Returns
    -------
    str
        The final, conditional reproduction claim text.
    """
    logger.info("Evaluating methodological checklist for final reproduction claim.")

    # Define the core methodological pillars that must be met
    # Note: We omit the evidence retrieval from the strict gating because divergences there
    # are tolerated, but model selection, judge logic gates, and traceability paths are mandatory.
    required_invariants: List[bool] = [
        checklist["app1_model_selection"],
        checklist["app1_judge_logic_gates"],
        checklist["app1_epistemic_traceability"],
        checklist["app2_model_selection"],
        checklist["app2_judge_logic_gates"],
        checklist["app2_epistemic_traceability"],
        checklist["app2_bank_metrics_created"]
    ]

    # Evaluate the logical conjunction over the fixed checklist
    if all(required_invariants):
        claim_text = (
            "TERMINAL REPRODUCTION CLAIM:\n"
            "This implementation reproduces the study's core methodological findings with high fidelity: "
            "(1) the three-condition information-set design, (2) the graph-based model-grounding mechanism, "
            "(3) the judge rubric logic gates enforcing that model mentions without execution yield model_grounding = 0, "
            "and (4) the full epistemic traceability chain from Scenario through ModelRun to ModelOutputPoint. "
            "Numeric outputs are contingent on the documented implementation assumptions for under-specified model components."
        )
    else:
        # Identify failed invariants for reporting
        failures = [k for k, v in checklist.items() if not v]
        claim_text = (
            "TERMINAL REPRODUCTION CLAIM:\n"
            "This implementation encountered critical methodological failures and therefore does not "
            f"fully reproduce the study's methodological design. Failed checkpoints: {failures}. "
            "Further investigation or access to the authors' reference implementation is required."
        )

    return claim_text

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def generate_validation_report(
    app1_results: Dict[str, Any],
    app2_results: Dict[str, Any],
    study_config: Dict[str, Any],
    archive_dir_path: str
) -> str:
    """
    Orchestrates the generation and persistence of the final validation report.

    This function acts as the entry point for Task 29. It gathers checkpoint summaries,
    evaluates numerical deviations, applies conditional logic gates to issue the final
    reproduction claim, and writes the comprehensive report to the designated archive.

    Parameters
    ----------
    app1_results : Dict[str, Any]
        The results dictionary from the Application 1 run.
    app2_results : Dict[str, Any]
        The results dictionary from the Application 2 run.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    archive_dir_path : str
        The path to the active archive directory where the report should be persisted.

    Returns
    -------
    str
        The complete string text of the generated final validation report.

    Raises
    ------
    IOError
        If writing the file to the archive directory fails.
    RuntimeError
        If the evaluation or assembly process fails critically.
    """
    logger.info("=== Task 29: Initiating Final Validation Report Generation ===")

    try:
        # Execute Step 1: Summarize successful reproductions and extract checklist
        summary_text, checklist = _summarize_reproductions(
            app1_results=app1_results,
            app2_results=app2_results,
            study_config=study_config
        )

        # Execute Step 2: Document numerical deviations and limitations
        limitations_text = _document_numerical_limitations(
            app1_results=app1_results,
            app2_results=app2_results
        )

        # Execute Step 3: Issue the final reproduction claim
        claim_text = _issue_final_reproduction_claim(
            checklist=checklist
        )

        # Assemble the comprehensive validation report
        divider = "=" * 80
        report_text = (
            f"{divider}\n"
            f"AI ECONOMIST AGENT: FINAL REPRODUCTION VALIDATION REPORT\n"
            f"{divider}\n\n"
            f"{summary_text}\n\n"
            f"{divider}\n\n"
            f"{limitations_text}\n\n"
            f"{divider}\n\n"
            f"{claim_text}\n\n"
            f"{divider}\n"
        )

        # Write the report to a text file in the designated archive directory
        report_path = Path(archive_dir_path) / "reproduction_validation_report.txt"

        try:
            with open(report_path, 'w', encoding='utf-8') as f:
                f.write(report_text)
            logger.info(f"Final validation report successfully written to {report_path.absolute()}")
        except Exception as e:
            raise IOError(f"Failed to write validation report to {report_path}: {e}") from e

        logger.info("=== Task 29: Final Validation Report completed successfully ===")
        return report_text

    except Exception as e:
        # Catch any errors, log a critical failure, and raise a RuntimeError
        error_msg = f"=== Task 29: Final Validation Report FAILED ===\nDetails: {e}"
        logger.error(error_msg)
        raise RuntimeError(error_msg) from e

# %%
# Top-Level Orchestrator

# ==============================================================================
# Top-Level Orchestrator: Master AI Economist Pipeline Execution
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Master Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def execute_master_ai_economist_pipeline(
    dataframes_dict: Dict[str, Any],
    study_config: Dict[str, Any],
    neo4j_driver: Any,
    base_archive_path: str = "./provenance_archives"
) -> Dict[str, Any]:
    """
    Master orchestrator that executes the entire AI Economist Agent framework from end to end.

    This top-level callable rigorously sequences Tasks 1 through 29. It explicitly enforces
    the critical data validation, cleansing, synthesis, and infrastructure provisioning phases
    (Tasks 1-12) prior to application execution. It instantiates the global assumption registry
    and threads it down through the application executors to ensure full regulatory traceability.

    Parameters
    ----------
    dataframes_dict : Dict[str, Any]
        The dictionary containing all raw pipeline DataFrames. This dictionary will be
        mutated in-place during the cleansing and synthesis phases.
    study_config : Dict[str, Any]
        The master study configuration dictionary.
    neo4j_driver : Any
        The authenticated Neo4j driver connection pool manager.
    base_archive_path : str, optional
        The root directory where regulatory provenance archives should be stored,
        by default "./provenance_archives".

    Returns
    -------
    Dict[str, Any]
        A comprehensive master dictionary containing data preparation logs, application
        results, archive paths, and the final validation report.

    Raises
    ------
    RuntimeError
        If any critical failure occurs at any stage of the pipeline, ensuring a fail-closed
        system architecture.
    """
    logger.info("================================================================================")
    logger.info("INITIATING MASTER AI ECONOMIST PIPELINE EXECUTION")
    logger.info("================================================================================")

    # Initialize the master results dictionary to aggregate all pipeline artifacts
    master_results: Dict[str, Any] = {}

    # Initialize the global assumption registry to track all manuscript-unspecified choices
    assumption_registry: Dict[str, Any] = {}

    try:
        # ==============================================================================
        # PHASE 1: Configuration and Infrastructure Validation (Tasks 1-3, 11-12)
        # ==============================================================================
        logger.info("--- PHASE 1: Configuration and Infrastructure Validation ---")

        # Task 1: Validate the study configuration dictionary for completeness and internal consistency
        # Note: validate_study_configuration is assumed to be in namespace
        validate_study_configuration(
            study_config=study_config,
            raw_implementation_functions_df=dataframes_dict["raw_implementation_functions_df"]
        )

        # Task 2: Validate retrieval and graph search policies
        # Note: validate_retrieval_and_graph_policies is assumed to be in namespace
        validate_retrieval_and_graph_policies(
            study_config=study_config,
            assumption_registry=assumption_registry
        )

        # Task 3: Validate that all prompt templates exist and match the required structure
        # Note: validate_prompt_templates is assumed to be in namespace
        validate_prompt_templates(
            study_config=study_config
        )

        # Task 11: Provision the local deterministic LLM endpoint and validate determinism
        # Note: provision_llm_endpoint is assumed to be in namespace
        llm_client = provision_llm_endpoint(
            study_config=study_config,
            assumption_registry=assumption_registry
        )
        master_results["infrastructure_status"] = "LLM Provisioned and Verified"

        # Task 12: Provision Neo4j graph database and enforce schema constraints
        # Note: provision_neo4j_database is assumed to be in namespace
        provision_neo4j_database(
            driver=neo4j_driver
        )

        # ==============================================================================
        # PHASE 2: Data Validation, Cleansing, and Synthesis (Tasks 4-10)
        # ==============================================================================
        logger.info("--- PHASE 2: Data Validation, Cleansing, and Synthesis ---")
        data_prep_logs: Dict[str, Any] = {}

        # Task 4: Validate DataFrame schemas for column presence and dtype correctness
        # Note: validate_all_dataframe_schemas is assumed to be in namespace
        validate_all_dataframe_schemas(
            dataframes_dict=dataframes_dict
        )

        # Task 5 (Pre-Cleansing): Validate primary key/foreign key referential integrity
        # Note: validate_referential_integrity is assumed to be in namespace
        validate_referential_integrity(
            dataframes_dict=dataframes_dict,
            study_config=study_config,
            is_pre_cleansing_pass=True
        )

        # Task 6: Validate row-level invariants on all DataFrames
        # Note: validate_row_level_invariants is assumed to be in namespace
        quarantine_logs_t6 = validate_row_level_invariants(
            dataframes_dict=dataframes_dict
        )
        data_prep_logs.update(quarantine_logs_t6)

        # Task 7: Cleanse identifier and text fields deterministically
        # Note: cleanse_identifier_and_text_fields is assumed to be in namespace
        cleansing_logs_t7 = cleanse_identifier_and_text_fields(
            dataframes_dict=dataframes_dict
        )
        data_prep_logs.update(cleansing_logs_t7)

        # Task 8: Cleanse and normalize datetime columns
        # Note: cleanse_and_normalize_datetimes is assumed to be in namespace
        cleanse_and_normalize_datetimes(
            dataframes_dict=dataframes_dict,
            assumption_registry=assumption_registry
        )

        # Task 9: Validate and cleanse JSON payload fields
        # Note: validate_and_cleanse_json_payloads is assumed to be in namespace
        quarantine_logs_t9 = validate_and_cleanse_json_payloads(
            dataframes_dict=dataframes_dict
        )
        data_prep_logs.update(quarantine_logs_t9)

        # Task 5 (Post-Cleansing): Validate primary key/foreign key referential integrity
        validate_referential_integrity(
            dataframes_dict=dataframes_dict,
            study_config=study_config,
            is_pre_cleansing_pass=False
        )

        # Task 10: Verify or generate synthetic data to match manuscript scale
        # Note: verify_and_synthesize_data_scale is assumed to be in namespace
        verify_and_synthesize_data_scale(
            dataframes_dict=dataframes_dict,
            assumption_registry=assumption_registry,
            study_config=study_config
        )

        # Store all data preparation logs in the master results
        master_results["data_preparation_logs"] = data_prep_logs

        # ==============================================================================
        # PHASE 3: Application Execution and Validation (Tasks 26-27)
        # ==============================================================================
        logger.info("--- PHASE 3: Application Execution and Validation ---")

        # Task 26: Execute Application 1 and validate all intermediate checkpoints
        # Note: execute_and_validate_application_1 is assumed to be modified to accept assumption_registry
        app1_results: Dict[str, Any] = execute_and_validate_application_1(
            dataframes_dict=dataframes_dict,
            study_config=study_config,
            neo4j_driver=neo4j_driver,
            llm_client=llm_client,
            assumption_registry=assumption_registry
        )
        master_results["application_1_results"] = app1_results

        # Task 27: Execute Application 2 and validate all intermediate checkpoints
        # Note: execute_and_validate_application_2 is assumed to be modified to accept assumption_registry
        app2_results: Dict[str, Any] = execute_and_validate_application_2(
            dataframes_dict=dataframes_dict,
            study_config=study_config,
            neo4j_driver=neo4j_driver,
            llm_client=llm_client,
            assumption_registry=assumption_registry
        )
        master_results["application_2_results"] = app2_results

        # ==============================================================================
        # PHASE 4: Archival and Reporting (Tasks 28-29)
        # ==============================================================================
        logger.info("--- PHASE 4: Archival and Reporting ---")

        # Task 28: Archive the full provenance package for Application 1
        # Note: archive_provenance_package is assumed to be in namespace
        app1_archive_path: str = archive_provenance_package(
            application_number=1,
            results=app1_results,
            study_config=study_config,
            assumption_registry=assumption_registry,
            base_archive_path=base_archive_path
        )
        master_results["application_1_archive_path"] = app1_archive_path

        # Task 28: Archive the full provenance package for Application 2
        app2_archive_path: str = archive_provenance_package(
            application_number=2,
            results=app2_results,
            study_config=study_config,
            assumption_registry=assumption_registry,
            base_archive_path=base_archive_path
        )
        master_results["application_2_archive_path"] = app2_archive_path

        # Task 29: Generate final validation report and truthful limitation statement
        # Note: generate_validation_report is assumed to be in namespace
        final_report: str = generate_validation_report(
            app1_results=app1_results,
            app2_results=app2_results,
            study_config=study_config,
            archive_dir_path=app2_archive_path
        )
        master_results["final_validation_report"] = final_report

        logger.info("================================================================================")
        logger.info("MASTER AI ECONOMIST PIPELINE EXECUTION COMPLETED SUCCESSFULLY")
        logger.info("================================================================================")

        return master_results

    except Exception as e:
        # Catch any critical failure from any phase, log it at the highest level, and halt
        error_msg = f"MASTER PIPELINE EXECUTION FAILED: {e}"
        logger.critical(error_msg, exc_info=True)
        raise RuntimeError(error_msg) from e
